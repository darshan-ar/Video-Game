# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np


Batch_Size = 250
num_epochs = 200
learning_rate = 1e-5
samples = 20000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
for i in range(samples):
    r = np.random.choice(np.arange(1, 4), p=[0.3,0.3,0.4])
    if r==1:
        img = Image.new('RGB', (28, 28), color = 'white')
        row,col,ch= np.shape(img)
        mean = 0
        var = 1
        sigma = var**0.5
        gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
        noisy_pos1 = img + gauss_pos1
        im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
        draw = ImageDraw.Draw(im2_pos1)
        draw.rectangle([21, 12, 24, 15], fill='red', outline='red')
        data1.append(np.asarray(im2_pos1))
    elif r==2:
        img = Image.new('RGB', (28, 28), color = 'white')
        row,col,ch= np.shape(img)
        mean = 0
        var = 1
        sigma = var**0.5
        gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
        noisy_pos1 = img + gauss_pos1
        im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
        draw = ImageDraw.Draw(im2_pos1)
        draw.rectangle([9,12,12,15],fill='red',outline='red')
        data1.append(np.asarray(im2_pos1))
    elif r==3:
        img = Image.new('RGB', (28, 28), color = 'white')
        row,col,ch= np.shape(img)
        mean = 0
        var = 1
        sigma = var**0.5
        gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
        noisy_pos1 = img + gauss_pos1
        im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
        data1.append(np.asarray(im2_pos1))
        




for i in range(samples):
    
    r = np.random.choice(np.arange(1, 4), p=[0.3,0.3,0.4])

    if r==1:
        img = Image.new('RGB', (28, 28), color = 'white')
        row,col,ch= np.shape(img)
        mean = 0
        var = 1
        sigma = var**0.5
        gauss_pos2 = np.random.normal(mean,sigma,(row,col,ch))
        noisy_pos2 = img + gauss_pos2
        im2_pos2 = Image.fromarray(noisy_pos2,'RGB')
        draw = ImageDraw.Draw(im2_pos2)
        draw.rectangle([21, 12, 24, 15], fill='red', outline='red')
        data2.append(np.asarray(im2_pos2))
    elif r==2:
        img = Image.new('RGB', (28, 28), color = 'white')
        row,col,ch= np.shape(img)
        mean = 0
        var = 1
        sigma = var**0.5
        gauss_pos2 = np.random.normal(mean,sigma,(row,col,ch))
        noisy_pos2 = img + gauss_pos2
        im2_pos2 = Image.fromarray(noisy_pos2,'RGB')
        draw = ImageDraw.Draw(im2_pos2)
        draw.rectangle([9,12,12,15],fill='red',outline='red')
        data2.append(np.asarray(im2_pos2))
    elif r==3:
        img = Image.new('RGB', (28, 28), color = 'white')
        row,col,ch= np.shape(img)
        mean = 0
        var = 1
        sigma = var**0.5
        gauss_pos2 = np.random.normal(mean,sigma,(row,col,ch))
        noisy_pos2 = img + gauss_pos2
        im2_pos2 = Image.fromarray(noisy_pos2,'RGB')
        data2.append(np.asarray(im2_pos2))



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (28, 28), color = 'white')
row,col,ch= np.shape(img)
mean = 0
var = 1
sigma = var**0.5
gauss = np.random.normal(mean,sigma,(row,col,ch))
noisy = img + gauss
im2 = Image.fromarray(noisy,'RGB')
b = np.asarray(im2)
b = np.array(b, dtype=np.float32)
b=b[:,:,0]
b = torch.from_numpy(b)
print(np.shape(b))
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.array(data1, dtype=np.float32)
y1 = np.array(data2, dtype=np.float32)
y0 = y0[:,:,:,0]
y1 = y1[:,:,:,0]

print(y0.shape)

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class AE(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        self.encoder_hidden_layer = nn.Linear(
            in_features=kwargs["input_shape"], out_features=128
        )
        self.encoder_output_layer = nn.Linear(
            in_features=128, out_features=64
        )
        self.encoder_output_layer_1 = nn.Linear(
            in_features=64, out_features=32
        )
        self.encoder_output_layer_2 = nn.Linear(
            in_features=32, out_features=16
        )
        self.encoder_output_layer_3 = nn.Linear(
            in_features=16, out_features=8
        )
        self.encoder_output_layer_4 = nn.Linear(
            in_features=8, out_features=1
        )




    def forward(self, features):
        activation = self.encoder_hidden_layer(features)
        activation = torch.relu(activation)
        code = self.encoder_output_layer(activation)
        code = torch.relu(code)
        code = self.encoder_output_layer_1(code)
        code = torch.relu(code)
        code = self.encoder_output_layer_2(code)
        code = torch.relu(code)
        code = self.encoder_output_layer_3(code)
        code = torch.relu(code)
        code = self.encoder_output_layer_4(code)
        code = torch.sigmoid(code)
        return code

#  use gpu if available

# create a model from `AE` autoencoder class
# load it to the specified device, either gpu or cpu
model = AE(input_shape=784)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)

    covf = torch.matmul((fx.t()), fx) / Nsamples

    covg = torch.matmul((gy.t()), (gy)) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h



optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-5)



for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        x = x.view(-1, 784)
        y = y.view(-1, 784)
        loss = h_score(model(x),model(y))
        # ===================backward====================

        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    b = b.view(-1,784)
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print(np.shape(x[0]))
    print("x: ", model(x[0]))
    print("y:", model(y[0]))
    print("b:", model(b))
# Out:
# torch.Size([28, 28])
# (20000, 28, 28)
# epoch [1/200], loss:0.0002
# torch.Size([784])
# x:  tensor([0.4051], grad_fn=<SigmoidBackward>)
# y: tensor([0.5658], grad_fn=<SigmoidBackward>)
# b: tensor([[0.5380]], grad_fn=<SigmoidBackward>)
# epoch [2/200], loss:0.0007
# torch.Size([784])
# x:  tensor([0.8070], grad_fn=<SigmoidBackward>)
# y: tensor([0.5560], grad_fn=<SigmoidBackward>)
# b: tensor([[0.7432]], grad_fn=<SigmoidBackward>)
# epoch [3/200], loss:0.0002
# torch.Size([784])
# x:  tensor([0.9821], grad_fn=<SigmoidBackward>)
# y: tensor([0.9763], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9669]], grad_fn=<SigmoidBackward>)
# epoch [4/200], loss:0.0000
# torch.Size([784])
# x:  tensor([0.9835], grad_fn=<SigmoidBackward>)
# y: tensor([0.9860], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9787]], grad_fn=<SigmoidBackward>)
# epoch [5/200], loss:-0.0001
# torch.Size([784])
# x:  tensor([0.9667], grad_fn=<SigmoidBackward>)
# y: tensor([0.9343], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9743]], grad_fn=<SigmoidBackward>)
# epoch [6/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.0154], grad_fn=<SigmoidBackward>)
# y: tensor([0.0137], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0172]], grad_fn=<SigmoidBackward>)
# epoch [7/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.0124], grad_fn=<SigmoidBackward>)
# y: tensor([0.0123], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0147]], grad_fn=<SigmoidBackward>)
# epoch [8/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.0127], grad_fn=<SigmoidBackward>)
# y: tensor([0.0137], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0150]], grad_fn=<SigmoidBackward>)
# epoch [9/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.0049], grad_fn=<SigmoidBackward>)
# y: tensor([0.0088], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0155]], grad_fn=<SigmoidBackward>)
# epoch [10/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.0200], grad_fn=<SigmoidBackward>)
# y: tensor([0.0148], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0161]], grad_fn=<SigmoidBackward>)
# epoch [11/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.0237], grad_fn=<SigmoidBackward>)
# y: tensor([0.0182], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0223]], grad_fn=<SigmoidBackward>)
# epoch [12/200], loss:-0.0114
# torch.Size([784])
# x:  tensor([0.9371], grad_fn=<SigmoidBackward>)
# y: tensor([0.8531], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9633]], grad_fn=<SigmoidBackward>)
# epoch [13/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9977], grad_fn=<SigmoidBackward>)
# y: tensor([0.9985], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9988]], grad_fn=<SigmoidBackward>)
# epoch [14/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9967], grad_fn=<SigmoidBackward>)
# y: tensor([0.9982], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9987]], grad_fn=<SigmoidBackward>)
# epoch [15/200], loss:0.0000
# torch.Size([784])
# x:  tensor([0.9891], grad_fn=<SigmoidBackward>)
# y: tensor([0.9964], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9986]], grad_fn=<SigmoidBackward>)
# epoch [16/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9957], grad_fn=<SigmoidBackward>)
# y: tensor([0.9931], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9967]], grad_fn=<SigmoidBackward>)
# epoch [17/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.0134], grad_fn=<SigmoidBackward>)
# y: tensor([0.0076], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0299]], grad_fn=<SigmoidBackward>)
# epoch [18/200], loss:-0.0126
# torch.Size([784])
# x:  tensor([0.0424], grad_fn=<SigmoidBackward>)
# y: tensor([0.5796], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9392]], grad_fn=<SigmoidBackward>)
# epoch [19/200], loss:-0.0186
# torch.Size([784])
# x:  tensor([0.9755], grad_fn=<SigmoidBackward>)
# y: tensor([0.9839], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9880]], grad_fn=<SigmoidBackward>)
# epoch [20/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9958], grad_fn=<SigmoidBackward>)
# y: tensor([0.9964], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9975]], grad_fn=<SigmoidBackward>)
# epoch [21/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9976], grad_fn=<SigmoidBackward>)
# y: tensor([0.9963], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9970]], grad_fn=<SigmoidBackward>)
# epoch [22/200], loss:-0.0012
# torch.Size([784])
# x:  tensor([0.1917], grad_fn=<SigmoidBackward>)
# y: tensor([0.0526], grad_fn=<SigmoidBackward>)
# b: tensor([[0.6130]], grad_fn=<SigmoidBackward>)
# epoch [23/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9992], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [24/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9994], grad_fn=<SigmoidBackward>)
# y: tensor([0.9991], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [25/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9996], grad_fn=<SigmoidBackward>)
# y: tensor([0.9996], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [26/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9990], grad_fn=<SigmoidBackward>)
# y: tensor([0.9996], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [27/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9996], grad_fn=<SigmoidBackward>)
# y: tensor([0.9989], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [28/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9997], grad_fn=<SigmoidBackward>)
# y: tensor([0.9993], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [29/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9994], grad_fn=<SigmoidBackward>)
# y: tensor([0.9994], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [30/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9993], grad_fn=<SigmoidBackward>)
# y: tensor([0.9995], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [31/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9994], grad_fn=<SigmoidBackward>)
# y: tensor([0.9995], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [32/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9996], grad_fn=<SigmoidBackward>)
# y: tensor([0.9993], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [33/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9993], grad_fn=<SigmoidBackward>)
# y: tensor([0.9995], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [34/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9993], grad_fn=<SigmoidBackward>)
# y: tensor([0.9993], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [35/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9991], grad_fn=<SigmoidBackward>)
# y: tensor([0.9991], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [36/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9989], grad_fn=<SigmoidBackward>)
# y: tensor([0.9993], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [37/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9988], grad_fn=<SigmoidBackward>)
# y: tensor([0.9995], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [38/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9993], grad_fn=<SigmoidBackward>)
# y: tensor([0.9992], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [39/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9992], grad_fn=<SigmoidBackward>)
# y: tensor([0.9992], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [40/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9993], grad_fn=<SigmoidBackward>)
# y: tensor([0.9996], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [41/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9988], grad_fn=<SigmoidBackward>)
# y: tensor([0.9986], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9995]], grad_fn=<SigmoidBackward>)
# epoch [42/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9990], grad_fn=<SigmoidBackward>)
# y: tensor([0.9992], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9995]], grad_fn=<SigmoidBackward>)
# epoch [43/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9988], grad_fn=<SigmoidBackward>)
# y: tensor([0.9986], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9995]], grad_fn=<SigmoidBackward>)
# epoch [44/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9990], grad_fn=<SigmoidBackward>)
# y: tensor([0.9987], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9995]], grad_fn=<SigmoidBackward>)
# epoch [45/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9992], grad_fn=<SigmoidBackward>)
# y: tensor([0.9983], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9994]], grad_fn=<SigmoidBackward>)
# epoch [46/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9986], grad_fn=<SigmoidBackward>)
# y: tensor([0.9989], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9994]], grad_fn=<SigmoidBackward>)
# epoch [47/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9983], grad_fn=<SigmoidBackward>)
# y: tensor([0.9984], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9994]], grad_fn=<SigmoidBackward>)
# epoch [48/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9989], grad_fn=<SigmoidBackward>)
# y: tensor([0.9980], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9993]], grad_fn=<SigmoidBackward>)
# epoch [49/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9982], grad_fn=<SigmoidBackward>)
# y: tensor([0.9977], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9993]], grad_fn=<SigmoidBackward>)
# epoch [50/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9990], grad_fn=<SigmoidBackward>)
# y: tensor([0.9988], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9992]], grad_fn=<SigmoidBackward>)
# epoch [51/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9993], grad_fn=<SigmoidBackward>)
# y: tensor([0.9987], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9992]], grad_fn=<SigmoidBackward>)
# epoch [52/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9990], grad_fn=<SigmoidBackward>)
# y: tensor([0.9986], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9991]], grad_fn=<SigmoidBackward>)
# epoch [53/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9984], grad_fn=<SigmoidBackward>)
# y: tensor([0.9990], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9991]], grad_fn=<SigmoidBackward>)
# epoch [54/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9988], grad_fn=<SigmoidBackward>)
# y: tensor([0.9987], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9990]], grad_fn=<SigmoidBackward>)
# epoch [55/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9965], grad_fn=<SigmoidBackward>)
# y: tensor([0.9970], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9989]], grad_fn=<SigmoidBackward>)
# epoch [56/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9991], grad_fn=<SigmoidBackward>)
# y: tensor([0.9990], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9988]], grad_fn=<SigmoidBackward>)
# epoch [57/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9972], grad_fn=<SigmoidBackward>)
# y: tensor([0.9983], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9987]], grad_fn=<SigmoidBackward>)
# epoch [58/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9983], grad_fn=<SigmoidBackward>)
# y: tensor([0.9980], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9985]], grad_fn=<SigmoidBackward>)
# epoch [59/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9982], grad_fn=<SigmoidBackward>)
# y: tensor([0.9990], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9984]], grad_fn=<SigmoidBackward>)
# epoch [60/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9976], grad_fn=<SigmoidBackward>)
# y: tensor([0.9950], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9982]], grad_fn=<SigmoidBackward>)
# epoch [61/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9952], grad_fn=<SigmoidBackward>)
# y: tensor([0.9962], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9979]], grad_fn=<SigmoidBackward>)
# epoch [62/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9936], grad_fn=<SigmoidBackward>)
# y: tensor([0.9961], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9975]], grad_fn=<SigmoidBackward>)
# epoch [63/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9935], grad_fn=<SigmoidBackward>)
# y: tensor([0.9872], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9970]], grad_fn=<SigmoidBackward>)
# epoch [64/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9960], grad_fn=<SigmoidBackward>)
# y: tensor([0.9953], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9961]], grad_fn=<SigmoidBackward>)
# epoch [65/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9914], grad_fn=<SigmoidBackward>)
# y: tensor([0.9804], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9905]], grad_fn=<SigmoidBackward>)
# epoch [66/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.0077], grad_fn=<SigmoidBackward>)
# y: tensor([0.0119], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0212]], grad_fn=<SigmoidBackward>)
# epoch [67/200], loss:-0.0052
# torch.Size([784])
# x:  tensor([0.0011], grad_fn=<SigmoidBackward>)
# y: tensor([0.0157], grad_fn=<SigmoidBackward>)
# b: tensor([[0.3624]], grad_fn=<SigmoidBackward>)
# epoch [68/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [69/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [70/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [71/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [72/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [73/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [74/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [75/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [76/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [77/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [78/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [79/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [80/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [81/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [82/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [83/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [84/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [85/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [86/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [87/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [88/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [89/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [90/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [91/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [92/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [93/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [94/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [95/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [96/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [97/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [98/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [99/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [100/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [101/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [102/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [103/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [104/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [105/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [106/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [107/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [108/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [109/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [110/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9998], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [111/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9995], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [112/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [113/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9998], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [114/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9997], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [115/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9996], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [116/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9994], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [117/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9997], grad_fn=<SigmoidBackward>)
# y: tensor([0.9998], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [118/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9996], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9998]], grad_fn=<SigmoidBackward>)
# epoch [119/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9995], grad_fn=<SigmoidBackward>)
# y: tensor([0.9996], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9998]], grad_fn=<SigmoidBackward>)
# epoch [120/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9993], grad_fn=<SigmoidBackward>)
# y: tensor([0.9995], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [121/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9991], grad_fn=<SigmoidBackward>)
# y: tensor([0.9995], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [122/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9997], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [123/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9994], grad_fn=<SigmoidBackward>)
# y: tensor([0.9994], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9995]], grad_fn=<SigmoidBackward>)
# epoch [124/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9992], grad_fn=<SigmoidBackward>)
# y: tensor([0.9991], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9994]], grad_fn=<SigmoidBackward>)
# epoch [125/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9980], grad_fn=<SigmoidBackward>)
# y: tensor([0.9991], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9992]], grad_fn=<SigmoidBackward>)
# epoch [126/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9990], grad_fn=<SigmoidBackward>)
# y: tensor([0.9986], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9989]], grad_fn=<SigmoidBackward>)
# epoch [127/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9944], grad_fn=<SigmoidBackward>)
# y: tensor([0.9977], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9984]], grad_fn=<SigmoidBackward>)
# epoch [128/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9929], grad_fn=<SigmoidBackward>)
# y: tensor([0.9924], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9962]], grad_fn=<SigmoidBackward>)
# epoch [129/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [130/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [131/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [132/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [133/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [134/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [135/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [136/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [137/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [138/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [139/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [140/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [141/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [142/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [143/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [144/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [145/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [146/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [147/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [148/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [149/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [150/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [151/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [152/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [153/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [154/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [155/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [156/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [157/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [158/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [159/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [160/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [161/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [162/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [163/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [164/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [165/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [166/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [167/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [168/200], loss:0.0000
# torch.Size([784])
# x:  tensor([0.9997], grad_fn=<SigmoidBackward>)
# y: tensor([0.9997], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [169/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9994], grad_fn=<SigmoidBackward>)
# y: tensor([0.9992], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [170/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9997], grad_fn=<SigmoidBackward>)
# y: tensor([0.9997], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9998]], grad_fn=<SigmoidBackward>)
# epoch [171/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9997], grad_fn=<SigmoidBackward>)
# y: tensor([0.9997], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9998]], grad_fn=<SigmoidBackward>)
# epoch [172/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9996], grad_fn=<SigmoidBackward>)
# y: tensor([0.9990], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [173/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9994], grad_fn=<SigmoidBackward>)
# y: tensor([0.9995], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [174/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9994], grad_fn=<SigmoidBackward>)
# y: tensor([0.9987], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9995]], grad_fn=<SigmoidBackward>)
# epoch [175/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9990], grad_fn=<SigmoidBackward>)
# y: tensor([0.9980], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9994]], grad_fn=<SigmoidBackward>)
# epoch [176/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9984], grad_fn=<SigmoidBackward>)
# y: tensor([0.9979], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9991]], grad_fn=<SigmoidBackward>)
# epoch [177/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9980], grad_fn=<SigmoidBackward>)
# y: tensor([0.9984], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9988]], grad_fn=<SigmoidBackward>)
# epoch [178/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9952], grad_fn=<SigmoidBackward>)
# y: tensor([0.9987], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9984]], grad_fn=<SigmoidBackward>)
# epoch [179/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9942], grad_fn=<SigmoidBackward>)
# y: tensor([0.9949], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9978]], grad_fn=<SigmoidBackward>)
# epoch [180/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9958], grad_fn=<SigmoidBackward>)
# y: tensor([0.9920], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9966]], grad_fn=<SigmoidBackward>)
# epoch [181/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9897], grad_fn=<SigmoidBackward>)
# y: tensor([0.9919], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9939]], grad_fn=<SigmoidBackward>)
# epoch [182/200], loss:-0.0010
# torch.Size([784])
# x:  tensor([0.7454], grad_fn=<SigmoidBackward>)
# y: tensor([0.7419], grad_fn=<SigmoidBackward>)
# b: tensor([[0.7974]], grad_fn=<SigmoidBackward>)
# epoch [183/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [184/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [185/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [186/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [187/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [188/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [189/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [190/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [191/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [192/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [193/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [194/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [195/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [196/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [197/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [198/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [199/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [200/200], loss:-0.0000
# torch.Size([784])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)

# %%
for i in range(20):
    img = Image.new('RGB', (28, 28), color = 'white')
    row,col,ch= np.shape(img)
    mean = 0
    var = 1
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col,ch))
    noisy = img + gauss
    im2_n = Image.fromarray(noisy,'RGB')
    b = np.asarray(im2_n)
    b = np.array(b, dtype=np.float32)
    b = torch.from_numpy(b)
    im2_test = Image.fromarray(noisy,'RGB')
    draw1 = ImageDraw.Draw(im2_test)
    draw1.rectangle([5, 9, 8, 12], fill='red', outline='red')
    z = np.asarray(im2_test)
    z = np.array(z, dtype=np.float32)
    z = torch.from_numpy(z)
    b=b[:,:,0]
    z=z[:,:,0]
    print("b:", model(b.view(-1,784)))
    print("z: ", model(z.view(-1,784)))
    print("x: ", model(x[i]))
    print("y:", model(y[i]))
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
    print("  ")
    p = Image.fromarray(data1[i])
    #p.show()
    q = Image.fromarray(data2[i])
    #q.show()
# Out:
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# z:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# z:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# z:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# z:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# z:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# z:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# z:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
