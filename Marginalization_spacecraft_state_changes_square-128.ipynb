# %% [raw]
# In this code, multiple positions and reloading of drone and tank. Drone: Spacecraft. Reloading State: Going Black.
#
# Channels:128
# Output: 15
# CNN kernel: 10
# Maxpool kernel:10

# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random
import cv2
from torchvision import models
from torchsummary import summary

Batch_Size = 50
num_epochs = 200
learning_rate = 1e-5
samples = 20000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
uframes = []
vidcap = cv2.VideoCapture('square.avi')
success,image = vidcap.read()
while success:
    uframes.append(image)   
    success,image = vidcap.read()

# cap = cv2.VideoCapture('video_drone_tank.avi')


# ret, frame = cap.read()

# uframes.append(frame)
# flag = 0
# z = 0
# while(z<30):
#     ret, frame = cap.read()
#     #np_frame = cv2.imread('video', frame) # does not work
#     #np_frame = np.asarray(cv2.GetMat(frame)) # does not work
#     #print(np_frame.shape)
#     for a in uframes:
#         if (np.array(a).any() != None):
#             print("a: ",np.shape(a))
#             print("frame: ",np.shape(a))
#             difference = cv2.subtract(np.array(a), np.array(frame))    
#             result = not np.any(difference)
#             #print("inside for")
#             if result is True:
#                 flag = 1
#                 #print("setting flag")
#                 break
#     if(not flag):
#         #print("appending")
#         uframes.append(frame)
#     z+=1

for i,frame in enumerate(uframes):
    uframes[i] = cv2.resize(frame,(100,100))
    
print(np.shape(uframes[0]))

print("length: ",len(uframes))
for i in range(samples):
    data1.append(np.array(np.transpose(np.asarray(uframes[i % len(uframes)]),(2,0,1)),dtype=np.float32))
    data2.append(np.array(np.transpose(np.asarray(uframes[(i+1) % len(uframes)]),(2,0,1)),dtype=np.float32))



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = '#9b7653')
# img.paste(im1,(5,75),im1)
# img.paste(im1,(10,55),im1)
# img.paste(im1,(25,50),im1)
# img.paste(im2,(75,5),im2)
# img.paste(im2,(60,30),im2)
# img.paste(im2,(90,20),im2)
# img.paste(im3,(75,60),im3)
# img.paste(im3,(60,80),im3)
im_n = np.reshape(img,(100,100,3))
b = np.asarray(im_n)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)

#y0 = np.array(np.transpose(np.asarray(y0),(0,3,1,2)),dtype=np.float32)
#y1 = np.array(np.transpose(np.asarray(y1),(0,3,1,2)),dtype=np.float32)
print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=128, kernel_size=10, stride=1)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=5)

#         # Convolution 2
#         self.cnn2 = nn.Conv2d(in_channels=16, out_channels=3, kernel_size=5, stride=1, padding=2)
#         self.relu2 = nn.ReLU()

#         # Max pool 2
#         self.maxpool2 = nn.MaxPool2d(kernel_size=5)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(41472, 15)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        #out = self.cnn2(out)
        #out = self.relu2(out)

        # Max pool 2 
        #out = self.maxpool2(out)
        im_out = out
        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return im_out,out
    
model = CNNModel()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x)[1],model(y)[1])
        # ===================backward====================
 
        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    #print("shape: ", np.shape(model(x[0].reshape(1,3,100, 100))[0]))
#     print("x: ", model(x[0].reshape(1,3,100, 100)))
#     print("y:", model(y[0].reshape(1,3,100, 100)))
#     print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# (100, 100, 3)
# length:  892
# (20000, 3, 100, 100)
# epoch [1/200], loss:-0.3358
# epoch [2/200], loss:-0.3694
# epoch [3/200], loss:-0.3460
# epoch [4/200], loss:-0.3328
# epoch [5/200], loss:-0.3322
# epoch [6/200], loss:-0.3270
# epoch [7/200], loss:-0.3213
# epoch [8/200], loss:-0.2661
# epoch [9/200], loss:-0.3492
# epoch [10/200], loss:-0.3595
# epoch [11/200], loss:-0.3147
# epoch [12/200], loss:-0.3885
# epoch [13/200], loss:-0.3967
# epoch [14/200], loss:-0.2779
# epoch [15/200], loss:-0.3620
# epoch [16/200], loss:-0.3380
# epoch [17/200], loss:-0.3105
# epoch [18/200], loss:-0.4139
# epoch [19/200], loss:-0.4281
# epoch [20/200], loss:-0.3673
# epoch [21/200], loss:-0.3520
# epoch [22/200], loss:-0.3790
# epoch [23/200], loss:-0.3962
# epoch [24/200], loss:-0.3568
# epoch [25/200], loss:-0.3259
# epoch [26/200], loss:-0.3419
# epoch [27/200], loss:-0.3110
# epoch [28/200], loss:-0.3695
# epoch [29/200], loss:-0.3517
# epoch [30/200], loss:-0.3784
# epoch [31/200], loss:-0.4131
# epoch [32/200], loss:-0.3781
# epoch [33/200], loss:-0.3773
# epoch [34/200], loss:-0.3914
# epoch [35/200], loss:-0.3845
# epoch [36/200], loss:-0.3612
# epoch [37/200], loss:-0.3999
# epoch [38/200], loss:-0.9632
# epoch [39/200], loss:-1.4467
# epoch [40/200], loss:-1.8979
# epoch [41/200], loss:-2.9893
# epoch [42/200], loss:-3.0013
# epoch [43/200], loss:-3.2483
# epoch [44/200], loss:-3.3269
# epoch [45/200], loss:-3.5645
# epoch [46/200], loss:-4.0302
# epoch [47/200], loss:-4.3888
# epoch [48/200], loss:-3.9674
# epoch [49/200], loss:-4.2320
# epoch [50/200], loss:-4.1240
# epoch [51/200], loss:-4.0090
# epoch [52/200], loss:-4.2269
# epoch [53/200], loss:-3.9988
# epoch [54/200], loss:-4.8763
# epoch [55/200], loss:-4.5668
# epoch [56/200], loss:-4.9887
# epoch [57/200], loss:-4.0630
# epoch [58/200], loss:-4.6041
# epoch [59/200], loss:-4.8954
# epoch [60/200], loss:-4.7615
# epoch [61/200], loss:-4.7016
# epoch [62/200], loss:-4.8388
# epoch [63/200], loss:-4.7245
# epoch [64/200], loss:-4.8161
# epoch [65/200], loss:-4.9976
# epoch [66/200], loss:-4.6890
# epoch [67/200], loss:-4.6936
# epoch [68/200], loss:-4.8512
# epoch [69/200], loss:-4.7744
# epoch [70/200], loss:-4.8432
# epoch [71/200], loss:-4.8137
# epoch [72/200], loss:-5.0241
# epoch [73/200], loss:-4.8868
# epoch [74/200], loss:-4.8246
# epoch [75/200], loss:-5.0642
# epoch [76/200], loss:-5.0357
# epoch [77/200], loss:-4.2490
# epoch [78/200], loss:-4.7277
# epoch [79/200], loss:-4.8182
# epoch [80/200], loss:-5.1165
# epoch [81/200], loss:-4.5707
# epoch [82/200], loss:-4.8317
# epoch [83/200], loss:-4.9311
# epoch [84/200], loss:-4.7580
# epoch [85/200], loss:-4.7539
# epoch [86/200], loss:-4.9156
# epoch [87/200], loss:-4.3916
# epoch [88/200], loss:-4.8576
# epoch [89/200], loss:-4.9621
# epoch [90/200], loss:-4.9061
# epoch [91/200], loss:-4.6819
# epoch [92/200], loss:-4.5112
# epoch [93/200], loss:-4.4560
# epoch [94/200], loss:-5.2110
# epoch [95/200], loss:-5.0381
# epoch [96/200], loss:-4.6032
# epoch [97/200], loss:-5.0206
# epoch [98/200], loss:-5.0516
# epoch [99/200], loss:-4.8092
# epoch [100/200], loss:-4.9568
# epoch [101/200], loss:-5.2032
# epoch [102/200], loss:-4.9260
# epoch [103/200], loss:-4.7771
# epoch [104/200], loss:-4.8312
# epoch [105/200], loss:-4.9316
# epoch [106/200], loss:-4.7692
# epoch [107/200], loss:-4.9925
# epoch [108/200], loss:-4.9440
# epoch [109/200], loss:-4.5452
# epoch [110/200], loss:-4.9923
# epoch [111/200], loss:-5.1073
# epoch [112/200], loss:-4.9345
# epoch [113/200], loss:-4.9977
# epoch [114/200], loss:-4.7918
# epoch [115/200], loss:-4.8342
# epoch [116/200], loss:-5.0314
# epoch [117/200], loss:-5.1440
# epoch [118/200], loss:-5.1003
# epoch [119/200], loss:-5.1502
# epoch [120/200], loss:-5.1043
# epoch [121/200], loss:-5.2123
# epoch [122/200], loss:-4.9282
# epoch [123/200], loss:-4.4844
# epoch [124/200], loss:-4.8756
# epoch [125/200], loss:-5.2421
# epoch [126/200], loss:-5.2558
# epoch [127/200], loss:-5.0109
# epoch [128/200], loss:-4.8459
# epoch [129/200], loss:-4.9877
# epoch [130/200], loss:-4.8397
# epoch [131/200], loss:-4.6428
# epoch [132/200], loss:-5.0003
# epoch [133/200], loss:-4.8173
# epoch [134/200], loss:-5.1741
# epoch [135/200], loss:-4.8718
# epoch [136/200], loss:-4.4272
# epoch [137/200], loss:-5.0283
# epoch [138/200], loss:-5.0362
# epoch [139/200], loss:-4.7056
# epoch [140/200], loss:-4.6175
# epoch [141/200], loss:-5.0497
# epoch [142/200], loss:-4.9382
# epoch [143/200], loss:-5.1116
# epoch [144/200], loss:-4.9118
# epoch [145/200], loss:-4.6636
# epoch [146/200], loss:-4.6266
# epoch [147/200], loss:-4.9691
# epoch [148/200], loss:-5.0809
# epoch [149/200], loss:-4.7667
# epoch [150/200], loss:-4.7812
# epoch [151/200], loss:-4.7224
# epoch [152/200], loss:-4.7449
# epoch [153/200], loss:-5.2022
# epoch [154/200], loss:-4.9541
# epoch [155/200], loss:-4.6139
# epoch [156/200], loss:-5.0944
# epoch [157/200], loss:-4.8594
# epoch [158/200], loss:-4.9264
# epoch [159/200], loss:-4.7991
# epoch [160/200], loss:-5.1418
# epoch [161/200], loss:-4.7900
# epoch [162/200], loss:-4.8537
# epoch [163/200], loss:-4.8668
# epoch [164/200], loss:-4.9568
# epoch [165/200], loss:-5.1499
# epoch [166/200], loss:-4.5339
# epoch [167/200], loss:-4.9592
# epoch [168/200], loss:-5.0424
# epoch [169/200], loss:-4.7852
# epoch [170/200], loss:-5.3147
# epoch [171/200], loss:-4.7570
# epoch [172/200], loss:-4.6841
# epoch [173/200], loss:-4.9857
# epoch [174/200], loss:-4.8997
# epoch [175/200], loss:-5.0441
# epoch [176/200], loss:-4.8687
# epoch [177/200], loss:-4.9760
# epoch [178/200], loss:-5.2080
# epoch [179/200], loss:-4.4012
# epoch [180/200], loss:-4.9044
# epoch [181/200], loss:-4.6606
# epoch [182/200], loss:-5.0137
# epoch [183/200], loss:-4.7411
# epoch [184/200], loss:-5.1911
# epoch [185/200], loss:-5.4003
# epoch [186/200], loss:-5.5761
# epoch [187/200], loss:-4.9703
# epoch [188/200], loss:-5.0692
# epoch [189/200], loss:-4.6295
# epoch [190/200], loss:-4.9801
# epoch [191/200], loss:-5.1191
# epoch [192/200], loss:-5.2293
# epoch [193/200], loss:-4.9027
# epoch [194/200], loss:-4.9947
# epoch [195/200], loss:-4.9985
# epoch [196/200], loss:-4.8892
# epoch [197/200], loss:-5.0640
# epoch [198/200], loss:-5.0507
# epoch [199/200], loss:-5.0882
# epoch [200/200], loss:-4.9202

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

drone_panels={}
tank_panels={}
tank_reloading_panels={}
drone_reloading_panels={}

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

for i in range(64):

    tank_info_panel = i
    #rone_info_panel = i
    #Blank
    img = uframes[1]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Blank: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("Blank: ",val,pos)


    print("**********")
    img = uframes[2]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank_info,pos_tank_info = val_pos(output_tank)
    print("Tank: ",val_tank_info,pos_tank_info)
#     output_drone = output[0][drone_info_panel]
#     val_tank_drone_info,pos_tank_drone_info = val_pos(output_drone)
#     print("Tank: ",val,pos)
    print("**********")

    #Drone
    img = uframes[3]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_drone_info,pos_drone_info = val_pos(output_tank)
    print("Drone: ",val_drone_info,pos_drone_info)
#     output_drone = output[0][drone_info_panel]
#     val_drone_drone_info,pos_drone_drone_info = val_pos(output_drone)
#     print("Drone: ",val,pos)
    
    print("**********")  
    img = uframes[4]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank_reloading_info,pos_tank_reloading_info = val_pos(output_tank)
    print("Tank reloading: ",val_tank_reloading_info,pos_tank_reloading_info)
#     output_drone = output[0][drone_info_panel]
#     val_tank_reloading_drone_info,pos_tank_reloading_drone_info = val_pos(output_drone)
#     print("Tank reloading: ",val,pos)

    print("**********")
    #Drone Reloadingg
    img = uframes[5]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_drone_reloading_info,pos_drone_reloading_info = val_pos(output_tank)
    print("Drone reloading: ",val_drone_reloading_info,pos_drone_reloading_info)
#     output_drone = output[0][drone_info_panel]
#     val_drone_reloading_drone_info,pos_drone_reloading_drone_info = val_pos(output_drone)
#     print("Drone reloading: ",val,pos)

    print("**********")
    #Tank and Drone
    img= uframes[0]
    z = Image.fromarray(img)
    #z.show()
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TD: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("TD: ",val,pos)
    
    print("**********")
    #Tank and Drone reloading
    img= uframes[6]
    z = Image.fromarray(img)
    #z.show()
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TrDr: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("TD: ",val,pos)
    
    print("\nPanel ",i)
    print("\n++++++++++++++++++++++++++++++++++++++++++++\n")
    if val_tank_info > max(val_drone_reloading_info,val_tank_reloading_info,val_drone_info):
        tank_panels[i]=val_tank_info-5
    elif val_drone_info > max(val_drone_reloading_info,val_tank_reloading_info,val_tank_info):
        drone_panels[i]=val_drone_info-5
    elif val_tank_reloading_info > max(val_drone_reloading_info,val_tank_info,val_drone_info):
        tank_reloading_panels[i]=val_tank_reloading_info-5
    elif val_drone_reloading_info > max(val_tank_reloading_info,val_tank_info,val_drone_info):
        drone_reloading_panels[i]=val_drone_reloading_info-2
print(drone_panels)
# Out:
# Blank:  204.03383 (3, 8)
# **********
# Tank:  275.51743 (5, 0)
# **********
# Drone:  302.40936 (13, 2)
# **********
# Tank reloading:  408.74387 (6, 0)
# **********
# Drone reloading:  353.80252 (13, 1)
# **********
# TD:  368.45044 (13, 2)
# **********
# TrDr:  558.5044 (6, 0)
#
# Panel  0
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  621.0657 (11, 12)
# **********
# Tank:  825.75726 (5, 0)
# **********
# Drone:  783.81946 (11, 12)
# **********
# Tank reloading:  786.5104 (11, 12)
# **********
# Drone reloading:  942.9388 (13, 2)
# **********
# TD:  991.3714 (5, 0)
# **********
# TrDr:  1112.5355 (13, 2)
#
# Panel  1
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  532.18225 (10, 3)
# **********
# Tank:  708.10205 (4, 0)
# **********
# Drone:  709.2772 (13, 2)
# **********
# Tank reloading:  819.9264 (5, 1)
# **********
# Drone reloading:  946.71454 (12, 1)
# **********
# TD:  882.64966 (13, 2)
# **********
# TrDr:  1235.1675 (12, 1)
#
# Panel  2
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1550.1617 (11, 13)
# **********
# Tank:  1856.2684 (4, 0)
# **********
# Drone:  1903.0258 (11, 1)
# **********
# Tank reloading:  2050.3655 (5, 1)
# **********
# Drone reloading:  1987.8915 (12, 1)
# **********
# TD:  2199.9258 (4, 0)
# **********
# TrDr:  2492.3337 (12, 1)
#
# Panel  3
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  99.82268 (11, 13)
# **********
# Tank:  249.52933 (6, 0)
# **********
# Drone:  143.15912 (12, 2)
# **********
# Tank reloading:  276.36926 (5, 0)
# **********
# Drone reloading:  287.70374 (13, 2)
# **********
# TD:  293.06927 (6, 0)
# **********
# TrDr:  465.41638 (13, 2)
#
# Panel  4
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  400.61368 (16, 14)
# **********
# Tank:  645.72766 (4, 1)
# **********
# Drone:  594.8301 (11, 2)
# **********
# Tank reloading:  628.334 (6, 1)
# **********
# Drone reloading:  1008.24554 (13, 1)
# **********
# TD:  826.57495 (4, 1)
# **********
# TrDr:  1234.9539 (13, 1)
#
# Panel  5
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  655.51654 (16, 15)
# **********
# Tank:  981.081 (5, 1)
# **********
# Drone:  970.061 (13, 2)
# **********
# Tank reloading:  1020.95935 (4, 0)
# **********
# Drone reloading:  1315.6394 (12, 2)
# **********
# TD:  1297.1404 (5, 1)
# **********
# TrDr:  1680.9817 (12, 2)
#
# Panel  6
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1031.2698 (10, 13)
# **********
# Tank:  1186.2717 (10, 13)
# **********
# Drone:  1186.9103 (12, 1)
# **********
# Tank reloading:  1341.4722 (4, 0)
# **********
# Drone reloading:  1117.9255 (10, 13)
# **********
# TD:  1333.8464 (12, 1)
# **********
# TrDr:  1425.9254 (4, 0)
#
# Panel  7
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  469.80615 (11, 4)
# **********
# Tank:  729.4509 (4, 0)
# **********
# Drone:  674.34143 (12, 1)
# **********
# Tank reloading:  635.7197 (5, 1)
# **********
# Drone reloading:  1210.771 (12, 1)
# **********
# TD:  930.05634 (4, 0)
# **********
# TrDr:  1375.5665 (12, 1)
#
# Panel  8
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  505.44537 (11, 13)
# **********
# Tank:  584.1196 (11, 13)
# **********
# Drone:  733.109 (12, 0)
# **********
# Tank reloading:  889.45215 (6, 1)
# **********
# Drone reloading:  745.47656 (12, 1)
# **********
# TD:  817.5317 (12, 0)
# **********
# TrDr:  1130.1455 (6, 1)
#
# Panel  9
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  53.8586 (17, 15)
# **********
# Tank:  285.62576 (5, 0)
# **********
# Drone:  187.50867 (12, 2)
# **********
# Tank reloading:  56.6172 (17, 15)
# **********
# Drone reloading:  544.217 (12, 2)
# **********
# TD:  417.3615 (12, 2)
# **********
# TrDr:  547.0899 (12, 2)
#
# Panel  10
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  379.68964 (17, 14)
# **********
# Tank:  572.578 (5, 1)
# **********
# Drone:  563.0725 (12, 2)
# **********
# Tank reloading:  606.1123 (6, 1)
# **********
# Drone reloading:  873.66833 (12, 2)
# **********
# TD:  760.1626 (5, 1)
# **********
# TrDr:  1100.8341 (12, 2)
#
# Panel  11
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  278.59625 (10, 12)
# **********
# Tank:  451.83246 (4, 0)
# **********
# Drone:  418.42255 (11, 2)
# **********
# Tank reloading:  346.37146 (6, 1)
# **********
# Drone reloading:  557.5766 (13, 1)
# **********
# TD:  598.51306 (4, 0)
# **********
# TrDr:  626.1031 (13, 1)
#
# Panel  12
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  159.10837 (11, 12)
# **********
# Tank:  339.98517 (5, 1)
# **********
# Drone:  248.51324 (12, 2)
# **********
# Tank reloading:  226.90773 (5, 0)
# **********
# Drone reloading:  408.17072 (12, 2)
# **********
# TD:  423.2488 (5, 1)
# **********
# TrDr:  475.8233 (12, 2)
#
# Panel  13
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  549.1756 (11, 13)
# **********
# Tank:  760.1351 (6, 0)
# **********
# Drone:  727.78357 (11, 13)
# **********
# Tank reloading:  846.9373 (5, 0)
# **********
# Drone reloading:  906.8697 (13, 2)
# **********
# TD:  938.7677 (6, 0)
# **********
# TrDr:  1206.6616 (13, 2)
#
# Panel  14
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  918.5518 (12, 6)
# **********
# Tank:  1223.2897 (5, 0)
# **********
# Drone:  1093.2032 (12, 2)
# **********
# Tank reloading:  1080.448 (6, 0)
# **********
# Drone reloading:  1156.0033 (12, 2)
# **********
# TD:  1407.9342 (5, 0)
# **********
# TrDr:  1318.4092 (12, 2)
#
# Panel  15
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  628.09894 (0, 0)
# **********
# Tank:  792.1811 (5, 0)
# **********
# Drone:  800.0125 (12, 2)
# **********
# Tank reloading:  771.88184 (6, 1)
# **********
# Drone reloading:  893.6356 (12, 1)
# **********
# TD:  971.9896 (12, 2)
# **********
# TrDr:  1040.2922 (12, 1)
#
# Panel  16
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  514.8127 (8, 10)
# **********
# Tank:  747.87756 (5, 1)
# **********
# Drone:  683.25037 (8, 10)
# **********
# Tank reloading:  634.5683 (5, 0)
# **********
# Drone reloading:  808.94617 (13, 2)
# **********
# TD:  922.0326 (5, 1)
# **********
# TrDr:  930.3949 (13, 2)
#
# Panel  17
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  464.42188 (11, 12)
# **********
# Tank:  581.8292 (5, 0)
# **********
# Drone:  677.6411 (12, 1)
# **********
# Tank reloading:  819.2135 (5, 1)
# **********
# Drone reloading:  659.949 (12, 1)
# **********
# TD:  792.4376 (12, 1)
# **********
# TrDr:  1014.9883 (5, 1)
#
# Panel  18
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  366.1286 (10, 12)
# **********
# Tank:  514.5436 (6, 0)
# **********
# Drone:  476.63348 (10, 12)
# **********
# Tank reloading:  579.73486 (6, 1)
# **********
# Drone reloading:  646.32715 (12, 1)
# **********
# TD:  620.7793 (6, 0)
# **********
# TrDr:  860.33813 (12, 1)
#
# Panel  19
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  112.845924 (8, 10)
# **********
# Tank:  293.98184 (5, 0)
# **********
# Drone:  243.0577 (13, 2)
# **********
# Tank reloading:  177.7868 (5, 0)
# **********
# Drone reloading:  495.0841 (13, 2)
# **********
# TD:  416.8071 (13, 2)
# **********
# TrDr:  560.3523 (13, 2)
#
# Panel  20
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  351.53955 (12, 13)
# **********
# Tank:  479.82602 (5, 0)
# **********
# Drone:  451.34207 (13, 1)
# **********
# Tank reloading:  653.67615 (5, 1)
# **********
# Drone reloading:  811.2319 (13, 1)
# **********
# TD:  582.3594 (5, 0)
# **********
# TrDr:  1113.0746 (13, 1)
#
# Panel  21
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  105.0508 (16, 14)
# **********
# Tank:  226.64784 (5, 1)
# **********
# Drone:  114.01338 (16, 14)
# **********
# Tank reloading:  312.2557 (6, 1)
# **********
# Drone reloading:  273.00696 (13, 2)
# **********
# TD:  228.75278 (5, 1)
# **********
# TrDr:  479.2614 (6, 1)
#
# Panel  22
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  562.6155 (15, 15)
# **********
# Tank:  830.82355 (6, 1)
# **********
# Drone:  816.48035 (13, 2)
# **********
# Tank reloading:  790.2251 (5, 0)
# **********
# Drone reloading:  1080.477 (14, 2)
# **********
# TD:  1091.0718 (13, 2)
# **********
# TrDr:  1308.9408 (14, 2)
#
# Panel  23
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  737.5558 (2, 1)
# **********
# Tank:  892.71155 (2, 1)
# **********
# Drone:  946.85596 (11, 1)
# **********
# Tank reloading:  1027.9994 (6, 0)
# **********
# Drone reloading:  960.1426 (13, 2)
# **********
# TD:  1095.6813 (11, 1)
# **********
# TrDr:  1247.8419 (6, 0)
#
# Panel  24
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  322.6892 (10, 13)
# **********
# Tank:  607.68567 (6, 0)
# **********
# Drone:  388.2791 (10, 13)
# **********
# Tank reloading:  413.4756 (10, 13)
# **********
# Drone reloading:  709.5007 (14, 2)
# **********
# TD:  685.0288 (6, 0)
# **********
# TrDr:  797.45306 (14, 2)
#
# Panel  25
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  102.472595 (8, 9)
# **********
# Tank:  247.17532 (5, 2)
# **********
# Drone:  198.26031 (12, 2)
# **********
# Tank reloading:  203.40904 (5, 2)
# **********
# Drone reloading:  414.05496 (13, 1)
# **********
# TD:  331.94183 (5, 2)
# **********
# TrDr:  514.93085 (13, 1)
#
# Panel  26
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  342.1363 (17, 15)
# **********
# Tank:  627.70667 (5, 1)
# **********
# Drone:  564.9088 (13, 2)
# **********
# Tank reloading:  418.6535 (17, 15)
# **********
# Drone reloading:  912.25226 (13, 2)
# **********
# TD:  856.928 (5, 1)
# **********
# TrDr:  989.07935 (13, 2)
#
# Panel  27
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  562.0383 (10, 13)
# **********
# Tank:  656.1327 (10, 13)
# **********
# Drone:  643.08887 (13, 2)
# **********
# Tank reloading:  905.5575 (5, 0)
# **********
# Drone reloading:  760.3207 (12, 1)
# **********
# TD:  736.62305 (13, 2)
# **********
# TrDr:  1104.3716 (5, 0)
#
# Panel  28
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  867.05756 (11, 2)
# **********
# Tank:  1025.7855 (6, 1)
# **********
# Drone:  1066.3704 (12, 2)
# **********
# Tank reloading:  1199.4508 (5, 0)
# **********
# Drone reloading:  932.2317 (11, 2)
# **********
# TD:  1214.5151 (12, 2)
# **********
# TrDr:  1265.6189 (5, 0)
#
# Panel  29
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  509.669 (8, 8)
# **********
# Tank:  671.35376 (5, 0)
# **********
# Drone:  694.0139 (13, 2)
# **********
# Tank reloading:  681.2836 (5, 0)
# **********
# Drone reloading:  732.1422 (13, 2)
# **********
# TD:  846.85254 (13, 2)
# **********
# TrDr:  905.42584 (5, 0)
#
# Panel  30
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  515.5486 (16, 14)
# **********
# Tank:  849.7809 (5, 1)
# **********
# Drone:  798.2815 (13, 2)
# **********
# Tank reloading:  916.947 (5, 0)
# **********
# Drone reloading:  1264.3966 (12, 1)
# **********
# TD:  1137.8347 (13, 2)
# **********
# TrDr:  1664.3596 (12, 1)
#
# Panel  31
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  296.03015 (8, 10)
# **********
# Tank:  478.35785 (5, 0)
# **********
# Drone:  428.66843 (8, 10)
# **********
# Tank reloading:  503.79437 (5, 0)
# **********
# Drone reloading:  546.84235 (13, 2)
# **********
# TD:  606.4596 (5, 0)
# **********
# TrDr:  753.7653 (5, 0)
#
# Panel  32
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  470.5907 (10, 12)
# **********
# Tank:  735.9441 (4, 1)
# **********
# Drone:  691.8112 (12, 1)
# **********
# Tank reloading:  666.46954 (5, 0)
# **********
# Drone reloading:  995.19745 (13, 1)
# **********
# TD:  963.02905 (4, 1)
# **********
# TrDr:  1190.973 (13, 1)
#
# Panel  33
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  392.02963 (11, 11)
# **********
# Tank:  479.85883 (6, 1)
# **********
# Drone:  541.67035 (11, 2)
# **********
# Tank reloading:  656.9696 (5, 1)
# **********
# Drone reloading:  772.1762 (14, 1)
# **********
# TD:  633.60516 (11, 2)
# **********
# TrDr:  1035.117 (5, 1)
#
# Panel  34
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  235.96664 (11, 2)
# **********
# Tank:  406.00497 (5, 0)
# **********
# Drone:  361.92328 (12, 2)
# **********
# Tank reloading:  492.96265 (4, 1)
# **********
# Drone reloading:  742.68976 (13, 1)
# **********
# TD:  536.70844 (12, 2)
# **********
# TrDr:  999.82587 (13, 1)
#
# Panel  35
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  78.01462 (7, 8)
# **********
# Tank:  142.45326 (4, 0)
# **********
# Drone:  185.09183 (12, 1)
# **********
# Tank reloading:  355.0924 (6, 1)
# **********
# Drone reloading:  301.26334 (13, 1)
# **********
# TD:  243.16791 (12, 1)
# **********
# TrDr:  577.33685 (13, 1)
#
# Panel  36
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1424.627 (11, 12)
# **********
# Tank:  1581.8856 (5, 0)
# **********
# Drone:  1695.8787 (11, 2)
# **********
# Tank reloading:  1906.0277 (6, 1)
# **********
# Drone reloading:  1798.0 (12, 1)
# **********
# TD:  1852.5553 (5, 0)
# **********
# TrDr:  2283.0547 (12, 1)
#
# Panel  37
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1309.6558 (10, 13)
# **********
# Tank:  1632.1663 (5, 0)
# **********
# Drone:  1643.729 (12, 2)
# **********
# Tank reloading:  1794.7053 (5, 1)
# **********
# Drone reloading:  1755.7349 (12, 1)
# **********
# TD:  1951.2462 (12, 2)
# **********
# TrDr:  2242.1372 (5, 1)
#
# Panel  38
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  426.10626 (10, 12)
# **********
# Tank:  528.05756 (5, 0)
# **********
# Drone:  631.9574 (13, 2)
# **********
# Tank reloading:  644.14233 (6, 0)
# **********
# Drone reloading:  523.24835 (13, 2)
# **********
# TD:  744.7147 (5, 0)
# **********
# TrDr:  739.42114 (6, 0)
#
# Panel  39
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  371.66995 (16, 13)
# **********
# Tank:  610.32666 (6, 1)
# **********
# Drone:  596.9444 (12, 3)
# **********
# Tank reloading:  634.53564 (5, 1)
# **********
# Drone reloading:  810.52686 (14, 2)
# **********
# TD:  842.1385 (6, 1)
# **********
# TrDr:  1072.6454 (14, 2)
#
# Panel  40
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  178.42351 (16, 13)
# **********
# Tank:  346.01624 (6, 0)
# **********
# Drone:  296.19394 (12, 2)
# **********
# Tank reloading:  396.237 (5, 0)
# **********
# Drone reloading:  621.52844 (13, 1)
# **********
# TD:  460.08966 (6, 0)
# **********
# TrDr:  838.0984 (13, 1)
#
# Panel  41
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  591.2405 (7, 8)
# **********
# Tank:  845.8095 (4, 0)
# **********
# Drone:  744.77246 (13, 2)
# **********
# Tank reloading:  797.99023 (5, 1)
# **********
# Drone reloading:  847.5836 (12, 1)
# **********
# TD:  994.8534 (4, 0)
# **********
# TrDr:  1054.8452 (12, 1)
#
# Panel  42
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1792.1014 (7, 8)
# **********
# Tank:  2146.9375 (5, 0)
# **********
# Drone:  2139.1836 (12, 2)
# **********
# Tank reloading:  2119.9717 (6, 0)
# **********
# Drone reloading:  2398.5615 (12, 1)
# **********
# TD:  2499.7803 (5, 0)
# **********
# TrDr:  2729.977 (12, 1)
#
# Panel  43
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  594.5696 (3, 8)
# **********
# Tank:  920.5494 (5, 1)
# **********
# Drone:  899.22327 (12, 2)
# **********
# Tank reloading:  977.50745 (5, 0)
# **********
# Drone reloading:  1256.0797 (13, 2)
# **********
# TD:  1226.0417 (5, 1)
# **********
# TrDr:  1636.7106 (13, 2)
#
# Panel  44
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  249.22324 (16, 13)
# **********
# Tank:  468.633 (4, 0)
# **********
# Drone:  485.13702 (11, 1)
# **********
# Tank reloading:  385.43454 (6, 1)
# **********
# Drone reloading:  658.2089 (12, 1)
# **********
# TD:  709.0089 (11, 1)
# **********
# TrDr:  797.13934 (12, 1)
#
# Panel  45
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  909.87024 (8, 10)
# **********
# Tank:  1199.2712 (5, 1)
# **********
# Drone:  1114.9663 (8, 10)
# **********
# Tank reloading:  1292.5896 (5, 0)
# **********
# Drone reloading:  1256.044 (13, 2)
# **********
# TD:  1405.8435 (5, 1)
# **********
# TrDr:  1639.9197 (13, 2)
#
# Panel  46
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1835.3025 (1, 0)
# **********
# Tank:  2272.5024 (4, 1)
# **********
# Drone:  2207.3843 (13, 2)
# **********
# Tank reloading:  2125.2717 (5, 1)
# **********
# Drone reloading:  2547.3328 (12, 2)
# **********
# TD:  2649.1855 (4, 1)
# **********
# TrDr:  2838.592 (12, 2)
#
# Panel  47
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  171.96333 (16, 15)
# **********
# Tank:  340.2651 (5, 1)
# **********
# Drone:  248.72397 (13, 2)
# **********
# Tank reloading:  228.08453 (5, 1)
# **********
# Drone reloading:  436.79916 (13, 2)
# **********
# TD:  408.49844 (5, 1)
# **********
# TrDr:  491.17398 (13, 2)
#
# Panel  48
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  12.236737 (8, 9)
# **********
# Tank:  246.94254 (5, 1)
# **********
# Drone:  49.800922 (12, 1)
# **********
# Tank reloading:  23.244802 (5, 0)
# **********
# Drone reloading:  451.1672 (13, 1)
# **********
# TD:  281.92902 (5, 1)
# **********
# TrDr:  461.63757 (13, 1)
#
# Panel  49
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2521.4958 (11, 3)
# **********
# Tank:  2931.696 (5, 0)
# **********
# Drone:  2852.4077 (11, 1)
# **********
# Tank reloading:  2988.0122 (5, 0)
# **********
# Drone reloading:  3065.8452 (12, 2)
# **********
# TD:  3239.3394 (5, 0)
# **********
# TrDr:  3535.8413 (12, 2)
#
# Panel  50
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  267.50067 (7, 8)
# **********
# Tank:  367.3436 (5, 0)
# **********
# Drone:  407.51678 (12, 2)
# **********
# Tank reloading:  515.50226 (6, 0)
# **********
# Drone reloading:  529.8528 (12, 1)
# **********
# TD:  509.6269 (12, 2)
# **********
# TrDr:  776.4863 (12, 1)
#
# Panel  51
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  52.661613 (16, 14)
# **********
# Tank:  116.4129 (4, 0)
# **********
# Drone:  70.27853 (12, 1)
# **********
# Tank reloading:  103.56047 (4, 0)
# **********
# Drone reloading:  213.19221 (13, 1)
# **********
# TD:  128.77617 (4, 0)
# **********
# TrDr:  263.97815 (13, 1)
#
# Panel  52
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  256.93042 (10, 13)
# **********
# Tank:  433.13403 (5, 0)
# **********
# Drone:  350.33286 (12, 2)
# **********
# Tank reloading:  434.40247 (5, 0)
# **********
# Drone reloading:  578.9535 (12, 1)
# **********
# TD:  523.45374 (5, 0)
# **********
# TrDr:  756.3452 (12, 1)
#
# Panel  53
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  907.20557 (0, 0)
# **********
# Tank:  1129.5819 (5, 0)
# **********
# Drone:  1113.9921 (11, 1)
# **********
# Tank reloading:  1259.8579 (5, 1)
# **********
# Drone reloading:  1299.3365 (13, 1)
# **********
# TD:  1336.4237 (11, 1)
# **********
# TrDr:  1652.0339 (5, 1)
#
# Panel  54
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  317.55707 (3, 8)
# **********
# Tank:  592.5536 (5, 0)
# **********
# Drone:  514.3013 (12, 2)
# **********
# Tank reloading:  368.4461 (3, 8)
# **********
# Drone reloading:  802.3187 (13, 1)
# **********
# TD:  786.87506 (5, 0)
# **********
# TrDr:  853.9156 (13, 1)
#
# Panel  55
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  124.92769 (3, 9)
# **********
# Tank:  304.13754 (5, 1)
# **********
# Drone:  270.58124 (12, 1)
# **********
# Tank reloading:  190.216 (4, 0)
# **********
# Drone reloading:  599.9236 (13, 1)
# **********
# TD:  456.68768 (5, 1)
# **********
# TrDr:  667.16626 (13, 1)
#
# Panel  56
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  363.07184 (10, 13)
# **********
# Tank:  683.4309 (5, 1)
# **********
# Drone:  569.6821 (12, 2)
# **********
# Tank reloading:  552.3611 (5, 0)
# **********
# Drone reloading:  854.79785 (13, 2)
# **********
# TD:  893.2044 (5, 1)
# **********
# TrDr:  1046.687 (13, 2)
#
# Panel  57
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  826.6097 (2, 7)
# **********
# Tank:  951.51996 (2, 7)
# **********
# Drone:  1041.1196 (13, 2)
# **********
# Tank reloading:  1198.1492 (5, 1)
# **********
# Drone reloading:  1060.1174 (12, 2)
# **********
# TD:  1168.9259 (13, 2)
# **********
# TrDr:  1431.7612 (5, 1)
#
# Panel  58
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2444.7593 (16, 14)
# **********
# Tank:  2871.9834 (5, 0)
# **********
# Drone:  2880.4773 (13, 1)
# **********
# Tank reloading:  2679.4028 (16, 14)
# **********
# Drone reloading:  3265.7634 (12, 2)
# **********
# TD:  3315.3594 (13, 1)
# **********
# TrDr:  3503.4011 (12, 2)
#
# Panel  59
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1441.6594 (12, 13)
# **********
# Tank:  1753.4784 (5, 0)
# **********
# Drone:  1739.9812 (12, 2)
# **********
# Tank reloading:  1841.3452 (4, 0)
# **********
# Drone reloading:  2037.4785 (13, 2)
# **********
# TD:  2055.6455 (5, 0)
# **********
# TrDr:  2439.7476 (13, 2)
#
# Panel  60
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  249.75964 (10, 13)
# **********
# Tank:  375.78275 (6, 1)
# **********
# Drone:  309.1903 (10, 13)
# **********
# Tank reloading:  607.06366 (5, 0)
# **********
# Drone reloading:  419.46548 (13, 1)
# **********
# TD:  435.56726 (6, 1)
# **********
# TrDr:  777.2556 (5, 0)
#
# Panel  61
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1676.7344 (17, 15)
# **********
# Tank:  2087.936 (5, 0)
# **********
# Drone:  1960.7369 (12, 1)
# **********
# Tank reloading:  2044.2695 (6, 0)
# **********
# Drone reloading:  2166.149 (13, 2)
# **********
# TD:  2372.2441 (5, 0)
# **********
# TrDr:  2536.9148 (13, 2)
#
# Panel  62
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  381.4278 (11, 13)
# **********
# Tank:  460.79456 (11, 13)
# **********
# Drone:  474.20175 (11, 13)
# **********
# Tank reloading:  648.70135 (5, 1)
# **********
# Drone reloading:  564.06384 (12, 3)
# **********
# TD:  545.3779 (11, 13)
# **********
# TrDr:  830.95386 (5, 1)
#
# Panel  63
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# {}

# %%
for i in range(7):
    img = uframes[i]
    z = Image.fromarray(img)
    z.show()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for j in range(len(list(tank_reloading_panels))):
    
    tank_info_panel = list(tank_panels)[0]
    drone_info_panel = list(drone_panels)[0]
    tankr_info_panel = list(tank_reloading_panels)[j]
    droner_info_panel = list(drone_reloading_panels)[0] #12

    #print(tankr_info_panel,tank_reloading_panels[tankr_info_panel])

    tank_threshold= tank_panels[tank_info_panel]
    tankr_threshold= tank_reloading_panels[tankr_info_panel]
    drone_threshold= drone_panels[drone_info_panel]
    droner_threshold= drone_reloading_panels[droner_info_panel]

    def val_pos(array):
        value = np.sum(array)
        position = np.unravel_index(np.argmax(array),array.shape)
        return value,position
    dronec=[]
    tankc=[]
    tankr=[]
    droner=[]
    #Blank
    for i in range(50):
        #x = cv2.imread(r"C:\Users\darshan19\Desktop\AoI\CNN\Images1\0b.png",-1)
        #x = cv2.resize(x,(100,100))
        img = uframes[i]
        #print(np.shape(img))
        # = Image.fromarray(img)
        #z.show()
        data3=[]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        #print(np.shape(x_1))
        output = model(x_1.reshape(1,3,100, 100))[0].detach().numpy()
        output_tank = output[0][tank_info_panel]
        val_tank,pos_tank = val_pos(output_tank)
        output_tankr = output[0][tankr_info_panel]
        val_tankr,pos_tankr = val_pos(output_tankr)
        print(i)
        output_drone = output[0][drone_info_panel]
        val_drone,pos_drone = val_pos(output_drone)
        output_droner = output[0][droner_info_panel]
        val_droner,pos_droner = val_pos(output_droner)

        if val_tank>tank_threshold:
    #         print("tank present")
    #         print("Tank info: ",val_tank,pos_tank)
            tankc.append(pos_tank)
        if val_drone>drone_threshold:
    #         print("drone present")
    #         print("Drone info: ",val_drone,pos_drone)
            dronec.append(pos_drone)
        if val_tankr>tankr_threshold:
            print("tank reloading present")
            print("Tank info: ",val_tank,pos_tank)
            tankr.append(pos_tankr)
        if val_droner>droner_threshold:
#             print("drone reloading present")
#             print("Drone info: ",val_droner,pos_droner)
            dronec.append(pos_drone)
    print("\n")
    print(list(tank_reloading_panels)[j])
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n\n")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-c6ab8e73bb04> in <module>
#       7
#       8     tank_info_panel = list(tank_panels)[0]
# ----> 9     drone_info_panel = list(drone_panels)[0]
#      10     tankr_info_panel = list(tank_reloading_panels)[j]
#      11     droner_info_panel = list(drone_reloading_panels)[0] #12
#
# IndexError: list index out of range

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)


tank_info_panel = 26#list(tank_panels)[2]
drone_info_panel = 33#list(drone_panels)[1]
tankr_info_panel = 21#list(tank_reloading_panels)[4]
droner_info_panel = 17#list(drone_reloading_panels)[12]

#print(drone_info_panel,drone_panels[drone_info_panel])

tank_threshold= tank_panels[tank_info_panel]
tankr_threshold= tank_reloading_panels[tankr_info_panel]
drone_threshold= drone_panels[drone_info_panel]
droner_threshold= drone_reloading_panels[droner_info_panel]

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position
dronec=[]
tankc=[]
tankr=[]
droner=[]
#Blank
print(len(uframes))
for i in range(200):
    #x = cv2.imread(r"C:\Users\darshan19\Desktop\AoI\CNN\Images1\0b.png",-1)
    #x = cv2.resize(x,(100,100))
    img = uframes[i]
    #print(np.shape(img))
    # = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    #print(np.shape(x_1))
    output = model(x_1.reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank,pos_tank = val_pos(output_tank)
    output_tankr = output[0][tankr_info_panel]
    val_tankr,pos_tankr = val_pos(output_tankr)
    print(i)
    output_drone = output[0][drone_info_panel]
    val_drone,pos_drone = val_pos(output_drone)
    output_droner = output[0][droner_info_panel]
    val_droner,pos_droner = val_pos(output_droner)
    
    if val_tank>tank_threshold:
        print("tank present")
        print("Tank info: ",val_tank,pos_tank)
        tankc.append(pos_tank)
    if val_drone>drone_threshold:
        print("drone present")
        print("Drone info: ",val_drone,pos_drone)
        dronec.append(pos_drone)
    if val_tankr>tankr_threshold:
        print("tank reloading present")
        print("Tank info: ",val_tank,pos_tank)
        tankr.append(pos_tankr)
    if val_droner>droner_threshold:
        print("drone reloading present")
        print("Drone info: ",val_droner,pos_droner)
        droner.append(pos_drone)
    print("\n")
    print("******************************************************************************")
    print("\n")
# Out:
# 264
# 0
# tank present
# Tank info:  1245.4308 (5, 1)
# drone present
# Drone info:  295.93127 (5, 0)
#
#
# ******************************************************************************
#
#
# 1
#
#
# ******************************************************************************
#
#
# 2
# tank present
# Tank info:  1003.29895 (5, 1)
#
#
# ******************************************************************************
#
#
# 3
# drone present
# Drone info:  186.09573 (11, 9)
#
#
# ******************************************************************************
#
#
# 4
# tank reloading present
# Tank info:  635.6013 (4, 0)
#
#
# ******************************************************************************
#
#
# 5
# drone reloading present
# Drone info:  136.94676 (11, 9)
#
#
# ******************************************************************************
#
#
# 6
# tank reloading present
# Tank info:  885.4109 (10, 9)
# drone reloading present
# Drone info:  214.86533 (5, 1)
#
#
# ******************************************************************************
#
#
# 7
# tank present
# Tank info:  1223.4937 (5, 1)
# drone present
# Drone info:  259.62103 (5, 0)
#
#
# ******************************************************************************
#
#
# 8
# tank present
# Tank info:  1228.8169 (5, 1)
# drone present
# Drone info:  269.7701 (12, 7)
#
#
# ******************************************************************************
#
#
# 9
# tank present
# Tank info:  1247.0386 (5, 1)
# drone present
# Drone info:  320.26367 (12, 6)
#
#
# ******************************************************************************
#
#
# 10
# tank present
# Tank info:  1236.6097 (5, 1)
# drone present
# Drone info:  303.62878 (5, 1)
#
#
# ******************************************************************************
#
#
# 11
# tank present
# Tank info:  1143.6492 (5, 1)
# drone present
# Drone info:  229.39296 (5, 1)
#
#
# ******************************************************************************
#
#
# 12
# tank present
# Tank info:  1160.5449 (5, 1)
# drone present
# Drone info:  326.15485 (10, 4)
#
#
# ******************************************************************************
#
#
# 13
# tank present
# Tank info:  1402.7664 (5, 2)
# drone present
# Drone info:  230.14502 (5, 1)
#
#
# ******************************************************************************
#
#
# 14
# tank present
# Tank info:  1340.9775 (5, 2)
# drone present
# Drone info:  255.94888 (9, 8)
#
#
# ******************************************************************************
#
#
# 15
# tank present
# Tank info:  1182.0222 (5, 2)
# drone present
# Drone info:  276.0677 (9, 9)
#
#
# ******************************************************************************
#
#
# 16
# tank present
# Tank info:  1230.4519 (5, 2)
# drone present
# Drone info:  345.57242 (5, 1)
#
#
# ******************************************************************************
#
#
# 17
# tank present
# Tank info:  1273.7231 (5, 2)
# drone present
# Drone info:  301.61032 (5, 1)
#
#
# ******************************************************************************
#
#
# 18
# tank present
# Tank info:  1273.849 (5, 2)
# drone present
# Drone info:  285.20367 (12, 7)
#
#
# ******************************************************************************
#
#
# 19
# tank present
# Tank info:  1268.2913 (5, 2)
# drone present
# Drone info:  291.77844 (5, 2)
#
#
# ******************************************************************************
#
#
# 20
# tank present
# Tank info:  1367.7185 (5, 3)
# drone present
# Drone info:  274.9943 (12, 4)
#
#
# ******************************************************************************
#
#
# 21
# tank present
# Tank info:  1227.3423 (5, 3)
# drone present
# Drone info:  215.6228 (5, 2)
#
#
# ******************************************************************************
#
#
# 22
# tank reloading present
# Tank info:  709.8927 (4, 2)
#
#
# ******************************************************************************
#
#
# 23
# drone reloading present
# Drone info:  148.08934 (11, 4)
#
#
# ******************************************************************************
#
#
# 24
# drone present
# Drone info:  196.31935 (10, 4)
# tank reloading present
# Tank info:  940.73096 (10, 4)
# drone reloading present
# Drone info:  206.40036 (11, 4)
#
#
# ******************************************************************************
#
#
# 25
# tank present
# Tank info:  1169.0334 (5, 3)
# drone present
# Drone info:  334.25116 (10, 4)
#
#
# ******************************************************************************
#
#
# 26
# tank present
# Tank info:  1293.3633 (5, 3)
# drone present
# Drone info:  251.44217 (5, 2)
#
#
# ******************************************************************************
#
#
# 27
# tank present
# Tank info:  1299.3381 (5, 3)
# drone present
# Drone info:  290.69034 (9, 8)
#
#
# ******************************************************************************
#
#
# 28
# tank present
# Tank info:  1179.762 (5, 3)
# drone present
# Drone info:  306.76245 (9, 9)
#
#
# ******************************************************************************
#
#
# 29
# tank present
# Tank info:  1230.7673 (5, 3)
# drone present
# Drone info:  295.99802 (5, 3)
#
#
# ******************************************************************************
#
#
# 30
#
#
# ******************************************************************************
#
#
# 31
# tank present
# Tank info:  1327.4294 (5, 3)
# drone present
# Drone info:  260.72815 (5, 3)
#
#
# ******************************************************************************
#
#
# 32
# tank present
# Tank info:  1341.7441 (5, 4)
# drone present
# Drone info:  269.96735 (12, 7)
#
#
# ******************************************************************************
#
#
# 33
# tank present
# Tank info:  1314.783 (5, 4)
# drone present
# Drone info:  300.08905 (12, 6)
#
#
# ******************************************************************************
#
#
# 34
# tank present
# Tank info:  1233.4834 (5, 4)
# drone present
# Drone info:  311.92447 (12, 4)
#
#
# ******************************************************************************
#
#
# 35
# tank present
# Tank info:  1211.8784 (5, 4)
# drone present
# Drone info:  260.52228 (5, 4)
#
#
# ******************************************************************************
#
#
# 36
# tank present
# Tank info:  1171.4512 (5, 4)
# drone present
# Drone info:  355.09467 (5, 3)
#
#
# ******************************************************************************
#
#
# 37
# tank present
# Tank info:  1338.1532 (5, 4)
# drone present
# Drone info:  232.2857 (9, 6)
#
#
# ******************************************************************************
#
#
# 38
# tank present
# Tank info:  1338.9082 (5, 4)
# drone present
# Drone info:  259.9688 (9, 8)
#
#
# ******************************************************************************
#
#
# 39
# tank present
# Tank info:  1257.5131 (5, 5)
# drone present
# Drone info:  281.51935 (9, 9)
#
#
# ******************************************************************************
#
#
# 40
# tank present
# Tank info:  1267.3865 (5, 5)
# drone present
# Drone info:  294.85135 (5, 4)
#
#
# ******************************************************************************
#
#
# 41
# tank present
# Tank info:  1033.7914 (5, 5)
#
#
# ******************************************************************************
#
#
# 42
# tank reloading present
# Tank info:  716.80383 (4, 4)
#
#
# ******************************************************************************
#
#
# 43
# drone reloading present
# Drone info:  167.38666 (11, 9)
#
#
# ******************************************************************************
#
#
# 44
# tank reloading present
# Tank info:  945.22125 (10, 9)
# drone reloading present
# Drone info:  230.6294 (11, 9)
#
#
# ******************************************************************************
#
#
# 45
# tank present
# Tank info:  1211.1375 (5, 5)
# drone present
# Drone info:  286.03418 (12, 8)
#
#
# ******************************************************************************
#
#
# 46
# tank present
# Tank info:  1296.9844 (5, 5)
# drone present
# Drone info:  309.8734 (12, 7)
#
#
# ******************************************************************************
#
#
# 47
# tank present
# Tank info:  1259.0922 (5, 5)
# drone present
# Drone info:  332.97913 (12, 6)
#
#
# ******************************************************************************
#
#
# 48
# tank present
# Tank info:  1266.5344 (5, 5)
# drone present
# Drone info:  290.45798 (12, 4)
#
#
# ******************************************************************************
#
#
# 49
# tank present
# Tank info:  1227.9674 (5, 5)
# drone present
# Drone info:  253.42543 (4, 5)
#
#
# ******************************************************************************
#
#
# 50
# tank present
# Tank info:  1271.0327 (5, 6)
# drone present
# Drone info:  327.80646 (5, 5)
#
#
# ******************************************************************************
#
#
# 51
# tank present
# Tank info:  1348.3057 (5, 6)
# drone present
# Drone info:  223.281 (9, 6)
#
#
# ******************************************************************************
#
#
# 52
# tank present
# Tank info:  1287.7944 (5, 6)
# drone present
# Drone info:  278.43597 (9, 8)
#
#
# ******************************************************************************
#
#
# 53
# tank present
# Tank info:  1224.687 (5, 6)
# drone present
# Drone info:  318.63965 (5, 5)
#
#
# ******************************************************************************
#
#
# 54
# tank present
# Tank info:  1275.4319 (5, 6)
# drone present
# Drone info:  319.36496 (10, 10)
#
#
# ******************************************************************************
#
#
# 55
#
#
# ******************************************************************************
#
#
# 56
# drone present
# Drone info:  200.53743 (10, 10)
#
#
# ******************************************************************************
#
#
# 57
# tank present
# Tank info:  1245.3191 (5, 6)
# drone present
# Drone info:  280.7945 (5, 6)
#
#
# ******************************************************************************
#
#
# 58
# tank present
# Tank info:  1315.4293 (5, 6)
# drone present
# Drone info:  298.13715 (12, 7)
#
#
# ******************************************************************************
#
#
# 59
# tank present
# Tank info:  1406.715 (5, 7)
# drone present
# Drone info:  272.3789 (12, 6)
#
#
# ******************************************************************************
#
#
# 60
# tank present
# Tank info:  1283.6915 (5, 7)
# drone present
# Drone info:  279.7943 (12, 4)
#
#
# ******************************************************************************
#
#
# 61
# tank present
# Tank info:  1198.8966 (5, 7)
# drone present
# Drone info:  258.15155 (4, 7)
#
#
# ******************************************************************************
#
#
# 62
# tank reloading present
# Tank info:  727.06915 (4, 6)
#
#
# ******************************************************************************
#
#
# 63
# drone reloading present
# Drone info:  147.94095 (11, 4)
#
#
# ******************************************************************************
#
#
# 64
# drone present
# Drone info:  196.1532 (10, 4)
# tank reloading present
# Tank info:  955.8152 (10, 4)
# drone reloading present
# Drone info:  220.1011 (11, 4)
#
#
# ******************************************************************************
#
#
# 65
# tank present
# Tank info:  1155.4421 (5, 7)
# drone present
# Drone info:  354.51794 (10, 4)
#
#
# ******************************************************************************
#
#
# 66
# tank present
# Tank info:  1339.1946 (5, 7)
# drone present
# Drone info:  269.20786 (9, 6)
#
#
# ******************************************************************************
#
#
# 67
# tank present
# Tank info:  1265.2864 (5, 7)
# drone present
# Drone info:  284.55804 (9, 8)
#
#
# ******************************************************************************
#
#
# 68
# tank present
# Tank info:  1153.4788 (5, 7)
# drone present
# Drone info:  275.2858 (5, 7)
#
#
# ******************************************************************************
#
#
# 69
# tank present
# Tank info:  1338.8328 (5, 8)
# drone present
# Drone info:  269.31006 (10, 10)
#
#
# ******************************************************************************
#
#
# 70
# tank present
# Tank info:  1256.4817 (5, 8)
# drone present
# Drone info:  255.84824 (12, 8)
#
#
# ******************************************************************************
#
#
# 71
# tank present
# Tank info:  1330.5095 (5, 8)
# drone present
# Drone info:  295.63904 (5, 7)
#
#
# ******************************************************************************
#
#
# 72
# tank present
# Tank info:  1296.5737 (5, 8)
# drone present
# Drone info:  297.4291 (12, 6)
#
#
# ******************************************************************************
#
#
# 73
# tank present
# Tank info:  1252.1064 (5, 8)
# drone present
# Drone info:  321.14618 (12, 4)
#
#
# ******************************************************************************
#
#
# 74
# tank present
# Tank info:  1217.2272 (5, 8)
# drone present
# Drone info:  278.38922 (5, 8)
#
#
# ******************************************************************************
#
#
# 75
# tank present
# Tank info:  1178.6978 (5, 8)
# drone present
# Drone info:  320.5603 (10, 4)
#
#
# ******************************************************************************
#
#
# 76
# tank present
# Tank info:  1407.4187 (5, 8)
# drone present
# Drone info:  235.03984 (9, 6)
#
#
# ******************************************************************************
#
#
# 77
# tank present
# Tank info:  1349.6329 (5, 9)
# drone present
# Drone info:  280.96646 (9, 8)
#
#
# ******************************************************************************
#
#
# 78
# tank present
# Tank info:  1223.6405 (5, 9)
# drone present
# Drone info:  300.18405 (9, 9)
#
#
# ******************************************************************************
#
#
# 79
# tank present
# Tank info:  1242.411 (5, 9)
# drone present
# Drone info:  326.4554 (10, 10)
#
#
# ******************************************************************************
#
#
# 80
#
#
# ******************************************************************************
#
#
# 81
# tank present
# Tank info:  1010.7774 (5, 9)
# drone present
# Drone info:  208.37932 (5, 8)
#
#
# ******************************************************************************
#
#
# 82
# tank reloading present
# Tank info:  752.08936 (7, 9)
#
#
# ******************************************************************************
#
#
# 83
# drone reloading present
# Drone info:  166.70076 (11, 9)
#
#
# ******************************************************************************
#
#
# 84
# drone present
# Drone info:  193.38884 (5, 8)
# tank reloading present
# Tank info:  963.4708 (10, 9)
# drone reloading present
# Drone info:  217.29181 (11, 9)
#
#
# ******************************************************************************
#
#
# 85
# tank present
# Tank info:  1276.8654 (5, 9)
# drone present
# Drone info:  301.11343 (12, 8)
#
#
# ******************************************************************************
#
#
# 86
# tank present
# Tank info:  1305.5442 (5, 9)
# drone present
# Drone info:  320.31793 (5, 8)
#
#
# ******************************************************************************
#
#
# 87
# tank present
# Tank info:  1349.4893 (5, 9)
# drone present
# Drone info:  267.08295 (12, 6)
#
#
# ******************************************************************************
#
#
# 88
# tank present
# Tank info:  1310.7881 (5, 9)
# drone present
# Drone info:  276.2899 (12, 4)
#
#
# ******************************************************************************
#
#
# 89
# tank present
# Tank info:  1313.8328 (5, 10)
# drone present
# Drone info:  258.2623 (5, 9)
#
#
# ******************************************************************************
#
#
# 90
# tank present
# Tank info:  1235.4935 (5, 10)
# drone present
# Drone info:  294.57495 (10, 4)
#
#
# ******************************************************************************
#
#
# 91
# tank present
# Tank info:  1309.117 (5, 10)
# drone present
# Drone info:  237.6036 (9, 6)
#
#
# ******************************************************************************
#
#
# 92
# tank present
# Tank info:  1317.2177 (5, 10)
# drone present
# Drone info:  306.97006 (9, 8)
#
#
# ******************************************************************************
#
#
# 93
# tank present
# Tank info:  1184.0215 (5, 10)
# drone present
# Drone info:  311.7373 (9, 9)
#
#
# ******************************************************************************
#
#
# 94
# tank present
# Tank info:  1276.8911 (5, 10)
# drone present
# Drone info:  291.26877 (10, 10)
#
#
# ******************************************************************************
#
#
# 95
# tank present
# Tank info:  1313.0413 (5, 10)
# drone present
# Drone info:  291.83124 (12, 8)
#
#
# ******************************************************************************
#
#
# 96
# tank present
# Tank info:  1427.6929 (5, 11)
# drone present
# Drone info:  293.85095 (5, 10)
#
#
# ******************************************************************************
#
#
# 97
# tank present
# Tank info:  1348.5715 (5, 11)
# drone present
# Drone info:  260.6305 (12, 6)
#
#
# ******************************************************************************
#
#
# 98
# tank present
# Tank info:  1206.9185 (5, 11)
# drone present
# Drone info:  301.0161 (12, 4)
#
#
# ******************************************************************************
#
#
# 99
# tank present
# Tank info:  1222.3289 (5, 11)
# drone present
# Drone info:  286.03137 (5, 10)
#
#
# ******************************************************************************
#
#
# 100
# tank reloading present
# Tank info:  760.9466 (4, 11)
# drone reloading present
# Drone info:  159.53812 (5, 11)
#
#
# ******************************************************************************
#
#
# 101
# drone reloading present
# Drone info:  148.55467 (11, 4)
#
#
# ******************************************************************************
#
#
# 102
# drone present
# Drone info:  192.8945 (10, 4)
# tank reloading present
# Tank info:  992.1736 (10, 4)
# drone reloading present
# Drone info:  246.50632 (5, 11)
#
#
# ******************************************************************************
#
#
# 103
# tank present
# Tank info:  1218.5243 (5, 11)
# drone present
# Drone info:  316.57962 (10, 4)
#
#
# ******************************************************************************
#
#
# 104
# tank present
# Tank info:  1304.4377 (5, 11)
# drone present
# Drone info:  240.2898 (9, 6)
#
#
# ******************************************************************************
#
#
# 105
# tank present
# Tank info:  1311.104 (5, 11)
# drone present
# Drone info:  284.05606 (9, 8)
#
#
# ******************************************************************************
#
#
# 106
# tank present
# Tank info:  1302.2439 (5, 12)
# drone present
# Drone info:  256.13947 (9, 9)
#
#
# ******************************************************************************
#
#
# 107
# tank present
# Tank info:  1278.9431 (5, 12)
# drone present
# Drone info:  278.24368 (10, 10)
#
#
# ******************************************************************************
#
#
# 108
#
#
# ******************************************************************************
#
#
# 109
# drone present
# Drone info:  198.75853 (10, 10)
#
#
# ******************************************************************************
#
#
# 110
# tank present
# Tank info:  1247.6414 (5, 12)
# drone present
# Drone info:  287.49188 (12, 8)
#
#
# ******************************************************************************
#
#
# 111
# tank present
# Tank info:  1328.5896 (5, 12)
# drone present
# Drone info:  327.63324 (5, 11)
#
#
# ******************************************************************************
#
#
# 112
# tank present
# Tank info:  1353.0083 (5, 12)
# drone present
# Drone info:  305.6347 (12, 6)
#
#
# ******************************************************************************
#
#
# 113
# tank present
# Tank info:  1218.9888 (5, 12)
# drone present
# Drone info:  305.53543 (12, 4)
#
#
# ******************************************************************************
#
#
# 114
# tank present
# Tank info:  1202.074 (5, 12)
# drone present
# Drone info:  253.91214 (5, 12)
#
#
# ******************************************************************************
#
#
# 115
# tank present
# Tank info:  1284.4102 (5, 13)
# drone present
# Drone info:  285.33102 (10, 4)
#
#
# ******************************************************************************
#
#
# 116
# tank present
# Tank info:  1325.3098 (5, 13)
# drone present
# Drone info:  230.74545 (9, 6)
#
#
# ******************************************************************************
#
#
# 117
# tank present
# Tank info:  1309.0156 (5, 13)
# drone present
# Drone info:  293.7145 (5, 12)
#
#
# ******************************************************************************
#
#
# 118
# tank present
# Tank info:  1197.5785 (5, 13)
# drone present
# Drone info:  280.7487 (9, 9)
#
#
# ******************************************************************************
#
#
# 119
# tank present
# Tank info:  1228.0751 (5, 13)
# drone present
# Drone info:  312.13266 (10, 10)
#
#
# ******************************************************************************
# 120
# drone present
# Drone info:  195.75284 (5, 13)
#
#
# ******************************************************************************
#
#
# 121
# tank reloading present
# Tank info:  698.7874 (4, 13)
#
#
# ******************************************************************************
#
#
# 122
# drone reloading present
# Drone info:  167.2195 (11, 9)
#
#
# ******************************************************************************
#
#
# 123
# drone present
# Drone info:  193.49196 (5, 13)
# tank reloading present
# Tank info:  932.621 (10, 9)
# drone reloading present
# Drone info:  238.14581 (11, 9)
#
#
# ******************************************************************************
#
#
# 124
# tank present
# Tank info:  1229.522 (5, 13)
# drone present
# Drone info:  325.1183 (5, 12)
#
#
# ******************************************************************************
#
#
# 125
# tank present
# Tank info:  1307.5729 (5, 13)
# drone present
# Drone info:  285.55228 (5, 13)
#
#
# ******************************************************************************
#
#
# 126
# tank present
# Tank info:  1395.0735 (5, 13)
# drone present
# Drone info:  262.0777 (12, 6)
#
#
# ******************************************************************************
#
#
# 127
# tank present
# Tank info:  1274.3451 (5, 14)
# drone present
# Drone info:  294.48535 (12, 4)
#
#
# ******************************************************************************
#
#
# 128
# tank present
# Tank info:  1222.0293 (5, 14)
# drone present
# Drone info:  259.44788 (5, 13)
#
#
# ******************************************************************************
#
#
# 129
# tank present
# Tank info:  1174.9893 (5, 14)
# drone present
# Drone info:  328.19446 (10, 4)
#
#
# ******************************************************************************
#
#
# 130
# tank present
# Tank info:  1305.5425 (5, 14)
# drone present
# Drone info:  263.5478 (9, 6)
#
#
# ******************************************************************************
#
#
# 131
# tank present
# Tank info:  1298.7998 (5, 14)
# drone present
# Drone info:  321.24866 (5, 13)
#
#
# ******************************************************************************
#
#
# 132
# tank present
# Tank info:  1239.8374 (5, 14)
# drone present
# Drone info:  256.29126 (9, 9)
#
#
# ******************************************************************************
#
#
# 133
# tank present
# Tank info:  1264.5203 (5, 14)
# drone present
# Drone info:  270.15237 (10, 10)
#
#
# ******************************************************************************
#
#
# 134
#
#
# ******************************************************************************
#
#
# 135
# tank present
# Tank info:  1309.653 (5, 15)
# drone present
# Drone info:  294.6723 (5, 14)
#
#
# ******************************************************************************
#
#
# 136
# tank present
# Tank info:  1349.5084 (5, 15)
# drone present
# Drone info:  264.3703 (12, 7)
#
#
# ******************************************************************************
#
#
# 137
# tank present
# Tank info:  1266.8853 (5, 15)
# drone present
# Drone info:  287.13678 (12, 6)
#
#
# ******************************************************************************
#
#
# 138
# tank present
# Tank info:  1228.298 (5, 15)
# drone present
# Drone info:  325.03082 (12, 4)
#
#
# ******************************************************************************
#
#
# 139
# tank present
# Tank info:  1173.6022 (5, 15)
# drone present
# Drone info:  290.52344 (5, 15)
#
#
# ******************************************************************************
#
#
# 140
# tank reloading present
# Tank info:  717.02264 (4, 15)
# drone reloading present
# Drone info:  136.84863 (5, 16)
#
#
# ******************************************************************************
#
#
# 141
# drone reloading present
# Drone info:  148.55467 (11, 4)
#
#
# ******************************************************************************
#
#
# 142
# drone present
# Drone info:  195.90378 (4, 15)
# tank reloading present
# Tank info:  938.124 (10, 4)
# drone reloading present
# Drone info:  220.55081 (11, 4)
#
#
# ******************************************************************************
#
#
# 143
# tank present
# Tank info:  1178.9396 (5, 15)
# drone present
# Drone info:  306.8459 (10, 4)
#
#
# ******************************************************************************
#
#
# 144
# tank present
# Tank info:  1322.2131 (5, 15)
# drone present
# Drone info:  260.23273 (9, 6)
#
#
# ******************************************************************************
#
#
# 145
# tank present
# Tank info:  1383.4563 (5, 16)
# drone present
# Drone info:  290.37622 (5, 15)
#
#
# ******************************************************************************
#
#
# 146
# tank present
# Tank info:  1232.7384 (5, 16)
# drone present
# Drone info:  250.82314 (9, 9)
#
#
# ******************************************************************************
#
#
# 147
# tank present
# Tank info:  1186.8805 (5, 16)
# drone present
# Drone info:  298.00177 (10, 10)
#
#
# ******************************************************************************
#
#
# 148
# tank present
# Tank info:  1226.0099 (5, 16)
# drone present
# Drone info:  328.0625 (5, 15)
#
#
# ******************************************************************************
#
#
# 149
# tank present
# Tank info:  1328.6227 (5, 16)
# drone present
# Drone info:  288.27625 (12, 7)
#
#
# ******************************************************************************
#
#
# 150
# tank present
# Tank info:  1260.3923 (5, 16)
# drone present
# Drone info:  279.31888 (12, 6)
#
#
# ******************************************************************************
#
#
# 151
# tank present
# Tank info:  1197.5913 (5, 16)
# drone present
# Drone info:  309.94147 (12, 4)
#
#
# ******************************************************************************
#
#
# 152
# tank present
# Tank info:  1254.937 (5, 17)
# drone present
# Drone info:  229.09697 (5, 16)
#
#
# ******************************************************************************
#
#
# 153
# tank present
# Tank info:  1160.2583 (5, 17)
# drone present
# Drone info:  284.64856 (10, 4)
#
#
# ******************************************************************************
#
#
# 154
# tank present
# Tank info:  1241.5027 (5, 17)
# drone present
# Drone info:  246.07913 (9, 6)
#
#
# ******************************************************************************
#
#
# 155
# tank present
# Tank info:  1240.0134 (5, 17)
# drone present
# Drone info:  306.47217 (5, 16)
#
#
# ******************************************************************************
#
#
# 156
# tank present
# Tank info:  1132.5798 (5, 17)
# drone present
# Drone info:  267.39624 (9, 9)
#
#
# ******************************************************************************
#
#
# 157
# tank present
# Tank info:  1162.7875 (5, 17)
# drone present
# Drone info:  291.52087 (5, 16)
#
#
# ******************************************************************************
#
#
# 158
#
#
# ******************************************************************************
#
#
# 159
#
#
# ******************************************************************************
#
#
# 160
# drone present
# Drone info:  188.5172 (10, 10)
#
#
# ******************************************************************************
#
#
# 161
# tank reloading present
# Tank info:  670.5274 (4, 17)
#
#
# ******************************************************************************
#
#
# 162
# drone reloading present
# Drone info:  143.34448 (11, 9)
#
#
# ******************************************************************************
#
#
# 163
# tank reloading present
# Tank info:  918.68976 (10, 9)
# drone reloading present
# Drone info:  188.13237 (11, 9)
#
#
# ******************************************************************************
#
#
# 164
# tank present
# Tank info:  1174.3696 (5, 17)
# drone present
# Drone info:  310.25433 (5, 16)
#
#
# ******************************************************************************
#
#
# 165
# tank present
# Tank info:  1232.3704 (5, 17)
# drone present
# Drone info:  272.50873 (12, 7)
#
#
# ******************************************************************************
#
#
# 166
# tank present
# Tank info:  1278.5713 (5, 17)
# drone present
# Drone info:  251.71922 (12, 6)
#
#
# ******************************************************************************
#
#
# 167
# tank present
# Tank info:  1287.0278 (5, 17)
# drone present
# Drone info:  279.24887 (5, 16)
#
#
# ******************************************************************************
#
#
# 168
# tank present
# Tank info:  1171.4053 (5, 16)
# drone present
# Drone info:  258.50385 (5, 16)
#
#
# ******************************************************************************
#
#
# 169
# tank present
# Tank info:  1134.1482 (5, 16)
# drone present
# Drone info:  310.03854 (10, 4)
#
#
# ******************************************************************************
#
#
# 170
# tank present
# Tank info:  1329.0697 (5, 16)
# drone present
# Drone info:  255.42252 (9, 6)
#
#
# ******************************************************************************
#
#
# 171
# tank present
# Tank info:  1298.8054 (5, 16)
# drone present
# Drone info:  326.75644 (5, 15)
#
#
# ******************************************************************************
#
#
# 172
# tank present
# Tank info:  1157.1047 (5, 16)
# drone present
# Drone info:  275.0085 (9, 9)
#
#
# ******************************************************************************
#
#
# 173
# tank present
# Tank info:  1267.3846 (5, 16)
# drone present
# Drone info:  282.30365 (10, 10)
#
#
# ******************************************************************************
#
#
# 174
# tank present
# Tank info:  1316.6257 (5, 16)
# drone present
# Drone info:  292.94635 (5, 15)
#
#
# ******************************************************************************
#
#
# 175
# tank present
# Tank info:  1315.8376 (5, 15)
# drone present
# Drone info:  282.26364 (12, 7)
#
#
# ******************************************************************************
#
#
# 176
# tank present
# Tank info:  1311.2858 (5, 15)
# drone present
# Drone info:  273.1728 (12, 6)
#
#
# ******************************************************************************
#
#
# 177
# tank present
# Tank info:  1207.2848 (5, 15)
# drone present
# Drone info:  343.14246 (5, 15)
#
#
# ******************************************************************************
#
#
# 178
# tank present
# Tank info:  1199.116 (5, 15)
# drone present
# Drone info:  267.39493 (5, 14)
#
#
# ******************************************************************************
#
#
# 179
# tank reloading present
# Tank info:  698.51166 (4, 15)
# drone reloading present
# Drone info:  167.78937 (5, 15)
#
#
# ******************************************************************************
# 180
# drone reloading present
# Drone info:  149.70776 (11, 4)
#
#
# ******************************************************************************
#
#
# 181
# drone present
# Drone info:  195.99533 (10, 4)
# tank reloading present
# Tank info:  939.9263 (10, 4)
# drone reloading present
# Drone info:  253.12784 (11, 4)
#
#
# ******************************************************************************
#
#
# 182
# tank present
# Tank info:  1138.592 (5, 15)
# drone present
# Drone info:  315.11755 (10, 4)
#
#
# ******************************************************************************
#
#
# 183
# tank present
# Tank info:  1328.183 (5, 15)
# drone present
# Drone info:  235.41614 (5, 14)
#
#
# ******************************************************************************
#
#
# 184
# tank present
# Tank info:  1373.1177 (5, 15)
# drone present
# Drone info:  292.16473 (5, 14)
#
#
# ******************************************************************************
#
#
# 185
# tank present
# Tank info:  1232.0156 (5, 14)
# drone present
# Drone info:  242.04472 (9, 9)
#
#
# ******************************************************************************
#
#
# 186
# tank present
# Tank info:  1248.1687 (5, 14)
# drone present
# Drone info:  287.83362 (10, 10)
#
#
# ******************************************************************************
#
#
# 187
#
#
# ******************************************************************************
#
#
# 188
# tank present
# Tank info:  1240.5323 (5, 14)
# drone present
# Drone info:  326.99594 (5, 13)
#
#
# ******************************************************************************
#
#
# 189
# tank present
# Tank info:  1317.6718 (5, 14)
# drone present
# Drone info:  298.45068 (12, 7)
#
#
# ******************************************************************************
#
#
# 190
# tank present
# Tank info:  1298.7668 (5, 14)
# drone present
# Drone info:  298.03302 (12, 6)
#
#
# ******************************************************************************
#
#
# 191
# tank present
# Tank info:  1260.9006 (5, 14)
# drone present
# Drone info:  309.5876 (5, 13)
#
#
# ******************************************************************************
#
#
# 192
# tank present
# Tank info:  1245.9456 (5, 14)
# drone present
# Drone info:  248.401 (4, 14)
#
#
# ******************************************************************************
#
#
# 193
# tank present
# Tank info:  1270.4607 (5, 13)
# drone present
# Drone info:  289.73572 (10, 4)
#
#
# ******************************************************************************
#
#
# 194
# tank present
# Tank info:  1310.1003 (5, 13)
# drone present
# Drone info:  254.11282 (5, 13)
#
#
# ******************************************************************************
#
#
# 195
# tank present
# Tank info:  1291.8208 (5, 13)
# drone present
# Drone info:  310.72968 (9, 8)
#
#
# ******************************************************************************
#
#
# 196
# tank present
# Tank info:  1192.0271 (5, 13)
# drone present
# Drone info:  286.35254 (9, 9)
#
#
# ******************************************************************************
#
#
# 197
# tank present
# Tank info:  1235.1698 (5, 13)
# drone present
# Drone info:  312.63647 (5, 12)
#
#
# ******************************************************************************
#
#
# 198
# tank present
# Tank info:  1000.57166 (5, 13)
# drone present
# Drone info:  188.35394 (5, 12)
#
#
# ******************************************************************************
#
#
# 199
# tank reloading present
# Tank info:  715.2822 (4, 13)
#
#
# ******************************************************************************

# %%
img = uframes[24]
z = Image.fromarray(img)
z.show()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)


def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

for i in range(32):

    tank_info_panel = i
    drone_info_panel = i
    #Blank
    img = Image.open("spacecraft/0blank.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Blank: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Blank: ",val,pos)


    
    img = Image.open("spacecraft/0tank.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Tank: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Tank: ",val,pos)


    #Drone

    img = Image.open("spacecraft/0drone.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Drone: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Drone: ",val,pos)
    
        
    img = Image.open("spacecraft/0tank_reloading.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Tank reloading: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Tank reloading: ",val,pos)


    #Drone

    img = Image.open("spacecraft/0drone_reloading.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Drone reloading: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Drone reloading: ",val,pos)


    #Tank and Drone
    img = Image.open("spacecraft/0.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TD: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("TD: ",val,pos)
    
    print("done ",i)
    print("++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# Blank:  385.18863 (10, 3)
# Blank:  385.18863 (10, 3)
# Tank:  512.6679 (5, 0)
# Tank:  512.6679 (5, 0)
# Drone:  491.6334 (11, 10)
# Drone:  491.6334 (11, 10)
# Tank reloading:  535.1559 (6, 1)
# Tank reloading:  535.1559 (6, 1)
# Drone reloading:  483.6514 (11, 9)
# Drone reloading:  483.6514 (11, 9)
# TD:  678.0335 (5, 0)
# TD:  678.0335 (5, 0)
# done  0
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  24570.285 (16, 15)
# Blank:  24570.285 (16, 15)
# Tank:  24819.215 (16, 15)
# Tank:  24819.215 (16, 15)
# Drone:  24844.879 (11, 9)
# Drone:  24844.879 (11, 9)
# Tank reloading:  25150.172 (5, 0)
# Tank reloading:  25150.172 (5, 0)
# Drone reloading:  24756.168 (11, 11)
# Drone reloading:  24756.168 (11, 11)
# TD:  25126.066 (11, 10)
# TD:  25126.066 (11, 10)
# done  1
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  2405.2634 (3, 8)
# Blank:  2405.2634 (3, 8)
# Tank:  2718.6584 (6, 1)
# Tank:  2718.6584 (6, 1)
# Drone:  2748.322 (10, 9)
# Drone:  2748.322 (10, 9)
# Tank reloading:  2891.2192 (5, 0)
# Tank reloading:  2891.2192 (5, 0)
# Drone reloading:  2657.215 (10, 10)
# Drone reloading:  2657.215 (10, 10)
# TD:  3148.4783 (10, 9)
# TD:  3148.4783 (10, 9)
# done  2
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  8416.891 (11, 12)
# Blank:  8416.891 (11, 12)
# Tank:  8660.594 (5, 1)
# Tank:  8660.594 (5, 1)
# Drone:  8691.426 (11, 12)
# Drone:  8691.426 (11, 12)
# Tank reloading:  8846.654 (5, 0)
# Tank reloading:  8846.654 (5, 0)
# Drone reloading:  8622.525 (10, 9)
# Drone reloading:  8622.525 (10, 9)
# TD:  8990.076 (5, 1)
# TD:  8990.076 (5, 1)
# done  3
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1.9199736 (10, 12)
# Blank:  1.9199736 (10, 12)
# Tank:  102.78109 (5, 1)
# Tank:  102.78109 (5, 1)
# Drone:  1.9199736 (10, 12)
# Drone:  1.9199736 (10, 12)
# Tank reloading:  1.9199736 (10, 12)
# Tank reloading:  1.9199736 (10, 12)
# Drone reloading:  71.95642 (10, 10)
# Drone reloading:  71.95642 (10, 10)
# TD:  146.4491 (5, 1)
# TD:  146.4491 (5, 1)
# done  4
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1552.1287 (7, 10)
# Blank:  1552.1287 (7, 10)
# Tank:  1791.9446 (4, 0)
# Tank:  1791.9446 (4, 0)
# Drone:  1812.4918 (11, 9)
# Drone:  1812.4918 (11, 9)
# Tank reloading:  2036.0718 (5, 1)
# Tank reloading:  2036.0718 (5, 1)
# Drone reloading:  1800.1954 (12, 9)
# Drone reloading:  1800.1954 (12, 9)
# TD:  2215.4873 (11, 11)
# TD:  2215.4873 (11, 11)
# done  5
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1430.9326 (11, 12)
# Blank:  1430.9326 (11, 12)
# Tank:  1681.3263 (11, 12)
# Tank:  1681.3263 (11, 12)
# Drone:  1739.56 (11, 9)
# Drone:  1739.56 (11, 9)
# Tank reloading:  1740.7021 (6, 0)
# Tank reloading:  1740.7021 (6, 0)
# Drone reloading:  1734.7278 (10, 10)
# Drone reloading:  1734.7278 (10, 10)
# TD:  1960.4856 (11, 9)
# TD:  1960.4856 (11, 9)
# done  6
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1498.4381 (11, 2)
# Blank:  1498.4381 (11, 2)
# Tank:  1816.531 (5, 1)
# Tank:  1816.531 (5, 1)
# Drone:  1776.8582 (10, 10)
# Drone:  1776.8582 (10, 10)
# Tank reloading:  1757.5642 (5, 0)
# Tank reloading:  1757.5642 (5, 0)
# Drone reloading:  1811.7799 (10, 10)
# Drone reloading:  1811.7799 (10, 10)
# TD:  2277.4185 (11, 11)
# TD:  2277.4185 (11, 11)
# done  7
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  3818.9587 (10, 11)
# Blank:  3818.9587 (10, 11)
# Tank:  4092.9734 (5, 0)
# Tank:  4092.9734 (5, 0)
# Drone:  4158.884 (11, 9)
# Drone:  4158.884 (11, 9)
# Tank reloading:  4208.376 (5, 1)
# Tank reloading:  4208.376 (5, 1)
# Drone reloading:  4024.7244 (10, 9)
# Drone reloading:  4024.7244 (10, 9)
# TD:  4430.9834 (11, 9)
# TD:  4430.9834 (11, 9)
# done  8
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  11870.693 (3, 8)
# Blank:  11870.693 (3, 8)
# Tank:  12060.139 (3, 8)
# Tank:  12060.139 (3, 8)
# Drone:  12154.389 (11, 10)
# Drone:  12154.389 (11, 10)
# Tank reloading:  12305.254 (4, 1)
# Tank reloading:  12305.254 (4, 1)
# Drone reloading:  12166.385 (11, 9)
# Drone reloading:  12166.385 (11, 9)
# TD:  12358.068 (10, 11)
# TD:  12358.068 (10, 11)
# done  9
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  76.26364 (10, 12)
# Blank:  76.26364 (10, 12)
# Tank:  126.85431 (5, 0)
# Tank:  126.85431 (5, 0)
# Drone:  129.12482 (10, 9)
# Drone:  129.12482 (10, 9)
# Tank reloading:  142.40044 (5, 0)
# Tank reloading:  142.40044 (5, 0)
# Drone reloading:  153.39871 (11, 10)
# Drone reloading:  153.39871 (11, 10)
# TD:  338.16696 (11, 11)
# TD:  338.16696 (11, 11)
# done  10
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  11789.486 (12, 11)
# Blank:  11789.486 (12, 11)
# Tank:  12007.085 (6, 0)
# Tank:  12007.085 (6, 0)
# Drone:  12108.867 (10, 10)
# Drone:  12108.867 (10, 10)
# Tank reloading:  12213.578 (5, 1)
# Tank reloading:  12213.578 (5, 1)
# Drone reloading:  11951.977 (11, 9)
# Drone reloading:  11951.977 (11, 9)
# TD:  12327.566 (10, 10)
# TD:  12327.566 (10, 10)
# done  11
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  163.04752 (16, 14)
# Blank:  163.04752 (16, 14)
# Tank:  243.49185 (4, 0)
# Tank:  243.49185 (4, 0)
# Drone:  187.56992 (11, 9)
# Drone:  187.56992 (11, 9)
# Tank reloading:  248.13255 (5, 1)
# Tank reloading:  248.13255 (5, 1)
# Drone reloading:  312.01495 (10, 9)
# Drone reloading:  312.01495 (10, 9)
# TD:  312.39532 (4, 0)
# TD:  312.39532 (4, 0)
# done  12
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  267.7516 (8, 9)
# Blank:  267.7516 (8, 9)
# Tank:  440.98477 (5, 1)
# Tank:  440.98477 (5, 1)
# Drone:  396.00876 (10, 9)
# Drone:  396.00876 (10, 9)
# Tank reloading:  404.91858 (6, 0)
# Tank reloading:  404.91858 (6, 0)
# Drone reloading:  418.8891 (11, 10)
# Drone reloading:  418.8891 (11, 10)
# TD:  655.881 (10, 10)
# TD:  655.881 (10, 10)
# done  13
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  924.6586 (10, 13)
# Blank:  924.6586 (10, 13)
# Tank:  1120.843 (10, 13)
# Tank:  1120.843 (10, 13)
# Drone:  1149.7418 (10, 9)
# Drone:  1149.7418 (10, 9)
# Tank reloading:  1186.8918 (10, 13)
# Tank reloading:  1186.8918 (10, 13)
# Drone reloading:  1238.5674 (12, 9)
# Drone reloading:  1238.5674 (12, 9)
# TD:  1352.8196 (11, 9)
# TD:  1352.8196 (11, 9)
# done  14
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  791.2262 (10, 12)
# Blank:  791.2262 (10, 12)
# Tank:  969.02246 (10, 12)
# Tank:  969.02246 (10, 12)
# Drone:  1007.20654 (10, 10)
# Drone:  1007.20654 (10, 10)
# Tank reloading:  896.66394 (10, 12)
# Tank reloading:  896.66394 (10, 12)
# Drone reloading:  1131.8282 (10, 10)
# Drone reloading:  1131.8282 (10, 10)
# TD:  1292.1936 (11, 11)
# TD:  1292.1936 (11, 11)
# done  15
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  164.93532 (5, 1)
# Tank:  164.93532 (5, 1)
# Drone:  53.181297 (11, 10)
# Drone:  53.181297 (11, 10)
# Tank reloading:  16.053507 (6, 1)
# Tank reloading:  16.053507 (6, 1)
# Drone reloading:  11.687356 (10, 9)
# Drone reloading:  11.687356 (10, 9)
# TD:  313.49728 (5, 1)
# TD:  313.49728 (5, 1)
# done  16
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  887.8002 (8, 10)
# Blank:  887.8002 (8, 10)
# Tank:  1110.7236 (5, 1)
# Tank:  1110.7236 (5, 1)
# Drone:  1096.8689 (10, 10)
# Drone:  1096.8689 (10, 10)
# Tank reloading:  1252.4817 (5, 0)
# Tank reloading:  1252.4817 (5, 0)
# Drone reloading:  1033.132 (8, 10)
# Drone reloading:  1033.132 (8, 10)
# TD:  1369.721 (10, 10)
# TD:  1369.721 (10, 10)
# done  17
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  11187.629 (16, 15)
# Blank:  11187.629 (16, 15)
# Tank:  11372.865 (6, 2)
# Tank:  11372.865 (6, 2)
# Drone:  11476.998 (11, 10)
# Drone:  11476.998 (11, 10)
# Tank reloading:  11559.797 (6, 0)
# Tank reloading:  11559.797 (6, 0)
# Drone reloading:  11553.63 (10, 9)
# Drone reloading:  11553.63 (10, 9)
# TD:  11743.968 (12, 11)
# TD:  11743.968 (12, 11)
# done  18
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  5811.877 (11, 12)
# Blank:  5811.877 (11, 12)
# Tank:  6062.1094 (11, 12)
# Tank:  6062.1094 (11, 12)
# Drone:  6105.2305 (11, 9)
# Drone:  6105.2305 (11, 9)
# Tank reloading:  6240.091 (5, 0)
# Tank reloading:  6240.091 (5, 0)
# Drone reloading:  6161.1436 (11, 9)
# Drone reloading:  6161.1436 (11, 9)
# TD:  6440.1455 (11, 10)
# TD:  6440.1455 (11, 10)
# done  19
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  24532.71 (12, 3)
# Blank:  24532.71 (12, 3)
# Tank:  24674.344 (12, 3)
# Tank:  24674.344 (12, 3)
# Drone:  24868.129 (10, 9)
# Drone:  24868.129 (10, 9)
# Tank reloading:  24884.844 (5, 1)
# Tank reloading:  24884.844 (5, 1)
# Drone reloading:  24686.473 (11, 9)
# Drone reloading:  24686.473 (11, 9)
# TD:  25034.541 (12, 9)
# TD:  25034.541 (12, 9)
# done  20
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  160.78061 (10, 13)
# Blank:  160.78061 (10, 13)
# Tank:  308.02267 (6, 1)
# Tank:  308.02267 (6, 1)
# Drone:  208.01671 (10, 13)
# Drone:  208.01671 (10, 13)
# Tank reloading:  226.81674 (5, 0)
# Tank reloading:  226.81674 (5, 0)
# Drone reloading:  272.68506 (12, 10)
# Drone reloading:  272.68506 (12, 10)
# TD:  420.11844 (6, 1)
# TD:  420.11844 (6, 1)
# done  21
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  53.2502 (10, 12)
# Blank:  53.2502 (10, 12)
# Tank:  174.52512 (5, 0)
# Tank:  174.52512 (5, 0)
# Drone:  124.26646 (10, 10)
# Drone:  124.26646 (10, 10)
# Tank reloading:  107.94854 (5, 2)
# Tank reloading:  107.94854 (5, 2)
# Drone reloading:  197.1109 (10, 9)
# Drone reloading:  197.1109 (10, 9)
# TD:  399.3283 (10, 10)
# TD:  399.3283 (10, 10)
# done  22
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1082.6456 (2, 8)
# Blank:  1082.6456 (2, 8)
# Tank:  1325.901 (5, 1)
# Tank:  1325.901 (5, 1)
# Drone:  1374.3658 (10, 9)
# Drone:  1374.3658 (10, 9)
# Tank reloading:  1401.387 (5, 0)
# Tank reloading:  1401.387 (5, 0)
# Drone reloading:  1286.0583 (11, 9)
# Drone reloading:  1286.0583 (11, 9)
# TD:  1615.2046 (5, 1)
# TD:  1615.2046 (5, 1)
# done  23
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  286.9539 (11, 11)
# Blank:  286.9539 (11, 11)
# Tank:  420.67145 (5, 0)
# Tank:  420.67145 (5, 0)
# Drone:  435.60278 (11, 10)
# Drone:  435.60278 (11, 10)
# Tank reloading:  557.5652 (5, 0)
# Tank reloading:  557.5652 (5, 0)
# Drone reloading:  418.51385 (11, 9)
# Drone reloading:  418.51385 (11, 9)
# TD:  725.0155 (11, 10)
# TD:  725.0155 (11, 10)
# done  24
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  748.41235 (12, 13)
# Blank:  748.41235 (12, 13)
# Tank:  1001.6749 (6, 1)
# Tank:  1001.6749 (6, 1)
# Drone:  973.8461 (11, 9)
# Drone:  973.8461 (11, 9)
# Tank reloading:  1134.4109 (6, 0)
# Tank reloading:  1134.4109 (6, 0)
# Drone reloading:  917.38904 (10, 9)
# Drone reloading:  917.38904 (10, 9)
# TD:  1291.3999 (6, 1)
# TD:  1291.3999 (6, 1)
# done  25
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  16786.326 (2, 8)
# Blank:  16786.326 (2, 8)
# Tank:  16954.887 (5, 0)
# Tank:  16954.887 (5, 0)
# Drone:  17100.383 (11, 9)
# Drone:  17100.383 (11, 9)
# Tank reloading:  17279.3 (5, 1)
# Tank reloading:  17279.3 (5, 1)
# Drone reloading:  16967.893 (11, 9)
# Drone reloading:  16967.893 (11, 9)
# TD:  17382.074 (5, 0)
# TD:  17382.074 (5, 0)
# done  26
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  13853.205 (10, 11)
# Blank:  13853.205 (10, 11)
# Tank:  14013.162 (10, 11)
# Tank:  14013.162 (10, 11)
# Drone:  14118.068 (11, 9)
# Drone:  14118.068 (11, 9)
# Tank reloading:  14180.816 (5, 0)
# Tank reloading:  14180.816 (5, 0)
# Drone reloading:  14094.271 (11, 11)
# Drone reloading:  14094.271 (11, 11)
# TD:  14350.802 (11, 11)
# TD:  14350.802 (11, 11)
# done  27
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  273.0174 (17, 14)
# Blank:  273.0174 (17, 14)
# Tank:  368.85803 (5, 0)
# Tank:  368.85803 (5, 0)
# Drone:  390.67377 (10, 9)
# Drone:  390.67377 (10, 9)
# Tank reloading:  326.31573 (17, 14)
# Tank reloading:  326.31573 (17, 14)
# Drone reloading:  476.73096 (11, 9)
# Drone reloading:  476.73096 (11, 9)
# TD:  541.4325 (5, 0)
# TD:  541.4325 (5, 0)
# done  28
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  24475.414 (13, 7)
# Blank:  24475.414 (13, 7)
# Tank:  24556.508 (13, 7)
# Tank:  24556.508 (13, 7)
# Drone:  24717.75 (11, 10)
# Drone:  24717.75 (11, 10)
# Tank reloading:  24941.531 (5, 1)
# Tank reloading:  24941.531 (5, 1)
# Drone reloading:  24601.855 (11, 10)
# Drone reloading:  24601.855 (11, 10)
# TD:  24812.273 (11, 9)
# TD:  24812.273 (11, 9)
# done  29
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1460.5662 (13, 17)
# Blank:  1460.5662 (13, 17)
# Tank:  1658.6077 (13, 17)
# Tank:  1658.6077 (13, 17)
# Drone:  1695.6794 (11, 10)
# Drone:  1695.6794 (11, 10)
# Tank reloading:  1592.0769 (13, 17)
# Tank reloading:  1592.0769 (13, 17)
# Drone reloading:  1729.5194 (11, 8)
# Drone reloading:  1729.5194 (11, 8)
# TD:  2009.9253 (11, 10)
# TD:  2009.9253 (11, 10)
# done  30
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  92.19703 (5, 0)
# Tank:  92.19703 (5, 0)
# Drone:  41.560806 (11, 9)
# Drone:  41.560806 (11, 9)
# Tank reloading:  30.90567 (5, 0)
# Tank reloading:  30.90567 (5, 0)
# Drone reloading:  14.500549 (11, 9)
# Drone reloading:  14.500549 (11, 9)
# TD:  177.17775 (10, 10)
# TD:  177.17775 (10, 10)
# done  31
# ++++++++++++++++++++++++++++++++++++++++++++

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

tank_info_panel = 4
drone_info_panel = 24

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

#Blank
for i in range(12):
    img = uframes[i]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank,pos_tank = val_pos(output_tank)
    print(i)
    output_drone = output[0][drone_info_panel]
    val_drone,pos_drone = val_pos(output_drone)
    if val_tank>500:
        print("tank present")
        print("Tank info: ",val_tank,pos_tank)
    if val_drone>770:
        print("drone present")
        print("Drone info: ",val_drone,pos_drone)
# Out:
# 0
# 1
# tank present
# Tank info:  520.7602 (6, 2)
# 2
# drone present
# Drone info:  781.4645 (1, 4)
# 3
# tank present
# Tank info:  634.67224 (6, 2)
# drone present
# Drone info:  942.7866 (1, 4)
# 4
# tank present
# Tank info:  654.7293 (6, 8)
# drone present
# Drone info:  927.96313 (1, 4)
# 5
# tank present
# Tank info:  642.7981 (6, 13)
# drone present
# Drone info:  985.1527 (1, 4)
# 6
# tank present
# Tank info:  722.30286 (6, 2)
# drone present
# Drone info:  938.44824 (5, 1)
# 7
# tank present
# Tank info:  740.57965 (6, 8)
# drone present
# Drone info:  860.5968 (5, 7)
# 8
# tank present
# Tank info:  730.4288 (6, 13)
# drone present
# Drone info:  976.33765 (5, 12)
# 9
# tank present
# Tank info:  669.9697 (6, 2)
# drone present
# Drone info:  1017.36505 (13, 15)
# 10
# tank present
# Tank info:  690.02686 (6, 8)
# drone present
# Drone info:  1002.5415 (13, 15)
# 11
# tank present
# Tank info:  678.09564 (6, 13)
# drone present
# Drone info:  1059.7312 (13, 15)

# %%
im1 = Image.open('tree1.png')
im1 = im1.resize((100,100))

imt = Image.open('tank.png')
imt = imt.resize((100,100))


im2 = Image.open('tree2.png')
im2 = im2.resize((100,100))

im3 = Image.open('tree3.png')
im3 = im3.resize((100,100))

im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((200,200))

imb = Image.open('bullet.png')
imb = imb.resize((40,40))



img_blank = Image.new('RGB', (720, 1080), color = '#9b7653')
img_blank.paste(im1,(5,75),im1)
img_blank.paste(im1,(450,550),im1)
img_blank.paste(im1,(205,720),im1)
img_blank.paste(im2,(500,900),im2)
img_blank.paste(im2,(650,750),im2)
img_blank.paste(im2,(320,440),im2)
img_blank.paste(im3,(100,600),im3)
img_blank.paste(im3,(440,620),im3)
img_blank.paste(im3,(300,150),im3)
img_blank.paste(imt.rotate(180),(500,500),imt.rotate(180))
img_blank = np.asarray(img_blank)
img_blank = cv2.resize(img_blank,(100,100))
pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
output = model(pil.reshape(1,3,100, 100))[0].detach().numpy()
output = output[0][info_panel]
val,pos = val_pos(output)
print(val,pos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c18b098abae9> in <module>
#      36 pil = torch.from_numpy(pil)
#      37 output = model(pil.reshape(1,3,100, 100))[0].detach().numpy()
# ---> 38 output = output[0][info_panel]
#      39 val,pos = val_pos(output)
#      40 print(val,pos)
#
# NameError: name 'info_panel' is not defined

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(12):
    k = uframes[i]
    #k.show()
    v = np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32)
    v = torch.from_numpy(v)
    filename = "Marginalization_Simple-increased_channels-32/ref_image_new_" + str(i) + ".txt"
    file = open(filename, 'w')
    file.write(str(model(v.reshape(1,3,100, 100))[0].detach().numpy()))
    file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

filename = "Marginalization_Simple-increased_channels-32/fc_weights.txt"
file = open(filename, 'w')
file.write(str(model.fc1.weight.detach().numpy()))
print(np.shape(model.fc1.weight.detach().numpy()))
file.close()
# Out:
# (15, 10368)

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(12):
    img = uframes[i]
    #print(np.shape(img))
    z = Image.fromarray(img)
    z.show()

# %%
import operator
import sys
#t1d1
img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
# img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))

# #t2d2
# img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
# draw = ImageDraw.Draw(img_blank)
# draw.ellipse((35,35,38,38), fill=(255, 0, 0))
# img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
# draw.ellipse((40,50,43,53), fill=(50, 182, 150))

# #t3d3
# img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
# img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
# img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
# img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

v = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
v = torch.from_numpy(v)
k = model(v.reshape(1,3,100, 100))[0].view(model(v.reshape(1,3,100, 100))[0].size(0), -1).detach().numpy()

filename = "Marginalization_Simple/flattened_tank_pos_1.txt"
file = open(filename, 'w')
file.write(str(k))
file.close()


# print(np.shape(k))
# index, value = max(enumerate(k), key=operator.itemgetter(1))
# print(index,value)


import operator
p=model.fc1.weight.detach().numpy()
for i in range(15):
    index, value = max(enumerate(p[i]), key=operator.itemgetter(1))
    print("FC - Feature "+ str(i) +" : ",index,value)
    print
    print("CNN value: ",k[0][index] )
# Out:
# FC - Feature 0 :  684 0.041578084
# CNN value:  17.59211
# FC - Feature 1 :  684 0.051804464
# CNN value:  17.59211
# FC - Feature 2 :  360 0.04816093
# CNN value:  0.53643996
# FC - Feature 3 :  492 0.035558272
# CNN value:  0.53643996
# FC - Feature 4 :  478 0.06459166
# CNN value:  0.53643996
# FC - Feature 5 :  585 0.049136233
# CNN value:  0.53643996
# FC - Feature 6 :  492 0.081621096
# CNN value:  0.53643996
# FC - Feature 7 :  360 0.065480515
# CNN value:  0.53643996
# FC - Feature 8 :  585 0.04792851
# CNN value:  0.53643996
# FC - Feature 9 :  492 0.06556648
# CNN value:  0.53643996
# FC - Feature 10 :  684 0.035789683
# CNN value:  17.59211
# FC - Feature 11 :  684 0.034514345
# CNN value:  17.59211
# FC - Feature 12 :  817 0.043642323
# CNN value:  17.59211
# FC - Feature 13 :  492 0.088237286
# CNN value:  0.53643996
# FC - Feature 14 :  492 0.09752004
# CNN value:  0.53643996

# %%
import random


p=0
class_data = []
while(p<len(uframes)):
    data3=[]
    print(p)
    for i in range(50):
        img = uframes[p]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        temp = model(x_1[i].reshape(1,3,100,100))[1]
        #print(temp)
        class_data.append((list(temp.detach().numpy()[0]),p))
    p+=1
    print(len(class_data))

random.shuffle(class_data)
random.shuffle(class_data)

print("length ", len(class_data))
# Out:
# 0
# 50
# 1
# 100
# 2
# 150
# 3
# 200
# 4
# 250
# 5
# 300
# 6
# 350
# 7
# 400
# 8
# 450
# 9
# 500
# 10
# 550
# 11
# 600
# length  600

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from colorama import init  
import time
import cv2

print(np.shape(uframes[0]))


#z  = np.array(np.transpose(np.asarray(z),(2,0,1)),dtype=np.float32)
# import some data to play with
print("Length of Class data: ", len(class_data))
# Take the first two features. We could avoid this by using a two-dim dataset
X = [(i[0]) for i in class_data]
y = [i[1] for i in class_data]
#print(X,np.shape(X))
#print(y,np.shape(y))
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel='linear', C=C)
clf = clf.fit(X, y)
data3=[]
y3=0

n1 = "\x1b[31m\"Drone Stationary, Tank Firing\"\x1b[0m"
n2 = "\x1b[31m\"Drone Reloading, Tank Firing\"\x1b[0m"
n3 = "\x1b[31m\"Drone Firing, Tank Stationary\"\x1b[0m"
n4 = "\x1b[31m\"Drone Firing, Tank Reloading\"\x1b[0m"
n5 = "\x1b[31m\"Drone Firing, Tank Firing\"\x1b[0m"

names = ['Just Background','Only Tank moving', 'Only Drone Moving', 'Drone stationary, Tank Stationary', 'Drone Stationary, Tank Reloading' ,
         n1, 'Drone reloading, Tank Stationary', 'Drone reloading, Tank Reloading', n2 , n3,n4,n5]

print("Start")

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

for i in range(12):
    #z = cv2.imread('Images_100/0a.png')
    #l = Image.fromarray(z)
#     print("shape of z", np.shape(z),type(z))
#     #l.show()
#     #z  = cv2.resize(z,(100,100))
#     img = uframes[i]
#     print(np.shape(img))
#     img.show()
#     data3.append(np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32))
#     y3 = np.array(data3)
#     x_1 = torch.from_numpy(y3)
# #     random_img = random.choice(x)
# #     print("random", np.shape(random_img),type(random_img))
# #     show = random_img.detach().numpy() * 255
# #     show = np.array(np.transpose(show,(1,2,0)),dtype=np.uint8)
# #     print("show", np.shape(show),type(show))
# #     ms = Image.fromarray(show)
# #     ms.show()
#     temp = model(x_1[i].reshape(1,3,100,100))[1]
#     temp = temp.detach().numpy()
#     img_blank.show()
#     #print(temp)
#     z = clf.predict(temp)
#     print(names[z[0]])
    img = uframes[i]
    print(np.shape(img))
    img.show()
    #ms = Image.fromarray(z)
    #ms.show()
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    temp = model(x_1[i].reshape(1,3,100,100))[1]
    temp = temp.detach().numpy()
    print(temp)
    z = clf.predict(temp)
    print(names[z[0]])
# Out:
# (100, 100, 3)
# Length of Class data:  600
# Start
# (100, 100, 3)
# [[5.69654167e-01 9.99462187e-01 5.63863292e-02 4.24214751e-01
#   9.99946237e-01 3.76719624e-01 9.24754981e-03 9.96866763e-01
#   3.24720666e-02 6.23485744e-01 9.99366581e-01 1.33173708e-05
#   9.99919176e-01 1.10880566e-04 7.16020440e-05]]
# Just Background
# (100, 100, 3)
# [[1.0693459e-01 9.7853309e-01 6.2482929e-01 8.8721722e-01 9.2732191e-01
#   3.8686104e-04 4.0334295e-03 9.7163016e-01 4.2039016e-01 9.9970645e-01
#   9.6105587e-01 4.5536429e-02 9.1955161e-01 2.7226047e-03 7.8407951e-02]]
# Only Tank moving
# (100, 100, 3)
# [[7.3534204e-03 9.9773276e-01 9.8508829e-01 9.9262118e-01 4.5104271e-01
#   3.5262175e-04 1.2917872e-04 7.4658793e-01 9.1725689e-01 9.9936992e-01
#   9.9860114e-01 5.1300049e-01 5.2829486e-01 2.9081654e-02 4.6734187e-01]]
# Only Drone Moving
# (100, 100, 3)
# [[6.6964526e-04 9.1521192e-01 9.9945718e-01 9.9930429e-01 5.6288450e-04
#   2.2586556e-07 5.6052031e-05 2.4077968e-01 9.9584311e-01 9.9999964e-01
#   9.1780317e-01 9.9973506e-01 1.0335925e-03 4.2442623e-01 9.9904162e-01]]
# Drone stationary, Tank Stationary
# (100, 100, 3)
# [[6.1773854e-01 5.1048535e-01 4.2821926e-01 3.8129362e-01 1.0322047e-02
#   8.4455933e-05 2.3334846e-03 2.1261269e-04 6.1853075e-01 9.9990475e-01
#   4.9628347e-01 9.9220043e-01 6.8009188e-03 9.8382390e-01 9.9368638e-01]]
# Drone Stationary, Tank Reloading
# (100, 100, 3)
# [[9.9997580e-01 8.7049991e-02 3.9350489e-01 2.6484555e-05 1.4167073e-01
#   1.3029476e-03 3.0017098e-05 3.1996256e-01 1.2829518e-01 9.9855381e-01
#   6.7431293e-02 8.8297009e-01 4.4132985e-02 6.9923133e-01 9.5737994e-01]]
# "Drone Stationary, Tank Firing"
# (100, 100, 3)
# [[9.9999666e-01 2.1902008e-06 1.0000000e+00 3.5267242e-06 3.7724271e-07
#   2.0260264e-03 6.5317053e-01 9.9999988e-01 2.2876749e-05 9.9758089e-01
#   4.7796307e-06 9.9999976e-01 3.5909158e-01 4.6132133e-08 6.4752334e-01]]
# Drone reloading, Tank Stationary
# (100, 100, 3)
# [[1.0000000e+00 2.1159988e-07 9.9998021e-01 1.5131814e-09 6.9859670e-06
#   4.3155217e-01 9.8743409e-01 9.9986637e-01 1.5483755e-07 5.7010096e-01
#   4.2174099e-07 9.9999261e-01 7.8759670e-01 3.8049018e-06 2.1713410e-01]]
# Drone reloading, Tank Reloading
# (100, 100, 3)
# [[1.0000000e+00 1.9347251e-08 9.9997711e-01 6.5030982e-14 1.1054412e-04
#   9.2142385e-01 5.0211656e-01 9.9999988e-01 1.4054513e-08 8.0260172e-02
#   3.0951572e-08 9.9987626e-01 9.6154159e-01 1.4544214e-07 3.8078785e-02]]
# "Drone Reloading, Tank Firing"
# (100, 100, 3)
# [[9.9998307e-01 9.9999917e-01 9.1853076e-01 1.7807450e-05 1.3325374e-02
#   9.9982435e-01 4.4189114e-06 2.7935535e-01 4.3374286e-03 1.8264313e-04
#   9.9999952e-01 9.9133462e-01 9.9873489e-01 3.9311872e-05 5.1611115e-04]]
# "Drone Firing, Tank Stationary"
# (100, 100, 3)
# [[1.0000000e+00 9.9999106e-01 4.5650690e-03 7.6405922e-09 2.0006411e-01
#   9.9999952e-01 1.8434954e-04 2.5986764e-04 2.9483532e-05 5.8745394e-07
#   9.9999404e-01 7.9409081e-01 9.9980861e-01 3.2320421e-03 7.7956029e-05]]
# "Drone Firing, Tank Reloading"
# (100, 100, 3)
# [[1.0000000e+00 9.9990249e-01 3.9572958e-03 3.2836459e-13 7.9830289e-01
#   1.0000000e+00 2.3663674e-06 3.6512318e-01 2.6762741e-06 3.8656605e-08
#   9.9991810e-01 1.8614928e-01 9.9997163e-01 1.2392933e-04 1.1127093e-05]]
# "Drone Firing, Tank Firing"

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()
x_limit = [tankc[i][0] for i in range(len(tankc))]
y_limit = [tankc[i][1] for i in range(len(tankc))]
ax.set_xlim((0,max(x_limit)+3))
ax.set_ylim((0,max(y_limit)+3))

line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)
# animation function. This is called sequentially
def animate(i):
    x = np.array(x_limit)

    y = np.array(y_limit)
    line.set_data(y, x)
    return (line,)
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7acb9cd99992> in <module>
#       8 # First set up the figure, the axis, and the plot element we want to animate
#       9 fig, ax = plt.subplots()
# ---> 10 x_limit = [tankc[i][0] for i in range(len(tankc))]
#      11 y_limit = [tankc[i][1] for i in range(len(tankc))]
#      12 ax.set_xlim((0,max(x_limit)+3))
#
# NameError: name 'tankc' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style

style.use('fivethirtyeight')

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
z=[[30,2],[1,2],[4,5]]
def animate(i):
    #graph_data = open('example.txt','r').read()
    lines = z#graph_data.split('\n')
    xs = []
    ys = []
    for line in lines:
        if len(line) > 1:
            x, y = line[0],line[1]
            print(x,y)
            xs.append(float(x))
            ys.append(float(y))
    ax1.clear()
    ax1.plot(xs, ys)
ani = animation.FuncAnimation(fig, animate, interval=1000000)
plt.show()
# Out:
# 30 2
# 1 2
# 4 5

# %%
import numpy as np
import matplotlib.pyplot as plt
print(dronec)
x = [tankc[i][0] for i in range(len(tankc))]
y = [tankc[i][1] for i in range(len(tankc))]
x1 = [dronec[i][0] for i in range(len(dronec))]
y1 = [dronec[i][1] for i in range(len(dronec))]
x2 = [droner[i][0] for i in range(len(droner))]
y2 = [droner[i][1] for i in range(len(droner))]


plt.scatter(x1,y1)
plt.scatter(x2,y2,color='red')
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7e6e6b022a9b> in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 print(dronec)
#       4 x = [tankc[i][0] for i in range(len(tankc))]
#       5 y = [tankc[i][1] for i in range(len(tankc))]
#
# NameError: name 'dronec' is not defined

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)   

from PIL import  Image,ImageDraw

img = uframes[20]
z = Image.fromarray(img)
z.show()
data3=[]
data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
y3 = np.array(data3)
x_1 = torch.from_numpy(y3)
temp = model(x_1[0].reshape(1,3,100,100))[0].detach().numpy()
filename = "Marginalization_Simple-increased_channels-32-video-multiple/TD.txt"
file = open(filename, 'w')
file.write(str(model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)   

from PIL import  Image,ImageDraw

img = Image.open("frame/tank_frame0.jpg")
img =  cv2.resize(np.asarray(img),(100,100))
data3=[]
data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
y3 = np.array(data3)
x_1 = torch.from_numpy(y3)
temp = model(x_1[0].reshape(1,3,100,100))[0].detach().numpy()
filename = "Marginalization_Simple-increased_channels-32-video-multiple/tank.txt"
file = open(filename, 'w')
file.write(str(model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()))
file.close()
