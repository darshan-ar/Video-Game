# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random

Batch_Size = 250
num_epochs = 200
learning_rate = 1e-5
samples = 30000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset


for i in range(samples):
    
    switch = random.randint(0,1)
    if switch==0:
        img = Image.new('RGB', (32, 32), color = 'white')
        row,col,ch= np.shape(img)
        mean = random.randint(1,6)
        var = random.random()
        sigma = var**0.5
        gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
        noisy_pos1 = img + gauss_pos1
        im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
        draw = ImageDraw.Draw(im2_pos1)
        draw.rectangle([9,12,12,15],fill='red',outline='red')
        data1.append(np.asarray(im2_pos1)/2)

        img_1 = Image.new('RGB', (32, 32), color = 'white')
        row_1,col_1,ch_1= np.shape(img_1)
        mean_1 = random.randint(1,6)
        var_1 = random.random()
        sigma_1 = var_1**0.5
        gauss_pos2 = np.random.normal(mean_1,sigma_1,(row_1,col_1,ch_1))
        noisy_pos2 = img_1 + gauss_pos2
        im2_pos2 = Image.fromarray(noisy_pos2,'RGB')
        draw_1 = ImageDraw.Draw(im2_pos2)
        draw_1.rectangle([21,12,24,15], fill='red', outline='red')
        data2.append(np.asarray(im2_pos2)/2)
    elif switch==1:
        img_blank = Image.new('RGB', (32, 32), color = 'white')
        row_blank,col_blank,ch_blank= np.shape(img_blank)
        mean_blank = random.randint(1,6)
        var_blank = random.random()
        sigma_blank = var_blank**0.5
        gauss_blank_pos1 = np.random.normal(mean_blank,sigma_blank,(row_blank,col_blank,ch_blank))
        noisy_blank_pos1 = img_blank + gauss_blank_pos1
        im2_blank_pos1 = Image.fromarray(noisy_blank_pos1,'RGB')
        data1.append(np.asarray(im2_blank_pos1)/2)

        img_blank_1 = Image.new('RGB', (32, 32), color = 'white')
        row_blank_1,col_blank_1,ch_blank_1= np.shape(img_blank_1)
        mean_blank_1 = random.randint(1,6)
        var_blank_1 = random.random()
        sigma_blank_1 = var_blank_1**0.5
        gauss_blank_pos2 = np.random.normal(mean_blank_1,sigma_blank_1,(row_blank_1,col_blank_1,ch_blank_1))
        noisy_blank_pos2 = img_blank_1 + gauss_blank_pos2
        im2_blank_pos2 = Image.fromarray(noisy_blank_pos2,'RGB')
        data2.append(np.asarray(im2_blank_pos2)/2)



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (32, 32), color = 'white')
row,col,ch= np.shape(img)
mean = random.randint(1,6)
var = random.random()
sigma = var**0.5
gauss = np.random.normal(mean,sigma,(row,col,ch))
noisy = img + gauss
im2 = Image.fromarray(noisy,'RGB')
b = np.asarray(im2)
b = np.array(b, dtype=np.float32)
b=b[:,:,0]
b = torch.from_numpy(b)
print(np.shape(b))
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.array(data1, dtype=np.float32)
y1 = np.array(data2, dtype=np.float32)
y0 = y0[:,:,:,0]
y1 = y1[:,:,:,0]

print(y0.shape)

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class AE(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        self.encoder_hidden_layer = nn.Linear(
            in_features=kwargs["input_shape"], out_features=128
        )
        self.encoder_output_layer = nn.Linear(
            in_features=128, out_features=64
        )
        self.encoder_output_layer_1 = nn.Linear(
            in_features=64, out_features=32
        )
        self.encoder_output_layer_2 = nn.Linear(
            in_features=32, out_features=16
        )
        self.encoder_output_layer_3 = nn.Linear(
            in_features=16, out_features=8
        )
        self.encoder_output_layer_4 = nn.Linear(
            in_features=8, out_features=1
        )




    def forward(self, features):
        activation = self.encoder_hidden_layer(features)
        activation = torch.relu(activation)
        code = self.encoder_output_layer(activation)
        code = torch.relu(code)
        code = self.encoder_output_layer_1(code)
        code = torch.relu(code)
        code = self.encoder_output_layer_2(code)
        code = torch.relu(code)
        code = self.encoder_output_layer_3(code)
        code = torch.relu(code)
        code = self.encoder_output_layer_4(code)
        code = torch.sigmoid(code)
        return code

#  use gpu if available

# create a model from `AE` autoencoder class
# load it to the specified device, either gpu or cpu
model = AE(input_shape=1024)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)

    covf = torch.matmul((fx.t()), fx) / Nsamples

    covg = torch.matmul((gy.t()), (gy)) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h



optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)



for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        x = x.view(-1, 1024)
        y = y.view(-1, 1024)
        loss = h_score(model(x),model(y))
        # ===================backward====================

        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    b = b.view(-1,1024)
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print(np.shape(x[0]))
    print("x: ", model(x[0]))
    print("y:", model(y[0]))
    print("b:", model(b))
# Out:
# torch.Size([32, 32])
# (30000, 32, 32)
# epoch [1/200], loss:-0.0008
# torch.Size([1024])
# x:  tensor([0.3591], grad_fn=<SigmoidBackward>)
# y: tensor([0.2851], grad_fn=<SigmoidBackward>)
# b: tensor([[0.2229]], grad_fn=<SigmoidBackward>)
# epoch [2/200], loss:-0.0218
# torch.Size([1024])
# x:  tensor([0.1864], grad_fn=<SigmoidBackward>)
# y: tensor([0.1756], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0620]], grad_fn=<SigmoidBackward>)
# epoch [3/200], loss:-0.1315
# torch.Size([1024])
# x:  tensor([0.7426], grad_fn=<SigmoidBackward>)
# y: tensor([0.7349], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0186]], grad_fn=<SigmoidBackward>)
# epoch [4/200], loss:-0.2955
# torch.Size([1024])
# x:  tensor([0.8549], grad_fn=<SigmoidBackward>)
# y: tensor([0.9284], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0048]], grad_fn=<SigmoidBackward>)
# epoch [5/200], loss:-0.3637
# torch.Size([1024])
# x:  tensor([0.0066], grad_fn=<SigmoidBackward>)
# y: tensor([0.0376], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0003]], grad_fn=<SigmoidBackward>)
# epoch [6/200], loss:-0.3886
# torch.Size([1024])
# x:  tensor([0.8950], grad_fn=<SigmoidBackward>)
# y: tensor([0.9869], grad_fn=<SigmoidBackward>)
# b: tensor([[3.7735e-05]], grad_fn=<SigmoidBackward>)
# epoch [7/200], loss:-0.4059
# torch.Size([1024])
# x:  tensor([0.9850], grad_fn=<SigmoidBackward>)
# y: tensor([0.9893], grad_fn=<SigmoidBackward>)
# b: tensor([[9.1250e-06]], grad_fn=<SigmoidBackward>)
# epoch [8/200], loss:-0.4186
# torch.Size([1024])
# x:  tensor([0.9957], grad_fn=<SigmoidBackward>)
# y: tensor([0.9932], grad_fn=<SigmoidBackward>)
# b: tensor([[2.6836e-06]], grad_fn=<SigmoidBackward>)
# epoch [9/200], loss:-0.4227
# torch.Size([1024])
# x:  tensor([0.0026], grad_fn=<SigmoidBackward>)
# y: tensor([0.0018], grad_fn=<SigmoidBackward>)
# b: tensor([[9.3217e-07]], grad_fn=<SigmoidBackward>)
# epoch [10/200], loss:-0.4278
# torch.Size([1024])
# x:  tensor([0.0092], grad_fn=<SigmoidBackward>)
# y: tensor([0.0035], grad_fn=<SigmoidBackward>)
# b: tensor([[3.5989e-07]], grad_fn=<SigmoidBackward>)
# epoch [11/200], loss:-0.4297
# torch.Size([1024])
# x:  tensor([0.0010], grad_fn=<SigmoidBackward>)
# y: tensor([1.1495e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[1.5924e-07]], grad_fn=<SigmoidBackward>)
# epoch [12/200], loss:-0.4276
# torch.Size([1024])
# x:  tensor([0.0007], grad_fn=<SigmoidBackward>)
# y: tensor([0.0025], grad_fn=<SigmoidBackward>)
# b: tensor([[8.6106e-08]], grad_fn=<SigmoidBackward>)
# epoch [13/200], loss:-0.4163
# torch.Size([1024])
# x:  tensor([0.0003], grad_fn=<SigmoidBackward>)
# y: tensor([0.0164], grad_fn=<SigmoidBackward>)
# b: tensor([[4.6248e-08]], grad_fn=<SigmoidBackward>)
# epoch [14/200], loss:-0.4303
# torch.Size([1024])
# x:  tensor([0.0018], grad_fn=<SigmoidBackward>)
# y: tensor([0.0002], grad_fn=<SigmoidBackward>)
# b: tensor([[1.4461e-08]], grad_fn=<SigmoidBackward>)
# epoch [15/200], loss:-0.4327
# torch.Size([1024])
# x:  tensor([0.9802], grad_fn=<SigmoidBackward>)
# y: tensor([0.9991], grad_fn=<SigmoidBackward>)
# b: tensor([[9.1025e-09]], grad_fn=<SigmoidBackward>)
# epoch [16/200], loss:-0.4345
# torch.Size([1024])
# x:  tensor([0.0001], grad_fn=<SigmoidBackward>)
# y: tensor([0.0009], grad_fn=<SigmoidBackward>)
# b: tensor([[8.2182e-09]], grad_fn=<SigmoidBackward>)
# epoch [17/200], loss:-0.4298
# torch.Size([1024])
# x:  tensor([0.9966], grad_fn=<SigmoidBackward>)
# y: tensor([0.9993], grad_fn=<SigmoidBackward>)
# b: tensor([[3.8724e-09]], grad_fn=<SigmoidBackward>)
# epoch [18/200], loss:-0.4323
# torch.Size([1024])
# x:  tensor([2.1838e-06], grad_fn=<SigmoidBackward>)
# y: tensor([1.1854e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[2.3803e-09]], grad_fn=<SigmoidBackward>)
# epoch [19/200], loss:-0.4351
# torch.Size([1024])
# x:  tensor([0.9995], grad_fn=<SigmoidBackward>)
# y: tensor([0.9989], grad_fn=<SigmoidBackward>)
# b: tensor([[1.5430e-09]], grad_fn=<SigmoidBackward>)
# epoch [20/200], loss:-0.4302
# torch.Size([1024])
# x:  tensor([1.7288e-05], grad_fn=<SigmoidBackward>)
# y: tensor([3.1886e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[7.4532e-10]], grad_fn=<SigmoidBackward>)
# epoch [21/200], loss:-0.4296
# torch.Size([1024])
# x:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# y: tensor([9.8594e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[6.8560e-10]], grad_fn=<SigmoidBackward>)
# epoch [22/200], loss:-0.4354
# torch.Size([1024])
# x:  tensor([0.9997], grad_fn=<SigmoidBackward>)
# y: tensor([0.9997], grad_fn=<SigmoidBackward>)
# b: tensor([[3.7128e-10]], grad_fn=<SigmoidBackward>)
# epoch [23/200], loss:-0.4346
# torch.Size([1024])
# x:  tensor([6.1972e-06], grad_fn=<SigmoidBackward>)
# y: tensor([0.0003], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0752e-10]], grad_fn=<SigmoidBackward>)
# epoch [24/200], loss:-0.4353
# torch.Size([1024])
# x:  tensor([0.0006], grad_fn=<SigmoidBackward>)
# y: tensor([3.7726e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[1.3512e-10]], grad_fn=<SigmoidBackward>)
# epoch [25/200], loss:-0.4350
# torch.Size([1024])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9998], grad_fn=<SigmoidBackward>)
# b: tensor([[7.4470e-11]], grad_fn=<SigmoidBackward>)
# epoch [26/200], loss:-0.4352
# torch.Size([1024])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9997], grad_fn=<SigmoidBackward>)
# b: tensor([[6.2701e-11]], grad_fn=<SigmoidBackward>)
# epoch [27/200], loss:-0.4351
# torch.Size([1024])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9998], grad_fn=<SigmoidBackward>)
# b: tensor([[7.0723e-11]], grad_fn=<SigmoidBackward>)
# epoch [28/200], loss:-0.4358
# torch.Size([1024])
# x:  tensor([1.7176e-05], grad_fn=<SigmoidBackward>)
# y: tensor([1.1620e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[2.5165e-11]], grad_fn=<SigmoidBackward>)
# epoch [29/200], loss:-0.4349
# torch.Size([1024])
# x:  tensor([0.9997], grad_fn=<SigmoidBackward>)
# y: tensor([0.9942], grad_fn=<SigmoidBackward>)
# b: tensor([[1.8378e-11]], grad_fn=<SigmoidBackward>)
# epoch [30/200], loss:-0.4369
# torch.Size([1024])
# x:  tensor([8.1334e-05], grad_fn=<SigmoidBackward>)
# y: tensor([2.0626e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[1.9391e-11]], grad_fn=<SigmoidBackward>)
# epoch [31/200], loss:-0.4368
# torch.Size([1024])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.8133e-11]], grad_fn=<SigmoidBackward>)
# epoch [32/200], loss:-0.4356
# torch.Size([1024])
# x:  tensor([0.0005], grad_fn=<SigmoidBackward>)
# y: tensor([2.8151e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1547e-11]], grad_fn=<SigmoidBackward>)
# epoch [33/200], loss:-0.4360
# torch.Size([1024])
# x:  tensor([1.9906e-05], grad_fn=<SigmoidBackward>)
# y: tensor([7.3047e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[8.7398e-12]], grad_fn=<SigmoidBackward>)
# epoch [34/200], loss:-0.4350
# torch.Size([1024])
# x:  tensor([2.7601e-07], grad_fn=<SigmoidBackward>)
# y: tensor([3.0547e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[4.7727e-12]], grad_fn=<SigmoidBackward>)
# epoch [35/200], loss:-0.4356
# torch.Size([1024])
# x:  tensor([9.0876e-08], grad_fn=<SigmoidBackward>)
# y: tensor([1.9310e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[6.3358e-12]], grad_fn=<SigmoidBackward>)
# epoch [36/200], loss:-0.4368
# torch.Size([1024])
# x:  tensor([3.4129e-06], grad_fn=<SigmoidBackward>)
# y: tensor([0.0003], grad_fn=<SigmoidBackward>)
# b: tensor([[3.0634e-12]], grad_fn=<SigmoidBackward>)
# epoch [37/200], loss:-0.4294
# torch.Size([1024])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[2.3811e-12]], grad_fn=<SigmoidBackward>)
# epoch [38/200], loss:-0.4369
# torch.Size([1024])
# x:  tensor([1.2034e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.6959e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[2.7942e-12]], grad_fn=<SigmoidBackward>)
# epoch [39/200], loss:-0.4372
# torch.Size([1024])
# x:  tensor([5.1919e-05], grad_fn=<SigmoidBackward>)
# y: tensor([4.3383e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0831e-12]], grad_fn=<SigmoidBackward>)
# epoch [40/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9999], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1067e-12]], grad_fn=<SigmoidBackward>)
# epoch [41/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([5.6298e-05], grad_fn=<SigmoidBackward>)
# y: tensor([2.8312e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[1.2678e-12]], grad_fn=<SigmoidBackward>)
# epoch [42/200], loss:-0.4372
# torch.Size([1024])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.5311e-13]], grad_fn=<SigmoidBackward>)
# epoch [43/200], loss:-0.4353
# torch.Size([1024])
# x:  tensor([4.9113e-09], grad_fn=<SigmoidBackward>)
# y: tensor([6.8976e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[4.5727e-13]], grad_fn=<SigmoidBackward>)
# epoch [44/200], loss:-0.4367
# torch.Size([1024])
# x:  tensor([4.3809e-06], grad_fn=<SigmoidBackward>)
# y: tensor([6.8451e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[6.3125e-13]], grad_fn=<SigmoidBackward>)
# epoch [45/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([5.6288e-06], grad_fn=<SigmoidBackward>)
# y: tensor([2.8283e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[3.7635e-13]], grad_fn=<SigmoidBackward>)
# epoch [46/200], loss:-0.4350
# torch.Size([1024])
# x:  tensor([2.6659e-09], grad_fn=<SigmoidBackward>)
# y: tensor([1.7885e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[2.1572e-13]], grad_fn=<SigmoidBackward>)
# epoch [47/200], loss:-0.4370
# torch.Size([1024])
# x:  tensor([0.9999], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.0133e-13]], grad_fn=<SigmoidBackward>)
# epoch [48/200], loss:-0.4358
# torch.Size([1024])
# x:  tensor([7.2229e-08], grad_fn=<SigmoidBackward>)
# y: tensor([0.0003], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1758e-13]], grad_fn=<SigmoidBackward>)
# epoch [49/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0534e-06], grad_fn=<SigmoidBackward>)
# y: tensor([1.0619e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[1.5790e-13]], grad_fn=<SigmoidBackward>)
# epoch [50/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.4160e-13]], grad_fn=<SigmoidBackward>)
# epoch [51/200], loss:-0.4339
# torch.Size([1024])
# x:  tensor([8.9462e-07], grad_fn=<SigmoidBackward>)
# y: tensor([7.5971e-09], grad_fn=<SigmoidBackward>)
# b: tensor([[6.2639e-14]], grad_fn=<SigmoidBackward>)
# epoch [52/200], loss:-0.4370
# torch.Size([1024])
# x:  tensor([5.8661e-07], grad_fn=<SigmoidBackward>)
# y: tensor([2.2132e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[4.7944e-14]], grad_fn=<SigmoidBackward>)
# epoch [53/200], loss:-0.4370
# torch.Size([1024])
# x:  tensor([1.1388e-06], grad_fn=<SigmoidBackward>)
# y: tensor([1.3227e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[4.1783e-14]], grad_fn=<SigmoidBackward>)
# epoch [54/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([4.7327e-08], grad_fn=<SigmoidBackward>)
# y: tensor([2.2689e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[3.3539e-14]], grad_fn=<SigmoidBackward>)
# epoch [55/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.0967e-14]], grad_fn=<SigmoidBackward>)
# epoch [56/200], loss:-0.4372
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.2033e-14]], grad_fn=<SigmoidBackward>)
# epoch [57/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0667e-14]], grad_fn=<SigmoidBackward>)
# epoch [58/200], loss:-0.4365
# torch.Size([1024])
# x:  tensor([0.9998], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.6178e-14]], grad_fn=<SigmoidBackward>)
# epoch [59/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[7.6556e-15]], grad_fn=<SigmoidBackward>)
# epoch [60/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([0.9995], grad_fn=<SigmoidBackward>)
# b: tensor([[7.6166e-15]], grad_fn=<SigmoidBackward>)
# epoch [61/200], loss:-0.4362
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[7.2929e-15]], grad_fn=<SigmoidBackward>)
# epoch [62/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([2.0408e-07], grad_fn=<SigmoidBackward>)
# y: tensor([2.0083e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[5.5197e-15]], grad_fn=<SigmoidBackward>)
# epoch [63/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[5.0967e-15]], grad_fn=<SigmoidBackward>)
# epoch [64/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.3855e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.8331e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[3.1066e-15]], grad_fn=<SigmoidBackward>)
# epoch [65/200], loss:-0.4368
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.0107e-15]], grad_fn=<SigmoidBackward>)
# epoch [66/200], loss:-0.4305
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.0507e-15]], grad_fn=<SigmoidBackward>)
# epoch [67/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.5819e-05], grad_fn=<SigmoidBackward>)
# y: tensor([2.1383e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[2.9473e-15]], grad_fn=<SigmoidBackward>)
# epoch [68/200], loss:-0.4359
# torch.Size([1024])
# x:  tensor([2.8036e-08], grad_fn=<SigmoidBackward>)
# y: tensor([1.3370e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[1.9771e-15]], grad_fn=<SigmoidBackward>)
# epoch [69/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.8963e-15]], grad_fn=<SigmoidBackward>)
# epoch [70/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([3.6185e-08], grad_fn=<SigmoidBackward>)
# y: tensor([9.4992e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[1.4882e-15]], grad_fn=<SigmoidBackward>)
# epoch [71/200], loss:-0.4369
# torch.Size([1024])
# x:  tensor([9.8835e-07], grad_fn=<SigmoidBackward>)
# y: tensor([5.9797e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[1.8033e-15]], grad_fn=<SigmoidBackward>)
# epoch [72/200], loss:-0.4359
# torch.Size([1024])
# x:  tensor([8.3421e-08], grad_fn=<SigmoidBackward>)
# y: tensor([1.2901e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[1.2542e-15]], grad_fn=<SigmoidBackward>)
# epoch [73/200], loss:-0.4351
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[9.2112e-16]], grad_fn=<SigmoidBackward>)
# epoch [74/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([2.0830e-05], grad_fn=<SigmoidBackward>)
# y: tensor([1.6272e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[9.1729e-16]], grad_fn=<SigmoidBackward>)
# epoch [75/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[8.5917e-16]], grad_fn=<SigmoidBackward>)
# epoch [76/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([5.2901e-10], grad_fn=<SigmoidBackward>)
# y: tensor([2.6978e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[5.8615e-16]], grad_fn=<SigmoidBackward>)
# epoch [77/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.2998e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.8001e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[5.3614e-16]], grad_fn=<SigmoidBackward>)
# epoch [78/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.7128e-16]], grad_fn=<SigmoidBackward>)
# epoch [79/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.6753e-16]], grad_fn=<SigmoidBackward>)
# epoch [80/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([1.0574e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.1736e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[3.8492e-16]], grad_fn=<SigmoidBackward>)
# epoch [81/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([3.1885e-06], grad_fn=<SigmoidBackward>)
# y: tensor([5.7462e-10], grad_fn=<SigmoidBackward>)
# b: tensor([[3.7397e-16]], grad_fn=<SigmoidBackward>)
# epoch [82/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([1.1562e-05], grad_fn=<SigmoidBackward>)
# y: tensor([2.8024e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[3.2395e-16]], grad_fn=<SigmoidBackward>)
# epoch [83/200], loss:-0.4346
# torch.Size([1024])
# x:  tensor([3.4243e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.3061e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[3.2097e-16]], grad_fn=<SigmoidBackward>)
# epoch [84/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([6.2009e-07], grad_fn=<SigmoidBackward>)
# y: tensor([2.1239e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[2.8514e-16]], grad_fn=<SigmoidBackward>)
# epoch [85/200], loss:-0.4328
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.6570e-16]], grad_fn=<SigmoidBackward>)
# epoch [86/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.4112e-16]], grad_fn=<SigmoidBackward>)
# epoch [87/200], loss:-0.4351
# torch.Size([1024])
# x:  tensor([1.1648e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.7082e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[2.7858e-16]], grad_fn=<SigmoidBackward>)
# epoch [88/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.3993e-16]], grad_fn=<SigmoidBackward>)
# epoch [89/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[5.3054e-16]], grad_fn=<SigmoidBackward>)
# epoch [90/200], loss:-0.4359
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.8134e-16]], grad_fn=<SigmoidBackward>)
# epoch [91/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.0310e-16]], grad_fn=<SigmoidBackward>)
# epoch [92/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[4.2179e-16]], grad_fn=<SigmoidBackward>)
# epoch [93/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[5.1079e-16]], grad_fn=<SigmoidBackward>)
# epoch [94/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([9.4385e-08], grad_fn=<SigmoidBackward>)
# y: tensor([3.5451e-09], grad_fn=<SigmoidBackward>)
# b: tensor([[1.8290e-16]], grad_fn=<SigmoidBackward>)
# epoch [95/200], loss:-0.4340
# torch.Size([1024])
# x:  tensor([4.9185e-07], grad_fn=<SigmoidBackward>)
# y: tensor([4.9283e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[3.3159e-16]], grad_fn=<SigmoidBackward>)
# epoch [96/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([9.1315e-09], grad_fn=<SigmoidBackward>)
# y: tensor([1.7064e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[5.6596e-16]], grad_fn=<SigmoidBackward>)
# epoch [97/200], loss:-0.4346
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[5.8730e-16]], grad_fn=<SigmoidBackward>)
# epoch [98/200], loss:-0.4369
# torch.Size([1024])
# x:  tensor([6.1199e-08], grad_fn=<SigmoidBackward>)
# y: tensor([2.4098e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[4.3886e-16]], grad_fn=<SigmoidBackward>)
# epoch [99/200], loss:-0.4360
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.4368e-16]], grad_fn=<SigmoidBackward>)
# epoch [100/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.0684e-16]], grad_fn=<SigmoidBackward>)
# epoch [101/200], loss:-0.4288
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[4.6411e-16]], grad_fn=<SigmoidBackward>)
# epoch [102/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.0668e-16]], grad_fn=<SigmoidBackward>)
# epoch [103/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.7297e-16]], grad_fn=<SigmoidBackward>)
# epoch [104/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([3.7825e-08], grad_fn=<SigmoidBackward>)
# y: tensor([9.6172e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[6.3662e-16]], grad_fn=<SigmoidBackward>)
# epoch [105/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([9.9440e-08], grad_fn=<SigmoidBackward>)
# y: tensor([2.0376e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[8.9187e-16]], grad_fn=<SigmoidBackward>)
# epoch [106/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[7.7201e-16]], grad_fn=<SigmoidBackward>)
# epoch [107/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.8162e-15]], grad_fn=<SigmoidBackward>)
# epoch [108/200], loss:-0.4313
# torch.Size([1024])
# x:  tensor([2.9876e-08], grad_fn=<SigmoidBackward>)
# y: tensor([3.4693e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[8.0539e-16]], grad_fn=<SigmoidBackward>)
# epoch [109/200], loss:-0.4288
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0836e-15]], grad_fn=<SigmoidBackward>)
# epoch [110/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([7.1410e-06], grad_fn=<SigmoidBackward>)
# y: tensor([3.4197e-09], grad_fn=<SigmoidBackward>)
# b: tensor([[1.4842e-15]], grad_fn=<SigmoidBackward>)
# epoch [111/200], loss:-0.4340
# torch.Size([1024])
# x:  tensor([7.7786e-08], grad_fn=<SigmoidBackward>)
# y: tensor([5.1090e-09], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1840e-15]], grad_fn=<SigmoidBackward>)
# epoch [112/200], loss:-0.4328
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.7925e-15]], grad_fn=<SigmoidBackward>)
# epoch [113/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([4.2969e-07], grad_fn=<SigmoidBackward>)
# y: tensor([3.3035e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[2.4908e-15]], grad_fn=<SigmoidBackward>)
# epoch [114/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.8239e-15]], grad_fn=<SigmoidBackward>)
# epoch [115/200], loss:-0.4369
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[5.0563e-15]], grad_fn=<SigmoidBackward>)
# epoch [116/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([6.9949e-08], grad_fn=<SigmoidBackward>)
# y: tensor([6.2571e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[2.3034e-15]], grad_fn=<SigmoidBackward>)
# epoch [117/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.3085e-15]], grad_fn=<SigmoidBackward>)
# epoch [118/200], loss:-0.4369
# torch.Size([1024])
# x:  tensor([6.9506e-08], grad_fn=<SigmoidBackward>)
# y: tensor([9.0881e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[2.3236e-15]], grad_fn=<SigmoidBackward>)
# epoch [119/200], loss:-0.4328
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.8784e-15]], grad_fn=<SigmoidBackward>)
# epoch [120/200], loss:-0.4346
# torch.Size([1024])
# x:  tensor([6.1635e-08], grad_fn=<SigmoidBackward>)
# y: tensor([8.3660e-09], grad_fn=<SigmoidBackward>)
# b: tensor([[1.2741e-15]], grad_fn=<SigmoidBackward>)
# epoch [121/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([7.9337e-07], grad_fn=<SigmoidBackward>)
# y: tensor([7.0556e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[2.6515e-15]], grad_fn=<SigmoidBackward>)
# epoch [122/200], loss:-0.4346
# torch.Size([1024])
# x:  tensor([9.6741e-06], grad_fn=<SigmoidBackward>)
# y: tensor([3.0391e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[5.8382e-15]], grad_fn=<SigmoidBackward>)
# epoch [123/200], loss:-0.4297
# torch.Size([1024])
# x:  tensor([2.7077e-07], grad_fn=<SigmoidBackward>)
# y: tensor([6.5482e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[4.1113e-15]], grad_fn=<SigmoidBackward>)
# epoch [124/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[4.5980e-15]], grad_fn=<SigmoidBackward>)
# epoch [125/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0464e-14]], grad_fn=<SigmoidBackward>)
# epoch [126/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[5.6150e-15]], grad_fn=<SigmoidBackward>)
# epoch [127/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([1.3257e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.4793e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[7.7125e-15]], grad_fn=<SigmoidBackward>)
# epoch [128/200], loss:-0.4313
# torch.Size([1024])
# x:  tensor([4.3611e-07], grad_fn=<SigmoidBackward>)
# y: tensor([2.1962e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1445e-14]], grad_fn=<SigmoidBackward>)
# epoch [129/200], loss:-0.4351
# torch.Size([1024])
# x:  tensor([6.7536e-08], grad_fn=<SigmoidBackward>)
# y: tensor([2.4883e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[5.8206e-15]], grad_fn=<SigmoidBackward>)
# epoch [130/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([2.6728e-08], grad_fn=<SigmoidBackward>)
# y: tensor([3.7114e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[1.3514e-14]], grad_fn=<SigmoidBackward>)
# epoch [131/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.5907e-06], grad_fn=<SigmoidBackward>)
# y: tensor([1.7723e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1397e-14]], grad_fn=<SigmoidBackward>)
# epoch [132/200], loss:-0.4346
# torch.Size([1024])
# x:  tensor([8.2329e-08], grad_fn=<SigmoidBackward>)
# y: tensor([4.7093e-05], grad_fn=<SigmoidBackward>)
# b: tensor([[9.5380e-15]], grad_fn=<SigmoidBackward>)
# epoch [133/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([8.4843e-07], grad_fn=<SigmoidBackward>)
# y: tensor([4.2627e-09], grad_fn=<SigmoidBackward>)
# b: tensor([[7.5888e-15]], grad_fn=<SigmoidBackward>)
# epoch [134/200], loss:-0.4334
# torch.Size([1024])
# x:  tensor([1.2674e-06], grad_fn=<SigmoidBackward>)
# y: tensor([8.4176e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[1.4136e-14]], grad_fn=<SigmoidBackward>)
# epoch [135/200], loss:-0.4351
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.4390e-14]], grad_fn=<SigmoidBackward>)
# epoch [136/200], loss:-0.4351
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[4.2305e-14]], grad_fn=<SigmoidBackward>)
# epoch [137/200], loss:-0.4340
# torch.Size([1024])
# x:  tensor([6.6911e-08], grad_fn=<SigmoidBackward>)
# y: tensor([4.2950e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[1.9778e-14]], grad_fn=<SigmoidBackward>)
# epoch [138/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.5623e-14]], grad_fn=<SigmoidBackward>)
# epoch [139/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.0731e-14]], grad_fn=<SigmoidBackward>)
# epoch [140/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([5.7550e-08], grad_fn=<SigmoidBackward>)
# y: tensor([9.1961e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[3.1906e-14]], grad_fn=<SigmoidBackward>)
# epoch [141/200], loss:-0.4334
# torch.Size([1024])
# x:  tensor([0.0004], grad_fn=<SigmoidBackward>)
# y: tensor([5.1663e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[2.4817e-14]], grad_fn=<SigmoidBackward>)
# epoch [142/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([0.0002], grad_fn=<SigmoidBackward>)
# y: tensor([1.5600e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[2.4708e-14]], grad_fn=<SigmoidBackward>)
# epoch [143/200], loss:-0.4351
# torch.Size([1024])
# x:  tensor([6.4880e-08], grad_fn=<SigmoidBackward>)
# y: tensor([3.2611e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[4.7811e-14]], grad_fn=<SigmoidBackward>)
# epoch [144/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([6.5824e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.3812e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[3.7188e-14]], grad_fn=<SigmoidBackward>)
# epoch [145/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([5.5948e-07], grad_fn=<SigmoidBackward>)
# y: tensor([9.4851e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[3.3772e-14]], grad_fn=<SigmoidBackward>)
# epoch [146/200], loss:-0.4340
# torch.Size([1024])
# x:  tensor([2.0458e-07], grad_fn=<SigmoidBackward>)
# y: tensor([9.6643e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[4.3746e-14]], grad_fn=<SigmoidBackward>)
# epoch [147/200], loss:-0.4369
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[2.6927e-14]], grad_fn=<SigmoidBackward>)
# epoch [148/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[4.6658e-14]], grad_fn=<SigmoidBackward>)
# epoch [149/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.6367e-14]], grad_fn=<SigmoidBackward>)
# epoch [150/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[7.4823e-14]], grad_fn=<SigmoidBackward>)
# epoch [151/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([9.9651e-07], grad_fn=<SigmoidBackward>)
# y: tensor([3.8851e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[5.0959e-14]], grad_fn=<SigmoidBackward>)
# epoch [152/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([3.9372e-08], grad_fn=<SigmoidBackward>)
# y: tensor([6.2101e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[3.3382e-14]], grad_fn=<SigmoidBackward>)
# epoch [153/200], loss:-0.4328
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.0948e-14]], grad_fn=<SigmoidBackward>)
# epoch [154/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([2.7625e-07], grad_fn=<SigmoidBackward>)
# y: tensor([5.7627e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[4.2186e-14]], grad_fn=<SigmoidBackward>)
# epoch [155/200], loss:-0.4346
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.6538e-14]], grad_fn=<SigmoidBackward>)
# epoch [156/200], loss:-0.4328
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[7.0539e-14]], grad_fn=<SigmoidBackward>)
# epoch [157/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([2.8975e-08], grad_fn=<SigmoidBackward>)
# y: tensor([3.9196e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[7.3797e-14]], grad_fn=<SigmoidBackward>)
# epoch [158/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1166e-13]], grad_fn=<SigmoidBackward>)
# epoch [159/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.3287e-06], grad_fn=<SigmoidBackward>)
# y: tensor([3.7603e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[1.3419e-13]], grad_fn=<SigmoidBackward>)
# epoch [160/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([3.1415e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.4154e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[5.3242e-14]], grad_fn=<SigmoidBackward>)
# epoch [161/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([6.1808e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.5086e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[5.0676e-14]], grad_fn=<SigmoidBackward>)
# epoch [162/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.1413e-07], grad_fn=<SigmoidBackward>)
# y: tensor([6.7146e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[2.1648e-14]], grad_fn=<SigmoidBackward>)
# epoch [163/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([8.9061e-07], grad_fn=<SigmoidBackward>)
# y: tensor([8.7045e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1197e-13]], grad_fn=<SigmoidBackward>)
# epoch [164/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.7469e-14]], grad_fn=<SigmoidBackward>)
# epoch [165/200], loss:-0.4288
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[5.9745e-14]], grad_fn=<SigmoidBackward>)
# epoch [166/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.7622e-14]], grad_fn=<SigmoidBackward>)
# epoch [167/200], loss:-0.4369
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.5785e-14]], grad_fn=<SigmoidBackward>)
# epoch [168/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[9.5979e-14]], grad_fn=<SigmoidBackward>)
# epoch [169/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[8.3159e-14]], grad_fn=<SigmoidBackward>)
# epoch [170/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0590e-13]], grad_fn=<SigmoidBackward>)
# epoch [171/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([1.9190e-06], grad_fn=<SigmoidBackward>)
# y: tensor([7.1557e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[6.0229e-14]], grad_fn=<SigmoidBackward>)
# epoch [172/200], loss:-0.4346
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.3554e-13]], grad_fn=<SigmoidBackward>)
# epoch [173/200], loss:-0.4328
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[7.2327e-14]], grad_fn=<SigmoidBackward>)
# epoch [174/200], loss:-0.4355
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[8.0496e-14]], grad_fn=<SigmoidBackward>)
# epoch [175/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.0390e-14]], grad_fn=<SigmoidBackward>)
# epoch [176/200], loss:-0.4351
# torch.Size([1024])
# x:  tensor([1.2147e-06], grad_fn=<SigmoidBackward>)
# y: tensor([2.1149e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[7.9835e-14]], grad_fn=<SigmoidBackward>)
# epoch [177/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1795e-13]], grad_fn=<SigmoidBackward>)
# epoch [178/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.1412e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.5445e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[6.8739e-14]], grad_fn=<SigmoidBackward>)
# epoch [179/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1540e-13]], grad_fn=<SigmoidBackward>)
# epoch [180/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([1.1482e-05], grad_fn=<SigmoidBackward>)
# y: tensor([2.3749e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[5.4167e-14]], grad_fn=<SigmoidBackward>)
# epoch [181/200], loss:-0.4374
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.5028e-14]], grad_fn=<SigmoidBackward>)
# epoch [182/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([4.2805e-06], grad_fn=<SigmoidBackward>)
# y: tensor([3.3175e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[4.8989e-14]], grad_fn=<SigmoidBackward>)
# epoch [183/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[8.2451e-14]], grad_fn=<SigmoidBackward>)
# epoch [184/200], loss:-0.4369
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[7.7180e-14]], grad_fn=<SigmoidBackward>)
# epoch [185/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.6993e-14]], grad_fn=<SigmoidBackward>)
# epoch [186/200], loss:-0.4360
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[9.8875e-14]], grad_fn=<SigmoidBackward>)
# epoch [187/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0342e-13]], grad_fn=<SigmoidBackward>)
# epoch [188/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([3.9803e-06], grad_fn=<SigmoidBackward>)
# y: tensor([6.8800e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[1.2885e-13]], grad_fn=<SigmoidBackward>)
# epoch [189/200], loss:-0.4305
# torch.Size([1024])
# x:  tensor([1.4568e-07], grad_fn=<SigmoidBackward>)
# y: tensor([2.0088e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[8.4489e-14]], grad_fn=<SigmoidBackward>)
# epoch [190/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.3445e-13]], grad_fn=<SigmoidBackward>)
# epoch [191/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([1.9658e-06], grad_fn=<SigmoidBackward>)
# y: tensor([4.3770e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[5.5197e-14]], grad_fn=<SigmoidBackward>)
# epoch [192/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[7.8605e-14]], grad_fn=<SigmoidBackward>)
# epoch [193/200], loss:-0.4334
# torch.Size([1024])
# x:  tensor([7.9084e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.5301e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[7.1625e-14]], grad_fn=<SigmoidBackward>)
# epoch [194/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([4.2747e-07], grad_fn=<SigmoidBackward>)
# y: tensor([7.8991e-08], grad_fn=<SigmoidBackward>)
# b: tensor([[5.3553e-14]], grad_fn=<SigmoidBackward>)
# epoch [195/200], loss:-0.4366
# torch.Size([1024])
# x:  tensor([2.1563e-07], grad_fn=<SigmoidBackward>)
# y: tensor([1.0843e-06], grad_fn=<SigmoidBackward>)
# b: tensor([[7.8317e-14]], grad_fn=<SigmoidBackward>)
# epoch [196/200], loss:-0.4375
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[3.2681e-14]], grad_fn=<SigmoidBackward>)
# epoch [197/200], loss:-0.4363
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[6.0417e-14]], grad_fn=<SigmoidBackward>)
# epoch [198/200], loss:-0.4360
# torch.Size([1024])
# x:  tensor([9.9025e-06], grad_fn=<SigmoidBackward>)
# y: tensor([2.0897e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1166e-13]], grad_fn=<SigmoidBackward>)
# epoch [199/200], loss:-0.4373
# torch.Size([1024])
# x:  tensor([1.0000], grad_fn=<SigmoidBackward>)
# y: tensor([1.0000], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1162e-13]], grad_fn=<SigmoidBackward>)
# epoch [200/200], loss:-0.4371
# torch.Size([1024])
# x:  tensor([4.0825e-08], grad_fn=<SigmoidBackward>)
# y: tensor([2.0281e-07], grad_fn=<SigmoidBackward>)
# b: tensor([[5.5526e-14]], grad_fn=<SigmoidBackward>)

# %%
data3=[]

for i in range(5):
    img = Image.new('RGB', (28, 28), color = 'white')
    row,col,ch= np.shape(img)
    mean = random.randint(1,6)
    var = random.random()
    sigma = var**0.5
    gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
    noisy_pos1 = img + gauss_pos1
    im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
    #draw = ImageDraw.Draw(im2_pos1)
    #draw.rectangle([9,12,12,15],fill='red',outline='red')
    data3.append(np.asarray(im2_pos1))

    y3 = np.array(data3, dtype=np.float32)
    #y1 = np.array(data2, dtype=np.float32)
    y3 = y3[:,:,:,0]
    #y1 = y1[:,:,:,0]
    x_1 = torch.from_numpy(y3)
    print("x: ", model(x_1[i].view(-1,784)))
# Out:
# x:  tensor([[1.0097e-11]], grad_fn=<SigmoidBackward>)
# x:  tensor([[6.6130e-12]], grad_fn=<SigmoidBackward>)
# x:  tensor([[1.6402e-12]], grad_fn=<SigmoidBackward>)
# x:  tensor([[4.5849e-13]], grad_fn=<SigmoidBackward>)
# x:  tensor([[8.6697e-13]], grad_fn=<SigmoidBackward>)
