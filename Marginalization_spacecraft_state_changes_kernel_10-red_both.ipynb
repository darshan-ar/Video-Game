# %% [raw]
# In this code, multiple positions and reloading of drone and tank. Drone: Spacecraft. Reloading State: Going Black.
#
# Drone and Tank reloading: Red
#
# Channels:32
# Output: 15
# CNN kernel: 10
# Maxpool kernel:10

# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random
import cv2
from torchvision import models
from torchsummary import summary

Batch_Size = 50
num_epochs = 200
learning_rate = 1e-5
samples = 20000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
uframes = []
vidcap = cv2.VideoCapture('red_both.avi')
success,image = vidcap.read()
while success:
    uframes.append(image)   
    success,image = vidcap.read()

# cap = cv2.VideoCapture('video_drone_tank.avi')


# ret, frame = cap.read()

# uframes.append(frame)
# flag = 0
# z = 0
# while(z<30):
#     ret, frame = cap.read()
#     #np_frame = cv2.imread('video', frame) # does not work
#     #np_frame = np.asarray(cv2.GetMat(frame)) # does not work
#     #print(np_frame.shape)
#     for a in uframes:
#         if (np.array(a).any() != None):
#             print("a: ",np.shape(a))
#             print("frame: ",np.shape(a))
#             difference = cv2.subtract(np.array(a), np.array(frame))    
#             result = not np.any(difference)
#             #print("inside for")
#             if result is True:
#                 flag = 1
#                 #print("setting flag")
#                 break
#     if(not flag):
#         #print("appending")
#         uframes.append(frame)
#     z+=1

for i,frame in enumerate(uframes):
    uframes[i] = cv2.resize(frame,(100,100))
    
print(np.shape(uframes[0]))

print("length: ",len(uframes))
for i in range(samples):
    data1.append(np.array(np.transpose(np.asarray(uframes[i % len(uframes)]),(2,0,1)),dtype=np.float32))
    data2.append(np.array(np.transpose(np.asarray(uframes[(i+1) % len(uframes)]),(2,0,1)),dtype=np.float32))



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = '#9b7653')
# img.paste(im1,(5,75),im1)
# img.paste(im1,(10,55),im1)
# img.paste(im1,(25,50),im1)
# img.paste(im2,(75,5),im2)
# img.paste(im2,(60,30),im2)
# img.paste(im2,(90,20),im2)
# img.paste(im3,(75,60),im3)
# img.paste(im3,(60,80),im3)
im_n = np.reshape(img,(100,100,3))
b = np.asarray(im_n)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)

#y0 = np.array(np.transpose(np.asarray(y0),(0,3,1,2)),dtype=np.float32)
#y1 = np.array(np.transpose(np.asarray(y1),(0,3,1,2)),dtype=np.float32)
print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=10, stride=1)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=5)

#         # Convolution 2
#         self.cnn2 = nn.Conv2d(in_channels=16, out_channels=3, kernel_size=5, stride=1, padding=2)
#         self.relu2 = nn.ReLU()

#         # Max pool 2
#         self.maxpool2 = nn.MaxPool2d(kernel_size=5)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(10368, 15)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        #out = self.cnn2(out)
        #out = self.relu2(out)

        # Max pool 2 
        #out = self.maxpool2(out)
        im_out = out
        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return im_out,out
    
model = CNNModel()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x)[1],model(y)[1])
        # ===================backward====================
 
        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    #print("shape: ", np.shape(model(x[0].reshape(1,3,100, 100))[0]))
#     print("x: ", model(x[0].reshape(1,3,100, 100)))
#     print("y:", model(y[0].reshape(1,3,100, 100)))
#     print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# (100, 100, 3)
# length:  264
# (20000, 3, 100, 100)
# epoch [1/200], loss:-1.8485
# epoch [2/200], loss:-2.8353
# epoch [3/200], loss:-3.3186
# epoch [4/200], loss:-3.2733
# epoch [5/200], loss:-3.1628
# epoch [6/200], loss:-3.0708
# epoch [7/200], loss:-3.2041
# epoch [8/200], loss:-3.3326
# epoch [9/200], loss:-3.1275
# epoch [10/200], loss:-3.1623
# epoch [11/200], loss:-3.2422
# epoch [12/200], loss:-3.1789
# epoch [13/200], loss:-3.3317
# epoch [14/200], loss:-3.2478
# epoch [15/200], loss:-3.1275
# epoch [16/200], loss:-3.4603
# epoch [17/200], loss:-3.3217
# epoch [18/200], loss:-3.3402
# epoch [19/200], loss:-3.4163
# epoch [20/200], loss:-3.5554
# epoch [21/200], loss:-3.9300
# epoch [22/200], loss:-3.8689
# epoch [23/200], loss:-4.1542
# epoch [24/200], loss:-3.9108
# epoch [25/200], loss:-4.1683
# epoch [26/200], loss:-4.1418
# epoch [27/200], loss:-4.3441
# epoch [28/200], loss:-4.0179
# epoch [29/200], loss:-4.0996
# epoch [30/200], loss:-4.1804
# epoch [31/200], loss:-4.1713
# epoch [32/200], loss:-4.3637
# epoch [33/200], loss:-4.1731
# epoch [34/200], loss:-4.3495
# epoch [35/200], loss:-3.9549
# epoch [36/200], loss:-4.2172
# epoch [37/200], loss:-4.1889
# epoch [38/200], loss:-4.1594
# epoch [39/200], loss:-4.5347
# epoch [40/200], loss:-4.1725
# epoch [41/200], loss:-4.3994
# epoch [42/200], loss:-4.4190
# epoch [43/200], loss:-4.1749
# epoch [44/200], loss:-4.3039
# epoch [45/200], loss:-4.5606
# epoch [46/200], loss:-4.4958
# epoch [47/200], loss:-4.2464
# epoch [48/200], loss:-4.5420
# epoch [49/200], loss:-4.3673
# epoch [50/200], loss:-4.6429
# epoch [51/200], loss:-4.6052
# epoch [52/200], loss:-4.6553
# epoch [53/200], loss:-4.8515
# epoch [54/200], loss:-4.7611
# epoch [55/200], loss:-4.4345
# epoch [56/200], loss:-4.5648
# epoch [57/200], loss:-4.2294
# epoch [58/200], loss:-4.3798
# epoch [59/200], loss:-4.6059
# epoch [60/200], loss:-4.8013
# epoch [61/200], loss:-5.1725
# epoch [62/200], loss:-4.8720
# epoch [63/200], loss:-4.6945
# epoch [64/200], loss:-4.4485
# epoch [65/200], loss:-4.9211
# epoch [66/200], loss:-4.3961
# epoch [67/200], loss:-4.6792
# epoch [68/200], loss:-4.4097
# epoch [69/200], loss:-4.5877
# epoch [70/200], loss:-4.5229
# epoch [71/200], loss:-4.6426
# epoch [72/200], loss:-4.6987
# epoch [73/200], loss:-4.9251
# epoch [74/200], loss:-4.6691
# epoch [75/200], loss:-4.5643
# epoch [76/200], loss:-4.8835
# epoch [77/200], loss:-4.6536
# epoch [78/200], loss:-4.6858
# epoch [79/200], loss:-4.4760
# epoch [80/200], loss:-4.7849
# epoch [81/200], loss:-5.0534
# epoch [82/200], loss:-4.8461
# epoch [83/200], loss:-4.7007
# epoch [84/200], loss:-4.4341
# epoch [85/200], loss:-4.5294
# epoch [86/200], loss:-4.5080
# epoch [87/200], loss:-4.2982
# epoch [88/200], loss:-4.5859
# epoch [89/200], loss:-4.3608
# epoch [90/200], loss:-5.0815
# epoch [91/200], loss:-4.9566
# epoch [92/200], loss:-4.4427
# epoch [93/200], loss:-4.6590
# epoch [94/200], loss:-4.6620
# epoch [95/200], loss:-4.3452
# epoch [96/200], loss:-4.4928
# epoch [97/200], loss:-4.8947
# epoch [98/200], loss:-4.5907
# epoch [99/200], loss:-4.5893
# epoch [100/200], loss:-4.7020
# epoch [101/200], loss:-5.1417
# epoch [102/200], loss:-4.6961
# epoch [103/200], loss:-4.4987
# epoch [104/200], loss:-4.2917
# epoch [105/200], loss:-4.5013
# epoch [106/200], loss:-4.6539
# epoch [107/200], loss:-4.6195
# epoch [108/200], loss:-4.9526
# epoch [109/200], loss:-4.8741
# epoch [110/200], loss:-4.8075
# epoch [111/200], loss:-4.7406
# epoch [112/200], loss:-4.7166
# epoch [113/200], loss:-4.7387
# epoch [114/200], loss:-4.8316
# epoch [115/200], loss:-4.8875
# epoch [116/200], loss:-4.7663
# epoch [117/200], loss:-4.6869
# epoch [118/200], loss:-4.6169
# epoch [119/200], loss:-4.8553
# epoch [120/200], loss:-4.6403
# epoch [121/200], loss:-4.8160
# epoch [122/200], loss:-4.9738
# epoch [123/200], loss:-4.8947
# epoch [124/200], loss:-5.0118
# epoch [125/200], loss:-4.7788
# epoch [126/200], loss:-4.9341
# epoch [127/200], loss:-4.5795
# epoch [128/200], loss:-4.6540
# epoch [129/200], loss:-4.7499
# epoch [130/200], loss:-5.0120
# epoch [131/200], loss:-4.9977
# epoch [132/200], loss:-5.0246
# epoch [133/200], loss:-4.3514
# epoch [134/200], loss:-4.6683
# epoch [135/200], loss:-4.8691
# epoch [136/200], loss:-4.9109
# epoch [137/200], loss:-4.6451
# epoch [138/200], loss:-4.7508
# epoch [139/200], loss:-4.9752
# epoch [140/200], loss:-4.6515
# epoch [141/200], loss:-4.6875
# epoch [142/200], loss:-4.8367
# epoch [143/200], loss:-4.6021
# epoch [144/200], loss:-4.3644
# epoch [145/200], loss:-5.0966
# epoch [146/200], loss:-4.5909
# epoch [147/200], loss:-4.8837
# epoch [148/200], loss:-4.7556
# epoch [149/200], loss:-4.6953
# epoch [150/200], loss:-4.9530
# epoch [151/200], loss:-4.9271
# epoch [152/200], loss:-5.0189
# epoch [153/200], loss:-4.8027
# epoch [154/200], loss:-5.0274
# epoch [155/200], loss:-4.7166
# epoch [156/200], loss:-5.0756
# epoch [157/200], loss:-4.8971
# epoch [158/200], loss:-4.5034
# epoch [159/200], loss:-5.0548
# epoch [160/200], loss:-5.0397
# epoch [161/200], loss:-4.8075
# epoch [162/200], loss:-4.9772
# epoch [163/200], loss:-4.4621
# epoch [164/200], loss:-4.6378
# epoch [165/200], loss:-4.9470
# epoch [166/200], loss:-4.9653
# epoch [167/200], loss:-5.0875
# epoch [168/200], loss:-4.7736
# epoch [169/200], loss:-4.8619
# epoch [170/200], loss:-4.6695
# epoch [171/200], loss:-4.6612
# epoch [172/200], loss:-4.7694
# epoch [173/200], loss:-4.8340
# epoch [174/200], loss:-4.8239
# epoch [175/200], loss:-4.7424
# epoch [176/200], loss:-4.6589
# epoch [177/200], loss:-4.2125
# epoch [178/200], loss:-4.8531
# epoch [179/200], loss:-4.9984
# epoch [180/200], loss:-4.7044
# epoch [181/200], loss:-4.6243
# epoch [182/200], loss:-5.3273
# epoch [183/200], loss:-4.5349
# epoch [184/200], loss:-4.8222
# epoch [185/200], loss:-4.7210
# epoch [186/200], loss:-5.0563
# epoch [187/200], loss:-5.2081
# epoch [188/200], loss:-4.7663
# epoch [189/200], loss:-4.6554
# epoch [190/200], loss:-4.9131
# epoch [191/200], loss:-4.7500
# epoch [192/200], loss:-4.7484
# epoch [193/200], loss:-4.8255
# epoch [194/200], loss:-4.7579
# epoch [195/200], loss:-4.7253
# epoch [196/200], loss:-4.9502
# epoch [197/200], loss:-4.8626
# epoch [198/200], loss:-4.7824
# epoch [199/200], loss:-4.9198
# epoch [200/200], loss:-4.8152

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

drone_panels={}
tank_panels={}
tank_reloading_panels={}
drone_reloading_panels={}

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

for i in range(32):

    tank_info_panel = i
    #rone_info_panel = i
    #Blank
    img = uframes[1]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Blank: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("Blank: ",val,pos)


    print("**********")
    img = uframes[2]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank_info,pos_tank_info = val_pos(output_tank)
    print("Tank: ",val_tank_info,pos_tank_info)
#     output_drone = output[0][drone_info_panel]
#     val_tank_drone_info,pos_tank_drone_info = val_pos(output_drone)
#     print("Tank: ",val,pos)
    print("**********")

    #Drone
    img = uframes[3]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_drone_info,pos_drone_info = val_pos(output_tank)
    print("Drone: ",val_drone_info,pos_drone_info)
#     output_drone = output[0][drone_info_panel]
#     val_drone_drone_info,pos_drone_drone_info = val_pos(output_drone)
#     print("Drone: ",val,pos)
    
    print("**********")  
    img = uframes[4]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank_reloading_info,pos_tank_reloading_info = val_pos(output_tank)
    print("Tank reloading: ",val_tank_reloading_info,pos_tank_reloading_info)
#     output_drone = output[0][drone_info_panel]
#     val_tank_reloading_drone_info,pos_tank_reloading_drone_info = val_pos(output_drone)
#     print("Tank reloading: ",val,pos)

    print("**********")
    #Drone Reloadingg
    img = uframes[5]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_drone_reloading_info,pos_drone_reloading_info = val_pos(output_tank)
    print("Drone reloading: ",val_drone_reloading_info,pos_drone_reloading_info)
#     output_drone = output[0][drone_info_panel]
#     val_drone_reloading_drone_info,pos_drone_reloading_drone_info = val_pos(output_drone)
#     print("Drone reloading: ",val,pos)

    print("**********")
    #Tank and Drone
    img= uframes[0]
    z = Image.fromarray(img)
    #z.show()
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TD: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("TD: ",val,pos)
    
    print("**********")
    #Tank and Drone reloading
    img= uframes[6]
    z = Image.fromarray(img)
    #z.show()
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TrDr: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("TD: ",val,pos)
    
    print("\nPanel ",i)
    print("\n++++++++++++++++++++++++++++++++++++++++++++\n")
    if val_tank_info > max(val_drone_reloading_info,val_tank_reloading_info,val_drone_info):
        tank_panels[i]=val_tank_info-0.5
    elif val_drone_info > max(val_drone_reloading_info,val_tank_reloading_info,val_tank_info):
        drone_panels[i]=val_drone_info-0.5
    elif val_tank_reloading_info > max(val_drone_reloading_info,val_tank_info,val_drone_info):
        tank_reloading_panels[i]=val_tank_reloading_info-0.5
    elif val_drone_reloading_info > max(val_tank_reloading_info,val_tank_info,val_drone_info):
        drone_reloading_panels[i]=val_drone_reloading_info-0.5
print(tank_panels)
# Out:
# Blank:  1153.5125 (1, 1)
# **********
# Tank:  1479.8754 (6, 0)
# **********
# Drone:  1384.3462 (11, 9)
# **********
# Tank reloading:  1378.522 (5, 1)
# **********
# Drone reloading:  1398.8904 (10, 10)
# **********
# TD:  1713.9255 (6, 0)
# **********
# TrDr:  1623.8489 (10, 10)
#
# Panel  0
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1209.0632 (3, 9)
# **********
# Tank:  1384.0013 (3, 9)
# **********
# Drone:  1502.0999 (10, 9)
# **********
# Tank reloading:  1483.5002 (5, 2)
# **********
# Drone reloading:  1486.0625 (11, 10)
# **********
# TD:  1663.6501 (10, 9)
# **********
# TrDr:  1759.4728 (11, 10)
#
# Panel  1
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1055.2733 (3, 8)
# **********
# Tank:  1362.9357 (5, 0)
# **********
# Drone:  1383.1643 (10, 9)
# **********
# Tank reloading:  1182.7394 (6, 0)
# **********
# Drone reloading:  1208.6636 (3, 8)
# **********
# TD:  1689.4412 (10, 9)
# **********
# TrDr:  1335.9835 (6, 0)
#
# Panel  2
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1915.407 (3, 8)
# **********
# Tank:  2201.632 (5, 1)
# **********
# Drone:  2245.7751 (10, 10)
# **********
# Tank reloading:  2285.8125 (6, 0)
# **********
# Drone reloading:  2252.669 (11, 9)
# **********
# TD:  2523.3594 (5, 1)
# **********
# TrDr:  2622.4841 (11, 9)
#
# Panel  3
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1235.4036 (3, 9)
# **********
# Tank:  1524.304 (6, 0)
# **********
# Drone:  1481.1162 (10, 9)
# **********
# Tank reloading:  1581.6108 (5, 1)
# **********
# Drone reloading:  1614.5435 (11, 9)
# **********
# TD:  1773.6052 (6, 0)
# **********
# TrDr:  1962.0153 (5, 1)
#
# Panel  4
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1657.3068 (16, 14)
# **********
# Tank:  2233.5918 (5, 0)
# **********
# Drone:  2086.9502 (10, 8)
# **********
# Tank reloading:  1952.4816 (6, 0)
# **********
# Drone reloading:  2015.1096 (11, 9)
# **********
# TD:  2675.8938 (5, 0)
# **********
# TrDr:  2310.1353 (6, 0)
#
# Panel  5
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1811.106 (8, 9)
# **********
# Tank:  2082.8428 (8, 9)
# **********
# Drone:  2162.8064 (10, 9)
# **********
# Tank reloading:  2285.7778 (5, 1)
# **********
# Drone reloading:  2254.8916 (10, 9)
# **********
# TD:  2423.2852 (10, 9)
# **********
# TrDr:  2730.755 (5, 1)
#
# Panel  6
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2069.5002 (16, 14)
# **********
# Tank:  2307.4404 (4, 1)
# **********
# Drone:  2447.4885 (11, 10)
# **********
# Tank reloading:  2651.695 (5, 0)
# **********
# Drone reloading:  2787.1555 (10, 9)
# **********
# TD:  2689.399 (11, 10)
# **********
# TrDr:  3372.956 (10, 9)
#
# Panel  7
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2122.3044 (11, 12)
# **********
# Tank:  2452.2446 (11, 12)
# **********
# Drone:  2485.5088 (10, 10)
# **********
# Tank reloading:  2455.035 (6, 0)
# **********
# Drone reloading:  2461.9941 (12, 9)
# **********
# TD:  2810.8345 (10, 10)
# **********
# TrDr:  2794.669 (12, 9)
#
# Panel  8
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1393.8999 (7, 9)
# **********
# Tank:  1898.2494 (5, 0)
# **********
# Drone:  1835.0334 (11, 9)
# **********
# Tank reloading:  1745.0355 (5, 1)
# **********
# Drone reloading:  1731.5104 (11, 10)
# **********
# TD:  2342.0923 (5, 1)
# **********
# TrDr:  2084.6602 (5, 1)
#
# Panel  9
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1458.9431 (16, 14)
# **********
# Tank:  1736.6569 (16, 14)
# **********
# Drone:  1717.9048 (16, 14)
# **********
# Tank reloading:  1739.2156 (16, 14)
# **********
# Drone reloading:  1758.6072 (16, 14)
# **********
# TD:  1992.6179 (16, 14)
# **********
# TrDr:  2041.8317 (16, 14)
#
# Panel  10
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2348.297 (12, 6)
# **********
# Tank:  2622.1982 (5, 1)
# **********
# Drone:  2696.2769 (10, 10)
# **********
# Tank reloading:  2750.8904 (5, 1)
# **********
# Drone reloading:  2750.7795 (11, 9)
# **********
# TD:  2959.8257 (5, 1)
# **********
# TrDr:  3153.677 (5, 1)
#
# Panel  11
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1930.4277 (7, 8)
# **********
# Tank:  2223.8235 (5, 0)
# **********
# Drone:  2243.3848 (10, 10)
# **********
# Tank reloading:  2276.5725 (6, 1)
# **********
# Drone reloading:  2381.1062 (11, 9)
# **********
# TD:  2535.4492 (5, 0)
# **********
# TrDr:  2724.7832 (11, 9)
#
# Panel  12
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  0.0 (0, 0)
# **********
# Tank:  0.0 (0, 0)
# **********
# Drone:  0.0 (0, 0)
# **********
# Tank reloading:  0.0 (0, 0)
# **********
# Drone reloading:  0.0 (0, 0)
# **********
# TD:  0.0 (0, 0)
# **********
# TrDr:  0.0 (0, 0)
#
# Panel  13
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2178.7568 (9, 12)
# **********
# Tank:  2482.3982 (9, 12)
# **********
# Drone:  2569.8467 (10, 8)
# **********
# Tank reloading:  2564.6848 (6, 1)
# **********
# Drone reloading:  2492.7178 (11, 10)
# **********
# TD:  2865.8533 (10, 9)
# **********
# TrDr:  2878.7698 (6, 1)
#
# Panel  14
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  0.0 (0, 0)
# **********
# Tank:  0.0 (0, 0)
# **********
# Drone:  0.0 (0, 0)
# **********
# Tank reloading:  0.0 (0, 0)
# **********
# Drone reloading:  0.0 (0, 0)
# **********
# TD:  0.0 (0, 0)
# **********
# TrDr:  0.0 (0, 0)
#
# Panel  15
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1093.7128 (11, 12)
# **********
# Tank:  1452.2007 (5, 1)
# **********
# Drone:  1349.6016 (3, 8)
# **********
# Tank reloading:  1362.9921 (5, 1)
# **********
# Drone reloading:  1320.4429 (11, 10)
# **********
# TD:  1701.1968 (5, 1)
# **********
# TrDr:  1589.126 (5, 1)
#
# Panel  16
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1674.752 (15, 15)
# **********
# Tank:  2038.9463 (5, 1)
# **********
# Drone:  1927.9473 (15, 15)
# **********
# Tank reloading:  2167.042 (5, 0)
# **********
# Drone reloading:  2160.976 (10, 9)
# **********
# TD:  2286.5479 (5, 1)
# **********
# TrDr:  2656.4263 (10, 9)
#
# Panel  17
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1927.5684 (7, 9)
# **********
# Tank:  2294.2527 (5, 0)
# **********
# Drone:  2351.106 (10, 10)
# **********
# Tank reloading:  2182.2559 (6, 0)
# **********
# Drone reloading:  2212.9468 (11, 9)
# **********
# TD:  2719.8242 (5, 0)
# **********
# TrDr:  2469.3582 (11, 9)
#
# Panel  18
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2195.7397 (17, 14)
# **********
# Tank:  2680.6235 (6, 0)
# **********
# Drone:  2582.5474 (10, 9)
# **********
# Tank reloading:  2546.5728 (5, 0)
# **********
# Drone reloading:  2483.1777 (10, 10)
# **********
# TD:  3069.1196 (10, 9)
# **********
# TrDr:  2834.9993 (10, 10)
#
# Panel  19
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1691.5546 (16, 15)
# **********
# Tank:  2100.242 (5, 1)
# **********
# Drone:  2080.9604 (11, 9)
# **********
# Tank reloading:  2177.8037 (5, 1)
# **********
# Drone reloading:  2203.614 (10, 9)
# **********
# TD:  2480.3257 (11, 9)
# **********
# TrDr:  2691.227 (5, 1)
#
# Panel  20
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1997.5066 (11, 12)
# **********
# Tank:  2449.9268 (5, 0)
# **********
# Drone:  2346.5342 (11, 10)
# **********
# Tank reloading:  2578.8926 (5, 1)
# **********
# Drone reloading:  2461.2117 (10, 10)
# **********
# TD:  2799.7437 (5, 0)
# **********
# TrDr:  3047.2878 (5, 1)
#
# Panel  21
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2006.9948 (14, 16)
# **********
# Tank:  2273.8113 (5, 0)
# **********
# Drone:  2314.0466 (10, 10)
# **********
# Tank reloading:  2461.916 (6, 1)
# **********
# Drone reloading:  2568.9695 (12, 10)
# **********
# TD:  2585.9998 (5, 0)
# **********
# TrDr:  3026.3354 (6, 1)
#
# Panel  22
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2368.9883 (16, 14)
# **********
# Tank:  2867.934 (5, 0)
# **********
# Drone:  2707.543 (11, 10)
# **********
# Tank reloading:  2731.954 (4, 1)
# **********
# Drone reloading:  2715.6187 (11, 10)
# **********
# TD:  3219.0908 (5, 0)
# **********
# TrDr:  3078.2744 (11, 10)
#
# Panel  23
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  0.0 (0, 0)
# **********
# Tank:  0.0 (0, 0)
# **********
# Drone:  0.0 (0, 0)
# **********
# Tank reloading:  0.0 (0, 0)
# **********
# Drone reloading:  0.0 (0, 0)
# **********
# TD:  0.0 (0, 0)
# **********
# TrDr:  0.0 (0, 0)
#
# Panel  24
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1671.9407 (8, 10)
# **********
# Tank:  2073.6172 (5, 1)
# **********
# Drone:  1994.1005 (11, 10)
# **********
# Tank reloading:  2169.9421 (5, 0)
# **********
# Drone reloading:  2077.6987 (11, 10)
# **********
# TD:  2393.912 (11, 10)
# **********
# TrDr:  2578.3726 (5, 0)
#
# Panel  25
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1621.306 (12, 3)
# **********
# Tank:  1874.3358 (12, 3)
# **********
# Drone:  1936.4609 (11, 9)
# **********
# Tank reloading:  2129.957 (5, 1)
# **********
# Drone reloading:  2118.973 (11, 10)
# **********
# TD:  2195.477 (11, 9)
# **********
# TrDr:  2627.3616 (11, 10)
#
# Panel  26
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  756.89026 (10, 12)
# **********
# Tank:  1024.8633 (5, 0)
# **********
# Drone:  979.439 (10, 10)
# **********
# Tank reloading:  874.9042 (10, 12)
# **********
# Drone reloading:  976.4205 (10, 12)
# **********
# TD:  1251.0542 (5, 0)
# **********
# TrDr:  1095.2656 (10, 12)
#
# Panel  27
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  0.0 (0, 0)
# **********
# Tank:  0.0 (0, 0)
# **********
# Drone:  0.0 (0, 0)
# **********
# Tank reloading:  0.0 (0, 0)
# **********
# Drone reloading:  0.0 (0, 0)
# **********
# TD:  0.0 (0, 0)
# **********
# TrDr:  0.0 (0, 0)
#
# Panel  28
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1277.9924 (2, 9)
# **********
# Tank:  1642.5876 (4, 0)
# **********
# Drone:  1613.4863 (11, 9)
# **********
# Tank reloading:  1628.1095 (5, 1)
# **********
# Drone reloading:  1657.4192 (10, 11)
# **********
# TD:  1970.5428 (4, 0)
# **********
# TrDr:  2009.0664 (10, 11)
#
# Panel  29
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1328.4319 (12, 5)
# **********
# Tank:  1614.6013 (6, 0)
# **********
# Drone:  1623.385 (10, 10)
# **********
# Tank reloading:  1374.1921 (12, 5)
# **********
# Drone reloading:  1402.8134 (12, 5)
# **********
# TD:  1906.9154 (6, 0)
# **********
# TrDr:  1450.2993 (12, 5)
#
# Panel  30
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2188.0298 (16, 14)
# **********
# Tank:  2654.065 (4, 0)
# **********
# Drone:  2571.1255 (16, 14)
# **********
# Tank reloading:  2552.0522 (16, 14)
# **********
# Drone reloading:  2555.9138 (16, 14)
# **********
# TD:  3052.021 (4, 0)
# **********
# TrDr:  2923.2295 (11, 10)
#
# Panel  31
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# {0: 1479.3753662109375, 5: 2233.091796875, 9: 1897.7493896484375, 16: 1451.70068359375, 19: 2680.12353515625, 23: 2867.43408203125, 27: 1024.36328125, 31: 2653.56494140625}

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for j in range(len(list(drone_reloading_panels))):
    
    tank_info_panel = list(tank_panels)[0]
    drone_info_panel = list(drone_panels)[0]
    tankr_info_panel = list(tank_reloading_panels)[0]
    droner_info_panel = list(drone_reloading_panels)[j] #12

    #print(tankr_info_panel,tank_reloading_panels[tankr_info_panel])

    tank_threshold= tank_panels[tank_info_panel]
    tankr_threshold= tank_reloading_panels[tankr_info_panel]
    drone_threshold= drone_panels[drone_info_panel]
    droner_threshold= drone_reloading_panels[droner_info_panel]

    def val_pos(array):
        value = np.sum(array)
        position = np.unravel_index(np.argmax(array),array.shape)
        return value,position
    dronec=[]
    tankc=[]
    tankr=[]
    droner=[]
    #Blank
    for i in range(50):
        #x = cv2.imread(r"C:\Users\darshan19\Desktop\AoI\CNN\Images1\0b.png",-1)
        #x = cv2.resize(x,(100,100))
        img = uframes[i]
        #print(np.shape(img))
        # = Image.fromarray(img)
        #z.show()
        data3=[]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        #print(np.shape(x_1))
        output = model(x_1.reshape(1,3,100, 100))[0].detach().numpy()
        output_tank = output[0][tank_info_panel]
        val_tank,pos_tank = val_pos(output_tank)
        output_tankr = output[0][tankr_info_panel]
        val_tankr,pos_tankr = val_pos(output_tankr)
        print(i)
        output_drone = output[0][drone_info_panel]
        val_drone,pos_drone = val_pos(output_drone)
        output_droner = output[0][droner_info_panel]
        val_droner,pos_droner = val_pos(output_droner)

        if val_tank>tank_threshold:
    #         print("tank present")
    #         print("Tank info: ",val_tank,pos_tank)
            tankc.append(pos_tank)
        if val_drone>drone_threshold:
    #         print("drone present")
    #         print("Drone info: ",val_drone,pos_drone)
            dronec.append(pos_drone)
        if val_tankr>tankr_threshold:
#             print("tank reloading present")
#             print("Tank info: ",val_tank,pos_tank)
            tankr.append(pos_tankr)
        if val_droner>droner_threshold:
            print("drone reloading present")
            print("Drone info: ",val_droner,pos_droner)
            dronec.append(pos_drone)
    print("\n")
    print(list(tank_reloading_panels)[j])
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n\n")
# Out:
# 0
# drone reloading present
# Drone info:  1773.6052 (6, 0)
# 1
# 2
# 3
# 4
# 5
# drone reloading present
# Drone info:  1614.5435 (11, 9)
# 6
# drone reloading present
# Drone info:  1962.0153 (5, 1)
# 7
# drone reloading present
# Drone info:  1756.9249 (6, 0)
# 8
# drone reloading present
# Drone info:  1753.6697 (6, 0)
# 9
# drone reloading present
# Drone info:  1755.7698 (6, 0)
# 10
# drone reloading present
# Drone info:  1780.6375 (6, 0)
# 11
# drone reloading present
# Drone info:  1814.2847 (6, 1)
# 12
# drone reloading present
# Drone info:  1884.4939 (6, 1)
# 13
# drone reloading present
# Drone info:  1938.242 (6, 1)
# 14
# drone reloading present
# Drone info:  1835.8589 (6, 1)
# 15
# drone reloading present
# Drone info:  1889.8134 (9, 9)
# 16
# drone reloading present
# Drone info:  1905.404 (6, 1)
# 17
# drone reloading present
# Drone info:  1896.8596 (6, 1)
# 18
# drone reloading present
# Drone info:  1901.2742 (6, 2)
# 19
# drone reloading present
# Drone info:  1887.131 (6, 2)
# 20
# drone reloading present
# Drone info:  1875.6727 (6, 2)
# 21
# drone reloading present
# Drone info:  1831.4019 (6, 2)
# 22
# drone reloading present
# Drone info:  1640.9879 (5, 2)
# 23
# 24
# drone reloading present
# Drone info:  1965.195 (11, 4)
# 25
# drone reloading present
# Drone info:  1857.554 (6, 2)
# 26
# drone reloading present
# Drone info:  1918.9105 (6, 2)
# 27
# drone reloading present
# Drone info:  1871.227 (6, 2)
# 28
# drone reloading present
# Drone info:  1913.2645 (9, 9)
# 29
# drone reloading present
# Drone info:  1939.3745 (6, 3)
# 30
# 31
# drone reloading present
# Drone info:  1923.8188 (6, 3)
# 32
# drone reloading present
# Drone info:  1833.9016 (6, 3)
# 33
# drone reloading present
# Drone info:  1865.4463 (6, 3)
# 34
# drone reloading present
# Drone info:  1805.1292 (6, 3)
# 35
# drone reloading present
# Drone info:  1868.6362 (6, 3)
# 36
# drone reloading present
# Drone info:  1895.9181 (6, 4)
# 37
# drone reloading present
# Drone info:  1935.8303 (6, 4)
# 38
# drone reloading present
# Drone info:  1896.4197 (6, 4)
# 39
# drone reloading present
# Drone info:  1905.6847 (9, 9)
# 40
# drone reloading present
# Drone info:  1907.7885 (6, 4)
# 41
# drone reloading present
# Drone info:  1655.5503 (6, 4)
# 42
# drone reloading present
# Drone info:  1697.4563 (5, 5)
# 43
# drone reloading present
# Drone info:  1635.2949 (11, 10)
# 44
# drone reloading present
# Drone info:  2076.7021 (5, 5)
# 45
# drone reloading present
# Drone info:  1851.4148 (6, 4)
# 46
# drone reloading present
# Drone info:  1872.1189 (6, 4)
# 47
# drone reloading present
# Drone info:  1875.8411 (6, 4)
# 48
# drone reloading present
# Drone info:  1855.4199 (6, 5)
# 49
# drone reloading present
# Drone info:  1876.846 (6, 5)
#
#
# 3
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# 1
# 2
# 3
# 4
# 5
# drone reloading present
# Drone info:  2787.1555 (10, 9)
# 6
# drone reloading present
# Drone info:  3372.956 (10, 9)
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# drone reloading present
# Drone info:  2801.0132 (9, 7)
# 14
# 15
# 16
# 17
# drone reloading present
# Drone info:  2815.211 (12, 9)
# 18
# drone reloading present
# Drone info:  2886.7583 (12, 8)
# 19
# 20
# 21
# 22
# 23
# 24
# drone reloading present
# Drone info:  3344.8042 (10, 4)
# 25
# 26
# drone reloading present
# Drone info:  2798.4888 (9, 7)
# 27
# drone reloading present
# Drone info:  2853.6655 (9, 8)
# 28
# drone reloading present
# Drone info:  2804.7178 (10, 9)
# 29
# 30
# 31
# 32
# drone reloading present
# Drone info:  2835.8438 (12, 8)
# 33
# 34
# 35
# 36
# drone reloading present
# Drone info:  2814.2344 (10, 5)
# 37
# drone reloading present
# Drone info:  2836.1738 (9, 7)
# 38
# drone reloading present
# Drone info:  2815.4294 (9, 8)
# 39
# 40
# 41
# 42
# 43
# drone reloading present
# Drone info:  2827.7483 (10, 9)
# 44
# drone reloading present
# Drone info:  3490.6035 (10, 9)
# 45
# 46
# drone reloading present
# Drone info:  2849.7678 (12, 8)
# 47
# drone reloading present
# Drone info:  2795.193 (12, 6)
# 48
# 49
#
#
# 6
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# drone reloading present
# Drone info:  1992.6179 (16, 14)
# 1
# 2
# 3
# 4
# 5
# drone reloading present
# Drone info:  1758.6072 (16, 14)
# 6
# drone reloading present
# Drone info:  2041.8317 (16, 14)
# 7
# drone reloading present
# Drone info:  1952.9877 (16, 14)
# 8
# drone reloading present
# Drone info:  2059.9658 (12, 8)
# 9
# drone reloading present
# Drone info:  2117.7627 (13, 6)
# 10
# drone reloading present
# Drone info:  1874.4927 (16, 14)
# 11
# drone reloading present
# Drone info:  1981.1963 (11, 4)
# 12
# drone reloading present
# Drone info:  2103.2747 (10, 5)
# 13
# drone reloading present
# Drone info:  2090.8616 (9, 6)
# 14
# drone reloading present
# Drone info:  2081.2168 (9, 8)
# 15
# drone reloading present
# Drone info:  2039.9203 (5, 1)
# 16
# drone reloading present
# Drone info:  2125.0007 (5, 2)
# 17
# drone reloading present
# Drone info:  2024.7971 (16, 14)
# 18
# drone reloading present
# Drone info:  2117.2483 (16, 14)
# 19
# drone reloading present
# Drone info:  2169.712 (13, 6)
# 20
# drone reloading present
# Drone info:  1910.3766 (16, 14)
# 21
# drone reloading present
# Drone info:  2035.0507 (11, 4)
# 22
# drone reloading present
# Drone info:  1916.509 (16, 14)
# 23
# 24
# drone reloading present
# Drone info:  2176.8882 (16, 14)
# 25
# drone reloading present
# Drone info:  2158.2876 (10, 5)
# 26
# drone reloading present
# Drone info:  2151.326 (9, 6)
# 27
# drone reloading present
# Drone info:  2076.2139 (9, 8)
# 28
# drone reloading present
# Drone info:  2030.9431 (5, 3)
# 29
# drone reloading present
# Drone info:  2067.3035 (16, 14)
# 30
# 31
# drone reloading present
# Drone info:  2017.1243 (16, 14)
# 32
# drone reloading present
# Drone info:  2112.1902 (16, 14)
# 33
# drone reloading present
# Drone info:  2206.5679 (13, 6)
# 34
# drone reloading present
# Drone info:  1940.5743 (16, 14)
# 35
# drone reloading present
# Drone info:  2011.5093 (11, 4)
# 36
# drone reloading present
# Drone info:  2116.5464 (10, 5)
# 37
# drone reloading present
# Drone info:  2110.1475 (9, 6)
# 38
# drone reloading present
# Drone info:  2109.6519 (9, 8)
# 39
# drone reloading present
# Drone info:  2024.8524 (10, 9)
# 40
# drone reloading present
# Drone info:  2088.4482 (16, 14)
# 41
# drone reloading present
# Drone info:  1821.9983 (16, 14)
# 42
# drone reloading present
# Drone info:  1889.2427 (16, 14)
# 43
# drone reloading present
# Drone info:  1812.1039 (16, 14)
# 44
# drone reloading present
# Drone info:  2215.045 (16, 14)
# 45
# drone reloading present
# Drone info:  2092.2603 (16, 14)
# 46
# drone reloading present
# Drone info:  2164.8855 (5, 5)
# 47
# drone reloading present
# Drone info:  2130.6724 (13, 6)
# 48
# drone reloading present
# Drone info:  1921.8124 (16, 14)
# 49
# drone reloading present
# Drone info:  2049.7312 (11, 4)
#
#
# 11
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# drone reloading present
# Drone info:  2535.4492 (5, 0)
# 1
# 2
# 3
# 4
# 5
# drone reloading present
# Drone info:  2381.1062 (11, 9)
# 6
# drone reloading present
# Drone info:  2724.7832 (11, 9)
# 7
# drone reloading present
# Drone info:  2614.1118 (5, 0)
# 8
# drone reloading present
# Drone info:  2644.5864 (5, 0)
# 9
# drone reloading present
# Drone info:  2603.256 (5, 0)
# 10
# drone reloading present
# Drone info:  2493.2246 (5, 1)
# 11
# drone reloading present
# Drone info:  2589.5947 (5, 1)
# 12
# drone reloading present
# Drone info:  2614.857 (5, 1)
# 13
# drone reloading present
# Drone info:  2738.437 (5, 1)
# 14
# drone reloading present
# Drone info:  2679.4263 (5, 1)
# 15
# drone reloading present
# Drone info:  2652.0713 (5, 1)
# 16
# drone reloading present
# Drone info:  2707.2476 (5, 1)
# 17
# drone reloading present
# Drone info:  2814.8926 (5, 2)
# 18
# drone reloading present
# Drone info:  2819.209 (5, 2)
# 19
# drone reloading present
# Drone info:  2719.7827 (5, 2)
# 20
# drone reloading present
# Drone info:  2607.1196 (5, 2)
# 21
# drone reloading present
# Drone info:  2609.5405 (5, 2)
# 22
# drone reloading present
# Drone info:  2473.028 (5, 2)
# 23
# 24
# drone reloading present
# Drone info:  2799.6792 (11, 4)
# 25
# drone reloading present
# Drone info:  2629.5908 (5, 2)
# 26
# drone reloading present
# Drone info:  2729.2295 (5, 2)
# 27
# drone reloading present
# Drone info:  2771.811 (5, 3)
# 28
# drone reloading present
# Drone info:  2701.71 (5, 3)
# 29
# drone reloading present
# Drone info:  2710.5605 (5, 3)
# 30
# 31
# drone reloading present
# Drone info:  2789.5862 (5, 3)
# 32
# drone reloading present
# Drone info:  2765.3574 (5, 3)
# 33
# drone reloading present
# Drone info:  2702.252 (5, 3)
# 34
# drone reloading present
# Drone info:  2593.8154 (5, 3)
# 35
# drone reloading present
# Drone info:  2690.2761 (5, 3)
# 36
# drone reloading present
# Drone info:  2690.5444 (5, 4)
# 37
# drone reloading present
# Drone info:  2797.2617 (5, 4)
# 38
# drone reloading present
# Drone info:  2729.8057 (5, 4)
# 39
# drone reloading present
# Drone info:  2661.0962 (5, 4)
# 40
# drone reloading present
# Drone info:  2683.51 (5, 4)
# 41
# 42
# drone reloading present
# Drone info:  2431.0347 (5, 4)
# 43
# 44
# drone reloading present
# Drone info:  2853.0813 (11, 9)
# 45
# drone reloading present
# Drone info:  2747.1714 (5, 4)
# 46
# drone reloading present
# Drone info:  2786.5896 (5, 4)
# 47
# drone reloading present
# Drone info:  2722.6582 (5, 5)
# 48
# drone reloading present
# Drone info:  2660.376 (5, 5)
# 49
# drone reloading present
# Drone info:  2647.2104 (5, 5)
#
#
# 17
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# drone reloading present
# Drone info:  2480.3257 (11, 9)
# 1
# 2
# 3
# 4
# 5
# drone reloading present
# Drone info:  2203.614 (10, 9)
# 6
# drone reloading present
# Drone info:  2691.227 (5, 1)
# 7
# drone reloading present
# Drone info:  2619.3284 (5, 0)
# 8
# drone reloading present
# Drone info:  2508.2642 (12, 8)
# 9
# drone reloading present
# Drone info:  2462.8716 (12, 6)
# 10
# drone reloading present
# Drone info:  2539.6377 (5, 1)
# 11
# drone reloading present
# Drone info:  2571.928 (11, 4)
# 12
# drone reloading present
# Drone info:  2649.4954 (10, 5)
# 13
# drone reloading present
# Drone info:  2657.4468 (9, 6)
# 14
# drone reloading present
# Drone info:  2515.9912 (5, 1)
# 15
# drone reloading present
# Drone info:  2580.3135 (10, 9)
# 16
# drone reloading present
# Drone info:  2573.9556 (11, 9)
# 17
# drone reloading present
# Drone info:  2701.061 (5, 2)
# 18
# drone reloading present
# Drone info:  2627.6182 (12, 8)
# 19
# drone reloading present
# Drone info:  2612.4697 (12, 6)
# 20
# drone reloading present
# Drone info:  2607.8655 (5, 2)
# 21
# drone reloading present
# Drone info:  2538.8494 (11, 4)
# 22
# drone reloading present
# Drone info:  2359.6895 (5, 2)
# 23
# 24
# drone reloading present
# Drone info:  2774.7554 (10, 4)
# 25
# drone reloading present
# Drone info:  2584.3057 (10, 5)
# 26
# drone reloading present
# Drone info:  2636.3047 (9, 6)
# 27
# drone reloading present
# Drone info:  2537.2595 (5, 3)
# 28
# drone reloading present
# Drone info:  2632.6775 (10, 9)
# 29
# drone reloading present
# Drone info:  2665.545 (5, 3)
# 30
# 31
# drone reloading present
# Drone info:  2757.309 (5, 3)
# 32
# drone reloading present
# Drone info:  2569.3198 (12, 8)
# 33
# drone reloading present
# Drone info:  2497.687 (12, 6)
# 34
# drone reloading present
# Drone info:  2533.3887 (5, 4)
# 35
# drone reloading present
# Drone info:  2566.4626 (11, 4)
# 36
# drone reloading present
# Drone info:  2641.9128 (10, 5)
# 37
# drone reloading present
# Drone info:  2740.202 (9, 6)
# 38
# drone reloading present
# Drone info:  2609.5283 (5, 4)
# 39
# drone reloading present
# Drone info:  2635.48 (10, 9)
# 40
# drone reloading present
# Drone info:  2568.0908 (10, 9)
# 41
# 42
# drone reloading present
# Drone info:  2368.8066 (5, 4)
# 43
# drone reloading present
# Drone info:  2217.2402 (10, 9)
# 44
# drone reloading present
# Drone info:  2872.8206 (10, 9)
# 45
# drone reloading present
# Drone info:  2679.6538 (5, 5)
# 46
# drone reloading present
# Drone info:  2541.9182 (12, 8)
# 47
# drone reloading present
# Drone info:  2500.0742 (12, 6)
# 48
# drone reloading present
# Drone info:  2603.6826 (5, 5)
# 49
# drone reloading present
# Drone info:  2618.267 (11, 4)
#
#
# 21
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# drone reloading present
# Drone info:  2585.9998 (5, 0)
# 1
# 2
# 3
# 4
# 5
# drone reloading present
# Drone info:  2568.9695 (12, 10)
# 6
# drone reloading present
# Drone info:  3026.3354 (6, 1)
# 7
# drone reloading present
# Drone info:  2640.6606 (4, 1)
# 8
# drone reloading present
# Drone info:  2665.249 (5, 0)
# 9
# drone reloading present
# Drone info:  2618.5166 (5, 0)
# 10
# drone reloading present
# Drone info:  2583.2837 (5, 1)
# 11
# drone reloading present
# Drone info:  2588.3955 (10, 5)
# 12
# drone reloading present
# Drone info:  2718.979 (5, 0)
# 13
# drone reloading present
# Drone info:  2783.8528 (8, 7)
# 14
# drone reloading present
# Drone info:  2758.4219 (8, 9)
# 15
# drone reloading present
# Drone info:  2759.4365 (5, 1)
# 16
# drone reloading present
# Drone info:  2796.407 (5, 1)
# 17
# drone reloading present
# Drone info:  2776.2344 (4, 3)
# 18
# drone reloading present
# Drone info:  2843.7383 (5, 2)
# 19
# drone reloading present
# Drone info:  2802.524 (5, 2)
# 20
# drone reloading present
# Drone info:  2723.6963 (4, 3)
# 21
# drone reloading present
# Drone info:  2675.9673 (5, 2)
# 22
# drone reloading present
# Drone info:  2669.1594 (6, 3)
# 23
# 24
# drone reloading present
# Drone info:  3144.6587 (6, 3)
# 25
# drone reloading present
# Drone info:  2814.9722 (5, 2)
# 26
# drone reloading present
# Drone info:  2855.3887 (8, 7)
# 27
# drone reloading present
# Drone info:  2769.9563 (8, 9)
# 28
# drone reloading present
# Drone info:  2804.3232 (5, 3)
# 29
# drone reloading present
# Drone info:  2816.4312 (5, 3)
# 30
# 31
# drone reloading present
# Drone info:  2753.939 (11, 10)
# 32
# drone reloading present
# Drone info:  2809.0742 (5, 3)
# 33
# drone reloading present
# Drone info:  2802.976 (5, 3)
# 34
# drone reloading present
# Drone info:  2743.8867 (4, 5)
# 35
# drone reloading present
# Drone info:  2709.6438 (5, 4)
# 36
# drone reloading present
# Drone info:  2808.3296 (5, 3)
# 37
# drone reloading present
# Drone info:  2877.5361 (8, 7)
# 38
# drone reloading present
# Drone info:  2756.0044 (8, 9)
# 39
# drone reloading present
# Drone info:  2765.9282 (5, 3)
# 40
# drone reloading present
# Drone info:  2801.6987 (5, 4)
# 41
# 42
# drone reloading present
# Drone info:  2691.4329 (6, 5)
# 43
# drone reloading present
# Drone info:  2594.2551 (12, 10)
# 44
# drone reloading present
# Drone info:  3256.168 (6, 5)
# 45
# drone reloading present
# Drone info:  2760.1272 (11, 10)
# 46
# drone reloading present
# Drone info:  2838.305 (5, 5)
# 47
# drone reloading present
# Drone info:  2768.1099 (11, 7)
# 48
# drone reloading present
# Drone info:  2728.9185 (4, 6)
# 49
# drone reloading present
# Drone info:  2678.584 (5, 5)
#
#
# 25
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# drone reloading present
# Drone info:  1970.5428 (4, 0)
# 1
# 2
# 3
# 4
# 5
# drone reloading present
# Drone info:  1657.4192 (10, 11)
# 6
# drone reloading present
# Drone info:  2009.0664 (10, 11)
# 7
# drone reloading present
# Drone info:  2011.7063 (4, 0)
# 8
# drone reloading present
# Drone info:  1973.1389 (4, 0)
# 9
# drone reloading present
# Drone info:  1896.822 (4, 0)
# 10
# drone reloading present
# Drone info:  1962.7015 (12, 5)
# 11
# drone reloading present
# Drone info:  2019.6274 (4, 1)
# 12
# drone reloading present
# Drone info:  2029.6384 (4, 1)
# 13
# drone reloading present
# Drone info:  2076.376 (4, 1)
# 14
# drone reloading present
# Drone info:  2040.2733 (4, 1)
# 15
# drone reloading present
# Drone info:  1961.9163 (4, 1)
# 16
# drone reloading present
# Drone info:  2060.1484 (4, 1)
# 17
# drone reloading present
# Drone info:  2137.4858 (4, 1)
# 18
# drone reloading present
# Drone info:  2108.9397 (4, 2)
# 19
# drone reloading present
# Drone info:  2000.2859 (4, 2)
# 20
# drone reloading present
# Drone info:  2057.542 (4, 2)
# 21
# drone reloading present
# Drone info:  1987.0656 (4, 2)
# 22
# drone reloading present
# Drone info:  1713.4332 (5, 3)
# 23
# 24
# drone reloading present
# Drone info:  2056.06 (5, 3)
# 25
# drone reloading present
# Drone info:  2032.4124 (4, 2)
# 26
# drone reloading present
# Drone info:  2006.6097 (4, 2)
# 27
# drone reloading present
# Drone info:  2033.4255 (4, 2)
# 28
# drone reloading present
# Drone info:  2031.473 (4, 3)
# 29
# drone reloading present
# Drone info:  2094.13 (4, 3)
# 30
# 31
# drone reloading present
# Drone info:  2152.9404 (4, 3)
# 32
# drone reloading present
# Drone info:  2037.6558 (4, 3)
# 33
# drone reloading present
# Drone info:  1952.5887 (4, 3)
# 34
# drone reloading present
# Drone info:  1992.5684 (4, 3)
# 35
# drone reloading present
# Drone info:  1963.0575 (4, 3)
# 36
# drone reloading present
# Drone info:  2084.9175 (4, 4)
# 37
# drone reloading present
# Drone info:  2118.6812 (4, 4)
# 38
# drone reloading present
# Drone info:  2067.9966 (4, 4)
# 39
# drone reloading present
# Drone info:  1993.4569 (4, 4)
# 40
# drone reloading present
# Drone info:  1996.4288 (4, 4)
# 41
# drone reloading present
# Drone info:  1691.8761 (4, 4)
# 42
# drone reloading present
# Drone info:  1746.9663 (5, 5)
# 43
# 44
# drone reloading present
# Drone info:  2095.4766 (10, 11)
# 45
# drone reloading present
# Drone info:  2078.1855 (4, 4)
# 46
# drone reloading present
# Drone info:  2039.2196 (4, 4)
# 47
# drone reloading present
# Drone info:  1993.6201 (4, 5)
# 48
# drone reloading present
# Drone info:  2095.5693 (4, 5)
# 49
# drone reloading present
# Drone info:  2005.3882 (4, 5)
#
#
# 26
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
img = uframes[4]
z = Image.fromarray(img)
z.show()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

tank_info_panel = 29# --done:7,9,16,21
drone_info_panel = 5 #8,14,27,28
tankr_info_panel = 11#,12,13,15,17,19,20,23 --done: 4,6,10
droner_info_panel = 30
tank_threshold= 2475 #--done: 3020,1150,2775,958
tankr_threshold= 1260#,2970,2175,1940,665,1910,1254,2200 -- done: 1025,2440,1480
drone_threshold= 2625 #896,2785,1925,2485
droner_threshold= 1090

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position
dronec=[]
tankc=[]
tankr=[]
droner=[]
#Blank
for i in range(50):
    #x = cv2.imread(r"C:\Users\darshan19\Desktop\AoI\CNN\Images1\0b.png",-1)
    #x = cv2.resize(x,(100,100))
    img = uframes[i]
    #print(np.shape(img))
    # = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    #print(np.shape(x_1))
    output = model(x_1.reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank,pos_tank = val_pos(output_tank)
    output_tankr = output[0][tankr_info_panel]
    val_tankr,pos_tankr = val_pos(output_tankr)
    print(i)
    output_drone = output[0][drone_info_panel]
    val_drone,pos_drone = val_pos(output_drone)
    output_droner = output[0][droner_info_panel]
    val_droner,pos_droner = val_pos(output_droner)
    
    if val_tank>tank_threshold:
        print("tank present")
        print("Tank info: ",val_tank,pos_tank)
        tankc.append(pos_tank)
    if val_drone>drone_threshold:
        print("drone present")
        print("Drone info: ",val_drone,pos_drone)
        dronec.append(pos_drone)
    if val_tankr>tankr_threshold:
        print("tank reloading present")
        print("Tank info: ",val_tank,pos_tank)
        tankr.append(pos_tankr)
    if val_droner>droner_threshold:
        print("drone reloading present")
        print("Drone info: ",val_droner,pos_droner)
        dronec.append(pos_drone)
# Out:
# 0
# tank present
# Tank info:  2846.479 (4, 0)
# drone present
# Drone info:  3023.8042 (5, 0)
# drone reloading present
# Drone info:  1275.1257 (10, 10)
# 1
# 2
# tank present
# Tank info:  2485.3955 (4, 0)
# 3
# drone present
# Drone info:  2633.3057 (8, 9)
# 4
# tank reloading present
# Tank info:  2353.2332 (5, 2)
# 5
# drone reloading present
# Drone info:  1090.4395 (11, 9)
# 6
# tank present
# Tank info:  2759.4927 (5, 2)
# drone present
# Drone info:  2856.3335 (6, 0)
# tank reloading present
# Tank info:  2759.4927 (5, 2)
# drone reloading present
# Drone info:  1329.6665 (11, 9)
# 7
# tank present
# Tank info:  2949.1938 (4, 0)
# drone present
# Drone info:  3039.2358 (5, 0)
# drone reloading present
# Drone info:  1358.6427 (5, 0)
# 8
# tank present
# Tank info:  2871.037 (5, 1)
# drone present
# Drone info:  2959.031 (5, 0)
# drone reloading present
# Drone info:  1360.76 (5, 0)
# 9
# tank present
# Tank info:  2737.7136 (4, 0)
# drone present
# Drone info:  2921.4033 (5, 0)
# drone reloading present
# Drone info:  1286.6704 (12, 7)
# 10
# tank present
# Tank info:  2879.8982 (5, 2)
# drone present
# Drone info:  2990.3677 (5, 0)
# drone reloading present
# Drone info:  1405.5173 (5, 1)
# 11
# tank present
# Tank info:  2843.7002 (9, 4)
# drone present
# Drone info:  3046.4954 (5, 0)
# drone reloading present
# Drone info:  1332.3198 (5, 1)
# 12
# tank present
# Tank info:  2904.941 (4, 1)
# drone present
# Drone info:  3047.713 (5, 1)
# drone reloading present
# Drone info:  1355.7212 (9, 5)
# 13
# tank present
# Tank info:  2875.4805 (5, 2)
# drone present
# Drone info:  3133.4927 (5, 1)
# drone reloading present
# Drone info:  1354.0562 (6, 1)
# 14
# tank present
# Tank info:  2877.4224 (4, 1)
# drone present
# Drone info:  3054.0913 (5, 1)
# drone reloading present
# Drone info:  1392.7385 (6, 1)
# 15
# tank present
# Tank info:  2900.5513 (5, 2)
# drone present
# Drone info:  3074.2966 (5, 1)
# drone reloading present
# Drone info:  1370.3789 (9, 9)
# 16
# tank present
# Tank info:  2926.3074 (4, 1)
# drone present
# Drone info:  3169.9053 (5, 1)
# drone reloading present
# Drone info:  1366.2498 (10, 10)
# 17
# tank present
# Tank info:  3080.879 (4, 1)
# drone present
# Drone info:  3191.3972 (5, 1)
# drone reloading present
# Drone info:  1434.1799 (5, 2)
# 18
# tank present
# Tank info:  2859.2617 (5, 3)
# drone present
# Drone info:  3094.9526 (5, 1)
# drone reloading present
# Drone info:  1414.5256 (5, 2)
# 19
# tank present
# Tank info:  2743.6592 (4, 2)
# drone present
# Drone info:  2992.9165 (5, 1)
# drone reloading present
# Drone info:  1301.8118 (12, 7)
# 20
# tank present
# Tank info:  2851.064 (4, 2)
# drone present
# Drone info:  3021.2246 (5, 2)
# drone reloading present
# Drone info:  1419.6354 (5, 2)
# 21
# tank present
# Tank info:  2907.5198 (5, 3)
# drone present
# Drone info:  3080.7854 (5, 2)
# drone reloading present
# Drone info:  1350.5675 (5, 2)
# 22
# drone present
# Drone info:  2708.2646 (6, 2)
# tank reloading present
# Tank info:  2390.0425 (5, 4)
# drone reloading present
# Drone info:  1171.9366 (5, 2)
# 23
# 24
# tank present
# Tank info:  2680.2952 (5, 4)
# drone present
# Drone info:  2928.9644 (6, 2)
# tank reloading present
# Tank info:  2680.2952 (5, 4)
# drone reloading present
# Drone info:  1340.765 (5, 2)
# 25
# tank present
# Tank info:  2902.9688 (5, 3)
# drone present
# Drone info:  3063.5276 (5, 2)
# drone reloading present
# Drone info:  1399.551 (9, 5)
# 26
# tank present
# Tank info:  2935.602 (4, 3)
# drone present
# Drone info:  3173.6763 (5, 2)
# drone reloading present
# Drone info:  1388.2 (5, 2)
# 27
# tank present
# Tank info:  2950.4106 (4, 2)
# drone present
# Drone info:  3080.3027 (5, 2)
# drone reloading present
# Drone info:  1386.4453 (6, 3)
# 28
# tank present
# Tank info:  2890.21 (5, 4)
# drone present
# Drone info:  3073.7153 (5, 2)
# drone reloading present
# Drone info:  1340.2583 (9, 9)
# 29
# tank present
# Tank info:  2851.9148 (5, 4)
# drone present
# Drone info:  3189.4307 (5, 2)
# drone reloading present
# Drone info:  1381.7023 (6, 3)
# 30
# 31
# tank present
# Tank info:  2967.2405 (4, 3)
# drone present
# Drone info:  3130.7627 (5, 3)
# drone reloading present
# Drone info:  1401.7319 (5, 3)
# 32
# tank present
# Tank info:  2852.9092 (5, 4)
# drone present
# Drone info:  3089.027 (5, 3)
# drone reloading present
# Drone info:  1372.0518 (12, 8)
# 33
# tank present
# Tank info:  2749.0784 (4, 3)
# drone present
# Drone info:  2981.2646 (5, 3)
# drone reloading present
# Drone info:  1325.2756 (12, 7)
# 34
# tank present
# Tank info:  2894.3604 (4, 3)
# drone present
# Drone info:  3032.1746 (5, 3)
# drone reloading present
# Drone info:  1444.4993 (5, 3)
# 35
# tank present
# Tank info:  2956.1138 (5, 4)
# drone present
# Drone info:  3115.7021 (5, 3)
# drone reloading present
# Drone info:  1345.8157 (6, 4)
# 36
# tank present
# Tank info:  2942.1743 (4, 4)
# drone present
# Drone info:  3104.212 (5, 3)
# drone reloading present
# Drone info:  1385.6589 (9, 5)
# 37
# tank present
# Tank info:  2898.6062 (5, 5)
# drone present
# Drone info:  3172.46 (5, 3)
# drone reloading present
# Drone info:  1409.82 (5, 4)
# 38
# tank present
# Tank info:  2854.48 (5, 5)
# drone present
# Drone info:  3041.777 (5, 3)
# drone reloading present
# Drone info:  1368.3254 (6, 4)
# 39
# tank present
# Tank info:  2871.6025 (4, 4)
# drone present
# Drone info:  3061.8157 (5, 4)
# drone reloading present
# Drone info:  1300.6022 (9, 9)
# 40
# tank present
# Tank info:  2932.5715 (9, 9)
# drone present
# Drone info:  3159.3413 (5, 4)
# drone reloading present
# Drone info:  1415.2004 (5, 4)
# 41
# tank present
# Tank info:  2514.5425 (5, 5)
# drone present
# Drone info:  2758.1794 (5, 4)
# drone reloading present
# Drone info:  1157.5659 (5, 4)
# 42
# drone present
# Drone info:  2698.4463 (5, 5)
# tank reloading present
# Tank info:  2385.7585 (5, 6)
# drone reloading present
# Drone info:  1162.8682 (5, 4)
# 43
# drone reloading present
# Drone info:  1108.6926 (11, 9)
# 44
# tank present
# Tank info:  2792.654 (5, 6)
# drone present
# Drone info:  2959.5137 (6, 4)
# tank reloading present
# Tank info:  2792.654 (5, 6)
# drone reloading present
# Drone info:  1435.9556 (11, 9)
# 45
# tank present
# Tank info:  3022.4531 (4, 4)
# drone present
# Drone info:  3156.3489 (5, 4)
# drone reloading present
# Drone info:  1449.1588 (6, 4)
# 46
# tank present
# Tank info:  2873.0027 (5, 5)
# drone present
# Drone info:  3087.476 (5, 4)
# drone reloading present
# Drone info:  1376.9872 (12, 8)
# 47
# tank present
# Tank info:  2785.3972 (4, 5)
# drone present
# Drone info:  3020.1306 (5, 4)
# drone reloading present
# Drone info:  1325.0703 (12, 7)
# 48
# tank present
# Tank info:  2849.8708 (4, 5)
# drone present
# Drone info:  3028.788 (5, 4)
# drone reloading present
# Drone info:  1435.5735 (5, 5)
# 49
# tank present
# Tank info:  2853.299 (5, 6)
# drone present
# Drone info:  3084.8262 (5, 5)
# drone reloading present
# Drone info:  1324.9465 (5, 5)

# %%
img = uframes[6]
z = Image.fromarray(img)
z.show()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)
import time
for i in range(40):
    img = uframes[i]
    #print(np.shape(img))
    z = Image.fromarray(img)
    z.show()
    time.sleep(5)

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)


def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

for i in range(32):

    tank_info_panel = i
    drone_info_panel = i
    #Blank
    img = Image.open("spacecraft/0blank.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Blank: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Blank: ",val,pos)


    
    img = Image.open("spacecraft/0tank.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Tank: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Tank: ",val,pos)


    #Drone

    img = Image.open("spacecraft/0drone.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Drone: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Drone: ",val,pos)
    
        
    img = Image.open("spacecraft/0tank_reloading.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Tank reloading: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Tank reloading: ",val,pos)


    #Drone

    img = Image.open("spacecraft/0drone_reloading.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Drone reloading: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Drone reloading: ",val,pos)


    #Tank and Drone
    img = Image.open("spacecraft/0.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TD: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("TD: ",val,pos)
    
    print("done ",i)
    print("++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# Blank:  6030.4375 (11, 2)
# Blank:  6030.4375 (11, 2)
# Tank:  6313.0186 (6, 0)
# Tank:  6313.0186 (6, 0)
# Drone:  6352.264 (10, 10)
# Drone:  6352.264 (10, 10)
# Tank reloading:  6397.289 (5, 1)
# Tank reloading:  6397.289 (5, 1)
# Drone reloading:  6365.005 (11, 9)
# Drone reloading:  6365.005 (11, 9)
# TD:  6710.33 (11, 10)
# TD:  6710.33 (11, 10)
# done  0
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  7292.926 (9, 12)
# Blank:  7292.926 (9, 12)
# Tank:  7563.21 (9, 12)
# Tank:  7563.21 (9, 12)
# Drone:  7634.428 (9, 12)
# Drone:  7634.428 (9, 12)
# Tank reloading:  7727.736 (6, 0)
# Tank reloading:  7727.736 (6, 0)
# Drone reloading:  7651.0894 (10, 9)
# Drone reloading:  7651.0894 (10, 9)
# TD:  7923.5293 (10, 11)
# TD:  7923.5293 (10, 11)
# done  1
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  91.698265 (5, 0)
# Tank:  91.698265 (5, 0)
# Drone:  24.079773 (10, 9)
# Drone:  24.079773 (10, 9)
# Tank reloading:  99.876816 (5, 2)
# Tank reloading:  99.876816 (5, 2)
# Drone reloading:  105.821335 (10, 9)
# Drone reloading:  105.821335 (10, 9)
# TD:  240.94351 (5, 0)
# TD:  240.94351 (5, 0)
# done  2
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  24.783487 (7, 9)
# Blank:  24.783487 (7, 9)
# Tank:  112.870514 (5, 1)
# Tank:  112.870514 (5, 1)
# Drone:  34.009605 (7, 9)
# Drone:  34.009605 (7, 9)
# Tank reloading:  54.76466 (5, 1)
# Tank reloading:  54.76466 (5, 1)
# Drone reloading:  24.783487 (7, 9)
# Drone reloading:  24.783487 (7, 9)
# TD:  184.71616 (11, 11)
# TD:  184.71616 (11, 11)
# done  3
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  8995.51 (13, 5)
# Blank:  8995.51 (13, 5)
# Tank:  9250.804 (4, 0)
# Tank:  9250.804 (4, 0)
# Drone:  9275.936 (10, 10)
# Drone:  9275.936 (10, 10)
# Tank reloading:  9277.022 (5, 0)
# Tank reloading:  9277.022 (5, 0)
# Drone reloading:  9214.348 (11, 10)
# Drone reloading:  9214.348 (11, 10)
# TD:  9599.721 (11, 10)
# TD:  9599.721 (11, 10)
# done  4
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  7749.788 (10, 3)
# Blank:  7749.788 (10, 3)
# Tank:  8085.9336 (4, 1)
# Tank:  8085.9336 (4, 1)
# Drone:  8178.285 (11, 9)
# Drone:  8178.285 (11, 9)
# Tank reloading:  8279.332 (5, 1)
# Tank reloading:  8279.332 (5, 1)
# Drone reloading:  8110.3154 (10, 10)
# Drone reloading:  8110.3154 (10, 10)
# TD:  8591.169 (10, 9)
# TD:  8591.169 (10, 9)
# done  5
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  3850.3618 (2, 8)
# Blank:  3850.3618 (2, 8)
# Tank:  4173.1846 (6, 0)
# Tank:  4173.1846 (6, 0)
# Drone:  4192.449 (10, 10)
# Drone:  4192.449 (10, 10)
# Tank reloading:  4362.8086 (6, 0)
# Tank reloading:  4362.8086 (6, 0)
# Drone reloading:  4229.2246 (11, 10)
# Drone reloading:  4229.2246 (11, 10)
# TD:  4599.176 (10, 10)
# TD:  4599.176 (10, 10)
# done  6
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  7423.867 (1, 1)
# Blank:  7423.867 (1, 1)
# Tank:  7631.924 (5, 1)
# Tank:  7631.924 (5, 1)
# Drone:  7731.4097 (10, 10)
# Drone:  7731.4097 (10, 10)
# Tank reloading:  7777.064 (5, 0)
# Tank reloading:  7777.064 (5, 0)
# Drone reloading:  7786.7617 (10, 10)
# Drone reloading:  7786.7617 (10, 10)
# TD:  8008.909 (5, 1)
# TD:  8008.909 (5, 1)
# done  7
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1435.148 (6, 8)
# Blank:  1435.148 (6, 8)
# Tank:  1731.2336 (4, 1)
# Tank:  1731.2336 (4, 1)
# Drone:  1745.4163 (11, 9)
# Drone:  1745.4163 (11, 9)
# Tank reloading:  1761.7563 (5, 1)
# Tank reloading:  1761.7563 (5, 1)
# Drone reloading:  1627.5316 (6, 8)
# Drone reloading:  1627.5316 (6, 8)
# TD:  2133.924 (11, 10)
# TD:  2133.924 (11, 10)
# done  8
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  4542.583 (11, 12)
# Blank:  4542.583 (11, 12)
# Tank:  4770.271 (11, 12)
# Tank:  4770.271 (11, 12)
# Drone:  4796.5015 (11, 12)
# Drone:  4796.5015 (11, 12)
# Tank reloading:  4881.9473 (5, 1)
# Tank reloading:  4881.9473 (5, 1)
# Drone reloading:  4930.5254 (11, 9)
# Drone reloading:  4930.5254 (11, 9)
# TD:  5119.535 (12, 11)
# TD:  5119.535 (12, 11)
# done  9
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  51.859566 (6, 0)
# Tank:  51.859566 (6, 0)
# Drone:  27.896717 (10, 9)
# Drone:  27.896717 (10, 9)
# Tank reloading:  27.792164 (5, 1)
# Tank reloading:  27.792164 (5, 1)
# Drone reloading:  11.585205 (10, 9)
# Drone reloading:  11.585205 (10, 9)
# TD:  130.50137 (10, 10)
# TD:  130.50137 (10, 10)
# done  10
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  28484.219 (10, 11)
# Blank:  28484.219 (10, 11)
# Tank:  28520.79 (10, 11)
# Tank:  28520.79 (10, 11)
# Drone:  28671.879 (10, 10)
# Drone:  28671.879 (10, 10)
# Tank reloading:  28874.695 (6, 1)
# Tank reloading:  28874.695 (6, 1)
# Drone reloading:  28633.322 (10, 11)
# Drone reloading:  28633.322 (10, 11)
# TD:  28751.31 (11, 11)
# TD:  28751.31 (11, 11)
# done  11
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  374.45703 (7, 9)
# Blank:  374.45703 (7, 9)
# Tank:  524.1942 (5, 1)
# Tank:  524.1942 (5, 1)
# Drone:  566.43884 (10, 10)
# Drone:  566.43884 (10, 10)
# Tank reloading:  601.3748 (5, 0)
# Tank reloading:  601.3748 (5, 0)
# Drone reloading:  506.30917 (10, 9)
# Drone reloading:  506.30917 (10, 9)
# TD:  697.41516 (11, 10)
# TD:  697.41516 (11, 10)
# done  12
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  15505.9375 (11, 13)
# Blank:  15505.9375 (11, 13)
# Tank:  15764.656 (5, 1)
# Tank:  15764.656 (5, 1)
# Drone:  15801.258 (11, 10)
# Drone:  15801.258 (11, 10)
# Tank reloading:  16015.086 (5, 0)
# Tank reloading:  16015.086 (5, 0)
# Drone reloading:  15654.12 (11, 10)
# Drone reloading:  15654.12 (11, 10)
# TD:  16105.51 (5, 1)
# TD:  16105.51 (5, 1)
# done  13
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  315.94183 (10, 12)
# Blank:  315.94183 (10, 12)
# Tank:  389.31177 (10, 12)
# Tank:  389.31177 (10, 12)
# Drone:  466.74567 (11, 9)
# Drone:  466.74567 (11, 9)
# Tank reloading:  378.86508 (10, 12)
# Tank reloading:  378.86508 (10, 12)
# Drone reloading:  501.22565 (10, 12)
# Drone reloading:  501.22565 (10, 12)
# TD:  574.7948 (11, 10)
# TD:  574.7948 (11, 10)
# done  14
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  323.19617 (10, 13)
# Blank:  323.19617 (10, 13)
# Tank:  526.13794 (5, 1)
# Tank:  526.13794 (5, 1)
# Drone:  450.18396 (11, 9)
# Drone:  450.18396 (11, 9)
# Tank reloading:  471.68622 (5, 0)
# Tank reloading:  471.68622 (5, 0)
# Drone reloading:  462.03186 (11, 9)
# Drone reloading:  462.03186 (11, 9)
# TD:  758.7136 (11, 10)
# TD:  758.7136 (11, 10)
# done  15
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  150.25323 (11, 11)
# Blank:  150.25323 (11, 11)
# Tank:  263.76874 (5, 0)
# Tank:  263.76874 (5, 0)
# Drone:  236.20544 (11, 10)
# Drone:  236.20544 (11, 10)
# Tank reloading:  382.88306 (5, 0)
# Tank reloading:  382.88306 (5, 0)
# Drone reloading:  175.33182 (11, 8)
# Drone reloading:  175.33182 (11, 8)
# TD:  459.7015 (11, 10)
# TD:  459.7015 (11, 10)
# done  16
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  14320.631 (16, 12)
# Blank:  14320.631 (16, 12)
# Tank:  14353.914 (16, 12)
# Tank:  14353.914 (16, 12)
# Drone:  14425.411 (10, 10)
# Drone:  14425.411 (10, 10)
# Tank reloading:  14506.45 (5, 1)
# Tank reloading:  14506.45 (5, 1)
# Drone reloading:  14370.489 (10, 8)
# Drone reloading:  14370.489 (10, 8)
# TD:  14445.98 (10, 10)
# TD:  14445.98 (10, 10)
# done  17
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  172.07431 (10, 12)
# Blank:  172.07431 (10, 12)
# Tank:  305.0288 (5, 1)
# Tank:  305.0288 (5, 1)
# Drone:  319.38333 (11, 10)
# Drone:  319.38333 (11, 10)
# Tank reloading:  273.8933 (5, 1)
# Tank reloading:  273.8933 (5, 1)
# Drone reloading:  283.73157 (10, 10)
# Drone reloading:  283.73157 (10, 10)
# TD:  431.42212 (11, 10)
# TD:  431.42212 (11, 10)
# done  18
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  170.94727 (10, 2)
# Blank:  170.94727 (10, 2)
# Tank:  334.21298 (4, 1)
# Tank:  334.21298 (4, 1)
# Drone:  361.7343 (10, 11)
# Drone:  361.7343 (10, 11)
# Tank reloading:  429.42017 (5, 1)
# Tank reloading:  429.42017 (5, 1)
# Drone reloading:  298.835 (10, 9)
# Drone reloading:  298.835 (10, 9)
# TD:  544.7146 (10, 11)
# TD:  544.7146 (10, 11)
# done  19
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  42.672237 (9, 12)
# Blank:  42.672237 (9, 12)
# Tank:  92.917915 (9, 12)
# Tank:  92.917915 (9, 12)
# Drone:  97.62856 (9, 12)
# Drone:  97.62856 (9, 12)
# Tank reloading:  93.33926 (5, 1)
# Tank reloading:  93.33926 (5, 1)
# Drone reloading:  106.234985 (10, 9)
# Drone reloading:  106.234985 (10, 9)
# TD:  169.11603 (11, 9)
# TD:  169.11603 (11, 9)
# done  20
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  6921.207 (12, 2)
# Blank:  6921.207 (12, 2)
# Tank:  7135.3784 (6, 0)
# Tank:  7135.3784 (6, 0)
# Drone:  7194.257 (11, 10)
# Drone:  7194.257 (11, 10)
# Tank reloading:  7317.041 (4, 0)
# Tank reloading:  7317.041 (4, 0)
# Drone reloading:  7179.242 (11, 10)
# Drone reloading:  7179.242 (11, 10)
# TD:  7527.0 (11, 11)
# TD:  7527.0 (11, 11)
# done  21
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  25.255066 (8, 9)
# Blank:  25.255066 (8, 9)
# Tank:  156.70833 (5, 0)
# Tank:  156.70833 (5, 0)
# Drone:  77.091675 (11, 9)
# Drone:  77.091675 (11, 9)
# Tank reloading:  122.028694 (5, 0)
# Tank reloading:  122.028694 (5, 0)
# Drone reloading:  147.3464 (10, 9)
# Drone reloading:  147.3464 (10, 9)
# TD:  333.06714 (5, 0)
# TD:  333.06714 (5, 0)
# done  22
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  0.0 (0, 0)
# Tank:  0.0 (0, 0)
# Drone:  0.0 (0, 0)
# Drone:  0.0 (0, 0)
# Tank reloading:  0.0 (0, 0)
# Tank reloading:  0.0 (0, 0)
# Drone reloading:  0.0 (0, 0)
# Drone reloading:  0.0 (0, 0)
# TD:  0.0 (0, 0)
# TD:  0.0 (0, 0)
# done  23
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  3817.0005 (6, 9)
# Blank:  3817.0005 (6, 9)
# Tank:  4149.4507 (5, 0)
# Tank:  4149.4507 (5, 0)
# Drone:  4100.4185 (10, 10)
# Drone:  4100.4185 (10, 10)
# Tank reloading:  4199.4062 (5, 0)
# Tank reloading:  4199.4062 (5, 0)
# Drone reloading:  4111.6274 (10, 9)
# Drone reloading:  4111.6274 (10, 9)
# TD:  4538.5186 (10, 10)
# TD:  4538.5186 (10, 10)
# done  24
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  79.4991 (15, 15)
# Blank:  79.4991 (15, 15)
# Tank:  239.8229 (5, 1)
# Tank:  239.8229 (5, 1)
# Drone:  170.4319 (10, 9)
# Drone:  170.4319 (10, 9)
# Tank reloading:  247.18979 (5, 0)
# Tank reloading:  247.18979 (5, 0)
# Drone reloading:  106.84668 (10, 10)
# Drone reloading:  106.84668 (10, 10)
# TD:  379.30133 (5, 1)
# TD:  379.30133 (5, 1)
# done  25
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  2587.1875 (11, 11)
# Blank:  2587.1875 (11, 11)
# Tank:  2846.6494 (5, 0)
# Tank:  2846.6494 (5, 0)
# Drone:  2881.7954 (11, 9)
# Drone:  2881.7954 (11, 9)
# Tank reloading:  2941.5198 (4, 1)
# Tank reloading:  2941.5198 (4, 1)
# Drone reloading:  2959.9932 (11, 9)
# Drone reloading:  2959.9932 (11, 9)
# TD:  3265.4531 (5, 0)
# TD:  3265.4531 (5, 0)
# done  26
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  5026.1973 (16, 14)
# Blank:  5026.1973 (16, 14)
# Tank:  5338.915 (5, 0)
# Tank:  5338.915 (5, 0)
# Drone:  5373.4854 (10, 9)
# Drone:  5373.4854 (10, 9)
# Tank reloading:  5465.433 (6, 1)
# Tank reloading:  5465.433 (6, 1)
# Drone reloading:  5335.285 (10, 9)
# Drone reloading:  5335.285 (10, 9)
# TD:  5905.72 (10, 10)
# TD:  5905.72 (10, 10)
# done  27
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  12819.695 (15, 15)
# Blank:  12819.695 (15, 15)
# Tank:  13135.973 (15, 15)
# Tank:  13135.973 (15, 15)
# Drone:  13138.252 (9, 9)
# Drone:  13138.252 (9, 9)
# Tank reloading:  13494.194 (5, 0)
# Tank reloading:  13494.194 (5, 0)
# Drone reloading:  13063.715 (15, 15)
# Drone reloading:  13063.715 (15, 15)
# TD:  13598.862 (10, 10)
# TD:  13598.862 (10, 10)
# done  28
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  719.8484 (10, 11)
# Blank:  719.8484 (10, 11)
# Tank:  833.80164 (10, 11)
# Tank:  833.80164 (10, 11)
# Drone:  930.52045 (10, 11)
# Drone:  930.52045 (10, 11)
# Tank reloading:  955.81854 (5, 1)
# Tank reloading:  955.81854 (5, 1)
# Drone reloading:  903.8184 (11, 9)
# Drone reloading:  903.8184 (11, 9)
# TD:  1124.4618 (10, 11)
# TD:  1124.4618 (10, 11)
# done  29
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  13056.463 (2, 9)
# Blank:  13056.463 (2, 9)
# Tank:  13206.75 (4, 1)
# Tank:  13206.75 (4, 1)
# Drone:  13316.672 (10, 9)
# Drone:  13316.672 (10, 9)
# Tank reloading:  13473.336 (6, 1)
# Tank reloading:  13473.336 (6, 1)
# Drone reloading:  13285.063 (11, 9)
# Drone reloading:  13285.063 (11, 9)
# TD:  13584.771 (10, 9)
# TD:  13584.771 (10, 9)
# done  30
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  975.1273 (17, 15)
# Blank:  975.1273 (17, 15)
# Tank:  1298.4028 (5, 0)
# Tank:  1298.4028 (5, 0)
# Drone:  1211.3696 (11, 9)
# Drone:  1211.3696 (11, 9)
# Tank reloading:  1350.303 (5, 0)
# Tank reloading:  1350.303 (5, 0)
# Drone reloading:  1184.7102 (12, 9)
# Drone reloading:  1184.7102 (12, 9)
# TD:  1735.5718 (5, 0)
# TD:  1735.5718 (5, 0)
# done  31
# ++++++++++++++++++++++++++++++++++++++++++++

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

tank_info_panel = 4
drone_info_panel = 24

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

#Blank
for i in range(12):
    img = uframes[i]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank,pos_tank = val_pos(output_tank)
    print(i)
    output_drone = output[0][drone_info_panel]
    val_drone,pos_drone = val_pos(output_drone)
    if val_tank>500:
        print("tank present")
        print("Tank info: ",val_tank,pos_tank)
    if val_drone>770:
        print("drone present")
        print("Drone info: ",val_drone,pos_drone)
# Out:
# 0
# 1
# tank present
# Tank info:  520.7602 (6, 2)
# 2
# drone present
# Drone info:  781.4645 (1, 4)
# 3
# tank present
# Tank info:  634.67224 (6, 2)
# drone present
# Drone info:  942.7866 (1, 4)
# 4
# tank present
# Tank info:  654.7293 (6, 8)
# drone present
# Drone info:  927.96313 (1, 4)
# 5
# tank present
# Tank info:  642.7981 (6, 13)
# drone present
# Drone info:  985.1527 (1, 4)
# 6
# tank present
# Tank info:  722.30286 (6, 2)
# drone present
# Drone info:  938.44824 (5, 1)
# 7
# tank present
# Tank info:  740.57965 (6, 8)
# drone present
# Drone info:  860.5968 (5, 7)
# 8
# tank present
# Tank info:  730.4288 (6, 13)
# drone present
# Drone info:  976.33765 (5, 12)
# 9
# tank present
# Tank info:  669.9697 (6, 2)
# drone present
# Drone info:  1017.36505 (13, 15)
# 10
# tank present
# Tank info:  690.02686 (6, 8)
# drone present
# Drone info:  1002.5415 (13, 15)
# 11
# tank present
# Tank info:  678.09564 (6, 13)
# drone present
# Drone info:  1059.7312 (13, 15)

# %%
im1 = Image.open('tree1.png')
im1 = im1.resize((100,100))

imt = Image.open('tank.png')
imt = imt.resize((100,100))


im2 = Image.open('tree2.png')
im2 = im2.resize((100,100))

im3 = Image.open('tree3.png')
im3 = im3.resize((100,100))

im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((200,200))

imb = Image.open('bullet.png')
imb = imb.resize((40,40))



img_blank = Image.new('RGB', (720, 1080), color = '#9b7653')
img_blank.paste(im1,(5,75),im1)
img_blank.paste(im1,(450,550),im1)
img_blank.paste(im1,(205,720),im1)
img_blank.paste(im2,(500,900),im2)
img_blank.paste(im2,(650,750),im2)
img_blank.paste(im2,(320,440),im2)
img_blank.paste(im3,(100,600),im3)
img_blank.paste(im3,(440,620),im3)
img_blank.paste(im3,(300,150),im3)
img_blank.paste(imt.rotate(180),(500,500),imt.rotate(180))
img_blank = np.asarray(img_blank)
img_blank = cv2.resize(img_blank,(100,100))
pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
output = model(pil.reshape(1,3,100, 100))[0].detach().numpy()
output = output[0][info_panel]
val,pos = val_pos(output)
print(val,pos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c18b098abae9> in <module>
#      36 pil = torch.from_numpy(pil)
#      37 output = model(pil.reshape(1,3,100, 100))[0].detach().numpy()
# ---> 38 output = output[0][info_panel]
#      39 val,pos = val_pos(output)
#      40 print(val,pos)
#
# NameError: name 'info_panel' is not defined

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(12):
    k = uframes[i]
    #k.show()
    v = np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32)
    v = torch.from_numpy(v)
    filename = "Marginalization_Simple-increased_channels-32/ref_image_new_" + str(i) + ".txt"
    file = open(filename, 'w')
    file.write(str(model(v.reshape(1,3,100, 100))[0].detach().numpy()))
    file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

filename = "Marginalization_Simple-increased_channels-32/fc_weights.txt"
file = open(filename, 'w')
file.write(str(model.fc1.weight.detach().numpy()))
print(np.shape(model.fc1.weight.detach().numpy()))
file.close()
# Out:
# (15, 10368)

# %%
##Weights

import operator
k=model.fc1.weight.detach().numpy()
for i in range(15):
    index, value = max(enumerate(k[i]), key=operator.itemgetter(1))
    print("FC - Feature "+ "i: ",index,value)
    print("CNN value: ", )
# Out:
# FC - Feature i:  684 0.041578084
# CNN value:
# FC - Feature i:  684 0.051804464
# CNN value:
# FC - Feature i:  360 0.04816093
# CNN value:
# FC - Feature i:  492 0.035558272
# CNN value:
# FC - Feature i:  478 0.06459166
# CNN value:
# FC - Feature i:  585 0.049136233
# CNN value:
# FC - Feature i:  492 0.081621096
# CNN value:
# FC - Feature i:  360 0.065480515
# CNN value:
# FC - Feature i:  585 0.04792851
# CNN value:
# FC - Feature i:  492 0.06556648
# CNN value:
# FC - Feature i:  684 0.035789683
# CNN value:
# FC - Feature i:  684 0.034514345
# CNN value:
# FC - Feature i:  817 0.043642323
# CNN value:
# FC - Feature i:  492 0.088237286
# CNN value:
# FC - Feature i:  492 0.09752004
# CNN value:

# %%
import operator
import sys
#t1d1
img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
# img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))

# #t2d2
# img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
# draw = ImageDraw.Draw(img_blank)
# draw.ellipse((35,35,38,38), fill=(255, 0, 0))
# img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
# draw.ellipse((40,50,43,53), fill=(50, 182, 150))

# #t3d3
# img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
# img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
# img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
# img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

v = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
v = torch.from_numpy(v)
k = model(v.reshape(1,3,100, 100))[0].view(model(v.reshape(1,3,100, 100))[0].size(0), -1).detach().numpy()

filename = "Marginalization_Simple/flattened_tank_pos_1.txt"
file = open(filename, 'w')
file.write(str(k))
file.close()


# print(np.shape(k))
# index, value = max(enumerate(k), key=operator.itemgetter(1))
# print(index,value)


import operator
p=model.fc1.weight.detach().numpy()
for i in range(15):
    index, value = max(enumerate(p[i]), key=operator.itemgetter(1))
    print("FC - Feature "+ str(i) +" : ",index,value)
    print
    print("CNN value: ",k[0][index] )
# Out:
# FC - Feature 0 :  684 0.041578084
# CNN value:  17.59211
# FC - Feature 1 :  684 0.051804464
# CNN value:  17.59211
# FC - Feature 2 :  360 0.04816093
# CNN value:  0.53643996
# FC - Feature 3 :  492 0.035558272
# CNN value:  0.53643996
# FC - Feature 4 :  478 0.06459166
# CNN value:  0.53643996
# FC - Feature 5 :  585 0.049136233
# CNN value:  0.53643996
# FC - Feature 6 :  492 0.081621096
# CNN value:  0.53643996
# FC - Feature 7 :  360 0.065480515
# CNN value:  0.53643996
# FC - Feature 8 :  585 0.04792851
# CNN value:  0.53643996
# FC - Feature 9 :  492 0.06556648
# CNN value:  0.53643996
# FC - Feature 10 :  684 0.035789683
# CNN value:  17.59211
# FC - Feature 11 :  684 0.034514345
# CNN value:  17.59211
# FC - Feature 12 :  817 0.043642323
# CNN value:  17.59211
# FC - Feature 13 :  492 0.088237286
# CNN value:  0.53643996
# FC - Feature 14 :  492 0.09752004
# CNN value:  0.53643996

# %%
import random


p=0
class_data = []
while(p<len(uframes)):
    data3=[]
    print(p)
    for i in range(50):
        img = uframes[p]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        temp = model(x_1[i].reshape(1,3,100,100))[1]
        #print(temp)
        class_data.append((list(temp.detach().numpy()[0]),p))
    p+=1
    print(len(class_data))

random.shuffle(class_data)
random.shuffle(class_data)

print("length ", len(class_data))
# Out:
# 0
# 50
# 1
# 100
# 2
# 150
# 3
# 200
# 4
# 250
# 5
# 300
# 6
# 350
# 7
# 400
# 8
# 450
# 9
# 500
# 10
# 550
# 11
# 600
# length  600

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from colorama import init  
import time
import cv2

print(np.shape(uframes[0]))


#z  = np.array(np.transpose(np.asarray(z),(2,0,1)),dtype=np.float32)
# import some data to play with
print("Length of Class data: ", len(class_data))
# Take the first two features. We could avoid this by using a two-dim dataset
X = [(i[0]) for i in class_data]
y = [i[1] for i in class_data]
#print(X,np.shape(X))
#print(y,np.shape(y))
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel='linear', C=C)
clf = clf.fit(X, y)
data3=[]
y3=0

n1 = "\x1b[31m\"Drone Stationary, Tank Firing\"\x1b[0m"
n2 = "\x1b[31m\"Drone Reloading, Tank Firing\"\x1b[0m"
n3 = "\x1b[31m\"Drone Firing, Tank Stationary\"\x1b[0m"
n4 = "\x1b[31m\"Drone Firing, Tank Reloading\"\x1b[0m"
n5 = "\x1b[31m\"Drone Firing, Tank Firing\"\x1b[0m"

names = ['Just Background','Only Tank moving', 'Only Drone Moving', 'Drone stationary, Tank Stationary', 'Drone Stationary, Tank Reloading' ,
         n1, 'Drone reloading, Tank Stationary', 'Drone reloading, Tank Reloading', n2 , n3,n4,n5]

print("Start")

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

for i in range(12):
    #z = cv2.imread('Images_100/0a.png')
    #l = Image.fromarray(z)
#     print("shape of z", np.shape(z),type(z))
#     #l.show()
#     #z  = cv2.resize(z,(100,100))
#     img = uframes[i]
#     print(np.shape(img))
#     img.show()
#     data3.append(np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32))
#     y3 = np.array(data3)
#     x_1 = torch.from_numpy(y3)
# #     random_img = random.choice(x)
# #     print("random", np.shape(random_img),type(random_img))
# #     show = random_img.detach().numpy() * 255
# #     show = np.array(np.transpose(show,(1,2,0)),dtype=np.uint8)
# #     print("show", np.shape(show),type(show))
# #     ms = Image.fromarray(show)
# #     ms.show()
#     temp = model(x_1[i].reshape(1,3,100,100))[1]
#     temp = temp.detach().numpy()
#     img_blank.show()
#     #print(temp)
#     z = clf.predict(temp)
#     print(names[z[0]])
    img = uframes[i]
    print(np.shape(img))
    img.show()
    #ms = Image.fromarray(z)
    #ms.show()
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    temp = model(x_1[i].reshape(1,3,100,100))[1]
    temp = temp.detach().numpy()
    print(temp)
    z = clf.predict(temp)
    print(names[z[0]])
# Out:
# (100, 100, 3)
# Length of Class data:  600
# Start
# (100, 100, 3)
# [[5.69654167e-01 9.99462187e-01 5.63863292e-02 4.24214751e-01
#   9.99946237e-01 3.76719624e-01 9.24754981e-03 9.96866763e-01
#   3.24720666e-02 6.23485744e-01 9.99366581e-01 1.33173708e-05
#   9.99919176e-01 1.10880566e-04 7.16020440e-05]]
# Just Background
# (100, 100, 3)
# [[1.0693459e-01 9.7853309e-01 6.2482929e-01 8.8721722e-01 9.2732191e-01
#   3.8686104e-04 4.0334295e-03 9.7163016e-01 4.2039016e-01 9.9970645e-01
#   9.6105587e-01 4.5536429e-02 9.1955161e-01 2.7226047e-03 7.8407951e-02]]
# Only Tank moving
# (100, 100, 3)
# [[7.3534204e-03 9.9773276e-01 9.8508829e-01 9.9262118e-01 4.5104271e-01
#   3.5262175e-04 1.2917872e-04 7.4658793e-01 9.1725689e-01 9.9936992e-01
#   9.9860114e-01 5.1300049e-01 5.2829486e-01 2.9081654e-02 4.6734187e-01]]
# Only Drone Moving
# (100, 100, 3)
# [[6.6964526e-04 9.1521192e-01 9.9945718e-01 9.9930429e-01 5.6288450e-04
#   2.2586556e-07 5.6052031e-05 2.4077968e-01 9.9584311e-01 9.9999964e-01
#   9.1780317e-01 9.9973506e-01 1.0335925e-03 4.2442623e-01 9.9904162e-01]]
# Drone stationary, Tank Stationary
# (100, 100, 3)
# [[6.1773854e-01 5.1048535e-01 4.2821926e-01 3.8129362e-01 1.0322047e-02
#   8.4455933e-05 2.3334846e-03 2.1261269e-04 6.1853075e-01 9.9990475e-01
#   4.9628347e-01 9.9220043e-01 6.8009188e-03 9.8382390e-01 9.9368638e-01]]
# Drone Stationary, Tank Reloading
# (100, 100, 3)
# [[9.9997580e-01 8.7049991e-02 3.9350489e-01 2.6484555e-05 1.4167073e-01
#   1.3029476e-03 3.0017098e-05 3.1996256e-01 1.2829518e-01 9.9855381e-01
#   6.7431293e-02 8.8297009e-01 4.4132985e-02 6.9923133e-01 9.5737994e-01]]
# "Drone Stationary, Tank Firing"
# (100, 100, 3)
# [[9.9999666e-01 2.1902008e-06 1.0000000e+00 3.5267242e-06 3.7724271e-07
#   2.0260264e-03 6.5317053e-01 9.9999988e-01 2.2876749e-05 9.9758089e-01
#   4.7796307e-06 9.9999976e-01 3.5909158e-01 4.6132133e-08 6.4752334e-01]]
# Drone reloading, Tank Stationary
# (100, 100, 3)
# [[1.0000000e+00 2.1159988e-07 9.9998021e-01 1.5131814e-09 6.9859670e-06
#   4.3155217e-01 9.8743409e-01 9.9986637e-01 1.5483755e-07 5.7010096e-01
#   4.2174099e-07 9.9999261e-01 7.8759670e-01 3.8049018e-06 2.1713410e-01]]
# Drone reloading, Tank Reloading
# (100, 100, 3)
# [[1.0000000e+00 1.9347251e-08 9.9997711e-01 6.5030982e-14 1.1054412e-04
#   9.2142385e-01 5.0211656e-01 9.9999988e-01 1.4054513e-08 8.0260172e-02
#   3.0951572e-08 9.9987626e-01 9.6154159e-01 1.4544214e-07 3.8078785e-02]]
# "Drone Reloading, Tank Firing"
# (100, 100, 3)
# [[9.9998307e-01 9.9999917e-01 9.1853076e-01 1.7807450e-05 1.3325374e-02
#   9.9982435e-01 4.4189114e-06 2.7935535e-01 4.3374286e-03 1.8264313e-04
#   9.9999952e-01 9.9133462e-01 9.9873489e-01 3.9311872e-05 5.1611115e-04]]
# "Drone Firing, Tank Stationary"
# (100, 100, 3)
# [[1.0000000e+00 9.9999106e-01 4.5650690e-03 7.6405922e-09 2.0006411e-01
#   9.9999952e-01 1.8434954e-04 2.5986764e-04 2.9483532e-05 5.8745394e-07
#   9.9999404e-01 7.9409081e-01 9.9980861e-01 3.2320421e-03 7.7956029e-05]]
# "Drone Firing, Tank Reloading"
# (100, 100, 3)
# [[1.0000000e+00 9.9990249e-01 3.9572958e-03 3.2836459e-13 7.9830289e-01
#   1.0000000e+00 2.3663674e-06 3.6512318e-01 2.6762741e-06 3.8656605e-08
#   9.9991810e-01 1.8614928e-01 9.9997163e-01 1.2392933e-04 1.1127093e-05]]
# "Drone Firing, Tank Firing"

# %%
import numpy as np
import matplotlib.pyplot as plt
print(droner)
x = [dronec[i][0] for i in range(len(dronec))]
y = [dronec[i][1] for i in range(len(dronec))]
x1 = [droner[i][0] for i in range(len(droner))]
y1 = [droner[i][1] for i in range(len(droner))]
#
#plt.scatter(y,x)
plt.scatter(y1,x1,color='red')
plt.show
# Out:
# []
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(60,60),imt.rotate(180))
#img_blank.paste(im_drone.resize((10,10)),(10,30),im_drone.resize((10,10)))
#img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
#draw = ImageDraw.Draw(img_blank)
#draw.ellipse((60,60,68,68), fill=(255, 0, 0))
# img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
#draw = ImageDraw.Draw(img_blank)
#draw.ellipse((10,30,18,38), fill=(50, 182, 150))
#img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
#img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
img_blank.show()
pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
filename = "lesser_15_features/testing.txt"
file = open(filename, 'w')
file.write(str(model(pil.reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)
img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
#img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
#img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))

#img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))

pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
filename = "Marginalization_Simple-increased_channels-32/drone_pos_3.txt"
file = open(filename, 'w')
file.write(str(model(pil.reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import cv2
vidcap = cv2.VideoCapture('tank.avi')
success,image = vidcap.read()
count = 0
while success:
  cv2.imwrite("frame/tank_frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)   

from PIL import  Image,ImageDraw

img = uframes[20]
z = Image.fromarray(img)
z.show()
data3=[]
data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
y3 = np.array(data3)
x_1 = torch.from_numpy(y3)
temp = model(x_1[0].reshape(1,3,100,100))[0].detach().numpy()
filename = "Marginalization_Simple-increased_channels-32-video-multiple/TD.txt"
file = open(filename, 'w')
file.write(str(model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)   

from PIL import  Image,ImageDraw

img = Image.open("frame/tank_frame0.jpg")
img =  cv2.resize(np.asarray(img),(100,100))
data3=[]
data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
y3 = np.array(data3)
x_1 = torch.from_numpy(y3)
temp = model(x_1[0].reshape(1,3,100,100))[0].detach().numpy()
filename = "Marginalization_Simple-increased_channels-32-video-multiple/tank.txt"
file = open(filename, 'w')
file.write(str(model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()))
file.close()
