# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random
import cv2

Batch_Size = 50
num_epochs = 200
learning_rate = 1e-5
samples = 10000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
uframes = []

im1 = Image.open('tree1.png')
im1 = im1.resize((8,8))

imt = Image.open('tank.png')
imt = imt.resize((10,10))


im2 = Image.open('tree2.png')
im2 = im2.resize((8,8))

im3 = Image.open('tree3.png')
im3 = im3.resize((8,8))

im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((10,10))

imb = Image.open('bullet.png')
imb = imb.resize((2,2))

for i in range(1):
    
    #blank
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)

    uframes.append(img_blank)
    
    #only tank
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    
    uframes.append(img_blank)
    
    #only drone
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t1d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t2d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,35,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t3d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t1d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw.ellipse((40,50,43,53), fill=(50, 182, 150))
    
    uframes.append(img_blank)
    
    #t2d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,35,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw.ellipse((40,50,43,53), fill=(50, 182, 150))
    
    
    uframes.append(img_blank)
    
    #t3d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw.ellipse((40,50,43,53), fill=(50, 182, 150))
    
    
    uframes.append(img_blank)
    
    #t1d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    uframes.append(img_blank)
    
    #t2d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,35,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    
    uframes.append(img_blank)
    
    #t3d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    
    uframes.append(img_blank)



for i in range(samples):
    data1.append(np.array(np.transpose(np.asarray(uframes[i % len(uframes)]),(2,0,1)),dtype=np.float32))
    data2.append(np.array(np.transpose(np.asarray(uframes[(i+1) % len(uframes)]),(2,0,1)),dtype=np.float32))



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = '#9b7653')
img.paste(im1,(5,75),im1)
img.paste(im1,(10,55),im1)
img.paste(im1,(25,50),im1)
img.paste(im2,(75,5),im2)
img.paste(im2,(60,30),im2)
img.paste(im2,(90,20),im2)
img.paste(im3,(75,60),im3)
img.paste(im3,(60,80),im3)
im_n = np.reshape(img,(100,100,3))
b = np.asarray(im_n)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)

#y0 = np.array(np.transpose(np.asarray(y0),(0,3,1,2)),dtype=np.float32)
#y1 = np.array(np.transpose(np.asarray(y1),(0,3,1,2)),dtype=np.float32)
print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, stride=1, padding=2)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)

        # Convolution 2
        self.cnn2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.relu2 = nn.ReLU()

        # Max pool 2
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(20000, 15)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        out = self.cnn2(out)
        out = self.relu2(out)

        # Max pool 2 
        out = self.maxpool2(out)
        im_out = out
        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return im_out,out
    
model = CNNModel()


optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x)[1],model(y)[1])
        # ===================backward====================
 
        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print("shape: ", np.shape(model(x[0].reshape(1,3,100, 100))[0]))
#     print("x: ", model(x[0].reshape(1,3,100, 100)))
#     print("y:", model(y[0].reshape(1,3,100, 100)))
#     print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# (10000, 3, 100, 100)
# epoch [1/200], loss:-0.0441
# shape:  torch.Size([1, 32, 25, 25])
# epoch [2/200], loss:-0.1249
# shape:  torch.Size([1, 32, 25, 25])
# epoch [3/200], loss:-0.1972
# shape:  torch.Size([1, 32, 25, 25])
# epoch [4/200], loss:-0.1960
# shape:  torch.Size([1, 32, 25, 25])
# epoch [5/200], loss:-0.2556
# shape:  torch.Size([1, 32, 25, 25])
# epoch [6/200], loss:-0.2349
# shape:  torch.Size([1, 32, 25, 25])
# epoch [7/200], loss:-0.2670
# shape:  torch.Size([1, 32, 25, 25])
# epoch [8/200], loss:-0.2739
# shape:  torch.Size([1, 32, 25, 25])
# epoch [9/200], loss:-0.2788
# shape:  torch.Size([1, 32, 25, 25])
# epoch [10/200], loss:-0.2801
# shape:  torch.Size([1, 32, 25, 25])
# epoch [11/200], loss:-0.2831
# shape:  torch.Size([1, 32, 25, 25])
# epoch [12/200], loss:-0.2623
# shape:  torch.Size([1, 32, 25, 25])
# epoch [13/200], loss:-0.2734
# shape:  torch.Size([1, 32, 25, 25])
# epoch [14/200], loss:-0.2962
# shape:  torch.Size([1, 32, 25, 25])
# epoch [15/200], loss:-0.2816
# shape:  torch.Size([1, 32, 25, 25])
# epoch [16/200], loss:-0.1746
# shape:  torch.Size([1, 32, 25, 25])
# epoch [17/200], loss:-0.2996
# shape:  torch.Size([1, 32, 25, 25])
# epoch [18/200], loss:-0.3413
# shape:  torch.Size([1, 32, 25, 25])
# epoch [19/200], loss:-0.3060
# shape:  torch.Size([1, 32, 25, 25])
# epoch [20/200], loss:-0.2336
# shape:  torch.Size([1, 32, 25, 25])
# epoch [21/200], loss:-0.2735
# shape:  torch.Size([1, 32, 25, 25])
# epoch [22/200], loss:-0.2522
# shape:  torch.Size([1, 32, 25, 25])
# epoch [23/200], loss:-0.3068
# shape:  torch.Size([1, 32, 25, 25])
# epoch [24/200], loss:-0.2412
# shape:  torch.Size([1, 32, 25, 25])
# epoch [25/200], loss:-0.2606
# shape:  torch.Size([1, 32, 25, 25])
# epoch [26/200], loss:-0.2585
# shape:  torch.Size([1, 32, 25, 25])
# epoch [27/200], loss:-0.2665
# shape:  torch.Size([1, 32, 25, 25])
# epoch [28/200], loss:-0.3336
# shape:  torch.Size([1, 32, 25, 25])
# epoch [29/200], loss:-0.3115
# shape:  torch.Size([1, 32, 25, 25])
# epoch [30/200], loss:-0.2815
# shape:  torch.Size([1, 32, 25, 25])
# epoch [31/200], loss:-0.3403
# shape:  torch.Size([1, 32, 25, 25])
# epoch [32/200], loss:-0.3156
# shape:  torch.Size([1, 32, 25, 25])
# epoch [33/200], loss:-0.4499
# shape:  torch.Size([1, 32, 25, 25])
# epoch [34/200], loss:-0.4945
# shape:  torch.Size([1, 32, 25, 25])
# epoch [35/200], loss:-0.5163
# shape:  torch.Size([1, 32, 25, 25])
# epoch [36/200], loss:-0.5895
# shape:  torch.Size([1, 32, 25, 25])
# epoch [37/200], loss:-0.5527
# shape:  torch.Size([1, 32, 25, 25])
# epoch [38/200], loss:-0.6742
# shape:  torch.Size([1, 32, 25, 25])
# epoch [39/200], loss:-0.6773
# shape:  torch.Size([1, 32, 25, 25])
# epoch [40/200], loss:-0.8145
# shape:  torch.Size([1, 32, 25, 25])
# epoch [41/200], loss:-0.7415
# shape:  torch.Size([1, 32, 25, 25])
# epoch [42/200], loss:-0.7465
# shape:  torch.Size([1, 32, 25, 25])
# epoch [43/200], loss:-0.7339
# shape:  torch.Size([1, 32, 25, 25])
# epoch [44/200], loss:-0.7751
# shape:  torch.Size([1, 32, 25, 25])
# epoch [45/200], loss:-0.9501
# shape:  torch.Size([1, 32, 25, 25])
# epoch [46/200], loss:-0.9508
# shape:  torch.Size([1, 32, 25, 25])
# epoch [47/200], loss:-0.9144
# shape:  torch.Size([1, 32, 25, 25])
# epoch [48/200], loss:-0.9692
# shape:  torch.Size([1, 32, 25, 25])
# epoch [49/200], loss:-0.9499
# shape:  torch.Size([1, 32, 25, 25])
# epoch [50/200], loss:-0.9992
# shape:  torch.Size([1, 32, 25, 25])
# epoch [51/200], loss:-0.9680
# shape:  torch.Size([1, 32, 25, 25])
# epoch [52/200], loss:-1.1244
# shape:  torch.Size([1, 32, 25, 25])
# epoch [53/200], loss:-1.0429
# shape:  torch.Size([1, 32, 25, 25])
# epoch [54/200], loss:-0.9081
# shape:  torch.Size([1, 32, 25, 25])
# epoch [55/200], loss:-1.0680
# shape:  torch.Size([1, 32, 25, 25])
# epoch [56/200], loss:-0.9272
# shape:  torch.Size([1, 32, 25, 25])
# epoch [57/200], loss:-1.1803
# shape:  torch.Size([1, 32, 25, 25])
# epoch [58/200], loss:-1.1324
# shape:  torch.Size([1, 32, 25, 25])
# epoch [59/200], loss:-1.2029
# shape:  torch.Size([1, 32, 25, 25])
# epoch [60/200], loss:-1.1548
# shape:  torch.Size([1, 32, 25, 25])
# epoch [61/200], loss:-1.2310
# shape:  torch.Size([1, 32, 25, 25])
# epoch [62/200], loss:-1.1747
# shape:  torch.Size([1, 32, 25, 25])
# epoch [63/200], loss:-1.2860
# shape:  torch.Size([1, 32, 25, 25])
# epoch [64/200], loss:-1.2905
# shape:  torch.Size([1, 32, 25, 25])
# epoch [65/200], loss:-1.4531
# shape:  torch.Size([1, 32, 25, 25])
# epoch [66/200], loss:-1.3519
# shape:  torch.Size([1, 32, 25, 25])
# epoch [67/200], loss:-1.1687
# shape:  torch.Size([1, 32, 25, 25])
# epoch [68/200], loss:-1.4184
# shape:  torch.Size([1, 32, 25, 25])
# epoch [69/200], loss:-1.1882
# shape:  torch.Size([1, 32, 25, 25])
# epoch [70/200], loss:-1.2200
# shape:  torch.Size([1, 32, 25, 25])
# epoch [71/200], loss:-1.3626
# shape:  torch.Size([1, 32, 25, 25])
# epoch [72/200], loss:-1.5009
# shape:  torch.Size([1, 32, 25, 25])
# epoch [73/200], loss:-1.5179
# shape:  torch.Size([1, 32, 25, 25])
# epoch [74/200], loss:-1.4946
# shape:  torch.Size([1, 32, 25, 25])
# epoch [75/200], loss:-1.5086
# shape:  torch.Size([1, 32, 25, 25])
# epoch [76/200], loss:-1.4163
# shape:  torch.Size([1, 32, 25, 25])
# epoch [77/200], loss:-1.4989
# shape:  torch.Size([1, 32, 25, 25])
# epoch [78/200], loss:-1.5790
# shape:  torch.Size([1, 32, 25, 25])
# epoch [79/200], loss:-1.5061
# shape:  torch.Size([1, 32, 25, 25])
# epoch [80/200], loss:-1.5720
# shape:  torch.Size([1, 32, 25, 25])
# epoch [81/200], loss:-1.6024
# shape:  torch.Size([1, 32, 25, 25])
# epoch [82/200], loss:-1.5321
# shape:  torch.Size([1, 32, 25, 25])
# epoch [83/200], loss:-1.5640
# shape:  torch.Size([1, 32, 25, 25])
# epoch [84/200], loss:-1.7350
# shape:  torch.Size([1, 32, 25, 25])
# epoch [85/200], loss:-1.6590
# shape:  torch.Size([1, 32, 25, 25])
# epoch [86/200], loss:-1.7121
# shape:  torch.Size([1, 32, 25, 25])
# epoch [87/200], loss:-1.5663
# shape:  torch.Size([1, 32, 25, 25])
# epoch [88/200], loss:-1.4006
# shape:  torch.Size([1, 32, 25, 25])
# epoch [89/200], loss:-1.7288
# shape:  torch.Size([1, 32, 25, 25])
# epoch [90/200], loss:-1.6276
# shape:  torch.Size([1, 32, 25, 25])
# epoch [91/200], loss:-1.5357
# shape:  torch.Size([1, 32, 25, 25])
# epoch [92/200], loss:-1.6103
# shape:  torch.Size([1, 32, 25, 25])
# epoch [93/200], loss:-1.6458
# shape:  torch.Size([1, 32, 25, 25])
# epoch [94/200], loss:-1.7264
# shape:  torch.Size([1, 32, 25, 25])
# epoch [95/200], loss:-1.7526
# shape:  torch.Size([1, 32, 25, 25])
# epoch [96/200], loss:-1.6183
# shape:  torch.Size([1, 32, 25, 25])
# epoch [97/200], loss:-1.6418
# shape:  torch.Size([1, 32, 25, 25])
# epoch [98/200], loss:-1.5832
# shape:  torch.Size([1, 32, 25, 25])
# epoch [99/200], loss:-1.5434
# shape:  torch.Size([1, 32, 25, 25])
# epoch [100/200], loss:-1.5273
# shape:  torch.Size([1, 32, 25, 25])
# epoch [101/200], loss:-1.7039
# shape:  torch.Size([1, 32, 25, 25])
# epoch [102/200], loss:-1.5447
# shape:  torch.Size([1, 32, 25, 25])
# epoch [103/200], loss:-1.5241
# shape:  torch.Size([1, 32, 25, 25])
# epoch [104/200], loss:-1.6035
# shape:  torch.Size([1, 32, 25, 25])
# epoch [105/200], loss:-1.7658
# shape:  torch.Size([1, 32, 25, 25])
# epoch [106/200], loss:-1.5701
# shape:  torch.Size([1, 32, 25, 25])
# epoch [107/200], loss:-1.5987
# shape:  torch.Size([1, 32, 25, 25])
# epoch [108/200], loss:-1.5654
# shape:  torch.Size([1, 32, 25, 25])
# epoch [109/200], loss:-1.6052
# shape:  torch.Size([1, 32, 25, 25])
# epoch [110/200], loss:-1.6792
# shape:  torch.Size([1, 32, 25, 25])
# epoch [111/200], loss:-1.6728
# shape:  torch.Size([1, 32, 25, 25])
# epoch [112/200], loss:-1.6936
# shape:  torch.Size([1, 32, 25, 25])
# epoch [113/200], loss:-1.5717
# shape:  torch.Size([1, 32, 25, 25])
# epoch [114/200], loss:-1.5160
# shape:  torch.Size([1, 32, 25, 25])
# epoch [115/200], loss:-1.6467
# shape:  torch.Size([1, 32, 25, 25])
# epoch [116/200], loss:-1.5271
# shape:  torch.Size([1, 32, 25, 25])
# epoch [117/200], loss:-1.5696
# shape:  torch.Size([1, 32, 25, 25])
# epoch [118/200], loss:-1.6475
# shape:  torch.Size([1, 32, 25, 25])
# epoch [119/200], loss:-1.5955
# shape:  torch.Size([1, 32, 25, 25])
# epoch [120/200], loss:-1.6213
# shape:  torch.Size([1, 32, 25, 25])
# epoch [121/200], loss:-1.5969
# shape:  torch.Size([1, 32, 25, 25])
# epoch [122/200], loss:-1.5585
# shape:  torch.Size([1, 32, 25, 25])
# epoch [123/200], loss:-1.7174
# shape:  torch.Size([1, 32, 25, 25])
# epoch [124/200], loss:-1.5924
# shape:  torch.Size([1, 32, 25, 25])
# epoch [125/200], loss:-1.6939
# shape:  torch.Size([1, 32, 25, 25])
# epoch [126/200], loss:-1.6212
# shape:  torch.Size([1, 32, 25, 25])
# epoch [127/200], loss:-1.7506
# shape:  torch.Size([1, 32, 25, 25])
# epoch [128/200], loss:-1.6172
# shape:  torch.Size([1, 32, 25, 25])
# epoch [129/200], loss:-1.5826
# shape:  torch.Size([1, 32, 25, 25])
# epoch [130/200], loss:-1.5064
# shape:  torch.Size([1, 32, 25, 25])
# epoch [131/200], loss:-1.6249
# shape:  torch.Size([1, 32, 25, 25])
# epoch [132/200], loss:-1.6100
# shape:  torch.Size([1, 32, 25, 25])
# epoch [133/200], loss:-1.6028
# shape:  torch.Size([1, 32, 25, 25])
# epoch [134/200], loss:-1.6661
# shape:  torch.Size([1, 32, 25, 25])
# epoch [135/200], loss:-1.8138
# shape:  torch.Size([1, 32, 25, 25])
# epoch [136/200], loss:-1.7830
# shape:  torch.Size([1, 32, 25, 25])
# epoch [137/200], loss:-1.7332
# shape:  torch.Size([1, 32, 25, 25])
# epoch [138/200], loss:-1.7501
# shape:  torch.Size([1, 32, 25, 25])
# epoch [139/200], loss:-1.6964
# shape:  torch.Size([1, 32, 25, 25])
# epoch [140/200], loss:-1.7448
# shape:  torch.Size([1, 32, 25, 25])
# epoch [141/200], loss:-1.7839
# shape:  torch.Size([1, 32, 25, 25])
# epoch [142/200], loss:-1.7157
# shape:  torch.Size([1, 32, 25, 25])
# epoch [143/200], loss:-1.7485
# shape:  torch.Size([1, 32, 25, 25])
# epoch [144/200], loss:-1.5942
# shape:  torch.Size([1, 32, 25, 25])
# epoch [145/200], loss:-1.7835
# shape:  torch.Size([1, 32, 25, 25])
# epoch [146/200], loss:-1.7141
# shape:  torch.Size([1, 32, 25, 25])
# epoch [147/200], loss:-1.6823
# shape:  torch.Size([1, 32, 25, 25])
# epoch [148/200], loss:-1.6837
# shape:  torch.Size([1, 32, 25, 25])
# epoch [149/200], loss:-1.8797
# shape:  torch.Size([1, 32, 25, 25])
# epoch [150/200], loss:-1.6385
# shape:  torch.Size([1, 32, 25, 25])
# epoch [151/200], loss:-1.6353
# shape:  torch.Size([1, 32, 25, 25])
# epoch [152/200], loss:-1.7415
# shape:  torch.Size([1, 32, 25, 25])
# epoch [153/200], loss:-1.6560
# shape:  torch.Size([1, 32, 25, 25])
# epoch [154/200], loss:-1.6818
# shape:  torch.Size([1, 32, 25, 25])
# epoch [155/200], loss:-1.6272
# shape:  torch.Size([1, 32, 25, 25])
# epoch [156/200], loss:-1.7063
# shape:  torch.Size([1, 32, 25, 25])
# epoch [157/200], loss:-1.6605
# shape:  torch.Size([1, 32, 25, 25])
# epoch [158/200], loss:-1.7664
# shape:  torch.Size([1, 32, 25, 25])
# epoch [159/200], loss:-1.6606
# shape:  torch.Size([1, 32, 25, 25])
# epoch [160/200], loss:-1.6215
# shape:  torch.Size([1, 32, 25, 25])
# epoch [161/200], loss:-1.7336
# shape:  torch.Size([1, 32, 25, 25])
# epoch [162/200], loss:-1.8384
# shape:  torch.Size([1, 32, 25, 25])
# epoch [163/200], loss:-1.6634
# shape:  torch.Size([1, 32, 25, 25])
# epoch [164/200], loss:-1.7080
# shape:  torch.Size([1, 32, 25, 25])
# epoch [165/200], loss:-1.7220
# shape:  torch.Size([1, 32, 25, 25])
# epoch [166/200], loss:-1.7001
# shape:  torch.Size([1, 32, 25, 25])
# epoch [167/200], loss:-1.5696
# shape:  torch.Size([1, 32, 25, 25])
# epoch [168/200], loss:-1.7287
# shape:  torch.Size([1, 32, 25, 25])
# epoch [169/200], loss:-1.7728
# shape:  torch.Size([1, 32, 25, 25])
# epoch [170/200], loss:-1.6247
# shape:  torch.Size([1, 32, 25, 25])
# epoch [171/200], loss:-1.7967
# shape:  torch.Size([1, 32, 25, 25])
# epoch [172/200], loss:-1.5145
# shape:  torch.Size([1, 32, 25, 25])
# epoch [173/200], loss:-1.5781
# shape:  torch.Size([1, 32, 25, 25])
# epoch [174/200], loss:-1.8668
# shape:  torch.Size([1, 32, 25, 25])
# epoch [175/200], loss:-1.8242
# shape:  torch.Size([1, 32, 25, 25])
# epoch [176/200], loss:-1.7320
# shape:  torch.Size([1, 32, 25, 25])
# epoch [177/200], loss:-1.7895
# shape:  torch.Size([1, 32, 25, 25])
# epoch [178/200], loss:-1.6478
# shape:  torch.Size([1, 32, 25, 25])
# epoch [179/200], loss:-1.6985
# shape:  torch.Size([1, 32, 25, 25])
# epoch [180/200], loss:-1.6556
# shape:  torch.Size([1, 32, 25, 25])
# epoch [181/200], loss:-1.7010
# shape:  torch.Size([1, 32, 25, 25])
# epoch [182/200], loss:-1.8282
# shape:  torch.Size([1, 32, 25, 25])
# epoch [183/200], loss:-1.5733
# shape:  torch.Size([1, 32, 25, 25])
# epoch [184/200], loss:-1.7511
# shape:  torch.Size([1, 32, 25, 25])
# epoch [185/200], loss:-1.7940
# shape:  torch.Size([1, 32, 25, 25])
# epoch [186/200], loss:-1.8542
# shape:  torch.Size([1, 32, 25, 25])
# epoch [187/200], loss:-1.6670
# shape:  torch.Size([1, 32, 25, 25])
# epoch [188/200], loss:-1.7629
# shape:  torch.Size([1, 32, 25, 25])
# epoch [189/200], loss:-1.7738
# shape:  torch.Size([1, 32, 25, 25])
# epoch [190/200], loss:-1.6881
# shape:  torch.Size([1, 32, 25, 25])
# epoch [191/200], loss:-1.7000
# shape:  torch.Size([1, 32, 25, 25])
# epoch [192/200], loss:-1.7599
# shape:  torch.Size([1, 32, 25, 25])
# epoch [193/200], loss:-1.8136
# shape:  torch.Size([1, 32, 25, 25])
# epoch [194/200], loss:-1.5989
# shape:  torch.Size([1, 32, 25, 25])
# epoch [195/200], loss:-1.8678
# shape:  torch.Size([1, 32, 25, 25])
# epoch [196/200], loss:-1.6983
# shape:  torch.Size([1, 32, 25, 25])
# epoch [197/200], loss:-1.7047
# shape:  torch.Size([1, 32, 25, 25])
# epoch [198/200], loss:-1.6721
# shape:  torch.Size([1, 32, 25, 25])
# epoch [199/200], loss:-1.7874
# shape:  torch.Size([1, 32, 25, 25])
# epoch [200/200], loss:-1.7022
# shape:  torch.Size([1, 32, 25, 25])

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(12):
    k = uframes[i]
    v = np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32)
    v = torch.from_numpy(v)
    filename = "ref_image_" + str(i) + ".txt"
    file = open(filename, 'w')
    file.write(str(model(v.reshape(1,3,100, 100))[0].detach().numpy()))
    file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))


filename = "drone_only_pos_3.txt"
file = open(filename, 'w')
file.write(str(model(v.reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import random


p=0
class_data = []
while(p<len(uframes)):
    data3=[]
    print(p)
    for i in range(50):
        img = uframes[p]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        temp = model(x_1[i].reshape(1,3,100,100))[1]
        #print(temp)
        class_data.append((list(temp.detach().numpy()[0]),p))
    p+=1
    print(len(class_data))

random.shuffle(class_data)
random.shuffle(class_data)

print("length ", len(class_data))
# Out:
# 0
# 50
# 1
# 100
# 2
# 150
# 3
# 200
# 4
# 250
# 5
# 300
# 6
# 350
# 7
# 400
# 8
# 450
# 9
# 500
# 10
# 550
# 11
# 600
# length  600

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from colorama import init  
import time
import cv2

print(np.shape(uframes[0]))


#z  = np.array(np.transpose(np.asarray(z),(2,0,1)),dtype=np.float32)
# import some data to play with
print("Length of Class data: ", len(class_data))
# Take the first two features. We could avoid this by using a two-dim dataset
X = [(i[0]) for i in class_data]
y = [i[1] for i in class_data]
#print(X,np.shape(X))
#print(y,np.shape(y))
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel='linear', C=C)
clf = clf.fit(X, y)
data3=[]
y3=0

n1 = "\x1b[31m\"Drone Stationary, Tank Firing\"\x1b[0m"
n2 = "\x1b[31m\"Drone Reloading, Tank Firing\"\x1b[0m"
n3 = "\x1b[31m\"Drone Firing, Tank Stationary\"\x1b[0m"
n4 = "\x1b[31m\"Drone Firing, Tank Reloading\"\x1b[0m"
n5 = "\x1b[31m\"Drone Firing, Tank Firing\"\x1b[0m"

names = ['Just Background','Only Tank moving', 'Only Drone Moving', 'Drone stationary, Tank Stationary', 'Drone Stationary, Tank Reloading' ,
         n1, 'Drone reloading, Tank Stationary', 'Drone reloading, Tank Reloading', n2 , n3,n4,n5]

print("Start")

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

for i in range(1):
#     z = cv2.imread('Images_100/0a.png')
#     l = Image.fromarray(z)
#     print("shape of z", np.shape(z),type(z))
#     #l.show()
#     #z  = cv2.resize(z,(100,100))
#     img = z#uframes[i]
#     print(np.shape(img))
    #ms = Image.fromarray(z)
    #ms.show()
    data3.append(np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
#     random_img = random.choice(x)
#     print("random", np.shape(random_img),type(random_img))
#     show = random_img.detach().numpy() * 255
#     show = np.array(np.transpose(show,(1,2,0)),dtype=np.uint8)
#     print("show", np.shape(show),type(show))
#     ms = Image.fromarray(show)
#     ms.show()
    temp = model(x_1[i].reshape(1,3,100,100))[1]
    temp = temp.detach().numpy()
    img_blank.show()
    #print(temp)
    z = clf.predict(temp)
    print(names[z[0]])
# Out:
# (100, 100, 3)
# Length of Class data:  600
# Start
# Just Background

# %%
print(len(uframes
         ))
# Out:
# 12
