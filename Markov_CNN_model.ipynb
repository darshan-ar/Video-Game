# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np


Batch_Size = 250
num_epochs = 100
learning_rate = 1e-3
samples = 50000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset


for i in range(samples):
    img = Image.new('RGB', (28, 28), color = 'white')
    row,col,ch= np.shape(img)
    mean = 0
    var = 1
    sigma = var**0.5
    gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
    noisy_pos1 = img + gauss_pos1
    im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
    draw = ImageDraw.Draw(im2_pos1)
    draw.rectangle([9,12,12,15],fill='red',outline='red')
    data1.append(np.asarray(im2_pos1))



for i in range(samples):
    img = Image.new('RGB', (28, 28), color = 'white')
    row,col,ch= np.shape(img)
    mean = 0
    var = 1
    sigma = var**0.5
    gauss_pos2 = np.random.normal(mean,sigma,(row,col,ch))
    noisy_pos2 = img + gauss_pos2
    im2_pos2 = Image.fromarray(noisy_pos2,'RGB')
    r = np.random.choice(np.arange(1, 3), p=[0.5,0.5])
    draw = ImageDraw.Draw(im2_pos2)
    if r==1:
        draw.rectangle([21, 12, 24, 15], fill='red', outline='red')
        data2.append(np.asarray(im2_pos2))
    else:
        draw.rectangle([9,12,12,15],fill='red',outline='red')
        data2.append(np.asarray(im2_pos2))


#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data

gauss = np.random.normal(mean,sigma,(row,col,ch))
noisy = img + gauss
im2 = Image.fromarray(noisy,'RGB')
b = np.asarray(im2)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.array(data1, dtype=np.float32)
y1 = np.array(data2, dtype=np.float32)
y0 = np.transpose(y0, (0, 3, 1, 2))# This to make channels first for CNN
y1 = np.transpose(y1, (0, 3, 1, 2)) 


print(y0.shape)

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class autoencoder(nn.Module):
    def __init__(self):
        super(autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 16, 3, stride=3, padding=1),  # b, 16, 10, 10
            nn.ReLU(True),
            nn.MaxPool2d(2, stride=2),  # b, 16, 5, 5
            nn.Conv2d(16, 8, 3, stride=2, padding=1),  # b, 8, 3, 3
            nn.ReLU(True), # b, 8, 2, 2
            nn.Conv2d(8,4,3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(4,2,3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2, stride=1)
        )
        self.fc = nn.Linear(2, 1)

    def forward(self, x):
        x = self.encoder(x)
        x = x.view(-1,2)
        x = self.fc(x)
        return x

class auto_decoder(nn.Module):
    def __init__(self):
        super(auto_decoder,self).__init__()
        ## decoder layers ##
        ## a kernel of 2 and a stride of 2 will increase the spatial dims by 2
        self.t_conv1 = nn.ConvTranspose2d(4, 16, 3,padding=1)
        self.t_conv2 = nn.ConvTranspose2d(16, 3, 3,padding=1)
        
    def forward(self, x):
        ## decode ##
        # add transpose conv layers, with relu activation function
        x = F.relu(self.t_conv1(x))
        # output layer (with sigmoid for scaling from 0 to 1)
        x = F.sigmoid(self.t_conv2(x))
                
        return x
    

model = autoencoder()
model_1 = auto_decoder()

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)

    covf = torch.matmul((fx.t()), fx) / Nsamples

    covg = torch.matmul((gy.t()), (gy)) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h



optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-5)

criterion = nn.MSELoss()
optimizer_1 = torch.optim.Adam(model_1.parameters(), lr=learning_rate,weight_decay=1e-5)


for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x),model(y))
        # ===================backward====================

        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print("x: ", model(x[0].reshape(1,3,28,28)))
    print("y:", model(y[0].reshape(1,3,28,28)))
    print("b:", model(b.reshape(1,3,28,28)))
# Out:
# (50000, 3, 28, 28)
# epoch [1/100], loss:0.0007
# x:  tensor([[1.0824]], grad_fn=<AddmmBackward>)
# y: tensor([[0.9397]], grad_fn=<AddmmBackward>)
# b: tensor([[0.9296]], grad_fn=<AddmmBackward>)
# epoch [2/100], loss:-0.0001
# x:  tensor([[0.7867]], grad_fn=<AddmmBackward>)
# y: tensor([[0.7936]], grad_fn=<AddmmBackward>)
# b: tensor([[0.7095]], grad_fn=<AddmmBackward>)
# epoch [3/100], loss:-0.0006
# x:  tensor([[0.9148]], grad_fn=<AddmmBackward>)
# y: tensor([[0.9036]], grad_fn=<AddmmBackward>)
# b: tensor([[0.7849]], grad_fn=<AddmmBackward>)
# epoch [4/100], loss:-0.0024
# x:  tensor([[0.7995]], grad_fn=<AddmmBackward>)
# y: tensor([[0.7703]], grad_fn=<AddmmBackward>)
# b: tensor([[0.5488]], grad_fn=<AddmmBackward>)
# epoch [5/100], loss:-0.0016
# x:  tensor([[1.5558]], grad_fn=<AddmmBackward>)
# y: tensor([[1.7629]], grad_fn=<AddmmBackward>)
# b: tensor([[1.7022]], grad_fn=<AddmmBackward>)
# epoch [6/100], loss:-0.0021
# x:  tensor([[1.5224]], grad_fn=<AddmmBackward>)
# y: tensor([[1.5193]], grad_fn=<AddmmBackward>)
# b: tensor([[1.6543]], grad_fn=<AddmmBackward>)
# epoch [7/100], loss:0.0006
# x:  tensor([[1.7383]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0800]], grad_fn=<AddmmBackward>)
# b: tensor([[1.9157]], grad_fn=<AddmmBackward>)
# epoch [8/100], loss:-0.0126
# x:  tensor([[1.5604]], grad_fn=<AddmmBackward>)
# y: tensor([[1.1871]], grad_fn=<AddmmBackward>)
# b: tensor([[1.4045]], grad_fn=<AddmmBackward>)
# epoch [9/100], loss:-0.0123
# x:  tensor([[1.0881]], grad_fn=<AddmmBackward>)
# y: tensor([[1.5505]], grad_fn=<AddmmBackward>)
# b: tensor([[1.6063]], grad_fn=<AddmmBackward>)
# epoch [10/100], loss:-0.0279
# x:  tensor([[1.5273]], grad_fn=<AddmmBackward>)
# y: tensor([[1.5477]], grad_fn=<AddmmBackward>)
# b: tensor([[1.8825]], grad_fn=<AddmmBackward>)
# epoch [11/100], loss:-0.0030
# x:  tensor([[1.6210]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4829]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3508]], grad_fn=<AddmmBackward>)
# epoch [12/100], loss:0.0018
# x:  tensor([[1.5136]], grad_fn=<AddmmBackward>)
# y: tensor([[1.2381]], grad_fn=<AddmmBackward>)
# b: tensor([[1.8552]], grad_fn=<AddmmBackward>)
# epoch [13/100], loss:-0.0040
# x:  tensor([[1.7182]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1729]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1078]], grad_fn=<AddmmBackward>)
# epoch [14/100], loss:-0.0338
# x:  tensor([[2.9143]], grad_fn=<AddmmBackward>)
# y: tensor([[2.2478]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5157]], grad_fn=<AddmmBackward>)
# epoch [15/100], loss:-0.0220
# x:  tensor([[2.6595]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1514]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6962]], grad_fn=<AddmmBackward>)
# epoch [16/100], loss:-0.0167
# x:  tensor([[2.4530]], grad_fn=<AddmmBackward>)
# y: tensor([[1.8312]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3784]], grad_fn=<AddmmBackward>)
# epoch [17/100], loss:-0.0165
# x:  tensor([[2.2754]], grad_fn=<AddmmBackward>)
# y: tensor([[2.5830]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9051]], grad_fn=<AddmmBackward>)
# epoch [18/100], loss:-0.0311
# x:  tensor([[2.8118]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4981]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7176]], grad_fn=<AddmmBackward>)
# epoch [19/100], loss:-0.0076
# x:  tensor([[2.9418]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3808]], grad_fn=<AddmmBackward>)
# b: tensor([[2.8977]], grad_fn=<AddmmBackward>)
# epoch [20/100], loss:-0.0277
# x:  tensor([[2.6811]], grad_fn=<AddmmBackward>)
# y: tensor([[3.0232]], grad_fn=<AddmmBackward>)
# b: tensor([[3.2997]], grad_fn=<AddmmBackward>)
# epoch [21/100], loss:-0.0230
# x:  tensor([[2.5028]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3790]], grad_fn=<AddmmBackward>)
# b: tensor([[2.8077]], grad_fn=<AddmmBackward>)
# epoch [22/100], loss:-0.0330
# x:  tensor([[2.2208]], grad_fn=<AddmmBackward>)
# y: tensor([[2.9435]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5898]], grad_fn=<AddmmBackward>)
# epoch [23/100], loss:0.0037
# x:  tensor([[2.4974]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3797]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6329]], grad_fn=<AddmmBackward>)
# epoch [24/100], loss:-0.0478
# x:  tensor([[1.9881]], grad_fn=<AddmmBackward>)
# y: tensor([[1.6911]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7232]], grad_fn=<AddmmBackward>)
# epoch [25/100], loss:-0.0283
# x:  tensor([[1.9461]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0136]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5827]], grad_fn=<AddmmBackward>)
# epoch [26/100], loss:-0.0242
# x:  tensor([[1.4757]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0841]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1520]], grad_fn=<AddmmBackward>)
# epoch [27/100], loss:-0.0428
# x:  tensor([[2.7866]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0696]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7738]], grad_fn=<AddmmBackward>)
# epoch [28/100], loss:0.0125
# x:  tensor([[2.9964]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3319]], grad_fn=<AddmmBackward>)
# b: tensor([[2.8579]], grad_fn=<AddmmBackward>)
# epoch [29/100], loss:-0.0225
# x:  tensor([[2.8045]], grad_fn=<AddmmBackward>)
# y: tensor([[2.7326]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6723]], grad_fn=<AddmmBackward>)
# epoch [30/100], loss:0.0013
# x:  tensor([[3.1423]], grad_fn=<AddmmBackward>)
# y: tensor([[3.5282]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9298]], grad_fn=<AddmmBackward>)
# epoch [31/100], loss:-0.0286
# x:  tensor([[3.5688]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6431]], grad_fn=<AddmmBackward>)
# b: tensor([[3.6808]], grad_fn=<AddmmBackward>)
# epoch [32/100], loss:-0.0018
# x:  tensor([[2.3207]], grad_fn=<AddmmBackward>)
# y: tensor([[3.2327]], grad_fn=<AddmmBackward>)
# b: tensor([[3.1168]], grad_fn=<AddmmBackward>)
# epoch [33/100], loss:-0.0259
# x:  tensor([[2.3587]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3811]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7645]], grad_fn=<AddmmBackward>)
# epoch [34/100], loss:0.0111
# x:  tensor([[2.2772]], grad_fn=<AddmmBackward>)
# y: tensor([[2.8914]], grad_fn=<AddmmBackward>)
# b: tensor([[2.8778]], grad_fn=<AddmmBackward>)
# epoch [35/100], loss:-0.0476
# x:  tensor([[2.4941]], grad_fn=<AddmmBackward>)
# y: tensor([[1.9554]], grad_fn=<AddmmBackward>)
# b: tensor([[3.2698]], grad_fn=<AddmmBackward>)
# epoch [36/100], loss:-0.0491
# x:  tensor([[2.2007]], grad_fn=<AddmmBackward>)
# y: tensor([[2.2890]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7443]], grad_fn=<AddmmBackward>)
# epoch [37/100], loss:-0.0243
# x:  tensor([[2.5990]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4326]], grad_fn=<AddmmBackward>)
# b: tensor([[2.8220]], grad_fn=<AddmmBackward>)
# epoch [38/100], loss:-0.0348
# x:  tensor([[3.2366]], grad_fn=<AddmmBackward>)
# y: tensor([[4.0338]], grad_fn=<AddmmBackward>)
# b: tensor([[3.1495]], grad_fn=<AddmmBackward>)
# epoch [39/100], loss:-0.0151
# x:  tensor([[2.2205]], grad_fn=<AddmmBackward>)
# y: tensor([[3.0763]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6169]], grad_fn=<AddmmBackward>)
# epoch [40/100], loss:-0.0475
# x:  tensor([[2.6109]], grad_fn=<AddmmBackward>)
# y: tensor([[2.5558]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9548]], grad_fn=<AddmmBackward>)
# epoch [41/100], loss:-0.0361
# x:  tensor([[3.0581]], grad_fn=<AddmmBackward>)
# y: tensor([[3.0622]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9797]], grad_fn=<AddmmBackward>)
# epoch [42/100], loss:-0.0022
# x:  tensor([[3.2608]], grad_fn=<AddmmBackward>)
# y: tensor([[2.9820]], grad_fn=<AddmmBackward>)
# b: tensor([[3.1286]], grad_fn=<AddmmBackward>)
# epoch [43/100], loss:-0.0238
# x:  tensor([[1.7236]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1773]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6576]], grad_fn=<AddmmBackward>)
# epoch [44/100], loss:-0.0704
# x:  tensor([[2.8995]], grad_fn=<AddmmBackward>)
# y: tensor([[3.8997]], grad_fn=<AddmmBackward>)
# b: tensor([[2.8662]], grad_fn=<AddmmBackward>)
# epoch [45/100], loss:-0.0429
# x:  tensor([[2.6020]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4318]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6248]], grad_fn=<AddmmBackward>)
# epoch [46/100], loss:-0.0274
# x:  tensor([[2.4432]], grad_fn=<AddmmBackward>)
# y: tensor([[1.6014]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6287]], grad_fn=<AddmmBackward>)
# epoch [47/100], loss:-0.0352
# x:  tensor([[2.5606]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6210]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7977]], grad_fn=<AddmmBackward>)
# epoch [48/100], loss:-0.0023
# x:  tensor([[3.1115]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6295]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9555]], grad_fn=<AddmmBackward>)
# epoch [49/100], loss:-0.0183
# x:  tensor([[2.6849]], grad_fn=<AddmmBackward>)
# y: tensor([[2.5453]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4569]], grad_fn=<AddmmBackward>)
# epoch [50/100], loss:0.0211
# x:  tensor([[2.4449]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1571]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6771]], grad_fn=<AddmmBackward>)
# epoch [51/100], loss:-0.0658
# x:  tensor([[3.0454]], grad_fn=<AddmmBackward>)
# y: tensor([[2.5659]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6220]], grad_fn=<AddmmBackward>)
# epoch [52/100], loss:-0.0445
# x:  tensor([[3.1240]], grad_fn=<AddmmBackward>)
# y: tensor([[2.8353]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7563]], grad_fn=<AddmmBackward>)
# epoch [53/100], loss:-0.0292
# x:  tensor([[2.7765]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3710]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4770]], grad_fn=<AddmmBackward>)
# epoch [54/100], loss:-0.0443
# x:  tensor([[1.8055]], grad_fn=<AddmmBackward>)
# y: tensor([[1.2595]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5593]], grad_fn=<AddmmBackward>)
# epoch [55/100], loss:-0.0633
# x:  tensor([[2.8627]], grad_fn=<AddmmBackward>)
# y: tensor([[2.8352]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1791]], grad_fn=<AddmmBackward>)
# epoch [56/100], loss:-0.0349
# x:  tensor([[2.5552]], grad_fn=<AddmmBackward>)
# y: tensor([[2.7451]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5308]], grad_fn=<AddmmBackward>)
# epoch [57/100], loss:-0.0159
# x:  tensor([[2.2031]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6266]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6294]], grad_fn=<AddmmBackward>)
# epoch [58/100], loss:-0.0302
# x:  tensor([[1.8878]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1485]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5497]], grad_fn=<AddmmBackward>)
# epoch [59/100], loss:-0.0173
# x:  tensor([[1.6716]], grad_fn=<AddmmBackward>)
# y: tensor([[2.5512]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2520]], grad_fn=<AddmmBackward>)
# epoch [60/100], loss:-0.0328
# x:  tensor([[2.8030]], grad_fn=<AddmmBackward>)
# y: tensor([[3.4531]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4799]], grad_fn=<AddmmBackward>)
# epoch [61/100], loss:-0.0110
# x:  tensor([[1.9537]], grad_fn=<AddmmBackward>)
# y: tensor([[2.7439]], grad_fn=<AddmmBackward>)
# b: tensor([[2.8246]], grad_fn=<AddmmBackward>)
# epoch [62/100], loss:0.0022
# x:  tensor([[1.9739]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0826]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4428]], grad_fn=<AddmmBackward>)
# epoch [63/100], loss:-0.0376
# x:  tensor([[2.5903]], grad_fn=<AddmmBackward>)
# y: tensor([[1.6582]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5667]], grad_fn=<AddmmBackward>)
# epoch [64/100], loss:-0.0476
# x:  tensor([[1.9924]], grad_fn=<AddmmBackward>)
# y: tensor([[1.7332]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2946]], grad_fn=<AddmmBackward>)
# epoch [65/100], loss:-0.0320
# x:  tensor([[2.2576]], grad_fn=<AddmmBackward>)
# y: tensor([[3.2052]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4959]], grad_fn=<AddmmBackward>)
# epoch [66/100], loss:-0.0204
# x:  tensor([[2.2768]], grad_fn=<AddmmBackward>)
# y: tensor([[2.5178]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6694]], grad_fn=<AddmmBackward>)
# epoch [67/100], loss:-0.0728
# x:  tensor([[1.9804]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3765]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3182]], grad_fn=<AddmmBackward>)
# epoch [68/100], loss:-0.0822
# x:  tensor([[2.7119]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6959]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4902]], grad_fn=<AddmmBackward>)
# epoch [69/100], loss:-0.0161
# x:  tensor([[1.9784]], grad_fn=<AddmmBackward>)
# y: tensor([[3.0347]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4605]], grad_fn=<AddmmBackward>)
# epoch [70/100], loss:-0.0160
# x:  tensor([[3.1979]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6389]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5893]], grad_fn=<AddmmBackward>)
# epoch [71/100], loss:-0.0214
# x:  tensor([[1.4028]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1415]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2428]], grad_fn=<AddmmBackward>)
# epoch [72/100], loss:-0.0363
# x:  tensor([[2.0730]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0795]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1909]], grad_fn=<AddmmBackward>)
# epoch [73/100], loss:-0.0088
# x:  tensor([[2.1357]], grad_fn=<AddmmBackward>)
# y: tensor([[1.8784]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4289]], grad_fn=<AddmmBackward>)
# epoch [74/100], loss:-0.0604
# x:  tensor([[1.5195]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3859]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3237]], grad_fn=<AddmmBackward>)
# epoch [75/100], loss:-0.0325
# x:  tensor([[2.5194]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3040]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0545]], grad_fn=<AddmmBackward>)
# epoch [76/100], loss:-0.0122
# x:  tensor([[2.2916]], grad_fn=<AddmmBackward>)
# y: tensor([[1.8451]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2197]], grad_fn=<AddmmBackward>)
# epoch [77/100], loss:-0.0734
# x:  tensor([[2.6621]], grad_fn=<AddmmBackward>)
# y: tensor([[1.6876]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5602]], grad_fn=<AddmmBackward>)
# epoch [78/100], loss:-0.0197
# x:  tensor([[1.5864]], grad_fn=<AddmmBackward>)
# y: tensor([[2.5436]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6891]], grad_fn=<AddmmBackward>)
# epoch [79/100], loss:-0.0909
# x:  tensor([[1.9766]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3278]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5313]], grad_fn=<AddmmBackward>)
# epoch [80/100], loss:-0.0083
# x:  tensor([[2.2518]], grad_fn=<AddmmBackward>)
# y: tensor([[1.7460]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4357]], grad_fn=<AddmmBackward>)
# epoch [81/100], loss:0.0017
# x:  tensor([[1.7110]], grad_fn=<AddmmBackward>)
# y: tensor([[1.6392]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7968]], grad_fn=<AddmmBackward>)
# epoch [82/100], loss:-0.0287
# x:  tensor([[1.2105]], grad_fn=<AddmmBackward>)
# y: tensor([[1.2323]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0892]], grad_fn=<AddmmBackward>)
# epoch [83/100], loss:-0.0371
# x:  tensor([[1.6868]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1515]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2499]], grad_fn=<AddmmBackward>)
# epoch [84/100], loss:-0.0280
# x:  tensor([[1.6492]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4676]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1089]], grad_fn=<AddmmBackward>)
# epoch [85/100], loss:-0.0526
# x:  tensor([[2.5686]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0294]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5674]], grad_fn=<AddmmBackward>)
# epoch [86/100], loss:-0.0370
# x:  tensor([[1.7960]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6766]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2120]], grad_fn=<AddmmBackward>)
# epoch [87/100], loss:-0.0456
# x:  tensor([[1.1040]], grad_fn=<AddmmBackward>)
# y: tensor([[1.3314]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1925]], grad_fn=<AddmmBackward>)
# epoch [88/100], loss:-0.0481
# x:  tensor([[1.9245]], grad_fn=<AddmmBackward>)
# y: tensor([[1.9290]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2164]], grad_fn=<AddmmBackward>)
# epoch [89/100], loss:0.0170
# x:  tensor([[2.3450]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0470]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4951]], grad_fn=<AddmmBackward>)
# epoch [90/100], loss:-0.0089
# x:  tensor([[1.5660]], grad_fn=<AddmmBackward>)
# y: tensor([[1.7770]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1094]], grad_fn=<AddmmBackward>)
# epoch [91/100], loss:-0.0115
# x:  tensor([[2.4569]], grad_fn=<AddmmBackward>)
# y: tensor([[2.8154]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5678]], grad_fn=<AddmmBackward>)
# epoch [92/100], loss:-0.0851
# x:  tensor([[1.9531]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3383]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3443]], grad_fn=<AddmmBackward>)
# epoch [93/100], loss:-0.0127
# x:  tensor([[2.0960]], grad_fn=<AddmmBackward>)
# y: tensor([[1.5433]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6011]], grad_fn=<AddmmBackward>)
# epoch [94/100], loss:-0.0384
# x:  tensor([[2.4230]], grad_fn=<AddmmBackward>)
# y: tensor([[1.7903]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5734]], grad_fn=<AddmmBackward>)
# epoch [95/100], loss:-0.0341
# x:  tensor([[1.9497]], grad_fn=<AddmmBackward>)
# y: tensor([[1.9986]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3209]], grad_fn=<AddmmBackward>)
# epoch [96/100], loss:-0.0697
# x:  tensor([[2.2149]], grad_fn=<AddmmBackward>)
# y: tensor([[1.7687]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2356]], grad_fn=<AddmmBackward>)
# epoch [97/100], loss:-0.0290
# x:  tensor([[1.8855]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4563]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0717]], grad_fn=<AddmmBackward>)
# epoch [98/100], loss:-0.0381
# x:  tensor([[1.7913]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0172]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3549]], grad_fn=<AddmmBackward>)
# epoch [99/100], loss:-0.0165
# x:  tensor([[1.5891]], grad_fn=<AddmmBackward>)
# y: tensor([[1.2443]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0804]], grad_fn=<AddmmBackward>)
# epoch [100/100], loss:-0.0454
# x:  tensor([[1.7813]], grad_fn=<AddmmBackward>)
# y: tensor([[1.8399]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1442]], grad_fn=<AddmmBackward>)

# %%
for i in range(20):
    img = Image.new('RGB', (28, 28), color = 'white')
    row,col,ch= np.shape(img)
    mean = 0
    var = 1
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col,ch))
    noisy = img + gauss
    im2_n = Image.fromarray(noisy,'RGB')
    b = np.asarray(im2_n)
    b = np.array(b, dtype=np.float32)
    b = np.transpose(b,(2,1,0))
    b = torch.from_numpy(b)
    im2_test = Image.fromarray(noisy,'RGB')
    draw1 = ImageDraw.Draw(im2_test)
    draw1.rectangle([5, 9, 8, 12], fill='red', outline='red')
    z = np.asarray(im2_test)
    z = np.array(z, dtype=np.float32)
    z = torch.from_numpy(z)
    print("b:", model(b.reshape(1,3,28,28)))
    print("z: ", model(z.reshape(1,3,28,28)))
    print("x: ", model(x[i].reshape(1,3,28,28)))
    print("y:", model(y[i].reshape(1,3,28,28)))
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
    print("  ")
    p = Image.fromarray(data1[i])
    #p.show()
    q = Image.fromarray(data2[i])
    #q.show()
# Out:
# b: tensor([[-2.5034]], grad_fn=<AddmmBackward>)
# z:  tensor([[-2.4460]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.1566]], grad_fn=<AddmmBackward>)
# y: tensor([[-2.0657]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.4217]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.3823]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.7244]], grad_fn=<AddmmBackward>)
# y: tensor([[-0.9271]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-2.5565]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.4908]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.1712]], grad_fn=<AddmmBackward>)
# y: tensor([[-2.3842]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.2387]], grad_fn=<AddmmBackward>)
# z:  tensor([[-2.1858]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.6652]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8025]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-2.8895]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.9450]], grad_fn=<AddmmBackward>)
# x:  tensor([[-2.2855]], grad_fn=<AddmmBackward>)
# y: tensor([[-0.6060]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.5740]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.7064]], grad_fn=<AddmmBackward>)
# x:  tensor([[-0.5699]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.9859]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-2.0465]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.7612]], grad_fn=<AddmmBackward>)
# x:  tensor([[-2.0486]], grad_fn=<AddmmBackward>)
# y: tensor([[-2.1112]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.5426]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.3585]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8396]], grad_fn=<AddmmBackward>)
# y: tensor([[-2.0147]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-2.6962]], grad_fn=<AddmmBackward>)
# z:  tensor([[-2.8485]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8495]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.3247]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-2.3402]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.8008]], grad_fn=<AddmmBackward>)
# x:  tensor([[-2.4264]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.6387]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.7539]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.1594]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.0551]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.5198]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-2.7239]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.4989]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.3559]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.4909]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.4888]], grad_fn=<AddmmBackward>)
# z:  tensor([[-3.8571]], grad_fn=<AddmmBackward>)
# x:  tensor([[-2.4594]], grad_fn=<AddmmBackward>)
# y: tensor([[-0.9166]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.8252]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.5452]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.5781]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.9030]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.1870]], grad_fn=<AddmmBackward>)
# z:  tensor([[-2.2087]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.1405]], grad_fn=<AddmmBackward>)
# y: tensor([[-2.4581]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.6882]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.4506]], grad_fn=<AddmmBackward>)
# x:  tensor([[-2.1870]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8031]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-2.3122]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.4395]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.6392]], grad_fn=<AddmmBackward>)
# y: tensor([[-2.2134]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-2.5177]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.7728]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.1631]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.1807]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-1.3573]], grad_fn=<AddmmBackward>)
# z:  tensor([[-2.2632]], grad_fn=<AddmmBackward>)
# x:  tensor([[-3.1329]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.7714]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# b: tensor([[-2.0144]], grad_fn=<AddmmBackward>)
# z:  tensor([[-1.5336]], grad_fn=<AddmmBackward>)
# x:  tensor([[-2.5591]], grad_fn=<AddmmBackward>)
# y: tensor([[-2.3103]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
