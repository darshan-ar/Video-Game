# %%
import turtle
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import random


screen = turtle.Screen()

# this assures that the size of the screen will always be 400x400 ...
screen.setup(100, 100)

# ... which is the same size as our image
# now set the background to our space image
img = Image.new('RGB', (100, 100), color = 'white')
#img = np.reshape(img,(28,28,1))
#print(np.shape(img))
row,col,ch= np.shape(img)
mean = random.randint(1,6)
var = random.random()
sigma = var**0.5
gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
noisy_pos1 = img + gauss_pos1
im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
#draw = ImageDraw.Draw(im2_pos1)
#draw.rectangle([20,20,40,40],fill='red',outline='red')
#im2_pos1.show()
#print(np.shape(np.transpose(np.asarray(im2_pos1),(2,0,1))))
#im2_pos1 = np.reshape(im2_pos1,(100, 100,3))

im2_pos1.save("test.png","PNG")


screen.bgpic('test.png')

# Or, set the shape of a turtle
#screen.addshape("rocketship.png")
#turtle.shape("rocketship.png")

move_speed = 10 
turn_speed = 10

# these defs control the movement of our "turtle"
def forward():
  turtle.forward(move_speed)

def backward():
  turtle.backward(move_speed)

def left():
  turtle.left(turn_speed)

def right():
  turtle.right(turn_speed)

turtle.showturtle()
turtle.penup()
turtle.speed(0)
turtle.home()

# %%
import turtle
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import random


# ... which is the same size as our image
# now set the background to our space image
img = Image.new('RGB', (100, 100), color = 'green')
#img = np.reshape(img,(28,28,1))
#print(np.shape(img))
#row,col,ch= np.shape(img)
#mean = random.randint(1,6)
#var = random.random()
#sigma = var**0.5
#gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
#noisy_pos1 = img + gauss_pos1
#im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
#draw = ImageDraw.Draw(im2_pos1)
#draw.rectangle([20,20,40,40],fill='red',outline='red')
#im2_pos1.show()
#print(np.shape(np.transpose(np.asarray(im2_pos1),(2,0,1))))

im1 = Image.open('drone4-1.png')
im1 = im1.resize((35,35))

img.paste(im1,(20,20),im1)

img.show()

#im2_pos1 = np.reshape(im2_pos1,(100, 100,3))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-cd71d8e290c4> in <module>
#      28 img.paste(im1,(20,20),im1)
#      29
# ---> 30 img.show()
#      31
#      32 #im2_pos1 = np.reshape(im2_pos1,(100, 100,3))
#
# ~\anaconda3\envs\AoI\lib\site-packages\PIL\Image.py in show(self, title, command)
#    2176         """
#    2177
# -> 2178         _show(self, title=title, command=command)
#    2179
#    2180     def split(self):
#
# ~\anaconda3\envs\AoI\lib\site-packages\PIL\Image.py in _show(image, **options)
#    3117 def _show(image, **options):
#    3118     # override me, as necessary
# -> 3119     _showxv(image, **options)
#    3120
#    3121
#
# ~\anaconda3\envs\AoI\lib\site-packages\PIL\Image.py in _showxv(image, title, **options)
#    3123     from . import ImageShow
#    3124
# -> 3125     ImageShow.show(image, title, **options)
#    3126
#    3127
#
# ~\anaconda3\envs\AoI\lib\site-packages\PIL\ImageShow.py in show(image, title, **options)
#      46     """
#      47     for viewer in _viewers:
# ---> 48         if viewer.show(image, title=title, **options):
#      49             return 1
#      50     return 0
#
# ~\anaconda3\envs\AoI\lib\site-packages\PIL\ImageShow.py in show(self, image, **options)
#      66                 image = image.convert(base)
#      67
# ---> 68         return self.show_image(image, **options)
#      69
#      70     # hook methods
#
# ~\anaconda3\envs\AoI\lib\site-packages\PIL\ImageShow.py in show_image(self, image, **options)
#      86     def show_image(self, image, **options):
#      87         """Display given image"""
# ---> 88         return self.show_file(self.save_image(image), **options)
#      89
#      90     def show_file(self, file, **options):
#
# ~\anaconda3\envs\AoI\lib\site-packages\PIL\ImageShow.py in show_file(self, file, **options)
#      90     def show_file(self, file, **options):
#      91         """Display given file"""
# ---> 92         os.system(self.get_command(file, **options))
#      93         return 1
#      94
#
# KeyboardInterrupt:

# %%
import turtle
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import random

img = Image.new('RGB', (100, 100), color = '#9b7653')

im1 = Image.open('tree1.png')
im1 = im1.resize((10,10))

im2 = Image.open('tree2.png')
im2 = im2.resize((10,10))

im3 = Image.open('tree3.png')
im3 = im3.resize((10,10))


imd = Image.open('drone4-1.png')
imd = imd.resize((20,20))

imb = Image.open('bullet.png')
imb = imb.resize((5,5))


img.paste(im1,(5,75),im1)
img.paste(im1,(10,55),im1)
img.paste(im1,(25,50),im1)
img.paste(im2,(75,5),im2)
img.paste(im2,(60,30),im2)
img.paste(im2,(90,20),im2)
img.paste(im3,(75,60),im3)
img.paste(im3,(60,80),im3)
img.paste(imd,(5,5),imd)
#img.paste(imd,(40,40),imd)
#img.paste(imd,(72,65),imd)
#draw = ImageDraw.Draw(img)
#draw.ellipse((50,50,55,55), fill=(0, 0, 255))
#img.paste(imb,(80,80),imb)

img.show()

# %%
import turtle
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import random

img = Image.new('RGB', (100, 100), color = '#9b7653')

im1 = Image.open('tree1.png')
im1 = im1.resize((10,10))

im2 = Image.open('tree2.png')
im2 = im2.resize((10,10))

im3 = Image.open('tree3.png')
im3 = im3.resize((10,10))


imd = Image.open('drone4-1.png')
imd = imd.resize((20,20))

imb = Image.open('bullet.png')
imb = imb.resize((5,5))


img.paste(im1,(5,75),im1)
img.paste(im1,(10,55),im1)
img.paste(im1,(25,50),im1)
img.paste(im2,(75,5),im2)
img.paste(im2,(60,30),im2)
img.paste(im2,(90,20),im2)
img.paste(im3,(75,60),im3)
img.paste(im3,(60,80),im3)
#img.paste(imd,(5,5),imd)
img.paste(imd,(40,40),imd)
#img.paste(imd,(72,65),imd)
draw = ImageDraw.Draw(img)
draw.ellipse((50,50,55,55), fill=(0, 0, 255))
#img.paste(imb,(80,80),imb)

img.show()

# %%
import turtle
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import random

img = Image.new('RGB', (100, 100), color = '#9b7653')

im1 = Image.open('tree1.png')
im1 = im1.resize((10,10))

im2 = Image.open('tree2.png')
im2 = im2.resize((10,10))

im3 = Image.open('tree3.png')
im3 = im3.resize((10,10))


imd = Image.open('drone4-1.png')
imd = imd.resize((20,20))

imb = Image.open('bullet.png')
imb = imb.resize((5,5))


img.paste(im1,(5,75),im1)
img.paste(im1,(10,55),im1)
img.paste(im1,(25,50),im1)
img.paste(im2,(75,5),im2)
img.paste(im2,(60,30),im2)
img.paste(im2,(90,20),im2)
img.paste(im3,(75,60),im3)
img.paste(im3,(60,80),im3)
#img.paste(imd,(5,5),imd)
#img.paste(imd,(40,40),imd)
img.paste(imd,(72,65),imd)
#draw = ImageDraw.Draw(img)
#draw.ellipse((50,50,55,55), fill=(0, 0, 255))
img.paste(imb,(80,80),imb)

img.show()
