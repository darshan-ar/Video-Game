# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random

Batch_Size = 250
num_epochs = 100
learning_rate = 1e-5
samples = 30000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset


for i in range(samples):
    
    switch = random.randint(0,1)
    if switch==0:
        img = Image.new('RGB', (28, 28), color = 'white')
        #img = np.reshape(img,(28,28,1))
        #print(np.shape(img))
        row,col,ch= np.shape(img)
        mean = random.randint(1,6)
        var = random.random()
        sigma = var**0.5
        gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
        noisy_pos1 = img + gauss_pos1
        im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
        draw = ImageDraw.Draw(im2_pos1)
        draw.rectangle([0,0,5,5],fill='red',outline='red')
        #im2_pos1.show()
        #print(np.shape(np.transpose(np.asarray(im2_pos1),(2,0,1))))
        im2_pos1 = np.reshape(im2_pos1,(28,28,3))
        #print(np.shape(im2_pos1))
        data1.append(np.array(np.transpose(np.asarray(im2_pos1),(2,0,1)),dtype=np.float32))

        img_1 = Image.new('RGB', (28, 28), color = 'white')
        row_1,col_1,ch_1= np.shape(img_1)
        mean_1 = random.randint(1,6)
        var_1 = random.random()
        sigma_1 = var_1**0.5
        gauss_pos2 = np.random.normal(mean_1,sigma_1,(row_1,col_1,ch_1))
        noisy_pos2 = img_1 + gauss_pos2
        im2_pos2 = Image.fromarray(noisy_pos2,'RGB')
        draw_1 = ImageDraw.Draw(im2_pos2)
        draw_1.rectangle([15,15,20,20],fill='red',outline='red')
        im2_pos2 = np.reshape(im2_pos2,(28,28,3))
        data2.append(np.array(np.transpose(np.asarray(im2_pos2),(2,0,1)),dtype=np.float32))
    elif switch==1:
        img_blank = Image.new('RGB', (28, 28), color = 'white')
        row_blank,col_blank,ch_blank= np.shape(img_blank)
        mean_blank = random.randint(1,6)
        var_blank = random.random()
        sigma_blank = var_blank**0.5
        gauss_blank_pos1 = np.random.normal(mean_blank,sigma_blank,(row_blank,col_blank,ch_blank))
        noisy_blank_pos1 = img_blank + gauss_blank_pos1
        im2_blank_pos1 = Image.fromarray(noisy_blank_pos1,'RGB')
        im2_blank_pos1 = np.reshape(im2_blank_pos1,(28,28,3))
        data1.append(np.array(np.transpose(np.asarray(im2_blank_pos1),(2,0,1)),dtype=np.float32))

        img_blank_1 = Image.new('RGB', (28, 28), color = 'white')
        row_blank_1,col_blank_1,ch_blank_1= np.shape(img_blank_1)
        mean_blank_1 = random.randint(1,6)
        var_blank_1 = random.random()
        sigma_blank_1 = var_blank_1**0.5
        gauss_blank_pos2 = np.random.normal(mean_blank_1,sigma_blank_1,(row_blank_1,col_blank_1,ch_blank_1))
        noisy_blank_pos2 = img_blank_1 + gauss_blank_pos2
        im2_blank_pos2 = Image.fromarray(noisy_blank_pos2,'RGB')
        im2_blank_pos2 = np.reshape(im2_blank_pos2,(28,28,3))
        data2.append(np.array(np.transpose(np.asarray(im2_blank_pos2),(2,0,1)),dtype=np.float32))


#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (28,28), color = 'white')
row,col,ch= np.shape(img)
mean = 0
var = 1
sigma = var**0.5
gauss = np.random.normal(mean,sigma,(row,col,ch))
noisy = img + gauss
im2 = Image.fromarray(noisy,'RGB')
im2 = np.reshape(im2,(28,28,3))
b = np.asarray(im2)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)



print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, stride=1, padding=2)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)

        # Convolution 2
        self.cnn2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.relu2 = nn.ReLU()

        # Max pool 2
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(32 * 7 * 7, 1)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        out = self.cnn2(out)
        out = self.relu2(out)

        # Max pool 2 
        out = self.maxpool2(out)

        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return out
    
model = CNNModel()


optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x),model(y))
        # ===================backward====================

        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print("x: ", model(x[0].reshape(1,3,28,28)))
    print("y:", model(y[0].reshape(1,3,28,28)))
    print("b:", model(b.reshape(1,3,28,28)))
# Out:
# (30000, 3, 28, 28)
# epoch [1/100], loss:0.0000
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [2/100], loss:0.0000
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [3/100], loss:-0.0000
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [4/100], loss:0.0000
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [5/100], loss:-0.0005
# x:  tensor([[0.9984]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [6/100], loss:0.0000
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [7/100], loss:0.0000
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [8/100], loss:0.0000
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [9/100], loss:0.0000
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [10/100], loss:-0.0000
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [11/100], loss:0.0000
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [12/100], loss:0.0000
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [13/100], loss:0.0042
# x:  tensor([[0.9950]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9995]], grad_fn=<SigmoidBackward>)
# epoch [14/100], loss:0.0000
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9986]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [15/100], loss:0.0029
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9995]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [16/100], loss:-0.0040
# x:  tensor([[0.9926]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [17/100], loss:-0.3567
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.0829]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.0288e-05]], grad_fn=<SigmoidBackward>)
# epoch [18/100], loss:-0.4238
# x:  tensor([[0.9922]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[5.5713e-07]], grad_fn=<SigmoidBackward>)
# epoch [19/100], loss:-0.4276
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.7554e-07]], grad_fn=<SigmoidBackward>)
# epoch [20/100], loss:-0.4360
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.7778]], grad_fn=<SigmoidBackward>)
# b: tensor([[3.0601e-08]], grad_fn=<SigmoidBackward>)
# epoch [21/100], loss:-0.4360
# x:  tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.5287e-08]], grad_fn=<SigmoidBackward>)
# epoch [22/100], loss:-0.4341
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.6779e-08]], grad_fn=<SigmoidBackward>)
# epoch [23/100], loss:-0.4340
# x:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.0645e-09]], grad_fn=<SigmoidBackward>)
# epoch [24/100], loss:-0.4366
# x:  tensor([[9.1588e-09]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.6692e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.3393e-09]], grad_fn=<SigmoidBackward>)
# epoch [25/100], loss:-0.4368
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.3389e-09]], grad_fn=<SigmoidBackward>)
# epoch [26/100], loss:-0.4370
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1003e-09]], grad_fn=<SigmoidBackward>)
# epoch [27/100], loss:-0.4357
# x:  tensor([[9.0496e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[3.9683e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[9.7881e-10]], grad_fn=<SigmoidBackward>)
# epoch [28/100], loss:-0.4338
# x:  tensor([[0.9998]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[5.3166e-10]], grad_fn=<SigmoidBackward>)
# epoch [29/100], loss:-0.4371
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[3.1060e-10]], grad_fn=<SigmoidBackward>)
# epoch [30/100], loss:-0.4374
# x:  tensor([[3.0789e-10]], grad_fn=<SigmoidBackward>)
# y: tensor([[9.3921e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.9943e-10]], grad_fn=<SigmoidBackward>)
# epoch [31/100], loss:-0.4360
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.7813e-10]], grad_fn=<SigmoidBackward>)
# epoch [32/100], loss:-0.4372
# x:  tensor([[3.5225e-06]], grad_fn=<SigmoidBackward>)
# y: tensor([[3.8206e-06]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.8244e-10]], grad_fn=<SigmoidBackward>)
# epoch [33/100], loss:-0.4362
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[8.6650e-11]], grad_fn=<SigmoidBackward>)
# epoch [34/100], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.8714e-10]], grad_fn=<SigmoidBackward>)
# epoch [35/100], loss:-0.4372
# x:  tensor([[2.2574e-08]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.5673e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.2058e-10]], grad_fn=<SigmoidBackward>)
# epoch [36/100], loss:-0.4363
# x:  tensor([[1.9582e-12]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.2335e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[5.3716e-11]], grad_fn=<SigmoidBackward>)
# epoch [37/100], loss:-0.4334
# x:  tensor([[5.0451e-11]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.0453e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[6.7336e-11]], grad_fn=<SigmoidBackward>)
# epoch [38/100], loss:-0.4373
# x:  tensor([[2.0491e-06]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.3549e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[7.0194e-11]], grad_fn=<SigmoidBackward>)
# epoch [39/100], loss:-0.4370
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[5.0255e-11]], grad_fn=<SigmoidBackward>)
# epoch [40/100], loss:-0.4370
# x:  tensor([[2.5845e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.0449e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.8061e-11]], grad_fn=<SigmoidBackward>)
# epoch [41/100], loss:-0.4334
# x:  tensor([[4.2997e-10]], grad_fn=<SigmoidBackward>)
# y: tensor([[3.1778e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.6027e-11]], grad_fn=<SigmoidBackward>)
# epoch [42/100], loss:-0.4363
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.4577e-11]], grad_fn=<SigmoidBackward>)
# epoch [43/100], loss:-0.4340
# x:  tensor([[1.2333e-08]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.2586e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.7131e-11]], grad_fn=<SigmoidBackward>)
# epoch [44/100], loss:-0.4374
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.5793e-11]], grad_fn=<SigmoidBackward>)
# epoch [45/100], loss:-0.4334
# x:  tensor([[5.9337e-08]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.0589e-05]], grad_fn=<SigmoidBackward>)
# b: tensor([[8.4857e-12]], grad_fn=<SigmoidBackward>)
# epoch [46/100], loss:-0.4360
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.1134e-11]], grad_fn=<SigmoidBackward>)
# epoch [47/100], loss:-0.4343
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.5081e-11]], grad_fn=<SigmoidBackward>)
# epoch [48/100], loss:-0.4351
# x:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.6829e-11]], grad_fn=<SigmoidBackward>)
# epoch [49/100], loss:-0.4369
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1512e-11]], grad_fn=<SigmoidBackward>)
# epoch [50/100], loss:-0.4366
# x:  tensor([[5.7942e-11]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.5439e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1901e-11]], grad_fn=<SigmoidBackward>)
# epoch [51/100], loss:-0.4374
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.3675e-11]], grad_fn=<SigmoidBackward>)
# epoch [52/100], loss:-0.4371
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[7.1379e-12]], grad_fn=<SigmoidBackward>)
# epoch [53/100], loss:-0.4313
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[7.3163e-12]], grad_fn=<SigmoidBackward>)
# epoch [54/100], loss:-0.4321
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0133e-11]], grad_fn=<SigmoidBackward>)
# epoch [55/100], loss:-0.4360
# x:  tensor([[1.1553e-09]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.2309e-09]], grad_fn=<SigmoidBackward>)
# b: tensor([[9.9627e-12]], grad_fn=<SigmoidBackward>)
# epoch [56/100], loss:-0.4340
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[6.8268e-12]], grad_fn=<SigmoidBackward>)
# epoch [57/100], loss:-0.4359
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[7.3257e-12]], grad_fn=<SigmoidBackward>)
# epoch [58/100], loss:-0.4340
# x:  tensor([[3.8793e-16]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.9264e-08]], grad_fn=<SigmoidBackward>)
# b: tensor([[6.0539e-12]], grad_fn=<SigmoidBackward>)
# epoch [59/100], loss:-0.4355
# x:  tensor([[1.5618e-14]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.7034e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.8282e-12]], grad_fn=<SigmoidBackward>)
# epoch [60/100], loss:-0.4356
# x:  tensor([[7.8391e-08]], grad_fn=<SigmoidBackward>)
# y: tensor([[8.8493e-12]], grad_fn=<SigmoidBackward>)
# b: tensor([[5.0769e-12]], grad_fn=<SigmoidBackward>)
# epoch [61/100], loss:-0.4346
# x:  tensor([[3.2540e-12]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.0923e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[5.6521e-12]], grad_fn=<SigmoidBackward>)
# epoch [62/100], loss:-0.4340
# x:  tensor([[1.2495e-09]], grad_fn=<SigmoidBackward>)
# y: tensor([[9.3686e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[3.5804e-12]], grad_fn=<SigmoidBackward>)
# epoch [63/100], loss:-0.4355
# x:  tensor([[2.1244e-09]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.0595e-09]], grad_fn=<SigmoidBackward>)
# b: tensor([[3.8317e-12]], grad_fn=<SigmoidBackward>)
# epoch [64/100], loss:-0.4373
# x:  tensor([[4.2778e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.2148e-12]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.8588e-12]], grad_fn=<SigmoidBackward>)
# epoch [65/100], loss:-0.4375
# x:  tensor([[2.4066e-09]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.3053e-08]], grad_fn=<SigmoidBackward>)
# b: tensor([[3.2479e-12]], grad_fn=<SigmoidBackward>)
# epoch [66/100], loss:-0.4346
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[3.3671e-12]], grad_fn=<SigmoidBackward>)
# epoch [67/100], loss:-0.4366
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.8346e-12]], grad_fn=<SigmoidBackward>)
# epoch [68/100], loss:-0.4363
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.9264e-12]], grad_fn=<SigmoidBackward>)
# epoch [69/100], loss:-0.4334
# x:  tensor([[1.4745e-09]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.5190e-08]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.0807e-12]], grad_fn=<SigmoidBackward>)
# epoch [70/100], loss:-0.4374
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.7891e-12]], grad_fn=<SigmoidBackward>)
# epoch [71/100], loss:-0.4366
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.6491e-12]], grad_fn=<SigmoidBackward>)
# epoch [72/100], loss:-0.4363
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.8436e-12]], grad_fn=<SigmoidBackward>)
# epoch [73/100], loss:-0.4369
# x:  tensor([[1.3095e-10]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.1430e-12]], grad_fn=<SigmoidBackward>)
# b: tensor([[2.2507e-12]], grad_fn=<SigmoidBackward>)
# epoch [74/100], loss:-0.4375
# x:  tensor([[4.8937e-09]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.5242e-12]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.7410e-12]], grad_fn=<SigmoidBackward>)
# epoch [75/100], loss:-0.4351
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.3882e-12]], grad_fn=<SigmoidBackward>)
# epoch [76/100], loss:-0.4356
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.6025e-12]], grad_fn=<SigmoidBackward>)
# epoch [77/100], loss:-0.4360
# x:  tensor([[9.1955e-11]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.1688e-08]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.3988e-12]], grad_fn=<SigmoidBackward>)
# epoch [78/100], loss:-0.4375
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.4826e-12]], grad_fn=<SigmoidBackward>)
# epoch [79/100], loss:-0.4375
# x:  tensor([[6.2670e-08]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.9123e-12]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0095e-12]], grad_fn=<SigmoidBackward>)
# epoch [80/100], loss:-0.4375
# x:  tensor([[7.1804e-11]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.5834e-08]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0017e-12]], grad_fn=<SigmoidBackward>)
# epoch [81/100], loss:-0.4356
# x:  tensor([[4.3117e-12]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.9762e-09]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.1142e-12]], grad_fn=<SigmoidBackward>)
# epoch [82/100], loss:-0.4363
# x:  tensor([[1.0969e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.2662e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0411e-12]], grad_fn=<SigmoidBackward>)
# epoch [83/100], loss:-0.4351
# x:  tensor([[2.7582e-10]], grad_fn=<SigmoidBackward>)
# y: tensor([[3.4925e-14]], grad_fn=<SigmoidBackward>)
# b: tensor([[8.7710e-13]], grad_fn=<SigmoidBackward>)
# epoch [84/100], loss:-0.4375
# x:  tensor([[5.7924e-12]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.4426e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[8.5614e-13]], grad_fn=<SigmoidBackward>)
# epoch [85/100], loss:-0.4375
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[7.3447e-13]], grad_fn=<SigmoidBackward>)
# epoch [86/100], loss:-0.4375
# x:  tensor([[1.5825e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.6695e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[6.1400e-13]], grad_fn=<SigmoidBackward>)
# epoch [87/100], loss:-0.4363
# x:  tensor([[4.9933e-11]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.2123e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[8.4678e-13]], grad_fn=<SigmoidBackward>)
# epoch [88/100], loss:-0.4351
# x:  tensor([[4.0992e-11]], grad_fn=<SigmoidBackward>)
# y: tensor([[7.1334e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[6.0856e-13]], grad_fn=<SigmoidBackward>)
# epoch [89/100], loss:-0.4369
# x:  tensor([[4.7285e-14]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.7896e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[6.6796e-13]], grad_fn=<SigmoidBackward>)
# epoch [90/100], loss:-0.4363
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[5.8354e-13]], grad_fn=<SigmoidBackward>)
# epoch [91/100], loss:-0.4373
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.9909e-13]], grad_fn=<SigmoidBackward>)
# epoch [92/100], loss:-0.4369
# x:  tensor([[1.4389e-15]], grad_fn=<SigmoidBackward>)
# y: tensor([[9.2341e-13]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.3364e-13]], grad_fn=<SigmoidBackward>)
# epoch [93/100], loss:-0.4373
# x:  tensor([[9.5032e-09]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.0172e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.9807e-13]], grad_fn=<SigmoidBackward>)
# epoch [94/100], loss:-0.4371
# x:  tensor([[9.6141e-16]], grad_fn=<SigmoidBackward>)
# y: tensor([[7.5254e-11]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.5490e-13]], grad_fn=<SigmoidBackward>)
# epoch [95/100], loss:-0.4375
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.4354e-13]], grad_fn=<SigmoidBackward>)
# epoch [96/100], loss:-0.4373
# x:  tensor([[5.5227e-13]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.2000e-14]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.9000e-13]], grad_fn=<SigmoidBackward>)
# epoch [97/100], loss:-0.4321
# x:  tensor([[2.2420e-12]], grad_fn=<SigmoidBackward>)
# y: tensor([[3.0865e-12]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.5530e-13]], grad_fn=<SigmoidBackward>)
# epoch [98/100], loss:-0.4375
# x:  tensor([[2.6388e-09]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.2224e-10]], grad_fn=<SigmoidBackward>)
# b: tensor([[4.8249e-13]], grad_fn=<SigmoidBackward>)
# epoch [99/100], loss:-0.4346
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[3.7871e-13]], grad_fn=<SigmoidBackward>)
# epoch [100/100], loss:-0.4369
# x:  tensor([[1.]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.]], grad_fn=<SigmoidBackward>)
# b: tensor([[3.5962e-13]], grad_fn=<SigmoidBackward>)

# %%
data3=[]

for i in range(5):
    img = Image.new('RGB', (28, 28), color = 'white')
    #img = np.reshape(img,(28,28,1))
    #print(np.shape(img))
    row,col,ch= np.shape(img)
    mean = random.randint(1,6)
    var = random.random()
    sigma = var**0.5
    gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
    noisy_pos1 = img + gauss_pos1
    im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
    #draw = ImageDraw.Draw(im2_pos1)
    #draw.rectangle([15,15,20,20],fill='red',outline='red')
    #im2_pos1.show()
    #print(np.shape(np.transpose(np.asarray(im2_pos1),(2,0,1))))
    im2_pos1 = np.reshape(im2_pos1,(28,28,3))

    data3.append(np.array(np.transpose(np.asarray(im2_pos1),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    print("x: ", model(x_1[i].reshape(1,3,28,28)))
# Out:
# x:  tensor([[1.2460e-10]], grad_fn=<SigmoidBackward>)
# x:  tensor([[4.0017e-08]], grad_fn=<SigmoidBackward>)
# x:  tensor([[7.5675e-13]], grad_fn=<SigmoidBackward>)
# x:  tensor([[1.2738e-13]], grad_fn=<SigmoidBackward>)
# x:  tensor([[2.2298e-07]], grad_fn=<SigmoidBackward>)
