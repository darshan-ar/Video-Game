# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random

Batch_Size = 50
num_epochs = 200
learning_rate = 1e-5
samples = 10000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset

import cv2
import numpy as np

cap = cv2.VideoCapture('video_testing.avi')

uframes = []
ret, frame = cap.read()
uframes.append(frame)
flag = 0
z = 0
while(z<10):
    ret, frame = cap.read()
    #np_frame = cv2.imread('video', frame) # does not work
    #np_frame = np.asarray(cv2.GetMat(frame)) # does not work
    #print(np_frame.shape)
    
    for a in uframes:
        if np.array(frame).any() != None:
            difference = cv2.subtract(a, frame)    
            result = not np.any(difference)
            print("inside for")
            if result is True:
                flag = 1
                print("setting flag")
                break
    if(not flag):
        print("appending")
        uframes.append(frame)
    z+=1


# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

for i in range(samples):
    switch = random.randint(0,1)
    if switch==0:
        x = random.randint(0,1)
        if x==0:
            data1.append(np.array(np.transpose(np.asarray(uframes[1]),(2,0,1)),dtype=np.float32))
            data2.append(np.array(np.transpose(np.asarray(uframes[-1]),(2,0,1)),dtype=np.float32))
        elif x==1:
            data1.append(np.array(np.transpose(np.asarray(uframes[2]),(2,0,1)),dtype=np.float32))
            data2.append(np.array(np.transpose(np.asarray(uframes[-1]),(2,0,1)),dtype=np.float32))
        #mg.show()
        
    elif switch==1:
        data1.append(np.array(np.transpose(np.asarray(uframes[0]),(2,0,1)),dtype=np.float32))
        data2.append(np.array(np.transpose(np.asarray(uframes[0]),(2,0,1)),dtype=np.float32))

    



# cap = cv2.VideoCapture('video_testing.avi')
# cap1 = cv2.VideoCapture('video_testing.avi')
# frameCount = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
# frameWidth = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# frameHeight = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# data1 = np.empty((frameCount, frameHeight, frameWidth, 3), np.dtype('uint8'))
# data2 = np.empty((frameCount, frameHeight, frameWidth, 3), np.dtype('uint8'))

# fc = 0
# ret = True

# while (fc < 1000):
#     #print(cap.read())
#     ret, data1[fc] = cap.read()
#     ret, data2[fc] = cap1.read()
#     fc += 1

# cap.release()
# cap1.release()


# im1 = Image.open('tree1.png')
# im1 = im1.resize((10,10))

# im2 = Image.open('tree2.png')
# im2 = im2.resize((10,10))

# im3 = Image.open('tree3.png')
# im3 = im3.resize((10,10))

# im_drone = Image.open('drone4-1.png')
# im_drone = im_drone.resize((20,20))

# for i in range(samples):
    
#     switch = random.randint(0,1)
#     if switch==0:
#         img = Image.new('RGB', (100, 100), color = '#9b7653')
#         img.paste(im1,(5,75),im1)
#         img.paste(im1,(10,55),im1)
#         img.paste(im1,(25,50),im1)
#         img.paste(im2,(75,5),im2)
#         img.paste(im2,(60,30),im2)
#         img.paste(im2,(90,20),im2)
#         img.paste(im3,(75,60),im3)
#         img.paste(im3,(60,80),im3)
        
#         img_b = Image.new('RGB', (100, 100), color = '#9b7653')
#         img_b.paste(im1,(5,75),im1)
#         img_b.paste(im1,(10,55),im1)
#         img_b.paste(im1,(25,50),im1)
#         img_b.paste(im2,(75,5),im2)
#         img_b.paste(im2,(60,30),im2)
#         img_b.paste(im2,(90,20),im2)
#         img_b.paste(im3,(75,60),im3)
#         img_b.paste(im3,(60,80),im3)
        
#         x = random.randint(0,1)
#         if x==0:
#             img.paste(im_drone,(10,10),im_drone)
#             data1.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
#             img_b.paste(im_drone,(80,80),im_drone)
#             data2.append(np.array(np.transpose(np.asarray(img_b),(2,0,1)),dtype=np.float32))
#         elif x==1:
#             img.paste(im_drone,(50,50),im_drone)
#             data1.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
#             img_b.paste(im_drone,(80,80),im_drone)
#             data2.append(np.array(np.transpose(np.asarray(img_b),(2,0,1)),dtype=np.float32))
#         #mg.show()
        
#     elif switch==1:
#         img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
#         img_blank.paste(im1,(5,75),im1)
#         img_blank.paste(im1,(10,55),im1)
#         img_blank.paste(im1,(25,50),im1)
#         img_blank.paste(im2,(75,5),im2)
#         img_blank.paste(im2,(60,30),im2)
#         img_blank.paste(im2,(90,20),im2)
#         img_blank.paste(im3,(75,60),im3)
#         img_blank.paste(im3,(60,80),im3)
#         #mg_blank.show()
#         data1.append(np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32))
#         data2.append(np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32))


#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = '#9b7653')
img.paste(im1,(5,75),im1)
img.paste(im1,(10,55),im1)
img.paste(im1,(25,50),im1)
img.paste(im2,(75,5),im2)
img.paste(im2,(60,30),im2)
img.paste(im2,(90,20),im2)
img.paste(im3,(75,60),im3)
img.paste(im3,(60,80),im3)
im_n = np.reshape(img,(100,100,3))
b = np.asarray(im_n)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)

#y0 = np.array(np.transpose(np.asarray(y0),(0,3,1,2)),dtype=np.float32)
#y1 = np.array(np.transpose(np.asarray(y1),(0,3,1,2)),dtype=np.float32)
print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, stride=1, padding=2)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)

        # Convolution 2
        self.cnn2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.relu2 = nn.ReLU()

        # Max pool 2
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(20000, 1)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        out = self.cnn2(out)
        out = self.relu2(out)

        # Max pool 2 
        out = self.maxpool2(out)

        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return out
    
model = CNNModel()


optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x),model(y))
        # ===================backward====================

        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print("x: ", model(x[0].reshape(1,3,100, 100)))
    print("y:", model(y[0].reshape(1,3,100, 100)))
    print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# inside for
# appending
# inside for
# inside for
# appending
# inside for
# inside for
# inside for
# appending
# inside for
# setting flag
# inside for
# inside for
# setting flag
# inside for
# inside for
# inside for
# setting flag
# inside for
# inside for
# inside for
# inside for
# setting flag
# inside for
# setting flag
# inside for
# inside for
# setting flag
# inside for
# inside for
# inside for
# setting flag
# (10000, 3, 100, 100)
# epoch [1/200], loss:-0.1648
# x:  tensor([[0.7958]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.8140]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.8548]], grad_fn=<SigmoidBackward>)
# epoch [2/200], loss:-0.4225
# x:  tensor([[0.0096]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.0096]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9991]], grad_fn=<SigmoidBackward>)
# epoch [3/200], loss:-0.4329
# x:  tensor([[0.0026]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.0026]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9981]], grad_fn=<SigmoidBackward>)
# epoch [4/200], loss:-0.4212
# x:  tensor([[0.0009]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.0009]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9978]], grad_fn=<SigmoidBackward>)
# epoch [5/200], loss:-0.4151
# x:  tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9965]], grad_fn=<SigmoidBackward>)
# epoch [6/200], loss:-0.4371
# x:  tensor([[0.0003]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.0003]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9950]], grad_fn=<SigmoidBackward>)
# epoch [7/200], loss:-0.4348
# x:  tensor([[0.0002]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.0002]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9935]], grad_fn=<SigmoidBackward>)
# epoch [8/200], loss:-0.4349
# x:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9922]], grad_fn=<SigmoidBackward>)
# epoch [9/200], loss:-0.4350
# x:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9912]], grad_fn=<SigmoidBackward>)
# epoch [10/200], loss:-0.4278
# x:  tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# y: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9905]], grad_fn=<SigmoidBackward>)
# epoch [11/200], loss:-0.4350
# x:  tensor([[5.0214e-05]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.0214e-05]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9903]], grad_fn=<SigmoidBackward>)
# epoch [12/200], loss:-0.4156
# x:  tensor([[3.9546e-05]], grad_fn=<SigmoidBackward>)
# y: tensor([[3.9546e-05]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9901]], grad_fn=<SigmoidBackward>)
# epoch [13/200], loss:-0.4369
# x:  tensor([[3.1969e-05]], grad_fn=<SigmoidBackward>)
# y: tensor([[3.1969e-05]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9905]], grad_fn=<SigmoidBackward>)
# epoch [14/200], loss:-0.4320
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9910]], grad_fn=<SigmoidBackward>)
# epoch [15/200], loss:-0.4369
# x:  tensor([[2.1525e-05]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.1525e-05]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9914]], grad_fn=<SigmoidBackward>)
# epoch [16/200], loss:-0.4278
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9921]], grad_fn=<SigmoidBackward>)
# epoch [17/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9931]], grad_fn=<SigmoidBackward>)
# epoch [18/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9996]], grad_fn=<SigmoidBackward>)
# epoch [19/200], loss:-0.4321
# x:  tensor([[2.4422e-06]], grad_fn=<SigmoidBackward>)
# y: tensor([[2.4422e-06]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9998]], grad_fn=<SigmoidBackward>)
# epoch [20/200], loss:-0.4351
# x:  tensor([[1.5482e-06]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.5482e-06]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [21/200], loss:-0.4375
# x:  tensor([[1.1565e-06]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.1565e-06]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [22/200], loss:-0.4351
# x:  tensor([[9.1458e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[9.1458e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [23/200], loss:-0.4157
# x:  tensor([[8.0502e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[8.0502e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [24/200], loss:-0.4375
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [25/200], loss:-0.4369
# x:  tensor([[6.7994e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.7994e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [26/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [27/200], loss:-0.4375
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [28/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [29/200], loss:-0.4157
# x:  tensor([[5.8168e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.8168e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [30/200], loss:-0.4224
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [31/200], loss:-0.4369
# x:  tensor([[5.4522e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.4522e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [32/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [33/200], loss:-0.4369
# x:  tensor([[5.1439e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.1439e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [34/200], loss:-0.4224
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [35/200], loss:-0.4369
# x:  tensor([[5.1360e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.1360e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [36/200], loss:-0.4321
# x:  tensor([[4.9628e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.9628e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [37/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [38/200], loss:-0.4375
# x:  tensor([[4.9403e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.9403e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [39/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [40/200], loss:-0.3878
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [41/200], loss:-0.4375
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [42/200], loss:-0.4351
# x:  tensor([[4.8394e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.8394e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [43/200], loss:-0.4279
# x:  tensor([[4.7368e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.7368e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [44/200], loss:-0.4279
# x:  tensor([[4.4181e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.4181e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [45/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [46/200], loss:-0.4224
# x:  tensor([[4.6167e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.6167e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [47/200], loss:-0.4077
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [48/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [49/200], loss:-0.4279
# x:  tensor([[4.3482e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.3482e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [50/200], loss:-0.4351
# x:  tensor([[4.4331e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.4331e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [51/200], loss:-0.4375
# x:  tensor([[4.7607e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.7607e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [52/200], loss:-0.4369
# x:  tensor([[4.5586e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.5586e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [53/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [54/200], loss:-0.4279
# x:  tensor([[4.1086e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.1086e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [55/200], loss:-0.4375
# x:  tensor([[4.4726e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.4726e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [56/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [57/200], loss:-0.4351
# x:  tensor([[4.3361e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.3361e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [58/200], loss:-0.4351
# x:  tensor([[4.3353e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.3353e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [59/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [60/200], loss:-0.4279
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [61/200], loss:-0.3984
# x:  tensor([[4.4897e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.4897e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [62/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [63/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [64/200], loss:-0.4077
# x:  tensor([[4.5719e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.5719e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [65/200], loss:-0.4157
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [66/200], loss:-0.4077
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [67/200], loss:-0.4279
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [68/200], loss:-0.4321
# x:  tensor([[4.8076e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.8076e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [69/200], loss:-0.4369
# x:  tensor([[4.8927e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.8927e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [70/200], loss:-0.4077
# x:  tensor([[4.7020e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.7020e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [71/200], loss:-0.4351
# x:  tensor([[4.7261e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.7261e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [72/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [73/200], loss:-0.4369
# x:  tensor([[4.7773e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.7773e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [74/200], loss:-0.4279
# x:  tensor([[4.9994e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.9994e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [75/200], loss:-0.4321
# x:  tensor([[4.9121e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[4.9121e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [76/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [77/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [78/200], loss:-0.4224
# x:  tensor([[5.0158e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.0158e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [79/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [80/200], loss:-0.4157
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [81/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [82/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [83/200], loss:-0.4321
# x:  tensor([[5.6443e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.6443e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [84/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [85/200], loss:-0.4369
# x:  tensor([[5.5311e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.5311e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9995]], grad_fn=<SigmoidBackward>)
# epoch [86/200], loss:-0.4369
# x:  tensor([[5.3719e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.3719e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9991]], grad_fn=<SigmoidBackward>)
# epoch [87/200], loss:-0.4369
# x:  tensor([[5.5528e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.5528e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9987]], grad_fn=<SigmoidBackward>)
# epoch [88/200], loss:-0.4369
# x:  tensor([[5.5641e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.5641e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9986]], grad_fn=<SigmoidBackward>)
# epoch [89/200], loss:-0.4224
# x:  tensor([[5.7315e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.7315e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9989]], grad_fn=<SigmoidBackward>)
# epoch [90/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9994]], grad_fn=<SigmoidBackward>)
# epoch [91/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [92/200], loss:-0.4351
# x:  tensor([[5.9444e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.9444e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [93/200], loss:-0.4351
# x:  tensor([[6.1958e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.1958e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [94/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [95/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [96/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [97/200], loss:-0.3984
# x:  tensor([[5.9681e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.9681e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [98/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [99/200], loss:-0.4321
# x:  tensor([[5.9155e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.9155e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [100/200], loss:-0.4375
# x:  tensor([[6.0387e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.0387e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [101/200], loss:-0.4224
# x:  tensor([[6.6933e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.6933e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [102/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [103/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [104/200], loss:-0.4279
# x:  tensor([[5.8355e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.8355e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [105/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [106/200], loss:-0.4224
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [107/200], loss:-0.4375
# x:  tensor([[5.4407e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.4407e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [108/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [109/200], loss:-0.4351
# x:  tensor([[5.4780e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.4780e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [110/200], loss:-0.4369
# x:  tensor([[5.6880e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.6880e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [111/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [112/200], loss:-0.4224
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [113/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [114/200], loss:-0.4279
# x:  tensor([[5.8687e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.8687e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [115/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [116/200], loss:-0.4279
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [117/200], loss:-0.4369
# x:  tensor([[6.6791e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.6791e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [118/200], loss:-0.4351
# x:  tensor([[5.9672e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.9672e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [119/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [120/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [121/200], loss:-0.4279
# x:  tensor([[6.1187e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.1187e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [122/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [123/200], loss:-0.4375
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [124/200], loss:-0.4279
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [125/200], loss:-0.4375
# x:  tensor([[6.0707e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.0707e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [126/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [127/200], loss:-0.4369
# x:  tensor([[5.7667e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.7667e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [128/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [129/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [130/200], loss:-0.4369
# x:  tensor([[5.6253e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.6253e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [131/200], loss:-0.4351
# x:  tensor([[6.3812e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.3812e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [132/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [133/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [134/200], loss:-0.4279
# x:  tensor([[6.0144e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.0144e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [135/200], loss:-0.4375
# x:  tensor([[6.3712e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.3712e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [136/200], loss:-0.4157
# x:  tensor([[6.4449e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.4449e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [137/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [138/200], loss:-0.4157
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [139/200], loss:-0.4321
# x:  tensor([[6.5557e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.5557e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [140/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [141/200], loss:-0.4321
# x:  tensor([[7.0439e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[7.0439e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [142/200], loss:-0.4157
# x:  tensor([[5.6986e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.6986e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [143/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [144/200], loss:-0.4224
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [145/200], loss:-0.4369
# x:  tensor([[6.1904e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.1904e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [146/200], loss:-0.4369
# x:  tensor([[6.8041e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.8041e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [147/200], loss:-0.4375
# x:  tensor([[6.7437e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.7437e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [148/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [149/200], loss:-0.3626
# x:  tensor([[5.7842e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.7842e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [150/200], loss:-0.4369
# x:  tensor([[6.2169e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.2169e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [151/200], loss:-0.4321
# x:  tensor([[6.3461e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.3461e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [152/200], loss:-0.4321
# x:  tensor([[7.3897e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[7.3897e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [153/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [154/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [155/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [156/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [157/200], loss:-0.4321
# x:  tensor([[6.5807e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.5807e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [158/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [159/200], loss:-0.4279
# x:  tensor([[6.8440e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.8440e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [160/200], loss:-0.4321
# x:  tensor([[6.1934e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.1934e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [161/200], loss:-0.4321
# x:  tensor([[6.2454e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.2454e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [162/200], loss:-0.4375
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [163/200], loss:-0.4351
# x:  tensor([[6.0625e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.0625e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [164/200], loss:-0.4351
# x:  tensor([[5.6764e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.6764e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [165/200], loss:-0.4224
# x:  tensor([[6.2822e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.2822e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [166/200], loss:-0.4375
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [167/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [168/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [169/200], loss:-0.4077
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [170/200], loss:-0.4351
# x:  tensor([[6.3493e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.3493e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [171/200], loss:-0.4369
# x:  tensor([[5.6589e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.6589e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [172/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [173/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.]], grad_fn=<SigmoidBackward>)
# epoch [174/200], loss:-0.4279
# x:  tensor([[6.4673e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.4673e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [175/200], loss:-0.3984
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [176/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [177/200], loss:-0.4279
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [178/200], loss:-0.4224
# x:  tensor([[6.2208e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.2208e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [179/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [180/200], loss:-0.4157
# x:  tensor([[6.1263e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.1263e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [181/200], loss:-0.4321
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [182/200], loss:-0.4375
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# epoch [183/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9999]], grad_fn=<SigmoidBackward>)
# epoch [184/200], loss:-0.4321
# x:  tensor([[6.4124e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.4124e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9998]], grad_fn=<SigmoidBackward>)
# epoch [185/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9997]], grad_fn=<SigmoidBackward>)
# epoch [186/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9992]], grad_fn=<SigmoidBackward>)
# epoch [187/200], loss:-0.4369
# x:  tensor([[7.5020e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[7.5020e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9988]], grad_fn=<SigmoidBackward>)
# epoch [188/200], loss:-0.4351
# x:  tensor([[6.1930e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.1930e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9971]], grad_fn=<SigmoidBackward>)
# epoch [189/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9922]], grad_fn=<SigmoidBackward>)
# epoch [190/200], loss:-0.4224
# x:  tensor([[6.4638e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.4638e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9845]], grad_fn=<SigmoidBackward>)
# epoch [191/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9695]], grad_fn=<SigmoidBackward>)
# epoch [192/200], loss:-0.4351
# x:  tensor([[6.5777e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.5777e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.9478]], grad_fn=<SigmoidBackward>)
# epoch [193/200], loss:-0.4157
# x:  tensor([[6.4502e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[6.4502e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.8769]], grad_fn=<SigmoidBackward>)
# epoch [194/200], loss:-0.4375
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.8006]], grad_fn=<SigmoidBackward>)
# epoch [195/200], loss:-0.4077
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.6602]], grad_fn=<SigmoidBackward>)
# epoch [196/200], loss:-0.4279
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.5371]], grad_fn=<SigmoidBackward>)
# epoch [197/200], loss:-0.4351
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.3587]], grad_fn=<SigmoidBackward>)
# epoch [198/200], loss:-0.4279
# x:  tensor([[5.6391e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.6391e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.2232]], grad_fn=<SigmoidBackward>)
# epoch [199/200], loss:-0.4157
# x:  tensor([[5.5894e-07]], grad_fn=<SigmoidBackward>)
# y: tensor([[5.5894e-07]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.1470]], grad_fn=<SigmoidBackward>)
# epoch [200/200], loss:-0.4369
# x:  tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# y: tensor([[1.0000]], grad_fn=<SigmoidBackward>)
# b: tensor([[0.0854]], grad_fn=<SigmoidBackward>)

# %%
print(fc)

# %%
data3=[] 
im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((20,20))
for i in range(1):
    img = Image.new('RGB', (100, 100), color = '#9b7653')
    img.paste(im1,(5,75),im1)
    img.paste(im1,(10,55),im1)
    img.paste(im1,(25,50),im1)
    img.paste(im2,(75,5),im2)
    img.paste(im2,(60,30),im2)
    img.paste(im2,(90,20),im2)
    img.paste(im3,(75,60),im3)
    img.paste(im3,(60,80),im3)
    #img.paste(im_drone,(75,75),im_drone)
    #img.paste(im_drone,(50,50),im_drone)
    #img.paste(im_drone,(25,80),im_drone)
    img.paste(im_drone,(20,40),im_drone)
    img.show()
    #im2_pos1 = np.reshape(im2_pos1,(100,100,3))

    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    print("x: ", model(x_1[i].reshape(1,3,100,100)))
# Out:
# x:  tensor([[0.1330]], grad_fn=<SigmoidBackward>)

# %%
import random
x = random.randint(0,2)
print(x)
