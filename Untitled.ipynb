# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random

Batch_Size = 100
num_epochs = 100
learning_rate = 1e-5
samples = 10000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((35,35))

for i in range(samples):
    
    switch = random.randint(0,1)
    if switch==0:
        img = Image.new('RGB', (100, 100), color = 'white')
        #img = np.reshape(img,(28,28,1))
        #print(np.shape(img))
        row,col,ch= np.shape(img)
        mean = random.randint(1,6)
        var = random.random()
        sigma = var**0.5
        gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
        noisy_pos1 = img + gauss_pos1
        im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
        #draw = ImageDraw.Draw(im2_pos1)
        #draw.rectangle([20,20,40,40],fill='red',outline='red')
        #im2_pos1.show()
        #print(np.shape(np.transpose(np.asarray(im2_pos1),(2,0,1))))
        im2_pos1.paste(im_drone,(10,10),im_drone)
        im2_pos1 = np.reshape(im2_pos1,(100, 100,3))
        #print(np.shape(im2_pos1))
        data1.append(np.array(np.transpose(np.asarray(im2_pos1),(2,0,1)),dtype=np.float32))

        img_1 = Image.new('RGB', (100, 100), color = 'white')
        row_1,col_1,ch_1= np.shape(img_1)
        mean_1 = random.randint(1,6)
        var_1 = random.random()
        sigma_1 = var_1**0.5
        gauss_pos2 = np.random.normal(mean_1,sigma_1,(row_1,col_1,ch_1))
        noisy_pos2 = img_1 + gauss_pos2
        im2_pos2 = Image.fromarray(noisy_pos2,'RGB')
        #draw_1 = ImageDraw.Draw(im2_pos2)
        #draw_1.rectangle([20,20,40,40],fill='red',outline='red')
        im2_pos2.paste(im_drone,(10,10),im_drone)
        im2_pos2 = np.reshape(im2_pos2,(100, 100,3))
        data2.append(np.array(np.transpose(np.asarray(im2_pos2),(2,0,1)),dtype=np.float32))
    elif switch==1:
        img_blank = Image.new('RGB', (100, 100), color = 'white')
        row_blank,col_blank,ch_blank= np.shape(img_blank)
        mean_blank = random.randint(1,6)
        var_blank = random.random()
        sigma_blank = var_blank**0.5
        gauss_blank_pos1 = np.random.normal(mean_blank,sigma_blank,(row_blank,col_blank,ch_blank))
        noisy_blank_pos1 = img_blank + gauss_blank_pos1
        im2_blank_pos1 = Image.fromarray(noisy_blank_pos1,'RGB')
        im2_blank_pos1 = np.reshape(im2_blank_pos1,(100, 100,3))
        data1.append(np.array(np.transpose(np.asarray(im2_blank_pos1),(2,0,1)),dtype=np.float32))

        img_blank_1 = Image.new('RGB', (100, 100), color = 'white')
        row_blank_1,col_blank_1,ch_blank_1= np.shape(img_blank_1)
        mean_blank_1 = random.randint(1,6)
        var_blank_1 = random.random()
        sigma_blank_1 = var_blank_1**0.5
        gauss_blank_pos2 = np.random.normal(mean_blank_1,sigma_blank_1,(row_blank_1,col_blank_1,ch_blank_1))
        noisy_blank_pos2 = img_blank_1 + gauss_blank_pos2
        im2_blank_pos2 = Image.fromarray(noisy_blank_pos2,'RGB')
        im2_blank_pos2 = np.reshape(im2_blank_pos2,(100, 100,3))
        data2.append(np.array(np.transpose(np.asarray(im2_blank_pos2),(2,0,1)),dtype=np.float32))


#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = 'white')
row,col,ch= np.shape(img)
mean = 0
var = 1
sigma = var**0.5
gauss = np.random.normal(mean,sigma,(row,col,ch))
noisy = img + gauss
im2 = Image.fromarray(noisy,'RGB')
im2 = np.reshape(im2,(100,100,3))
b = np.asarray(im2)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)



print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, stride=1, padding=2)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)

        # Convolution 2
        self.cnn2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.relu2 = nn.ReLU()

        # Max pool 2
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(20000, 1)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        out = self.cnn2(out)
        out = self.relu2(out)

        # Max pool 2 
        out = self.maxpool2(out)

        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        #out = self.sigmoid1(out)
        return out
    
model = CNNModel()


optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x),model(y))
        # ===================backward====================

        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print("x: ", model(x[0].reshape(1,3,100, 100)))
    print("y:", model(y[0].reshape(1,3,100, 100)))
    print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# (10000, 3, 100, 100)
# epoch [1/100], loss:139.5840
# x:  tensor([[3.5101]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.0060]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.1467]], grad_fn=<AddmmBackward>)
# epoch [2/100], loss:78.0475
# x:  tensor([[-1.0697]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0959]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7964]], grad_fn=<AddmmBackward>)
# epoch [3/100], loss:38.1508
# x:  tensor([[4.9435]], grad_fn=<AddmmBackward>)
# y: tensor([[0.8259]], grad_fn=<AddmmBackward>)
# b: tensor([[0.9076]], grad_fn=<AddmmBackward>)
# epoch [4/100], loss:22.8725
# x:  tensor([[4.0956]], grad_fn=<AddmmBackward>)
# y: tensor([[1.5719]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0239]], grad_fn=<AddmmBackward>)
# epoch [5/100], loss:24.1369
# x:  tensor([[7.1239]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3846]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6796]], grad_fn=<AddmmBackward>)
# epoch [6/100], loss:25.7631
# x:  tensor([[0.3434]], grad_fn=<AddmmBackward>)
# y: tensor([[3.9671]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1279]], grad_fn=<AddmmBackward>)
# epoch [7/100], loss:21.4496
# x:  tensor([[2.3104]], grad_fn=<AddmmBackward>)
# y: tensor([[6.3364]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0871]], grad_fn=<AddmmBackward>)
# epoch [8/100], loss:15.7701
# x:  tensor([[4.2984]], grad_fn=<AddmmBackward>)
# y: tensor([[4.6777]], grad_fn=<AddmmBackward>)
# b: tensor([[1.7491]], grad_fn=<AddmmBackward>)
# epoch [9/100], loss:14.4052
# x:  tensor([[4.1783]], grad_fn=<AddmmBackward>)
# y: tensor([[0.8745]], grad_fn=<AddmmBackward>)
# b: tensor([[1.6980]], grad_fn=<AddmmBackward>)
# epoch [10/100], loss:8.9400
# x:  tensor([[-0.4033]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0429]], grad_fn=<AddmmBackward>)
# b: tensor([[1.0986]], grad_fn=<AddmmBackward>)
# epoch [11/100], loss:11.1348
# x:  tensor([[5.8675]], grad_fn=<AddmmBackward>)
# y: tensor([[1.4006]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5174]], grad_fn=<AddmmBackward>)
# epoch [12/100], loss:9.1545
# x:  tensor([[2.8615]], grad_fn=<AddmmBackward>)
# y: tensor([[3.6506]], grad_fn=<AddmmBackward>)
# b: tensor([[1.5840]], grad_fn=<AddmmBackward>)
# epoch [13/100], loss:8.3033
# x:  tensor([[2.8522]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4641]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0453]], grad_fn=<AddmmBackward>)
# epoch [14/100], loss:4.8152
# x:  tensor([[2.1302]], grad_fn=<AddmmBackward>)
# y: tensor([[-0.3085]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2479]], grad_fn=<AddmmBackward>)
# epoch [15/100], loss:6.6325
# x:  tensor([[1.4570]], grad_fn=<AddmmBackward>)
# y: tensor([[1.4452]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9569]], grad_fn=<AddmmBackward>)
# epoch [16/100], loss:5.9922
# x:  tensor([[0.5873]], grad_fn=<AddmmBackward>)
# y: tensor([[1.8446]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2275]], grad_fn=<AddmmBackward>)
# epoch [17/100], loss:4.3823
# x:  tensor([[2.5955]], grad_fn=<AddmmBackward>)
# y: tensor([[1.9464]], grad_fn=<AddmmBackward>)
# b: tensor([[1.9727]], grad_fn=<AddmmBackward>)
# epoch [18/100], loss:4.5037
# x:  tensor([[2.3500]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6818]], grad_fn=<AddmmBackward>)
# b: tensor([[1.2427]], grad_fn=<AddmmBackward>)
# epoch [19/100], loss:2.3692
# x:  tensor([[2.2000]], grad_fn=<AddmmBackward>)
# y: tensor([[3.3254]], grad_fn=<AddmmBackward>)
# b: tensor([[1.8464]], grad_fn=<AddmmBackward>)
# epoch [20/100], loss:2.8326
# x:  tensor([[3.4093]], grad_fn=<AddmmBackward>)
# y: tensor([[1.0317]], grad_fn=<AddmmBackward>)
# b: tensor([[1.8338]], grad_fn=<AddmmBackward>)
# epoch [21/100], loss:4.3451
# x:  tensor([[0.0616]], grad_fn=<AddmmBackward>)
# y: tensor([[2.9635]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2456]], grad_fn=<AddmmBackward>)
# epoch [22/100], loss:3.5692
# x:  tensor([[1.7188]], grad_fn=<AddmmBackward>)
# y: tensor([[4.5888]], grad_fn=<AddmmBackward>)
# b: tensor([[1.7813]], grad_fn=<AddmmBackward>)
# epoch [23/100], loss:2.8142
# x:  tensor([[-0.1182]], grad_fn=<AddmmBackward>)
# y: tensor([[0.3478]], grad_fn=<AddmmBackward>)
# b: tensor([[1.9295]], grad_fn=<AddmmBackward>)
# epoch [24/100], loss:2.2314
# x:  tensor([[0.7061]], grad_fn=<AddmmBackward>)
# y: tensor([[-0.0593]], grad_fn=<AddmmBackward>)
# b: tensor([[1.0037]], grad_fn=<AddmmBackward>)
# epoch [25/100], loss:2.1652
# x:  tensor([[2.9551]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1332]], grad_fn=<AddmmBackward>)
# b: tensor([[1.2327]], grad_fn=<AddmmBackward>)
# epoch [26/100], loss:1.6416
# x:  tensor([[2.1478]], grad_fn=<AddmmBackward>)
# y: tensor([[3.8677]], grad_fn=<AddmmBackward>)
# b: tensor([[1.3720]], grad_fn=<AddmmBackward>)
# epoch [27/100], loss:1.2130
# x:  tensor([[1.3251]], grad_fn=<AddmmBackward>)
# y: tensor([[-0.7582]], grad_fn=<AddmmBackward>)
# b: tensor([[0.5007]], grad_fn=<AddmmBackward>)
# epoch [28/100], loss:0.7195
# x:  tensor([[1.1272]], grad_fn=<AddmmBackward>)
# y: tensor([[1.1178]], grad_fn=<AddmmBackward>)
# b: tensor([[1.1654]], grad_fn=<AddmmBackward>)
# epoch [29/100], loss:1.2120
# x:  tensor([[2.9348]], grad_fn=<AddmmBackward>)
# y: tensor([[1.5034]], grad_fn=<AddmmBackward>)
# b: tensor([[0.7817]], grad_fn=<AddmmBackward>)
# epoch [30/100], loss:1.4314
# x:  tensor([[1.2489]], grad_fn=<AddmmBackward>)
# y: tensor([[0.7112]], grad_fn=<AddmmBackward>)
# b: tensor([[1.1079]], grad_fn=<AddmmBackward>)
# epoch [31/100], loss:1.3409
# x:  tensor([[3.1881]], grad_fn=<AddmmBackward>)
# y: tensor([[1.8303]], grad_fn=<AddmmBackward>)
# b: tensor([[1.2003]], grad_fn=<AddmmBackward>)
# epoch [32/100], loss:1.6844
# x:  tensor([[0.5166]], grad_fn=<AddmmBackward>)
# y: tensor([[3.2104]], grad_fn=<AddmmBackward>)
# b: tensor([[1.3226]], grad_fn=<AddmmBackward>)
# epoch [33/100], loss:0.4091
# x:  tensor([[0.6486]], grad_fn=<AddmmBackward>)
# y: tensor([[2.9098]], grad_fn=<AddmmBackward>)
# b: tensor([[1.2032]], grad_fn=<AddmmBackward>)
# epoch [34/100], loss:0.7114
# x:  tensor([[1.7643]], grad_fn=<AddmmBackward>)
# y: tensor([[1.5749]], grad_fn=<AddmmBackward>)
# b: tensor([[1.2536]], grad_fn=<AddmmBackward>)
# epoch [35/100], loss:0.3240
# x:  tensor([[0.5130]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0235]], grad_fn=<AddmmBackward>)
# b: tensor([[1.4392]], grad_fn=<AddmmBackward>)
# epoch [36/100], loss:0.8859
# x:  tensor([[3.7887]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4586]], grad_fn=<AddmmBackward>)
# b: tensor([[1.9380]], grad_fn=<AddmmBackward>)
# epoch [37/100], loss:0.4991
# x:  tensor([[1.3058]], grad_fn=<AddmmBackward>)
# y: tensor([[1.8853]], grad_fn=<AddmmBackward>)
# b: tensor([[1.1864]], grad_fn=<AddmmBackward>)
# epoch [38/100], loss:0.3607
# x:  tensor([[2.5396]], grad_fn=<AddmmBackward>)
# y: tensor([[3.0823]], grad_fn=<AddmmBackward>)
# b: tensor([[1.1073]], grad_fn=<AddmmBackward>)
# epoch [39/100], loss:0.5101
# x:  tensor([[0.6834]], grad_fn=<AddmmBackward>)
# y: tensor([[-0.3410]], grad_fn=<AddmmBackward>)
# b: tensor([[1.6760]], grad_fn=<AddmmBackward>)
# epoch [40/100], loss:0.6951
# x:  tensor([[3.0359]], grad_fn=<AddmmBackward>)
# y: tensor([[1.4204]], grad_fn=<AddmmBackward>)
# b: tensor([[1.1119]], grad_fn=<AddmmBackward>)
# epoch [41/100], loss:0.2087
# x:  tensor([[0.8515]], grad_fn=<AddmmBackward>)
# y: tensor([[0.6324]], grad_fn=<AddmmBackward>)
# b: tensor([[1.3111]], grad_fn=<AddmmBackward>)
# epoch [42/100], loss:0.1687
# x:  tensor([[2.7965]], grad_fn=<AddmmBackward>)
# y: tensor([[1.1557]], grad_fn=<AddmmBackward>)
# b: tensor([[1.4465]], grad_fn=<AddmmBackward>)
# epoch [43/100], loss:0.2931
# x:  tensor([[2.5639]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1343]], grad_fn=<AddmmBackward>)
# b: tensor([[1.5524]], grad_fn=<AddmmBackward>)
# epoch [44/100], loss:0.3163
# x:  tensor([[1.3245]], grad_fn=<AddmmBackward>)
# y: tensor([[0.5835]], grad_fn=<AddmmBackward>)
# b: tensor([[1.5686]], grad_fn=<AddmmBackward>)
# epoch [45/100], loss:0.1613
# x:  tensor([[2.0112]], grad_fn=<AddmmBackward>)
# y: tensor([[1.5350]], grad_fn=<AddmmBackward>)
# b: tensor([[1.4245]], grad_fn=<AddmmBackward>)
# epoch [46/100], loss:0.4240
# x:  tensor([[1.4444]], grad_fn=<AddmmBackward>)
# y: tensor([[1.0507]], grad_fn=<AddmmBackward>)
# b: tensor([[0.9759]], grad_fn=<AddmmBackward>)
# epoch [47/100], loss:0.1521
# x:  tensor([[0.9798]], grad_fn=<AddmmBackward>)
# y: tensor([[0.2614]], grad_fn=<AddmmBackward>)
# b: tensor([[1.4068]], grad_fn=<AddmmBackward>)
# epoch [48/100], loss:0.3251
# x:  tensor([[2.7667]], grad_fn=<AddmmBackward>)
# y: tensor([[1.9055]], grad_fn=<AddmmBackward>)
# b: tensor([[0.9478]], grad_fn=<AddmmBackward>)
# epoch [49/100], loss:0.2114
# x:  tensor([[0.7428]], grad_fn=<AddmmBackward>)
# y: tensor([[1.0436]], grad_fn=<AddmmBackward>)
# b: tensor([[1.3270]], grad_fn=<AddmmBackward>)
# epoch [50/100], loss:-0.0277
# x:  tensor([[1.3503]], grad_fn=<AddmmBackward>)
# y: tensor([[2.2462]], grad_fn=<AddmmBackward>)
# b: tensor([[1.9394]], grad_fn=<AddmmBackward>)
# epoch [51/100], loss:-0.0762
# x:  tensor([[1.2207]], grad_fn=<AddmmBackward>)
# y: tensor([[1.3984]], grad_fn=<AddmmBackward>)
# b: tensor([[0.9244]], grad_fn=<AddmmBackward>)
# epoch [52/100], loss:0.1466
# x:  tensor([[0.7518]], grad_fn=<AddmmBackward>)
# y: tensor([[-0.7094]], grad_fn=<AddmmBackward>)
# b: tensor([[1.5927]], grad_fn=<AddmmBackward>)
# epoch [53/100], loss:0.0117
# x:  tensor([[1.6593]], grad_fn=<AddmmBackward>)
# y: tensor([[1.7297]], grad_fn=<AddmmBackward>)
# b: tensor([[1.4364]], grad_fn=<AddmmBackward>)
# epoch [54/100], loss:0.0220
# x:  tensor([[2.2217]], grad_fn=<AddmmBackward>)
# y: tensor([[2.2669]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2305]], grad_fn=<AddmmBackward>)
# epoch [55/100], loss:-0.2033
# x:  tensor([[1.3015]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3302]], grad_fn=<AddmmBackward>)
# b: tensor([[1.1551]], grad_fn=<AddmmBackward>)
# epoch [56/100], loss:-0.0387
# x:  tensor([[1.8538]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6593]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1377]], grad_fn=<AddmmBackward>)
# epoch [57/100], loss:-0.1254
# x:  tensor([[2.2100]], grad_fn=<AddmmBackward>)
# y: tensor([[1.9298]], grad_fn=<AddmmBackward>)
# b: tensor([[1.7587]], grad_fn=<AddmmBackward>)
# epoch [58/100], loss:-0.2220
# x:  tensor([[2.3467]], grad_fn=<AddmmBackward>)
# y: tensor([[1.9554]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0596]], grad_fn=<AddmmBackward>)
# epoch [59/100], loss:-0.0353
# x:  tensor([[3.0451]], grad_fn=<AddmmBackward>)
# y: tensor([[3.7523]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6598]], grad_fn=<AddmmBackward>)
# epoch [60/100], loss:-0.1276
# x:  tensor([[2.6007]], grad_fn=<AddmmBackward>)
# y: tensor([[2.9791]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0724]], grad_fn=<AddmmBackward>)
# epoch [61/100], loss:-0.5357
# x:  tensor([[3.4252]], grad_fn=<AddmmBackward>)
# y: tensor([[3.3716]], grad_fn=<AddmmBackward>)
# b: tensor([[3.4299]], grad_fn=<AddmmBackward>)
# epoch [62/100], loss:-0.1582
# x:  tensor([[2.0964]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3900]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1990]], grad_fn=<AddmmBackward>)
# epoch [63/100], loss:-0.2266
# x:  tensor([[4.3230]], grad_fn=<AddmmBackward>)
# y: tensor([[3.5375]], grad_fn=<AddmmBackward>)
# b: tensor([[3.1935]], grad_fn=<AddmmBackward>)
# epoch [64/100], loss:-0.4479
# x:  tensor([[1.9370]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6699]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6261]], grad_fn=<AddmmBackward>)
# epoch [65/100], loss:-0.4648
# x:  tensor([[3.5369]], grad_fn=<AddmmBackward>)
# y: tensor([[2.7137]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9171]], grad_fn=<AddmmBackward>)
# epoch [66/100], loss:-0.5057
# x:  tensor([[2.1764]], grad_fn=<AddmmBackward>)
# y: tensor([[1.3731]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4702]], grad_fn=<AddmmBackward>)
# epoch [67/100], loss:-0.5590
# x:  tensor([[2.7448]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4366]], grad_fn=<AddmmBackward>)
# b: tensor([[3.6195]], grad_fn=<AddmmBackward>)
# epoch [68/100], loss:-0.4635
# x:  tensor([[3.8638]], grad_fn=<AddmmBackward>)
# y: tensor([[3.7097]], grad_fn=<AddmmBackward>)
# b: tensor([[3.5924]], grad_fn=<AddmmBackward>)
# epoch [69/100], loss:-0.3799
# x:  tensor([[2.8731]], grad_fn=<AddmmBackward>)
# y: tensor([[2.8741]], grad_fn=<AddmmBackward>)
# b: tensor([[3.4259]], grad_fn=<AddmmBackward>)
# epoch [70/100], loss:-0.6099
# x:  tensor([[0.8209]], grad_fn=<AddmmBackward>)
# y: tensor([[0.9550]], grad_fn=<AddmmBackward>)
# b: tensor([[2.8874]], grad_fn=<AddmmBackward>)
# epoch [71/100], loss:-0.6174
# x:  tensor([[2.7933]], grad_fn=<AddmmBackward>)
# y: tensor([[2.7896]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5096]], grad_fn=<AddmmBackward>)
# epoch [72/100], loss:-0.6076
# x:  tensor([[0.9621]], grad_fn=<AddmmBackward>)
# y: tensor([[2.2656]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5893]], grad_fn=<AddmmBackward>)
# epoch [73/100], loss:-0.6905
# x:  tensor([[1.3932]], grad_fn=<AddmmBackward>)
# y: tensor([[1.1617]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5077]], grad_fn=<AddmmBackward>)
# epoch [74/100], loss:-0.7131
# x:  tensor([[0.7599]], grad_fn=<AddmmBackward>)
# y: tensor([[0.6729]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6841]], grad_fn=<AddmmBackward>)
# epoch [75/100], loss:-0.7357
# x:  tensor([[2.4886]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6277]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6357]], grad_fn=<AddmmBackward>)
# epoch [76/100], loss:-0.7430
# x:  tensor([[1.0843]], grad_fn=<AddmmBackward>)
# y: tensor([[2.6252]], grad_fn=<AddmmBackward>)
# b: tensor([[3.0591]], grad_fn=<AddmmBackward>)
# epoch [77/100], loss:-0.6460
# x:  tensor([[4.1897]], grad_fn=<AddmmBackward>)
# y: tensor([[4.1135]], grad_fn=<AddmmBackward>)
# b: tensor([[3.1986]], grad_fn=<AddmmBackward>)
# epoch [78/100], loss:-0.7255
# x:  tensor([[1.7020]], grad_fn=<AddmmBackward>)
# y: tensor([[1.1350]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7151]], grad_fn=<AddmmBackward>)
# epoch [79/100], loss:-0.7686
# x:  tensor([[2.4254]], grad_fn=<AddmmBackward>)
# y: tensor([[3.9113]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9246]], grad_fn=<AddmmBackward>)
# epoch [80/100], loss:-0.7698
# x:  tensor([[2.5177]], grad_fn=<AddmmBackward>)
# y: tensor([[2.7169]], grad_fn=<AddmmBackward>)
# b: tensor([[2.7920]], grad_fn=<AddmmBackward>)
# epoch [81/100], loss:-0.7215
# x:  tensor([[1.1434]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0887]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9244]], grad_fn=<AddmmBackward>)
# epoch [82/100], loss:-0.7733
# x:  tensor([[3.8720]], grad_fn=<AddmmBackward>)
# y: tensor([[3.6162]], grad_fn=<AddmmBackward>)
# b: tensor([[2.9855]], grad_fn=<AddmmBackward>)
# epoch [83/100], loss:-0.7737
# x:  tensor([[1.3117]], grad_fn=<AddmmBackward>)
# y: tensor([[0.9744]], grad_fn=<AddmmBackward>)
# b: tensor([[1.8144]], grad_fn=<AddmmBackward>)
# epoch [84/100], loss:-0.7714
# x:  tensor([[1.3072]], grad_fn=<AddmmBackward>)
# y: tensor([[0.8918]], grad_fn=<AddmmBackward>)
# b: tensor([[2.6350]], grad_fn=<AddmmBackward>)
# epoch [85/100], loss:-0.7874
# x:  tensor([[2.4212]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4618]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3586]], grad_fn=<AddmmBackward>)
# epoch [86/100], loss:-0.7762
# x:  tensor([[0.8328]], grad_fn=<AddmmBackward>)
# y: tensor([[0.9389]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2400]], grad_fn=<AddmmBackward>)
# epoch [87/100], loss:-0.8222
# x:  tensor([[0.8745]], grad_fn=<AddmmBackward>)
# y: tensor([[0.4614]], grad_fn=<AddmmBackward>)
# b: tensor([[2.5819]], grad_fn=<AddmmBackward>)
# epoch [88/100], loss:-0.7935
# x:  tensor([[2.1369]], grad_fn=<AddmmBackward>)
# y: tensor([[1.7736]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2766]], grad_fn=<AddmmBackward>)
# epoch [89/100], loss:-0.8516
# x:  tensor([[0.7567]], grad_fn=<AddmmBackward>)
# y: tensor([[0.7854]], grad_fn=<AddmmBackward>)
# b: tensor([[2.1953]], grad_fn=<AddmmBackward>)
# epoch [90/100], loss:-0.8236
# x:  tensor([[1.7863]], grad_fn=<AddmmBackward>)
# y: tensor([[2.3775]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3127]], grad_fn=<AddmmBackward>)
# epoch [91/100], loss:-0.8775
# x:  tensor([[2.0428]], grad_fn=<AddmmBackward>)
# y: tensor([[2.5353]], grad_fn=<AddmmBackward>)
# b: tensor([[1.6564]], grad_fn=<AddmmBackward>)
# epoch [92/100], loss:-0.8569
# x:  tensor([[-0.4054]], grad_fn=<AddmmBackward>)
# y: tensor([[-0.2891]], grad_fn=<AddmmBackward>)
# b: tensor([[1.2902]], grad_fn=<AddmmBackward>)
# epoch [93/100], loss:-0.8351
# x:  tensor([[2.8565]], grad_fn=<AddmmBackward>)
# y: tensor([[2.4282]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3778]], grad_fn=<AddmmBackward>)
# epoch [94/100], loss:-0.8340
# x:  tensor([[2.4418]], grad_fn=<AddmmBackward>)
# y: tensor([[2.1330]], grad_fn=<AddmmBackward>)
# b: tensor([[2.3024]], grad_fn=<AddmmBackward>)
# epoch [95/100], loss:-0.8666
# x:  tensor([[2.3933]], grad_fn=<AddmmBackward>)
# y: tensor([[3.0913]], grad_fn=<AddmmBackward>)
# b: tensor([[2.2306]], grad_fn=<AddmmBackward>)
# epoch [96/100], loss:-0.8671
# x:  tensor([[2.4162]], grad_fn=<AddmmBackward>)
# y: tensor([[2.2183]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4325]], grad_fn=<AddmmBackward>)
# epoch [97/100], loss:-0.9013
# x:  tensor([[1.2560]], grad_fn=<AddmmBackward>)
# y: tensor([[1.3063]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4298]], grad_fn=<AddmmBackward>)
# epoch [98/100], loss:-0.8594
# x:  tensor([[2.3618]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0818]], grad_fn=<AddmmBackward>)
# b: tensor([[1.9737]], grad_fn=<AddmmBackward>)
# epoch [99/100], loss:-0.8804
# x:  tensor([[2.1354]], grad_fn=<AddmmBackward>)
# y: tensor([[2.0170]], grad_fn=<AddmmBackward>)
# b: tensor([[2.0801]], grad_fn=<AddmmBackward>)
# epoch [100/100], loss:-0.9040
# x:  tensor([[2.7614]], grad_fn=<AddmmBackward>)
# y: tensor([[2.7347]], grad_fn=<AddmmBackward>)
# b: tensor([[2.4371]], grad_fn=<AddmmBackward>)

# %%
data3=[]

for i in range(5):
    img = Image.new('RGB', (100, 100), color = 'white')
    #img = np.reshape(img,(28,28,1))
    #print(np.shape(img))
    row,col,ch= np.shape(img)
    mean = random.randint(1,6)
    var = random.random()
    sigma = var**0.5
    gauss_pos1 = np.random.normal(mean,sigma,(row,col,ch))
    noisy_pos1 = img + gauss_pos1
    im2_pos1 = Image.fromarray(noisy_pos1,'RGB')
    #draw = ImageDraw.Draw(im2_pos1)
    #draw.rectangle([20,20,40,40],fill='red',outline='red')
    #im2_pos1.show()
    #print(np.shape(np.transpose(np.asarray(im2_pos1),(2,0,1))))
    im2_pos1.paste(im_drone,(10,10),im_drone)
    im2_pos1 = np.reshape(im2_pos1,(100,100,3))

    data3.append(np.array(np.transpose(np.asarray(im2_pos1),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    print("x: ", model(x_1[i].reshape(1,3,100,100)))
# Out:
# x:  tensor([[0.7390]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.9138]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.3371]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.1607]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.6997]], grad_fn=<AddmmBackward>)
