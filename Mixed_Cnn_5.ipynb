# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data

blank = cv2.imread('blank_28x28.png')
b = np.array(blank,dtype=np.float32)
b = np.transpose(b,(2,1,0))
b = torch.from_numpy(b)

num_epochs = 100
learning_rate = 1e-5


from PIL import  Image,ImageDraw
import numpy as np


data1 = []
data2= []

img = Image.new('RGB', (28, 28), color = 'white')
row,col,ch= np.shape(img)
mean = 0
var = 1
sigma = var**0.5
gauss = np.random.normal(mean,sigma,(row,col,ch))
noisy = img + gauss


img1 = Image.new('RGB', (28, 28), color = 'white')
row,col,ch= np.shape(img1)
mean = 0
var = 1
sigma = var**0.5
gauss1 = np.random.normal(mean,sigma,(row,col,ch))
noisy1 = img1 + gauss1

for i in range(20000):
    r = np.random.randint(1,101)
    
    if r%2==0:
        im_2 = Image.fromarray(noisy,'RGB')
        draw = ImageDraw.Draw(im_2)
        draw.rectangle([9,12,12,15],fill='red',outline='red')
        data1.append(np.asarray(im_2))
    else:
        im_2 = Image.fromarray(noisy1,'RGB')
        draw = ImageDraw.Draw(im_2)
        draw.rectangle([21, 12, 24, 15], fill='red', outline='red')
        data1.append(np.asarray(im_2))
        

im_2.show()

for i in range(20000):
    r = np.random.randint(1,101)
    if r%2==0:
        im2 = Image.fromarray(noisy1,'RGB')
        draw = ImageDraw.Draw(im2)
        draw.rectangle([21, 12, 24, 15], fill='red', outline='red')
        data2.append(np.asarray(im2))
        #p = Image.fromarray(data1[i])
        #p.show()
        #q = Image.fromarray(data2[i])
        #q.show()
    else:
        im2 = Image.fromarray(noisy,'RGB')
        draw = ImageDraw.Draw(im2)
        draw.rectangle([9,12,12,15],fill='red',outline='red')
        data2.append(np.asarray(im2))
        #p = Image.fromarray(data1[i])
        #p.show()
        #q = Image.fromarray(data2[i])
        #q.show()

im2.show()

y0 = np.array(data1, dtype=np.float32)
y1 = np.array(data2, dtype=np.float32)
y0 = np.transpose(y0, (0, 3, 2, 1))# This to make channels first for CNN
y1 = np.transpose(y1, (0, 3, 2, 1)) 


print(y0.shape)

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)



torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=250,

    shuffle=True,

    num_workers=0,

)

class autoencoder(nn.Module):
    def __init__(self):
        super(autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 16, 3, stride=3, padding=1),  # b, 16, 10, 10
            nn.ReLU(True),
            nn.MaxPool2d(2, stride=2),  # b, 16, 5, 5
            nn.Conv2d(16, 8, 3, stride=2, padding=1),  # b, 8, 3, 3
            nn.ReLU(True), # b, 8, 2, 2
            nn.Conv2d(8,4,3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(4,2,3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2, stride=1)
        )
        self.fc = nn.Linear(2, 1)

    def forward(self, x):
        x = self.encoder(x)
        x = x.view(-1,2)
        x = self.fc(x)
        return x

class auto_decoder(nn.Module):
    def __init__(self):
        super(auto_decoder,self).__init__()
        ## decoder layers ##
        ## a kernel of 2 and a stride of 2 will increase the spatial dims by 2
        self.t_conv1 = nn.ConvTranspose2d(4, 16, 3,padding=1)
        self.t_conv2 = nn.ConvTranspose2d(16, 3, 3,padding=1)
        
    def forward(self, x):
        ## decode ##
        # add transpose conv layers, with relu activation function
        x = F.relu(self.t_conv1(x))
        # output layer (with sigmoid for scaling from 0 to 1)
        x = F.sigmoid(self.t_conv2(x))
                
        return x
    

model = autoencoder()


def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)

    covf = torch.matmul((fx.t()), fx) / Nsamples

    covg = torch.matmul((gy.t()), (gy)) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,
                             weight_decay=1e-5)

model_1 = auto_decoder()
optimizer_1 = torch.optim.Adam(model_1.parameters(), lr=learning_rate,
                             weight_decay=1e-5)


for epoch in range(num_epochs):
    for x,y in loader:

        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x),model(y))
        # ===================backward====================
        optimizer.zero_grad()
        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'
          .format(epoch+1, num_epochs, loss.item()))
    print("x: ", model(x[0].reshape(1,3,28,28)))
    print("y:", model(y[0].reshape(1,3,28,28)))

    print("b:", model(b.reshape(1,3,28,28)))



torch.save(model.state_dict(), './conv_autoencoder.pth')
# Out:
# (20000, 3, 28, 28)
# epoch [1/100], loss:0.0001
# x:  tensor([[0.1171]], grad_fn=<AddmmBackward>)
# y: tensor([[0.1171]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1611]], grad_fn=<AddmmBackward>)
# epoch [2/100], loss:-0.0001
# x:  tensor([[0.0011]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0011]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1448]], grad_fn=<AddmmBackward>)
# epoch [3/100], loss:-0.0001
# x:  tensor([[0.0089]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0089]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1352]], grad_fn=<AddmmBackward>)
# epoch [4/100], loss:0.0000
# x:  tensor([[0.0142]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0142]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1269]], grad_fn=<AddmmBackward>)
# epoch [5/100], loss:-0.0000
# x:  tensor([[0.0499]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0499]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1221]], grad_fn=<AddmmBackward>)
# epoch [6/100], loss:-0.0000
# x:  tensor([[0.0417]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0417]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1173]], grad_fn=<AddmmBackward>)
# epoch [7/100], loss:0.0000
# x:  tensor([[0.0211]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0211]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1118]], grad_fn=<AddmmBackward>)
# epoch [8/100], loss:0.0000
# x:  tensor([[0.0303]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0303]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1097]], grad_fn=<AddmmBackward>)
# epoch [9/100], loss:0.0000
# x:  tensor([[0.0212]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0212]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1075]], grad_fn=<AddmmBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-68a8c479915f> in <module>
#     193         optimizer.zero_grad()
#     194         #optimizer_1.zero_grad()
# --> 195         loss.backward()
#     196         optimizer.step()
#     197         #optimizer_1.step()
#
# ~\anaconda3\envs\AoI\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# ~\anaconda3\envs\AoI\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# KeyboardInterrupt:

# %%
for i in range(3):
    im2_n = Image.fromarray(noisy,'RGB')
    b = np.asarray(im2_n)
    b = np.array(b, dtype=np.float32)
    b = np.transpose(b,(2,1,0))
    b = torch.from_numpy(b)
    im2_test = Image.fromarray(noisy,'RGB')
    draw1 = ImageDraw.Draw(im2_test)
    draw1.rectangle([5, 9, 8, 12], fill='red', outline='red')
    z = np.asarray(im2_test)
    z = np.array(z, dtype=np.float32)
    z = np.transpose(z,(2,1,0))
    z = torch.from_numpy(z)
    y0 = np.transpose(y0, (0, 1, 2, 3))# This to make channels first for CNN
    y1 = np.transpose(y1, (0, 1, 2, 3)) 
    print("b:", model(b.reshape(1,3,28,28)))
    print("z: ", model(z.reshape(1,3,28,28)))
    print("x: ", model(x[i].reshape(1,3,28,28)))
    print("y:", model(y[i].reshape(1,3,28,28)))
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
    print("  ")
    p = Image.fromarray(data1[i])
    p.show()
    q = Image.fromarray(y1[i])
    q.show()
    
#im2_test.show()
# Out:
# b: tensor([[0.0374]], grad_fn=<AddmmBackward>)
# z:  tensor([[-0.0343]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\AoI\lib\site-packages\PIL\Image.py in fromarray(obj, mode)
#    2713         try:
# -> 2714             mode, rawmode = _fromarray_typemap[typekey]
#    2715         except KeyError:
#
# KeyError: ((1, 1, 28), '<f4')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-42e697caafe5> in <module>
#      20     print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
#      21     print("  ")
# ---> 22     p = Image.fromarray(y0[i])
#      23     p.show()
#      24     q = Image.fromarray(y1[i])
#
# ~\anaconda3\envs\AoI\lib\site-packages\PIL\Image.py in fromarray(obj, mode)
#    2714             mode, rawmode = _fromarray_typemap[typekey]
#    2715         except KeyError:
# -> 2716             raise TypeError("Cannot handle this data type: %s, %s" % typekey)
#    2717     else:
#    2718         rawmode = mode
#
# TypeError: Cannot handle this data type: (1, 1, 28), <f4

# %%
for i in range(20):
    img = Image.new('RGB', (28, 28), color = 'white')
    row,col,ch= np.shape(img)
    mean = 0
    var = 1
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col,ch))
    noisy = img + gauss
    im2 = Image.fromarray(noisy,'RGB')
    b = np.asarray(im2)
    b = np.array(b, dtype=np.float32)
    b = torch.from_numpy(b)
    print("b:", model(b.reshape(1,3,28,28)))
    print("x: ", model(x[i].reshape(1,3,28,28)))
    print("y:", model(y[i].reshape(1,3,28,28)))
# Out:
# b: tensor([[-1.6000]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.5331]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.7532]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.3698]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.7687]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.8867]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.9935]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.8876]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-2.0444]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.5745]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.8551]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.4508]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.9345]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.2724]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.6365]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.3189]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-2.6185]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.4775]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-2.2803]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# b: tensor([[-1.5295]], grad_fn=<AddmmBackward>)
# x:  tensor([[-1.8017]], grad_fn=<AddmmBackward>)
# y: tensor([[-1.8017]], grad_fn=<AddmmBackward>)

# %%
for i in range(20):
    img = Image.new('RGB', (28, 28), color = 'white')
    row,col,ch= np.shape(img)
    mean = 0
    var = 1
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col,ch))
    noisy = img + gauss
    im2 = Image.fromarray(noisy,'RGB')
    b = np.asarray(im2)
    b = np.array(b, dtype=np.float32)
    b = torch.from_numpy(b)
    print("b:", model(b.reshape(1,3,28,28)))
    print("x: ", model(x[i].reshape(1,3,28,28)))
    print("y:", model(y[i].reshape(1,3,28,28)))
# Out:
# b: tensor([[-0.1304]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1885]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.0158]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.2478]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.2003]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0218]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.3533]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0218]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.0847]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.1978]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.1911]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[0.0307]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.3407]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.0233]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0218]], grad_fn=<AddmmBackward>)
# b: tensor([[0.0039]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0218]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.0891]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0218]], grad_fn=<AddmmBackward>)
# b: tensor([[0.1956]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0218]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.1687]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.0681]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.2036]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0218]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0243]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.2719]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0218]], grad_fn=<AddmmBackward>)
# b: tensor([[-0.0833]], grad_fn=<AddmmBackward>)
# x:  tensor([[0.0243]], grad_fn=<AddmmBackward>)
# y: tensor([[0.0218]], grad_fn=<AddmmBackward>)
