# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random
import cv2

Batch_Size = 50
num_epochs = 200
learning_rate = 1e-5
samples = 10000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
uframes = []

im1 = Image.open('tree1.png')
im1 = im1.resize((8,8))

imt = Image.open('tank.png')
imt = imt.resize((10,10))


im2 = Image.open('tree2.png')
im2 = im2.resize((8,8))

im3 = Image.open('tree3.png')
im3 = im3.resize((8,8))

im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((10,10))

imb = Image.open('bullet.png')
imb = imb.resize((2,2))

for i in range(1):
    
    #blank
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)

    uframes.append(img_blank)
    
    #only tank
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    
    uframes.append(img_blank)
    
    #only drone
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t1d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t2d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,35,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t3d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t1d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((40,50,43,53), fill=(50, 182, 150))
    
    uframes.append(img_blank)
    
    #t2d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,35,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw.ellipse((40,50,43,53), fill=(50, 182, 150))
    
    
    uframes.append(img_blank)
    
    #t3d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((40,50,43,53), fill=(50, 182, 150))
    
    
    uframes.append(img_blank)
    
    #t1d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    uframes.append(img_blank)
    
    #t2d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,35,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    
    uframes.append(img_blank)
    
    #t3d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    
    uframes.append(img_blank)



for i in range(samples):
    data1.append(np.array(np.transpose(np.asarray(uframes[i % len(uframes)]),(2,0,1)),dtype=np.float32))
    data2.append(np.array(np.transpose(np.asarray(uframes[(i+1) % len(uframes)]),(2,0,1)),dtype=np.float32))



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = '#9b7653')
img.paste(im1,(5,75),im1)
img.paste(im1,(10,55),im1)
img.paste(im1,(25,50),im1)
img.paste(im2,(75,5),im2)
img.paste(im2,(60,30),im2)
img.paste(im2,(90,20),im2)
img.paste(im3,(75,60),im3)
img.paste(im3,(60,80),im3)
im_n = np.reshape(img,(100,100,3))
b = np.asarray(im_n)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)

#y0 = np.array(np.transpose(np.asarray(y0),(0,3,1,2)),dtype=np.float32)
#y1 = np.array(np.transpose(np.asarray(y1),(0,3,1,2)),dtype=np.float32)
print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, stride=1, padding=2)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=5)

        # Convolution 2
        self.cnn2 = nn.Conv2d(in_channels=16, out_channels=3, kernel_size=5, stride=1, padding=2)
        self.relu2 = nn.ReLU()

        # Max pool 2
        self.maxpool2 = nn.MaxPool2d(kernel_size=5)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(48, 15)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        out = self.cnn2(out)
        out = self.relu2(out)

        # Max pool 2 
        out = self.maxpool2(out)
        im_out = out
        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return im_out,out
    
model = CNNModel()


optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x)[1],model(y)[1])
        # ===================backward====================
 
        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print("shape: ", np.shape(model(x[0].reshape(1,3,100, 100))[0]))
#     print("x: ", model(x[0].reshape(1,3,100, 100)))
#     print("y:", model(y[0].reshape(1,3,100, 100)))
#     print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# (10000, 3, 100, 100)
# epoch [1/200], loss:-0.0022
# shape:  torch.Size([1, 3, 4, 4])
# epoch [2/200], loss:-0.0035
# shape:  torch.Size([1, 3, 4, 4])
# epoch [3/200], loss:-0.0055
# shape:  torch.Size([1, 3, 4, 4])
# epoch [4/200], loss:-0.0103
# shape:  torch.Size([1, 3, 4, 4])
# epoch [5/200], loss:-0.0105
# shape:  torch.Size([1, 3, 4, 4])
# epoch [6/200], loss:-0.0137
# shape:  torch.Size([1, 3, 4, 4])
# epoch [7/200], loss:-0.0153
# shape:  torch.Size([1, 3, 4, 4])
# epoch [8/200], loss:-0.0182
# shape:  torch.Size([1, 3, 4, 4])
# epoch [9/200], loss:-0.0155
# shape:  torch.Size([1, 3, 4, 4])
# epoch [10/200], loss:-0.0317
# shape:  torch.Size([1, 3, 4, 4])
# epoch [11/200], loss:-0.0349
# shape:  torch.Size([1, 3, 4, 4])
# epoch [12/200], loss:-0.0540
# shape:  torch.Size([1, 3, 4, 4])
# epoch [13/200], loss:-0.0566
# shape:  torch.Size([1, 3, 4, 4])
# epoch [14/200], loss:-0.0809
# shape:  torch.Size([1, 3, 4, 4])
# epoch [15/200], loss:-0.0742
# shape:  torch.Size([1, 3, 4, 4])
# epoch [16/200], loss:-0.0983
# shape:  torch.Size([1, 3, 4, 4])
# epoch [17/200], loss:-0.1570
# shape:  torch.Size([1, 3, 4, 4])
# epoch [18/200], loss:-0.2572
# shape:  torch.Size([1, 3, 4, 4])
# epoch [19/200], loss:-0.2871
# shape:  torch.Size([1, 3, 4, 4])
# epoch [20/200], loss:-0.2662
# shape:  torch.Size([1, 3, 4, 4])
# epoch [21/200], loss:-0.4229
# shape:  torch.Size([1, 3, 4, 4])
# epoch [22/200], loss:-0.4912
# shape:  torch.Size([1, 3, 4, 4])
# epoch [23/200], loss:-0.4950
# shape:  torch.Size([1, 3, 4, 4])
# epoch [24/200], loss:-0.5883
# shape:  torch.Size([1, 3, 4, 4])
# epoch [25/200], loss:-0.6592
# shape:  torch.Size([1, 3, 4, 4])
# epoch [26/200], loss:-0.6555
# shape:  torch.Size([1, 3, 4, 4])
# epoch [27/200], loss:-0.5489
# shape:  torch.Size([1, 3, 4, 4])
# epoch [28/200], loss:-0.6039
# shape:  torch.Size([1, 3, 4, 4])
# epoch [29/200], loss:-0.6415
# shape:  torch.Size([1, 3, 4, 4])
# epoch [30/200], loss:-0.6485
# shape:  torch.Size([1, 3, 4, 4])
# epoch [31/200], loss:-0.6348
# shape:  torch.Size([1, 3, 4, 4])
# epoch [32/200], loss:-0.6471
# shape:  torch.Size([1, 3, 4, 4])
# epoch [33/200], loss:-0.5513
# shape:  torch.Size([1, 3, 4, 4])
# epoch [34/200], loss:-0.4829
# shape:  torch.Size([1, 3, 4, 4])
# epoch [35/200], loss:-0.6820
# shape:  torch.Size([1, 3, 4, 4])
# epoch [36/200], loss:-0.4969
# shape:  torch.Size([1, 3, 4, 4])
# epoch [37/200], loss:-0.7119
# shape:  torch.Size([1, 3, 4, 4])
# epoch [38/200], loss:-0.7565
# shape:  torch.Size([1, 3, 4, 4])
# epoch [39/200], loss:-0.8000
# shape:  torch.Size([1, 3, 4, 4])
# epoch [40/200], loss:-0.6844
# shape:  torch.Size([1, 3, 4, 4])
# epoch [41/200], loss:-0.6076
# shape:  torch.Size([1, 3, 4, 4])
# epoch [42/200], loss:-0.6983
# shape:  torch.Size([1, 3, 4, 4])
# epoch [43/200], loss:-0.7226
# shape:  torch.Size([1, 3, 4, 4])
# epoch [44/200], loss:-0.6899
# shape:  torch.Size([1, 3, 4, 4])
# epoch [45/200], loss:-0.8741
# shape:  torch.Size([1, 3, 4, 4])
# epoch [46/200], loss:-0.7915
# shape:  torch.Size([1, 3, 4, 4])
# epoch [47/200], loss:-0.7903
# shape:  torch.Size([1, 3, 4, 4])
# epoch [48/200], loss:-0.7880
# shape:  torch.Size([1, 3, 4, 4])
# epoch [49/200], loss:-0.9327
# shape:  torch.Size([1, 3, 4, 4])
# epoch [50/200], loss:-0.9965
# shape:  torch.Size([1, 3, 4, 4])
# epoch [51/200], loss:-0.9495
# shape:  torch.Size([1, 3, 4, 4])
# epoch [52/200], loss:-0.8293
# shape:  torch.Size([1, 3, 4, 4])
# epoch [53/200], loss:-1.0443
# shape:  torch.Size([1, 3, 4, 4])
# epoch [54/200], loss:-1.0359
# shape:  torch.Size([1, 3, 4, 4])
# epoch [55/200], loss:-0.9487
# shape:  torch.Size([1, 3, 4, 4])
# epoch [56/200], loss:-1.1815
# shape:  torch.Size([1, 3, 4, 4])
# epoch [57/200], loss:-1.1008
# shape:  torch.Size([1, 3, 4, 4])
# epoch [58/200], loss:-0.9551
# shape:  torch.Size([1, 3, 4, 4])
# epoch [59/200], loss:-1.2919
# shape:  torch.Size([1, 3, 4, 4])
# epoch [60/200], loss:-1.2898
# shape:  torch.Size([1, 3, 4, 4])
# epoch [61/200], loss:-1.1811
# shape:  torch.Size([1, 3, 4, 4])
# epoch [62/200], loss:-1.4023
# shape:  torch.Size([1, 3, 4, 4])
# epoch [63/200], loss:-1.2603
# shape:  torch.Size([1, 3, 4, 4])
# epoch [64/200], loss:-1.2943
# shape:  torch.Size([1, 3, 4, 4])
# epoch [65/200], loss:-1.3856
# shape:  torch.Size([1, 3, 4, 4])
# epoch [66/200], loss:-1.2530
# shape:  torch.Size([1, 3, 4, 4])
# epoch [67/200], loss:-1.4035
# shape:  torch.Size([1, 3, 4, 4])
# epoch [68/200], loss:-1.4744
# shape:  torch.Size([1, 3, 4, 4])
# epoch [69/200], loss:-1.5348
# shape:  torch.Size([1, 3, 4, 4])
# epoch [70/200], loss:-1.3437
# shape:  torch.Size([1, 3, 4, 4])
# epoch [71/200], loss:-1.3059
# shape:  torch.Size([1, 3, 4, 4])
# epoch [72/200], loss:-1.3450
# shape:  torch.Size([1, 3, 4, 4])
# epoch [73/200], loss:-1.5260
# shape:  torch.Size([1, 3, 4, 4])
# epoch [74/200], loss:-1.4821
# shape:  torch.Size([1, 3, 4, 4])
# epoch [75/200], loss:-1.5332
# shape:  torch.Size([1, 3, 4, 4])
# epoch [76/200], loss:-1.4454
# shape:  torch.Size([1, 3, 4, 4])
# epoch [77/200], loss:-1.4197
# shape:  torch.Size([1, 3, 4, 4])
# epoch [78/200], loss:-1.5299
# shape:  torch.Size([1, 3, 4, 4])
# epoch [79/200], loss:-1.5197
# shape:  torch.Size([1, 3, 4, 4])
# epoch [80/200], loss:-1.4879
# shape:  torch.Size([1, 3, 4, 4])
# epoch [81/200], loss:-1.5374
# shape:  torch.Size([1, 3, 4, 4])
# epoch [82/200], loss:-1.4263
# shape:  torch.Size([1, 3, 4, 4])
# epoch [83/200], loss:-1.5647
# shape:  torch.Size([1, 3, 4, 4])
# epoch [84/200], loss:-1.5700
# shape:  torch.Size([1, 3, 4, 4])
# epoch [85/200], loss:-1.4959
# shape:  torch.Size([1, 3, 4, 4])
# epoch [86/200], loss:-1.4424
# shape:  torch.Size([1, 3, 4, 4])
# epoch [87/200], loss:-1.6182
# shape:  torch.Size([1, 3, 4, 4])
# epoch [88/200], loss:-1.7918
# shape:  torch.Size([1, 3, 4, 4])
# epoch [89/200], loss:-1.3911
# shape:  torch.Size([1, 3, 4, 4])
# epoch [90/200], loss:-1.6553
# shape:  torch.Size([1, 3, 4, 4])
# epoch [91/200], loss:-1.4448
# shape:  torch.Size([1, 3, 4, 4])
# epoch [92/200], loss:-1.5960
# shape:  torch.Size([1, 3, 4, 4])
# epoch [93/200], loss:-1.5580
# shape:  torch.Size([1, 3, 4, 4])
# epoch [94/200], loss:-1.4982
# shape:  torch.Size([1, 3, 4, 4])
# epoch [95/200], loss:-1.3978
# shape:  torch.Size([1, 3, 4, 4])
# epoch [96/200], loss:-1.4644
# shape:  torch.Size([1, 3, 4, 4])
# epoch [97/200], loss:-1.6487
# shape:  torch.Size([1, 3, 4, 4])
# epoch [98/200], loss:-1.5962
# shape:  torch.Size([1, 3, 4, 4])
# epoch [99/200], loss:-1.5286
# shape:  torch.Size([1, 3, 4, 4])
# epoch [100/200], loss:-1.6352
# shape:  torch.Size([1, 3, 4, 4])
# epoch [101/200], loss:-1.5880
# shape:  torch.Size([1, 3, 4, 4])
# epoch [102/200], loss:-1.3576
# shape:  torch.Size([1, 3, 4, 4])
# epoch [103/200], loss:-1.5591
# shape:  torch.Size([1, 3, 4, 4])
# epoch [104/200], loss:-1.4093
# shape:  torch.Size([1, 3, 4, 4])
# epoch [105/200], loss:-1.4713
# shape:  torch.Size([1, 3, 4, 4])
# epoch [106/200], loss:-1.5496
# shape:  torch.Size([1, 3, 4, 4])
# epoch [107/200], loss:-1.5408
# shape:  torch.Size([1, 3, 4, 4])
# epoch [108/200], loss:-1.5488
# shape:  torch.Size([1, 3, 4, 4])
# epoch [109/200], loss:-1.6442
# shape:  torch.Size([1, 3, 4, 4])
# epoch [110/200], loss:-1.5838
# shape:  torch.Size([1, 3, 4, 4])
# epoch [111/200], loss:-1.5259
# shape:  torch.Size([1, 3, 4, 4])
# epoch [112/200], loss:-1.5572
# shape:  torch.Size([1, 3, 4, 4])
# epoch [113/200], loss:-1.6790
# shape:  torch.Size([1, 3, 4, 4])
# epoch [114/200], loss:-1.5250
# shape:  torch.Size([1, 3, 4, 4])
# epoch [115/200], loss:-1.6398
# shape:  torch.Size([1, 3, 4, 4])
# epoch [116/200], loss:-1.6401
# shape:  torch.Size([1, 3, 4, 4])
# epoch [117/200], loss:-1.6435
# shape:  torch.Size([1, 3, 4, 4])
# epoch [118/200], loss:-1.5010
# shape:  torch.Size([1, 3, 4, 4])
# epoch [119/200], loss:-1.5630
# shape:  torch.Size([1, 3, 4, 4])
# epoch [120/200], loss:-1.6363
# shape:  torch.Size([1, 3, 4, 4])
# epoch [121/200], loss:-1.5643
# shape:  torch.Size([1, 3, 4, 4])
# epoch [122/200], loss:-1.7751
# shape:  torch.Size([1, 3, 4, 4])
# epoch [123/200], loss:-1.4199
# shape:  torch.Size([1, 3, 4, 4])
# epoch [124/200], loss:-1.4898
# shape:  torch.Size([1, 3, 4, 4])
# epoch [125/200], loss:-1.6529
# shape:  torch.Size([1, 3, 4, 4])
# epoch [126/200], loss:-1.6805
# shape:  torch.Size([1, 3, 4, 4])
# epoch [127/200], loss:-1.6045
# shape:  torch.Size([1, 3, 4, 4])
# epoch [128/200], loss:-1.6698
# shape:  torch.Size([1, 3, 4, 4])
# epoch [129/200], loss:-1.5480
# shape:  torch.Size([1, 3, 4, 4])
# epoch [130/200], loss:-1.4145
# shape:  torch.Size([1, 3, 4, 4])
# epoch [131/200], loss:-1.6368
# shape:  torch.Size([1, 3, 4, 4])
# epoch [132/200], loss:-1.6649
# shape:  torch.Size([1, 3, 4, 4])
# epoch [133/200], loss:-1.5726
# shape:  torch.Size([1, 3, 4, 4])
# epoch [134/200], loss:-1.6287
# shape:  torch.Size([1, 3, 4, 4])
# epoch [135/200], loss:-1.6166
# shape:  torch.Size([1, 3, 4, 4])
# epoch [136/200], loss:-1.4880
# shape:  torch.Size([1, 3, 4, 4])
# epoch [137/200], loss:-1.6604
# shape:  torch.Size([1, 3, 4, 4])
# epoch [138/200], loss:-1.7356
# shape:  torch.Size([1, 3, 4, 4])
# epoch [139/200], loss:-1.5729
# shape:  torch.Size([1, 3, 4, 4])
# epoch [140/200], loss:-1.4721
# shape:  torch.Size([1, 3, 4, 4])
# epoch [141/200], loss:-1.7092
# shape:  torch.Size([1, 3, 4, 4])
# epoch [142/200], loss:-1.5522
# shape:  torch.Size([1, 3, 4, 4])
# epoch [143/200], loss:-1.7606
# shape:  torch.Size([1, 3, 4, 4])
# epoch [144/200], loss:-1.6569
# shape:  torch.Size([1, 3, 4, 4])
# epoch [145/200], loss:-1.6078
# shape:  torch.Size([1, 3, 4, 4])
# epoch [146/200], loss:-1.7345
# shape:  torch.Size([1, 3, 4, 4])
# epoch [147/200], loss:-1.5877
# shape:  torch.Size([1, 3, 4, 4])
# epoch [148/200], loss:-1.6418
# shape:  torch.Size([1, 3, 4, 4])
# epoch [149/200], loss:-1.5349
# shape:  torch.Size([1, 3, 4, 4])
# epoch [150/200], loss:-1.6048
# shape:  torch.Size([1, 3, 4, 4])
# epoch [151/200], loss:-1.6529
# shape:  torch.Size([1, 3, 4, 4])
# epoch [152/200], loss:-1.6638
# shape:  torch.Size([1, 3, 4, 4])
# epoch [153/200], loss:-1.4888
# shape:  torch.Size([1, 3, 4, 4])
# epoch [154/200], loss:-1.6328
# shape:  torch.Size([1, 3, 4, 4])
# epoch [155/200], loss:-1.7199
# shape:  torch.Size([1, 3, 4, 4])
# epoch [156/200], loss:-1.5329
# shape:  torch.Size([1, 3, 4, 4])
# epoch [157/200], loss:-1.6329
# shape:  torch.Size([1, 3, 4, 4])
# epoch [158/200], loss:-1.5339
# shape:  torch.Size([1, 3, 4, 4])
# epoch [159/200], loss:-1.6603
# shape:  torch.Size([1, 3, 4, 4])
# epoch [160/200], loss:-1.7380
# shape:  torch.Size([1, 3, 4, 4])
# epoch [161/200], loss:-1.6428
# shape:  torch.Size([1, 3, 4, 4])
# epoch [162/200], loss:-1.7566
# shape:  torch.Size([1, 3, 4, 4])
# epoch [163/200], loss:-1.6713
# shape:  torch.Size([1, 3, 4, 4])
# epoch [164/200], loss:-1.7128
# shape:  torch.Size([1, 3, 4, 4])
# epoch [165/200], loss:-1.6109
# shape:  torch.Size([1, 3, 4, 4])
# epoch [166/200], loss:-1.7086
# shape:  torch.Size([1, 3, 4, 4])
# epoch [167/200], loss:-1.5840
# shape:  torch.Size([1, 3, 4, 4])
# epoch [168/200], loss:-1.7284
# shape:  torch.Size([1, 3, 4, 4])
# epoch [169/200], loss:-1.7023
# shape:  torch.Size([1, 3, 4, 4])
# epoch [170/200], loss:-1.4660
# shape:  torch.Size([1, 3, 4, 4])
# epoch [171/200], loss:-1.7508
# shape:  torch.Size([1, 3, 4, 4])
# epoch [172/200], loss:-1.5090
# shape:  torch.Size([1, 3, 4, 4])
# epoch [173/200], loss:-1.7959
# shape:  torch.Size([1, 3, 4, 4])
# epoch [174/200], loss:-1.7298
# shape:  torch.Size([1, 3, 4, 4])
# epoch [175/200], loss:-1.5344
# shape:  torch.Size([1, 3, 4, 4])
# epoch [176/200], loss:-1.6037
# shape:  torch.Size([1, 3, 4, 4])
# epoch [177/200], loss:-1.7044
# shape:  torch.Size([1, 3, 4, 4])
# epoch [178/200], loss:-1.8373
# shape:  torch.Size([1, 3, 4, 4])
# epoch [179/200], loss:-1.5480
# shape:  torch.Size([1, 3, 4, 4])
# epoch [180/200], loss:-1.7264
# shape:  torch.Size([1, 3, 4, 4])
# epoch [181/200], loss:-1.8019
# shape:  torch.Size([1, 3, 4, 4])
# epoch [182/200], loss:-1.6261
# shape:  torch.Size([1, 3, 4, 4])
# epoch [183/200], loss:-1.7224
# shape:  torch.Size([1, 3, 4, 4])
# epoch [184/200], loss:-1.7302
# shape:  torch.Size([1, 3, 4, 4])
# epoch [185/200], loss:-1.6180
# shape:  torch.Size([1, 3, 4, 4])
# epoch [186/200], loss:-1.6121
# shape:  torch.Size([1, 3, 4, 4])
# epoch [187/200], loss:-1.6926
# shape:  torch.Size([1, 3, 4, 4])
# epoch [188/200], loss:-1.4871
# shape:  torch.Size([1, 3, 4, 4])
# epoch [189/200], loss:-1.6915
# shape:  torch.Size([1, 3, 4, 4])
# epoch [190/200], loss:-1.5117
# shape:  torch.Size([1, 3, 4, 4])
# epoch [191/200], loss:-1.5644
# shape:  torch.Size([1, 3, 4, 4])
# epoch [192/200], loss:-1.7266
# shape:  torch.Size([1, 3, 4, 4])
# epoch [193/200], loss:-1.6940
# shape:  torch.Size([1, 3, 4, 4])
# epoch [194/200], loss:-1.6717
# shape:  torch.Size([1, 3, 4, 4])
# epoch [195/200], loss:-1.6274
# shape:  torch.Size([1, 3, 4, 4])
# epoch [196/200], loss:-1.6360
# shape:  torch.Size([1, 3, 4, 4])
# epoch [197/200], loss:-1.6864
# shape:  torch.Size([1, 3, 4, 4])
# epoch [198/200], loss:-1.6661
# shape:  torch.Size([1, 3, 4, 4])
# epoch [199/200], loss:-1.7018
# shape:  torch.Size([1, 3, 4, 4])
# epoch [200/200], loss:-1.5757
# shape:  torch.Size([1, 3, 4, 4])

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(12):
    k = uframes[i]
    k.show()
    v = np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32)
    v = torch.from_numpy(v)
#     filename = "less_features/ref_image_new_" + str(i) + ".txt"
#     file = open(filename, 'w')
#     file.write(str(model(v.reshape(1,3,100, 100))[0].detach().numpy()))
#     file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
#1 img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
#2 img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
#3 img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
#3 draw = ImageDraw.Draw(img_blank)
#3 draw.ellipse((35,35,38,38), fill=(255, 0, 0))
#4 img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
#4 draw.ellipse((40,50,43,53), fill=(50, 182, 150))
#5 img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
#5 img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
filename = "less_features/drone_pos_3.txt"
file = open(filename, 'w')
file.write(str(model(pil.reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import random


p=0
class_data = []
while(p<len(uframes)):
    data3=[]
    print(p)
    for i in range(50):
        img = uframes[p]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        temp = model(x_1[i].reshape(1,3,100,100))[1]
        #print(temp)
        class_data.append((list(temp.detach().numpy()[0]),p))
    p+=1
    print(len(class_data))

random.shuffle(class_data)
random.shuffle(class_data)

print("length ", len(class_data))
# Out:
# 0
# 50
# 1
# 100
# 2
# 150
# 3
# 200
# 4
# 250
# 5
# 300
# 6
# 350
# 7
# 400
# 8
# 450
# 9
# 500
# 10
# 550
# 11
# 600
# length  600

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from colorama import init  
import time
import cv2

print(np.shape(uframes[0]))


#z  = np.array(np.transpose(np.asarray(z),(2,0,1)),dtype=np.float32)
# import some data to play with
print("Length of Class data: ", len(class_data))
# Take the first two features. We could avoid this by using a two-dim dataset
X = [(i[0]) for i in class_data]
y = [i[1] for i in class_data]
#print(X,np.shape(X))
#print(y,np.shape(y))
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel='linear', C=C)
clf = clf.fit(X, y)
data3=[]
y3=0

n1 = "\x1b[31m\"Drone Stationary, Tank Firing\"\x1b[0m"
n2 = "\x1b[31m\"Drone Reloading, Tank Firing\"\x1b[0m"
n3 = "\x1b[31m\"Drone Firing, Tank Stationary\"\x1b[0m"
n4 = "\x1b[31m\"Drone Firing, Tank Reloading\"\x1b[0m"
n5 = "\x1b[31m\"Drone Firing, Tank Firing\"\x1b[0m"

names = ['Just Background','Only Tank moving', 'Only Drone Moving', 'Drone stationary, Tank Stationary', 'Drone Stationary, Tank Reloading' ,
         n1, 'Drone reloading, Tank Stationary', 'Drone reloading, Tank Reloading', n2 , n3,n4,n5]

print("Start")

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

for i in range(12):
    #z = cv2.imread('Images_100/0a.png')
    #l = Image.fromarray(z)
#     print("shape of z", np.shape(z),type(z))
#     #l.show()
#     #z  = cv2.resize(z,(100,100))
#     img = uframes[i]
#     print(np.shape(img))
#     img.show()
#     data3.append(np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32))
#     y3 = np.array(data3)
#     x_1 = torch.from_numpy(y3)
# #     random_img = random.choice(x)
# #     print("random", np.shape(random_img),type(random_img))
# #     show = random_img.detach().numpy() * 255
# #     show = np.array(np.transpose(show,(1,2,0)),dtype=np.uint8)
# #     print("show", np.shape(show),type(show))
# #     ms = Image.fromarray(show)
# #     ms.show()
#     temp = model(x_1[i].reshape(1,3,100,100))[1]
#     temp = temp.detach().numpy()
#     img_blank.show()
#     #print(temp)
#     z = clf.predict(temp)
#     print(names[z[0]])
    img = uframes[i]
    print(np.shape(img))
    img.show()
    #ms = Image.fromarray(z)
    #ms.show()
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    temp = model(x_1[i].reshape(1,3,100,100))[1]
    temp = temp.detach().numpy()
    print(temp)
    z = clf.predict(temp)
    print(names[z[0]])
# Out:
# (100, 100, 3)
# Length of Class data:  600
# Start
# (100, 100, 3)
# [[0.3189 1.     0.0784 0.0562 0.4017 0.9993 0.0018 0.4266 1.     0.1751
#   0.4762 0.9991 0.9999 0.9988 0.0001]]
# Just Background
# (100, 100, 3)
# [[0.0119 0.979  0.1682 1.     0.9972 0.9866 0.0004 0.0184 0.9961 0.5853
#   0.0282 0.9982 0.9974 0.9866 0.0063]]
# Only Tank moving
# (100, 100, 3)
# [[0.0001 0.9999 0.0178 0.9893 0.9687 0.9103 0.     0.0001 0.9988 0.9847
#   0.0014 1.     0.8885 0.6093 0.5152]]
# Only Drone Moving
# (100, 100, 3)
# [[0.     0.8268 0.0325 1.     0.9999 0.373  0.     0.     0.7616 0.9981
#   0.     1.     0.3235 0.0635 0.987 ]]
# Drone stationary, Tank Stationary
# (100, 100, 3)
# [[0.2126 0.421  0.0715 1.     0.9999 0.0377 0.0054 0.6141 0.2824 0.9928
#   0.6468 0.9877 0.0151 0.0222 0.9894]]
# Drone Stationary, Tank Reloading
# (100, 100, 3)
# [[0.6149 0.0829 0.0192 1.     0.9972 0.0088 0.0013 1.     0.0334 0.9884
#   0.996  0.9921 0.0504 0.4984 0.5738]]
# "Drone Stationary, Tank Firing"
# (100, 100, 3)
# [[0.9447 0.0393 0.0849 1.     1.     0.0212 0.5588 0.9889 0.0456 0.9182
#   0.9897 0.449  0.443  0.9993 0.1037]]
# Drone reloading, Tank Stationary
# (100, 100, 3)
# [[0.9999 0.3033 0.1863 1.     0.9995 0.0964 0.9919 1.     0.484  0.5345
#   1.     0.0147 0.8199 0.9868 0.0125]]
# Drone reloading, Tank Reloading
# (100, 100, 3)
# [[1.     0.7299 0.442  0.9872 0.958  0.4743 0.8197 1.     0.8766 0.0808
#   1.     0.1822 0.9849 0.9997 0.    ]]
# "Drone Reloading, Tank Firing"
# (100, 100, 3)
# [[0.9999 1.     0.7995 0.9918 0.7748 1.     0.     0.9998 1.     0.0002
#   0.9998 1.     0.9118 0.1922 0.    ]]
# "Drone Firing, Tank Stationary"
# (100, 100, 3)
# [[1.     1.     0.9398 0.5418 0.159  1.     0.     1.     1.     0.
#   1.     1.     0.6243 0.0035 0.    ]]
# "Drone Firing, Tank Reloading"
# (100, 100, 3)
# [[1.     0.9997 0.5168 0.0157 0.0562 0.9988 0.0001 1.     0.9984 0.
#   1.     0.9999 0.5825 0.4688 0.    ]]
# "Drone Firing, Tank Firing"

# %%
print(len(uframes
         ))
# Out:
# 12
