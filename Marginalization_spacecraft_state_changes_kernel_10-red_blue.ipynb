# %% [raw]
# In this code, multiple positions and reloading of drone and tank. Drone: Spacecraft. Reloading State: Going Black.
#
# Drone and Tank reloading: Red and blue
#
# Channels:32
# Output: 15
# CNN kernel: 10
# Maxpool kernel:10

# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random
import cv2
from torchvision import models
from torchsummary import summary

Batch_Size = 50
num_epochs = 200
learning_rate = 1e-5
samples = 20000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
uframes = []
vidcap = cv2.VideoCapture('red_blue.avi')
success,image = vidcap.read()
while success:
    uframes.append(image)   
    success,image = vidcap.read()

# cap = cv2.VideoCapture('video_drone_tank.avi')


# ret, frame = cap.read()

# uframes.append(frame)
# flag = 0
# z = 0
# while(z<30):
#     ret, frame = cap.read()
#     #np_frame = cv2.imread('video', frame) # does not work
#     #np_frame = np.asarray(cv2.GetMat(frame)) # does not work
#     #print(np_frame.shape)
#     for a in uframes:
#         if (np.array(a).any() != None):
#             print("a: ",np.shape(a))
#             print("frame: ",np.shape(a))
#             difference = cv2.subtract(np.array(a), np.array(frame))    
#             result = not np.any(difference)
#             #print("inside for")
#             if result is True:
#                 flag = 1
#                 #print("setting flag")
#                 break
#     if(not flag):
#         #print("appending")
#         uframes.append(frame)
#     z+=1

for i,frame in enumerate(uframes):
    uframes[i] = cv2.resize(frame,(100,100))
    
print(np.shape(uframes[0]))

print("length: ",len(uframes))
for i in range(samples):
    data1.append(np.array(np.transpose(np.asarray(uframes[i % len(uframes)]),(2,0,1)),dtype=np.float32))
    data2.append(np.array(np.transpose(np.asarray(uframes[(i+1) % len(uframes)]),(2,0,1)),dtype=np.float32))



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = '#9b7653')
# img.paste(im1,(5,75),im1)
# img.paste(im1,(10,55),im1)
# img.paste(im1,(25,50),im1)
# img.paste(im2,(75,5),im2)
# img.paste(im2,(60,30),im2)
# img.paste(im2,(90,20),im2)
# img.paste(im3,(75,60),im3)
# img.paste(im3,(60,80),im3)
im_n = np.reshape(img,(100,100,3))
b = np.asarray(im_n)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)

#y0 = np.array(np.transpose(np.asarray(y0),(0,3,1,2)),dtype=np.float32)
#y1 = np.array(np.transpose(np.asarray(y1),(0,3,1,2)),dtype=np.float32)
print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=10, stride=1)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=5)

#         # Convolution 2
#         self.cnn2 = nn.Conv2d(in_channels=16, out_channels=3, kernel_size=5, stride=1, padding=2)
#         self.relu2 = nn.ReLU()

#         # Max pool 2
#         self.maxpool2 = nn.MaxPool2d(kernel_size=5)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(20736, 15)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        #out = self.cnn2(out)
        #out = self.relu2(out)

        # Max pool 2 
        #out = self.maxpool2(out)
        im_out = out
        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return im_out,out
    
model = CNNModel()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x)[1],model(y)[1])
        # ===================backward====================
 
        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    #print("shape: ", np.shape(model(x[0].reshape(1,3,100, 100))[0]))
#     print("x: ", model(x[0].reshape(1,3,100, 100)))
#     print("y:", model(y[0].reshape(1,3,100, 100)))
#     print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# (100, 100, 3)
# length:  264
# (20000, 3, 100, 100)
# epoch [1/200], loss:-2.1247
# epoch [2/200], loss:-1.9084
# epoch [3/200], loss:-2.1884
# epoch [4/200], loss:-2.3018
# epoch [5/200], loss:-2.3977
# epoch [6/200], loss:-2.0267
# epoch [7/200], loss:-2.2489
# epoch [8/200], loss:-2.1903
# epoch [9/200], loss:-2.4030
# epoch [10/200], loss:-2.2894
# epoch [11/200], loss:-2.2488
# epoch [12/200], loss:-2.3682
# epoch [13/200], loss:-2.2332
# epoch [14/200], loss:-2.4677
# epoch [15/200], loss:-2.5757
# epoch [16/200], loss:-2.5031
# epoch [17/200], loss:-2.8116
# epoch [18/200], loss:-2.7045
# epoch [19/200], loss:-3.2637
# epoch [20/200], loss:-2.9658
# epoch [21/200], loss:-3.0951
# epoch [22/200], loss:-2.6908
# epoch [23/200], loss:-3.2652
# epoch [24/200], loss:-3.7916
# epoch [25/200], loss:-3.7687
# epoch [26/200], loss:-3.8816
# epoch [27/200], loss:-4.2823
# epoch [28/200], loss:-3.8500
# epoch [29/200], loss:-4.3024
# epoch [30/200], loss:-4.0268
# epoch [31/200], loss:-4.2815
# epoch [32/200], loss:-4.1469
# epoch [33/200], loss:-4.3252
# epoch [34/200], loss:-3.9937
# epoch [35/200], loss:-4.4251
# epoch [36/200], loss:-4.0130
# epoch [37/200], loss:-4.3686
# epoch [38/200], loss:-4.2597
# epoch [39/200], loss:-4.3873
# epoch [40/200], loss:-3.9421
# epoch [41/200], loss:-4.0672
# epoch [42/200], loss:-4.6401
# epoch [43/200], loss:-4.1229
# epoch [44/200], loss:-4.6991
# epoch [45/200], loss:-4.2038
# epoch [46/200], loss:-4.4612
# epoch [47/200], loss:-3.9538
# epoch [48/200], loss:-4.4243
# epoch [49/200], loss:-4.5016
# epoch [50/200], loss:-4.2617
# epoch [51/200], loss:-4.4427
# epoch [52/200], loss:-4.2960
# epoch [53/200], loss:-4.0654
# epoch [54/200], loss:-4.5136
# epoch [55/200], loss:-4.2010
# epoch [56/200], loss:-4.1525
# epoch [57/200], loss:-4.1572
# epoch [58/200], loss:-4.5510
# epoch [59/200], loss:-4.3097
# epoch [60/200], loss:-4.7158
# epoch [61/200], loss:-4.2415
# epoch [62/200], loss:-4.8668
# epoch [63/200], loss:-5.0718
# epoch [64/200], loss:-4.6090
# epoch [65/200], loss:-4.5018
# epoch [66/200], loss:-4.6762
# epoch [67/200], loss:-4.2077
# epoch [68/200], loss:-4.7575
# epoch [69/200], loss:-4.6853
# epoch [70/200], loss:-4.4199
# epoch [71/200], loss:-4.4436
# epoch [72/200], loss:-4.6604
# epoch [73/200], loss:-4.7826
# epoch [74/200], loss:-4.7341
# epoch [75/200], loss:-4.5745
# epoch [76/200], loss:-4.8477
# epoch [77/200], loss:-4.8694
# epoch [78/200], loss:-4.7393
# epoch [79/200], loss:-4.5160
# epoch [80/200], loss:-5.1061
# epoch [81/200], loss:-4.6873
# epoch [82/200], loss:-4.8630
# epoch [83/200], loss:-4.7454
# epoch [84/200], loss:-4.7150
# epoch [85/200], loss:-4.8384
# epoch [86/200], loss:-4.8929
# epoch [87/200], loss:-4.5924
# epoch [88/200], loss:-4.4547
# epoch [89/200], loss:-4.6191
# epoch [90/200], loss:-4.9680
# epoch [91/200], loss:-5.1386
# epoch [92/200], loss:-4.7963
# epoch [93/200], loss:-4.7833
# epoch [94/200], loss:-4.5802
# epoch [95/200], loss:-4.6477
# epoch [96/200], loss:-4.8704
# epoch [97/200], loss:-4.5982
# epoch [98/200], loss:-4.8279
# epoch [99/200], loss:-4.9195
# epoch [100/200], loss:-4.2838
# epoch [101/200], loss:-4.9055
# epoch [102/200], loss:-4.4099
# epoch [103/200], loss:-4.7785
# epoch [104/200], loss:-4.7913
# epoch [105/200], loss:-4.8491
# epoch [106/200], loss:-4.8571
# epoch [107/200], loss:-4.8294
# epoch [108/200], loss:-4.7804
# epoch [109/200], loss:-4.5043
# epoch [110/200], loss:-4.8378
# epoch [111/200], loss:-4.5276
# epoch [112/200], loss:-4.9206
# epoch [113/200], loss:-4.8120
# epoch [114/200], loss:-4.9230
# epoch [115/200], loss:-4.7604
# epoch [116/200], loss:-4.6356
# epoch [117/200], loss:-4.7773
# epoch [118/200], loss:-4.9944
# epoch [119/200], loss:-4.6809
# epoch [120/200], loss:-4.5823
# epoch [121/200], loss:-5.1761
# epoch [122/200], loss:-4.8174
# epoch [123/200], loss:-4.5849
# epoch [124/200], loss:-4.5245
# epoch [125/200], loss:-5.0072
# epoch [126/200], loss:-4.6860
# epoch [127/200], loss:-4.6436
# epoch [128/200], loss:-4.8075
# epoch [129/200], loss:-4.4285
# epoch [130/200], loss:-4.6784
# epoch [131/200], loss:-4.8340
# epoch [132/200], loss:-4.7840
# epoch [133/200], loss:-4.8859
# epoch [134/200], loss:-4.5682
# epoch [135/200], loss:-4.8144
# epoch [136/200], loss:-4.5312
# epoch [137/200], loss:-4.6180
# epoch [138/200], loss:-4.8401
# epoch [139/200], loss:-4.9822
# epoch [140/200], loss:-4.6890
# epoch [141/200], loss:-4.8384
# epoch [142/200], loss:-4.6725
# epoch [143/200], loss:-4.4484
# epoch [144/200], loss:-4.7549
# epoch [145/200], loss:-4.5386
# epoch [146/200], loss:-4.7297
# epoch [147/200], loss:-4.6246
# epoch [148/200], loss:-4.6476
# epoch [149/200], loss:-4.9009
# epoch [150/200], loss:-4.6883
# epoch [151/200], loss:-4.5333
# epoch [152/200], loss:-4.5984
# epoch [153/200], loss:-4.9578
# epoch [154/200], loss:-4.5318
# epoch [155/200], loss:-4.7124
# epoch [156/200], loss:-5.0760
# epoch [157/200], loss:-4.8615
# epoch [158/200], loss:-5.0035
# epoch [159/200], loss:-5.0665
# epoch [160/200], loss:-4.6572
# epoch [161/200], loss:-4.6872
# epoch [162/200], loss:-4.7676
# epoch [163/200], loss:-4.5686
# epoch [164/200], loss:-4.8129
# epoch [165/200], loss:-4.9155
# epoch [166/200], loss:-4.7874
# epoch [167/200], loss:-4.7107
# epoch [168/200], loss:-4.7311
# epoch [169/200], loss:-4.5020
# epoch [170/200], loss:-4.7621
# epoch [171/200], loss:-4.7331
# epoch [172/200], loss:-4.8529
# epoch [173/200], loss:-4.8653
# epoch [174/200], loss:-4.9938
# epoch [175/200], loss:-4.9862
# epoch [176/200], loss:-4.8344
# epoch [177/200], loss:-4.7477
# epoch [178/200], loss:-4.4873
# epoch [179/200], loss:-4.7277
# epoch [180/200], loss:-4.8863
# epoch [181/200], loss:-5.0891
# epoch [182/200], loss:-4.9001
# epoch [183/200], loss:-4.7906
# epoch [184/200], loss:-4.8867
# epoch [185/200], loss:-4.8856
# epoch [186/200], loss:-4.8053
# epoch [187/200], loss:-4.8347
# epoch [188/200], loss:-4.9750
# epoch [189/200], loss:-4.5343
# epoch [190/200], loss:-4.8267
# epoch [191/200], loss:-4.7521
# epoch [192/200], loss:-4.9567
# epoch [193/200], loss:-4.5801
# epoch [194/200], loss:-4.9948
# epoch [195/200], loss:-4.5965
# epoch [196/200], loss:-4.7188
# epoch [197/200], loss:-4.9833
# epoch [198/200], loss:-4.6120
# epoch [199/200], loss:-4.9911
# epoch [200/200], loss:-4.7730

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

drone_panels={}
tank_panels={}
tank_reloading_panels={}
drone_reloading_panels={}

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

for i in range(64):

    tank_info_panel = i
    #rone_info_panel = i
    #Blank
    img = uframes[1]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Blank: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("Blank: ",val,pos)


    print("**********")
    img = uframes[2]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank_info,pos_tank_info = val_pos(output_tank)
    print("Tank: ",val_tank_info,pos_tank_info)
#     output_drone = output[0][drone_info_panel]
#     val_tank_drone_info,pos_tank_drone_info = val_pos(output_drone)
#     print("Tank: ",val,pos)
    print("**********")

    #Drone
    img = uframes[3]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_drone_info,pos_drone_info = val_pos(output_tank)
    print("Drone: ",val_drone_info,pos_drone_info)
#     output_drone = output[0][drone_info_panel]
#     val_drone_drone_info,pos_drone_drone_info = val_pos(output_drone)
#     print("Drone: ",val,pos)
    
    print("**********")  
    img = uframes[4]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank_reloading_info,pos_tank_reloading_info = val_pos(output_tank)
    print("Tank reloading: ",val_tank_reloading_info,pos_tank_reloading_info)
#     output_drone = output[0][drone_info_panel]
#     val_tank_reloading_drone_info,pos_tank_reloading_drone_info = val_pos(output_drone)
#     print("Tank reloading: ",val,pos)

    print("**********")
    #Drone Reloadingg
    img = uframes[5]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_drone_reloading_info,pos_drone_reloading_info = val_pos(output_tank)
    print("Drone reloading: ",val_drone_reloading_info,pos_drone_reloading_info)
#     output_drone = output[0][drone_info_panel]
#     val_drone_reloading_drone_info,pos_drone_reloading_drone_info = val_pos(output_drone)
#     print("Drone reloading: ",val,pos)

    print("**********")
    #Tank and Drone
    img= uframes[0]
    z = Image.fromarray(img)
    #z.show()
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TD: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("TD: ",val,pos)
    
    print("**********")
    #Tank and Drone reloading
    img= uframes[6]
    z = Image.fromarray(img)
    #z.show()
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TrDr: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("TD: ",val,pos)
    
    print("\nPanel ",i)
    print("\n++++++++++++++++++++++++++++++++++++++++++++\n")
    if val_tank_info > max(val_drone_reloading_info,val_tank_reloading_info,val_drone_info):
        tank_panels[i]=val_tank_info-5
    elif val_drone_info > max(val_drone_reloading_info,val_tank_reloading_info,val_tank_info):
        drone_panels[i]=val_drone_info-5
    elif val_tank_reloading_info > max(val_drone_reloading_info,val_tank_info,val_drone_info):
        tank_reloading_panels[i]=val_tank_reloading_info-5
    elif val_drone_reloading_info > max(val_tank_reloading_info,val_tank_info,val_drone_info):
        drone_reloading_panels[i]=val_drone_reloading_info-2
print(tank_panels)
# Out:
# Blank:  472.6887 (10, 12)
# **********
# Tank:  652.6178 (6, 0)
# **********
# Drone:  672.74744 (10, 9)
# **********
# Tank reloading:  681.10815 (10, 12)
# **********
# Drone reloading:  759.6537 (11, 9)
# **********
# TD:  852.80347 (6, 0)
# **********
# TrDr:  969.10065 (11, 9)
#
# Panel  0
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  514.7163 (16, 15)
# **********
# Tank:  579.5387 (16, 15)
# **********
# Drone:  614.0161 (11, 9)
# **********
# Tank reloading:  679.5204 (5, 0)
# **********
# Drone reloading:  562.8746 (16, 15)
# **********
# TD:  673.03845 (11, 9)
# **********
# TrDr:  727.889 (5, 0)
#
# Panel  1
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  206.75505 (7, 8)
# **********
# Tank:  340.90463 (4, 0)
# **********
# Drone:  359.04752 (11, 10)
# **********
# Tank reloading:  311.69302 (4, 0)
# **********
# Drone reloading:  444.14743 (10, 9)
# **********
# TD:  488.35815 (4, 0)
# **********
# TrDr:  547.98956 (10, 9)
#
# Panel  2
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  509.35992 (1, 0)
# **********
# Tank:  765.15063 (5, 0)
# **********
# Drone:  681.88434 (10, 9)
# **********
# Tank reloading:  564.6892 (1, 0)
# **********
# Drone reloading:  728.2839 (11, 10)
# **********
# TD:  937.7949 (5, 0)
# **********
# TrDr:  783.6281 (11, 10)
#
# Panel  3
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  253.15807 (10, 13)
# **********
# Tank:  404.87842 (6, 1)
# **********
# Drone:  370.44678 (10, 9)
# **********
# Tank reloading:  341.70554 (6, 1)
# **********
# Drone reloading:  511.92737 (10, 10)
# **********
# TD:  513.7934 (6, 1)
# **********
# TrDr:  600.8583 (6, 1)
#
# Panel  4
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  327.78192 (10, 12)
# **********
# Tank:  449.91583 (6, 1)
# **********
# Drone:  431.92972 (11, 9)
# **********
# Tank reloading:  344.39532 (10, 12)
# **********
# Drone reloading:  601.78827 (11, 10)
# **********
# TD:  564.52893 (11, 9)
# **********
# TrDr:  617.8981 (11, 10)
#
# Panel  5
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  237.32094 (8, 9)
# **********
# Tank:  425.3064 (5, 0)
# **********
# Drone:  352.18243 (10, 10)
# **********
# Tank reloading:  340.87924 (6, 0)
# **********
# Drone reloading:  489.05188 (11, 10)
# **********
# TD:  539.9741 (5, 0)
# **********
# TrDr:  592.2697 (11, 10)
#
# Panel  6
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  449.7924 (16, 14)
# **********
# Tank:  629.02124 (5, 0)
# **********
# Drone:  615.65936 (10, 9)
# **********
# Tank reloading:  544.535 (6, 1)
# **********
# Drone reloading:  600.12 (10, 9)
# **********
# TD:  791.969 (5, 0)
# **********
# TrDr:  694.0787 (10, 9)
#
# Panel  7
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  537.76154 (10, 12)
# **********
# Tank:  718.8991 (5, 1)
# **********
# Drone:  659.578 (10, 12)
# **********
# Tank reloading:  760.57837 (4, 0)
# **********
# Drone reloading:  780.8203 (11, 10)
# **********
# TD:  828.7087 (5, 2)
# **********
# TrDr:  1002.3951 (11, 10)
#
# Panel  8
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  155.84898 (2, 7)
# **********
# Tank:  186.28616 (2, 7)
# **********
# Drone:  204.29382 (2, 7)
# **********
# Tank reloading:  259.49957 (5, 1)
# **********
# Drone reloading:  289.08685 (12, 10)
# **********
# TD:  231.09961 (2, 7)
# **********
# TrDr:  392.7846 (5, 1)
#
# Panel  9
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  191.61334 (8, 9)
# **********
# Tank:  207.43541 (8, 9)
# **********
# Drone:  209.40547 (8, 9)
# **********
# Tank reloading:  303.00732 (8, 9)
# **********
# Drone reloading:  328.73618 (10, 9)
# **********
# TD:  226.19705 (8, 9)
# **********
# TrDr:  440.29443 (10, 9)
#
# Panel  10
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  415.02545 (8, 9)
# **********
# Tank:  482.34326 (8, 9)
# **********
# Drone:  471.07535 (8, 9)
# **********
# Tank reloading:  556.8448 (5, 0)
# **********
# Drone reloading:  476.0162 (8, 9)
# **********
# TD:  537.9818 (8, 9)
# **********
# TrDr:  618.23486 (5, 0)
#
# Panel  11
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  216.21016 (17, 14)
# **********
# Tank:  438.41467 (5, 0)
# **********
# Drone:  339.92657 (11, 9)
# **********
# Tank reloading:  349.70154 (5, 0)
# **********
# Drone reloading:  498.77408 (11, 10)
# **********
# TD:  562.81494 (5, 0)
# **********
# TrDr:  632.2794 (11, 10)
#
# Panel  12
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  677.2811 (2, 8)
# **********
# Tank:  789.8063 (5, 1)
# **********
# Drone:  864.82446 (11, 9)
# **********
# Tank reloading:  966.5846 (5, 0)
# **********
# Drone reloading:  823.2667 (11, 10)
# **********
# TD:  961.4939 (11, 9)
# **********
# TrDr:  1112.171 (5, 0)
#
# Panel  13
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  467.22253 (10, 12)
# **********
# Tank:  716.01416 (6, 0)
# **********
# Drone:  639.0311 (10, 10)
# **********
# Tank reloading:  494.18497 (10, 12)
# **********
# Drone reloading:  766.9492 (11, 10)
# **********
# TD:  889.8115 (6, 0)
# **********
# TrDr:  794.73553 (11, 10)
#
# Panel  14
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  470.81653 (3, 9)
# **********
# Tank:  698.6778 (6, 1)
# **********
# Drone:  714.65186 (10, 9)
# **********
# Tank reloading:  829.2191 (5, 0)
# **********
# Drone reloading:  900.8139 (12, 10)
# **********
# TD:  951.57526 (6, 1)
# **********
# TrDr:  1260.8291 (5, 0)
#
# Panel  15
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  353.4859 (3, 8)
# **********
# Tank:  552.89984 (6, 1)
# **********
# Drone:  565.9498 (11, 10)
# **********
# Tank reloading:  557.86975 (6, 0)
# **********
# Drone reloading:  760.0889 (11, 10)
# **********
# TD:  763.39154 (11, 10)
# **********
# TrDr:  965.058 (11, 10)
#
# Panel  16
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  110.92795 (11, 3)
# **********
# Tank:  149.17867 (4, 0)
# **********
# Drone:  174.94008 (11, 10)
# **********
# Tank reloading:  177.80563 (5, 0)
# **********
# Drone reloading:  154.66719 (10, 9)
# **********
# TD:  208.95822 (11, 10)
# **********
# TrDr:  221.41519 (10, 9)
#
# Panel  17
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  203.97733 (10, 12)
# **********
# Tank:  350.66626 (5, 0)
# **********
# Drone:  348.81015 (11, 10)
# **********
# Tank reloading:  274.76187 (4, 1)
# **********
# Drone reloading:  519.22784 (11, 10)
# **********
# TD:  481.33374 (5, 0)
# **********
# TrDr:  588.63293 (11, 10)
#
# Panel  18
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  231.51146 (3, 9)
# **********
# Tank:  298.9303 (5, 0)
# **********
# Drone:  342.15332 (10, 9)
# **********
# Tank reloading:  513.91174 (5, 1)
# **********
# Drone reloading:  392.69373 (11, 9)
# **********
# TD:  415.48648 (10, 9)
# **********
# TrDr:  676.05164 (5, 1)
#
# Panel  19
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  462.6706 (10, 13)
# **********
# Tank:  632.3491 (5, 1)
# **********
# Drone:  597.8523 (10, 13)
# **********
# Tank reloading:  606.1801 (5, 0)
# **********
# Drone reloading:  632.8933 (10, 9)
# **********
# TD:  758.8167 (5, 1)
# **********
# TrDr:  777.9911 (5, 0)
#
# Panel  20
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  127.457146 (2, 8)
# **********
# Tank:  270.98572 (4, 0)
# **********
# Drone:  190.44476 (11, 9)
# **********
# Tank reloading:  311.37488 (5, 0)
# **********
# Drone reloading:  369.67078 (11, 9)
# **********
# TD:  333.71967 (4, 0)
# **********
# TrDr:  553.5333 (11, 9)
#
# Panel  21
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  192.92517 (10, 3)
# **********
# Tank:  250.57683 (5, 0)
# **********
# Drone:  356.20038 (11, 10)
# **********
# Tank reloading:  482.2031 (6, 0)
# **********
# Drone reloading:  395.43253 (10, 9)
# **********
# TD:  421.81696 (11, 10)
# **********
# TrDr:  685.8686 (6, 0)
#
# Panel  22
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  572.8615 (12, 2)
# **********
# Tank:  724.45355 (5, 1)
# **********
# Drone:  750.6469 (10, 9)
# **********
# Tank reloading:  638.187 (12, 2)
# **********
# Drone reloading:  784.4997 (11, 10)
# **********
# TD:  903.80786 (10, 9)
# **********
# TrDr:  851.73596 (11, 10)
#
# Panel  23
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  256.82587 (10, 14)
# **********
# Tank:  413.27417 (5, 1)
# **********
# Drone:  442.93475 (11, 9)
# **********
# Tank reloading:  411.7101 (4, 1)
# **********
# Drone reloading:  496.8344 (11, 10)
# **********
# TD:  597.33435 (5, 1)
# **********
# TrDr:  652.42126 (11, 10)
#
# Panel  24
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  273.11426 (7, 9)
# **********
# Tank:  454.9059 (4, 1)
# **********
# Drone:  423.4776 (10, 10)
# **********
# Tank reloading:  367.96744 (4, 0)
# **********
# Drone reloading:  431.47797 (11, 9)
# **********
# TD:  597.5541 (4, 1)
# **********
# TrDr:  527.43866 (11, 9)
#
# Panel  25
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  320.19543 (17, 14)
# **********
# Tank:  455.10056 (6, 0)
# **********
# Drone:  369.49243 (17, 14)
# **********
# Tank reloading:  360.52094 (17, 14)
# **********
# Drone reloading:  473.34537 (10, 10)
# **********
# TD:  497.22885 (6, 0)
# **********
# TrDr:  512.9159 (10, 10)
#
# Panel  26
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  412.82965 (10, 13)
# **********
# Tank:  484.03424 (10, 13)
# **********
# Drone:  613.6544 (10, 9)
# **********
# Tank reloading:  714.323 (5, 1)
# **********
# Drone reloading:  634.7624 (12, 9)
# **********
# TD:  672.9597 (10, 9)
# **********
# TrDr:  935.2985 (5, 1)
#
# Panel  27
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  283.1952 (9, 11)
# **********
# Tank:  446.23334 (5, 0)
# **********
# Drone:  415.82556 (10, 10)
# **********
# Tank reloading:  292.93457 (9, 11)
# **********
# Drone reloading:  429.81503 (10, 10)
# **********
# TD:  577.17035 (5, 0)
# **********
# TrDr:  439.24164 (10, 10)
#
# Panel  28
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  302.21484 (16, 13)
# **********
# Tank:  373.62543 (5, 0)
# **********
# Drone:  404.5196 (11, 9)
# **********
# Tank reloading:  419.3099 (6, 1)
# **********
# Drone reloading:  580.7529 (10, 9)
# **********
# TD:  467.76276 (11, 9)
# **********
# TrDr:  697.2608 (10, 9)
#
# Panel  29
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  859.2301 (11, 12)
# **********
# Tank:  983.8728 (11, 12)
# **********
# Drone:  1168.0386 (11, 9)
# **********
# Tank reloading:  1064.4894 (6, 0)
# **********
# Drone reloading:  1151.5854 (10, 9)
# **********
# TD:  1284.3889 (11, 9)
# **********
# TrDr:  1356.7107 (10, 9)
#
# Panel  30
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  325.3355 (8, 9)
# **********
# Tank:  434.93347 (6, 0)
# **********
# Drone:  443.4969 (10, 9)
# **********
# Tank reloading:  498.55612 (5, 0)
# **********
# Drone reloading:  515.89264 (10, 9)
# **********
# TD:  554.8796 (10, 9)
# **********
# TrDr:  688.67633 (5, 0)
#
# Panel  31
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  300.3808 (16, 13)
# **********
# Tank:  618.8013 (4, 0)
# **********
# Drone:  526.3293 (10, 9)
# **********
# Tank reloading:  362.70917 (16, 13)
# **********
# Drone reloading:  705.51135 (10, 9)
# **********
# TD:  845.66003 (4, 0)
# **********
# TrDr:  768.5497 (10, 9)
#
# Panel  32
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  501.48163 (16, 14)
# **********
# Tank:  755.8519 (5, 0)
# **********
# Drone:  776.13727 (10, 9)
# **********
# Tank reloading:  769.42755 (4, 1)
# **********
# Drone reloading:  1073.3824 (10, 10)
# **********
# TD:  1024.5557 (10, 9)
# **********
# TrDr:  1341.2025 (10, 10)
#
# Panel  33
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  102.43616 (11, 4)
# **********
# Tank:  159.12924 (5, 0)
# **********
# Drone:  138.97562 (9, 10)
# **********
# Tank reloading:  253.26633 (6, 0)
# **********
# Drone reloading:  190.13007 (11, 10)
# **********
# TD:  190.84772 (5, 0)
# **********
# TrDr:  340.83386 (6, 0)
#
# Panel  34
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  840.7696 (1, 0)
# **********
# Tank:  943.7677 (1, 0)
# **********
# Drone:  998.18 (1, 0)
# **********
# Tank reloading:  972.82434 (5, 1)
# **********
# Drone reloading:  950.0666 (1, 0)
# **********
# TD:  1092.8884 (1, 0)
# **********
# TrDr:  1081.5701 (5, 1)
#
# Panel  35
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  216.95462 (16, 15)
# **********
# Tank:  332.66415 (4, 1)
# **********
# Drone:  317.67178 (11, 10)
# **********
# Tank reloading:  479.11642 (6, 1)
# **********
# Drone reloading:  395.68414 (10, 11)
# **********
# TD:  437.2442 (4, 1)
# **********
# TrDr:  658.1844 (6, 1)
#
# Panel  36
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  313.2572 (10, 12)
# **********
# Tank:  390.31238 (6, 0)
# **********
# Drone:  435.21777 (11, 10)
# **********
# Tank reloading:  395.8225 (5, 1)
# **********
# Drone reloading:  429.87726 (11, 11)
# **********
# TD:  513.99646 (11, 10)
# **********
# TrDr:  514.25934 (11, 11)
#
# Panel  37
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  394.10712 (10, 11)
# **********
# Tank:  468.07202 (10, 11)
# **********
# Drone:  499.61566 (10, 11)
# **********
# Tank reloading:  555.161 (10, 11)
# **********
# Drone reloading:  661.2192 (10, 8)
# **********
# TD:  562.6607 (10, 11)
# **********
# TrDr:  822.84924 (10, 8)
#
# Panel  38
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  345.18304 (11, 12)
# **********
# Tank:  439.3175 (6, 1)
# **********
# Drone:  450.00534 (11, 10)
# **********
# Tank reloading:  754.1139 (6, 2)
# **********
# Drone reloading:  483.80945 (11, 9)
# **********
# TD:  541.60706 (11, 10)
# **********
# TrDr:  892.49084 (6, 2)
#
# Panel  39
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  532.7727 (3, 8)
# **********
# Tank:  652.95886 (4, 0)
# **********
# Drone:  701.07477 (10, 10)
# **********
# Tank reloading:  875.23737 (6, 1)
# **********
# Drone reloading:  972.0132 (10, 9)
# **********
# TD:  818.8648 (4, 0)
# **********
# TrDr:  1314.656 (6, 1)
#
# Panel  40
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  262.55426 (17, 13)
# **********
# Tank:  335.76175 (5, 0)
# **********
# Drone:  384.5195 (11, 9)
# **********
# Tank reloading:  623.3948 (6, 0)
# **********
# Drone reloading:  481.0745 (11, 9)
# **********
# TD:  458.41043 (11, 9)
# **********
# TrDr:  843.4931 (6, 0)
#
# Panel  41
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  537.6317 (10, 11)
# **********
# Tank:  646.4944 (5, 0)
# **********
# Drone:  639.0154 (10, 11)
# **********
# Tank reloading:  612.5243 (10, 11)
# **********
# Drone reloading:  700.58014 (11, 9)
# **********
# TD:  735.6499 (5, 0)
# **********
# TrDr:  775.54297 (11, 9)
#
# Panel  42
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  246.7701 (10, 11)
# **********
# Tank:  309.5874 (6, 0)
# **********
# Drone:  455.38275 (10, 9)
# **********
# Tank reloading:  553.95544 (5, 1)
# **********
# Drone reloading:  496.47534 (11, 9)
# **********
# TD:  513.18115 (10, 9)
# **********
# TrDr:  804.26355 (5, 1)
#
# Panel  43
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  296.49744 (10, 12)
# **********
# Tank:  367.7062 (5, 0)
# **********
# Drone:  391.98105 (10, 11)
# **********
# Tank reloading:  407.10062 (5, 0)
# **********
# Drone reloading:  499.0127 (11, 9)
# **********
# TD:  469.57666 (5, 0)
# **********
# TrDr:  610.1554 (11, 9)
#
# Panel  44
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  338.17682 (11, 3)
# **********
# Tank:  391.23517 (5, 1)
# **********
# Drone:  445.37924 (10, 9)
# **********
# Tank reloading:  479.8725 (5, 1)
# **********
# Drone reloading:  511.47574 (10, 10)
# **********
# TD:  491.7683 (10, 9)
# **********
# TrDr:  652.2578 (5, 1)
#
# Panel  45
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  376.63867 (1, 0)
# **********
# Tank:  539.47766 (5, 0)
# **********
# Drone:  550.6506 (11, 9)
# **********
# Tank reloading:  483.4403 (4, 1)
# **********
# Drone reloading:  754.502 (11, 9)
# **********
# TD:  719.0645 (5, 0)
# **********
# TrDr:  860.3635 (11, 9)
#
# Panel  46
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  254.7789 (11, 13)
# **********
# Tank:  357.64148 (5, 1)
# **********
# Drone:  359.354 (11, 9)
# **********
# Tank reloading:  371.46948 (5, 0)
# **********
# Drone reloading:  427.26532 (12, 9)
# **********
# TD:  466.0285 (11, 9)
# **********
# TrDr:  546.1343 (12, 9)
#
# Panel  47
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  514.0944 (10, 13)
# **********
# Tank:  785.0455 (5, 1)
# **********
# Drone:  707.8651 (10, 10)
# **********
# Tank reloading:  595.44543 (6, 0)
# **********
# Drone reloading:  922.6219 (11, 10)
# **********
# TD:  976.5343 (5, 1)
# **********
# TrDr:  1005.2573 (11, 10)
#
# Panel  48
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  417.18677 (7, 10)
# **********
# Tank:  558.7616 (5, 2)
# **********
# Drone:  525.2583 (11, 9)
# **********
# Tank reloading:  574.1429 (7, 10)
# **********
# Drone reloading:  601.13074 (10, 10)
# **********
# TD:  656.9175 (5, 2)
# **********
# TrDr:  758.0158 (10, 10)
#
# Panel  49
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  216.035 (10, 12)
# **********
# Tank:  369.2934 (5, 0)
# **********
# Drone:  391.6371 (10, 9)
# **********
# Tank reloading:  284.07684 (10, 12)
# **********
# Drone reloading:  508.05872 (11, 9)
# **********
# TD:  545.52576 (5, 0)
# **********
# TrDr:  576.9645 (11, 9)
#
# Panel  50
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  331.30933 (17, 14)
# **********
# Tank:  445.65527 (6, 0)
# **********
# Drone:  461.95752 (11, 10)
# **********
# Tank reloading:  575.18317 (5, 0)
# **********
# Drone reloading:  391.04266 (17, 14)
# **********
# TD:  561.5606 (11, 10)
# **********
# TrDr:  635.7868 (5, 0)
#
# Panel  51
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  508.93304 (9, 11)
# **********
# Tank:  529.193 (9, 11)
# **********
# Drone:  597.07965 (10, 10)
# **********
# Tank reloading:  640.37994 (5, 1)
# **********
# Drone reloading:  548.55493 (9, 11)
# **********
# TD:  608.41284 (10, 10)
# **********
# TrDr:  678.7341 (5, 1)
#
# Panel  52
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  340.75885 (16, 13)
# **********
# Tank:  505.10037 (5, 0)
# **********
# Drone:  541.95703 (11, 9)
# **********
# Tank reloading:  453.6008 (5, 0)
# **********
# Drone reloading:  694.02954 (10, 10)
# **********
# TD:  700.4038 (11, 9)
# **********
# TrDr:  807.547 (10, 10)
#
# Panel  53
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  293.06418 (13, 5)
# **********
# Tank:  468.29825 (5, 1)
# **********
# Drone:  425.37848 (11, 9)
# **********
# Tank reloading:  374.84143 (6, 0)
# **********
# Drone reloading:  525.3534 (11, 10)
# **********
# TD:  587.4564 (5, 1)
# **********
# TrDr:  606.975 (11, 10)
#
# Panel  54
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  0.0 (0, 0)
# **********
# Tank:  0.0 (0, 0)
# **********
# Drone:  0.0 (0, 0)
# **********
# Tank reloading:  0.0 (0, 0)
# **********
# Drone reloading:  0.0 (0, 0)
# **********
# TD:  0.0 (0, 0)
# **********
# TrDr:  0.0 (0, 0)
#
# Panel  55
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  427.7379 (14, 17)
# **********
# Tank:  529.0342 (5, 0)
# **********
# Drone:  492.5432 (14, 17)
# **********
# Tank reloading:  548.60626 (5, 1)
# **********
# Drone reloading:  653.5061 (10, 9)
# **********
# TD:  598.9905 (5, 0)
# **********
# TrDr:  774.83167 (10, 9)
#
# Panel  56
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  140.1916 (11, 13)
# **********
# Tank:  231.51675 (6, 0)
# **********
# Drone:  228.39587 (11, 10)
# **********
# Tank reloading:  369.2284 (6, 1)
# **********
# Drone reloading:  377.99078 (11, 9)
# **********
# TD:  311.0617 (6, 0)
# **********
# TrDr:  606.83795 (11, 9)
#
# Panel  57
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  0.0 (0, 0)
# **********
# Tank:  0.0 (0, 0)
# **********
# Drone:  0.0 (0, 0)
# **********
# Tank reloading:  0.0 (0, 0)
# **********
# Drone reloading:  0.0 (0, 0)
# **********
# TD:  0.0 (0, 0)
# **********
# TrDr:  0.0 (0, 0)
#
# Panel  58
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  652.9161 (10, 12)
# **********
# Tank:  848.31433 (5, 1)
# **********
# Drone:  888.9797 (11, 10)
# **********
# Tank reloading:  847.27045 (6, 0)
# **********
# Drone reloading:  1015.6228 (10, 10)
# **********
# TD:  1077.1493 (11, 10)
# **********
# TrDr:  1211.7899 (10, 10)
#
# Panel  59
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  655.4887 (10, 12)
# **********
# Tank:  814.08276 (10, 12)
# **********
# Drone:  727.3799 (10, 12)
# **********
# Tank reloading:  750.6469 (10, 12)
# **********
# Drone reloading:  924.3813 (10, 9)
# **********
# TD:  886.3955 (10, 12)
# **********
# TrDr:  1018.5949 (10, 9)
#
# Panel  60
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  0.0 (0, 0)
# **********
# Tank:  0.0 (0, 0)
# **********
# Drone:  0.0 (0, 0)
# **********
# Tank reloading:  0.0 (0, 0)
# **********
# Drone reloading:  0.0 (0, 0)
# **********
# TD:  0.0 (0, 0)
# **********
# TrDr:  0.0 (0, 0)
#
# Panel  61
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  347.13757 (10, 12)
# **********
# Tank:  403.34787 (4, 0)
# **********
# Drone:  400.32184 (10, 12)
# **********
# Tank reloading:  411.2121 (6, 1)
# **********
# Drone reloading:  392.078 (10, 12)
# **********
# TD:  456.40582 (4, 0)
# **********
# TrDr:  456.00494 (6, 1)
#
# Panel  62
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  110.818634 (9, 13)
# **********
# Tank:  202.40628 (4, 0)
# **********
# Drone:  143.1712 (9, 13)
# **********
# Tank reloading:  206.3667 (5, 0)
# **********
# Drone reloading:  340.62582 (11, 11)
# **********
# TD:  239.61261 (4, 0)
# **********
# TrDr:  435.40375 (5, 0)
#
# Panel  63
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# {3: 760.150634765625, 7: 624.021240234375, 25: 449.9059143066406, 28: 441.23333740234375}

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for j in range(len(list(drone_panels))):
    
    tank_info_panel = list(tank_panels)[0]
    drone_info_panel = list(drone_panels)[j]
    tankr_info_panel = 19#list(tank_reloading_panels)[j]
    droner_info_panel = 9#list(drone_reloading_panels)[j] #12

    #print(tankr_info_panel,tank_reloading_panels[tankr_info_panel])

    tank_threshold= tank_panels[tank_info_panel]
    tankr_threshold= tank_reloading_panels[tankr_info_panel]
    drone_threshold= drone_panels[drone_info_panel]
    droner_threshold= drone_reloading_panels[droner_info_panel]

    def val_pos(array):
        value = np.sum(array)
        position = np.unravel_index(np.argmax(array),array.shape)
        return value,position
    dronec=[]
    tankc=[]
    tankr=[]
    droner=[]
    #Blank
    for i in range(50):
        #x = cv2.imread(r"C:\Users\darshan19\Desktop\AoI\CNN\Images1\0b.png",-1)
        #x = cv2.resize(x,(100,100))
        img = uframes[i]
        #print(np.shape(img))
        # = Image.fromarray(img)
        #z.show()
        data3=[]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        #print(np.shape(x_1))
        output = model(x_1.reshape(1,3,100, 100))[0].detach().numpy()
        output_tank = output[0][tank_info_panel]
        val_tank,pos_tank = val_pos(output_tank)
        output_tankr = output[0][tankr_info_panel]
        val_tankr,pos_tankr = val_pos(output_tankr)
        print(i)
        output_drone = output[0][drone_info_panel]
        val_drone,pos_drone = val_pos(output_drone)
        output_droner = output[0][droner_info_panel]
        val_droner,pos_droner = val_pos(output_droner)

        if val_tank>tank_threshold:
    #         print("tank present")
    #         print("Tank info: ",val_tank,pos_tank)
            tankc.append(pos_tank)
        if val_drone>drone_threshold:
            print("drone present")
            print("Drone info: ",val_drone,pos_drone)
            dronec.append(pos_drone)
        if val_tankr>tankr_threshold:
#             print("tank reloading present")
#             print("Tank info: ",val_tank,pos_tank)
            tankr.append(pos_tankr)
        if val_droner>droner_threshold:
#             print("drone reloading present")
#             print("Drone info: ",val_droner,pos_droner)
            dronec.append(pos_drone)
    print("\n")
    print(list(drone_panels)[j])
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n\n")
# Out:
# 0
# drone present
# Drone info:  1284.3889 (11, 9)
# 1
# 2
# 3
# drone present
# Drone info:  1168.0386 (11, 9)
# 4
# 5
# 6
# drone present
# Drone info:  1356.7107 (10, 9)
# 7
# drone present
# Drone info:  1279.9006 (12, 10)
# 8
# drone present
# Drone info:  1301.0339 (13, 9)
# 9
# drone present
# Drone info:  1209.3318 (13, 7)
# 10
# drone present
# Drone info:  1288.7072 (12, 6)
# 11
# drone present
# Drone info:  1322.9453 (11, 4)
# 12
# drone present
# Drone info:  1306.6409 (8, 6)
# 13
# drone present
# Drone info:  1254.8208 (11, 12)
# 14
# drone present
# Drone info:  1328.2712 (8, 8)
# 15
# drone present
# Drone info:  1288.4353 (9, 8)
# 16
# drone present
# Drone info:  1350.2012 (11, 9)
# 17
# drone present
# Drone info:  1350.6144 (12, 10)
# 18
# drone present
# Drone info:  1347.4784 (13, 9)
# 19
# drone present
# Drone info:  1251.5955 (13, 7)
# 20
# drone present
# Drone info:  1295.9565 (12, 6)
# 21
# drone present
# Drone info:  1332.9248 (11, 4)
# 22
# drone present
# Drone info:  1170.3162 (11, 12)
# 23
# 24
# drone present
# Drone info:  1399.1658 (10, 4)
# 25
# drone present
# Drone info:  1294.8607 (8, 6)
# 26
# drone present
# Drone info:  1265.8264 (11, 12)
# 27
# drone present
# Drone info:  1360.0955 (8, 8)
# 28
# drone present
# Drone info:  1263.1233 (9, 8)
# 29
# drone present
# Drone info:  1343.7637 (11, 9)
# 30
# 31
# drone present
# Drone info:  1341.7068 (12, 10)
# 32
# drone present
# Drone info:  1321.2681 (13, 9)
# 33
# drone present
# Drone info:  1239.5706 (13, 7)
# 34
# drone present
# Drone info:  1293.4415 (12, 6)
# 35
# drone present
# Drone info:  1335.1204 (11, 4)
# 36
# drone present
# Drone info:  1296.9578 (8, 6)
# 37
# drone present
# Drone info:  1295.1162 (11, 12)
# 38
# drone present
# Drone info:  1366.4229 (8, 8)
# 39
# drone present
# Drone info:  1260.8914 (9, 8)
# 40
# drone present
# Drone info:  1335.5579 (10, 9)
# 41
# 42
# drone present
# Drone info:  1229.8833 (6, 4)
# 43
# 44
# drone present
# Drone info:  1500.9825 (10, 9)
# 45
# drone present
# Drone info:  1336.9873 (12, 10)
# 46
# drone present
# Drone info:  1336.666 (13, 9)
# 47
# drone present
# Drone info:  1251.3486 (13, 7)
# 48
# drone present
# Drone info:  1322.7672 (12, 6)
# 49
# drone present
# Drone info:  1336.7441 (11, 4)
#
#
# 30
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# drone present
# Drone info:  1092.8884 (1, 0)
# 1
# 2
# 3
# drone present
# Drone info:  998.18 (1, 0)
# 4
# 5
# 6
# drone present
# Drone info:  1081.5701 (5, 1)
# 7
# drone present
# Drone info:  1131.5132 (12, 9)
# 8
# drone present
# Drone info:  1098.7295 (1, 0)
# 9
# drone present
# Drone info:  1076.0458 (5, 0)
# 10
# drone present
# Drone info:  1164.1887 (12, 5)
# 11
# drone present
# Drone info:  1116.5238 (11, 4)
# 12
# drone present
# Drone info:  1076.2522 (5, 0)
# 13
# drone present
# Drone info:  1109.1887 (1, 0)
# 14
# drone present
# Drone info:  1168.3647 (8, 9)
# 15
# drone present
# Drone info:  1154.5901 (8, 8)
# 16
# drone present
# Drone info:  1184.2102 (5, 1)
# 17
# drone present
# Drone info:  1177.5322 (12, 9)
# 18
# drone present
# Drone info:  1156.0388 (1, 0)
# 19
# drone present
# Drone info:  1089.7954 (5, 1)
# 20
# drone present
# Drone info:  1190.0989 (12, 5)
# 21
# drone present
# Drone info:  1109.2737 (11, 4)
# 22
# drone present
# Drone info:  994.38416 (5, 3)
# 23
# 24
# drone present
# Drone info:  1085.9529 (5, 3)
# 25
# drone present
# Drone info:  1140.656 (5, 1)
# 26
# drone present
# Drone info:  1123.7129 (1, 0)
# 27
# drone present
# Drone info:  1157.074 (8, 9)
# 28
# drone present
# Drone info:  1148.6293 (8, 8)
# 29
# drone present
# Drone info:  1180.2971 (1, 0)
# 30
# 31
# drone present
# Drone info:  1166.718 (12, 9)
# 32
# drone present
# Drone info:  1123.7996 (1, 0)
# 33
# drone present
# Drone info:  1112.8223 (5, 2)
# 34
# drone present
# Drone info:  1200.1667 (12, 5)
# 35
# drone present
# Drone info:  1103.7249 (11, 4)
# 36
# drone present
# Drone info:  1135.9792 (5, 3)
# 37
# drone present
# Drone info:  1158.5254 (1, 0)
# 38
# drone present
# Drone info:  1146.7 (8, 9)
# 39
# drone present
# Drone info:  1149.1993 (5, 3)
# 40
# drone present
# Drone info:  1195.0426 (1, 0)
# 41
# drone present
# Drone info:  1023.9061 (1, 0)
# 42
# 43
# 44
# drone present
# Drone info:  1115.7025 (5, 5)
# 45
# drone present
# Drone info:  1162.0052 (12, 9)
# 46
# drone present
# Drone info:  1126.2671 (1, 0)
# 47
# drone present
# Drone info:  1094.79 (1, 0)
# 48
# drone present
# Drone info:  1221.864 (12, 5)
# 49
# drone present
# Drone info:  1090.3474 (11, 4)
#
#
# 35
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# drone present
# Drone info:  513.99646 (11, 10)
# 1
# 2
# 3
# drone present
# Drone info:  435.21777 (11, 10)
# 4
# 5
# 6
# drone present
# Drone info:  514.25934 (11, 11)
# 7
# drone present
# Drone info:  538.12476 (12, 9)
# 8
# drone present
# Drone info:  555.5243 (13, 8)
# 9
# drone present
# Drone info:  528.3657 (13, 6)
# 10
# drone present
# Drone info:  538.97375 (12, 5)
# 11
# drone present
# Drone info:  516.0388 (11, 5)
# 12
# drone present
# Drone info:  523.7379 (5, 0)
# 13
# drone present
# Drone info:  517.82294 (5, 0)
# 14
# drone present
# Drone info:  611.9546 (8, 8)
# 15
# drone present
# Drone info:  528.1865 (5, 1)
# 16
# drone present
# Drone info:  567.6168 (11, 10)
# 17
# drone present
# Drone info:  569.26 (12, 9)
# 18
# drone present
# Drone info:  557.5953 (13, 8)
# 19
# drone present
# Drone info:  551.83936 (13, 6)
# 20
# drone present
# Drone info:  579.30164 (12, 5)
# 21
# drone present
# Drone info:  543.8219 (11, 5)
# 22
# drone present
# Drone info:  467.36166 (5, 1)
# 23
# 24
# drone present
# Drone info:  563.33875 (5, 1)
# 25
# drone present
# Drone info:  538.8887 (5, 2)
# 26
# drone present
# Drone info:  522.0169 (5, 2)
# 27
# drone present
# Drone info:  578.4564 (8, 8)
# 28
# drone present
# Drone info:  518.10095 (5, 2)
# 29
# drone present
# Drone info:  536.9617 (11, 10)
# 30
# 31
# drone present
# Drone info:  606.86774 (12, 9)
# 32
# drone present
# Drone info:  575.6327 (13, 8)
# 33
# drone present
# Drone info:  566.14435 (13, 6)
# 34
# drone present
# Drone info:  589.35443 (12, 5)
# 35
# drone present
# Drone info:  529.53064 (11, 5)
# 36
# drone present
# Drone info:  525.39716 (5, 3)
# 37
# drone present
# Drone info:  520.3103 (5, 3)
# 38
# drone present
# Drone info:  587.8431 (8, 8)
# 39
# drone present
# Drone info:  531.24207 (5, 3)
# 40
# drone present
# Drone info:  567.7693 (11, 10)
# 41
# drone present
# Drone info:  431.9167 (5, 4)
# 42
# drone present
# Drone info:  473.61395 (5, 3)
# 43
# drone present
# Drone info:  447.4986 (11, 9)
# 44
# drone present
# Drone info:  599.4108 (5, 3)
# 45
# drone present
# Drone info:  567.07733 (12, 9)
# 46
# drone present
# Drone info:  550.24286 (13, 8)
# 47
# drone present
# Drone info:  520.2999 (13, 6)
# 48
# drone present
# Drone info:  598.42236 (12, 5)
# 49
# drone present
# Drone info:  551.93176 (11, 5)
#
#
# 37
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
img = uframes[41]
z = Image.fromarray(img)
z.show()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

tank_info_panel = 29# --done:7,9,16,21
drone_info_panel = 5 #8,14,27,28
tankr_info_panel = 11#,12,13,15,17,19,20,23 --done: 4,6,10
droner_info_panel = 30
tank_threshold= 2475 #--done: 3020,1150,2775,958
tankr_threshold= 1260#,2970,2175,1940,665,1910,1254,2200 -- done: 1025,2440,1480
drone_threshold= 2625 #896,2785,1925,2485
droner_threshold= 1090

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position
dronec=[]
tankc=[]
tankr=[]
droner=[]
#Blank
for i in range(50):
    #x = cv2.imread(r"C:\Users\darshan19\Desktop\AoI\CNN\Images1\0b.png",-1)
    #x = cv2.resize(x,(100,100))
    img = uframes[i]
    #print(np.shape(img))
    # = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    #print(np.shape(x_1))
    output = model(x_1.reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank,pos_tank = val_pos(output_tank)
    output_tankr = output[0][tankr_info_panel]
    val_tankr,pos_tankr = val_pos(output_tankr)
    print(i)
    output_drone = output[0][drone_info_panel]
    val_drone,pos_drone = val_pos(output_drone)
    output_droner = output[0][droner_info_panel]
    val_droner,pos_droner = val_pos(output_droner)
    
    if val_tank>tank_threshold:
        print("tank present")
        print("Tank info: ",val_tank,pos_tank)
        tankc.append(pos_tank)
    if val_drone>drone_threshold:
        print("drone present")
        print("Drone info: ",val_drone,pos_drone)
        dronec.append(pos_drone)
    if val_tankr>tankr_threshold:
        print("tank reloading present")
        print("Tank info: ",val_tank,pos_tank)
        tankr.append(pos_tankr)
    if val_droner>droner_threshold:
        print("drone reloading present")
        print("Drone info: ",val_droner,pos_droner)
        dronec.append(pos_drone)
# Out:
# 0
# tank present
# Tank info:  2846.479 (4, 0)
# drone present
# Drone info:  3023.8042 (5, 0)
# drone reloading present
# Drone info:  1275.1257 (10, 10)
# 1
# 2
# tank present
# Tank info:  2485.3955 (4, 0)
# 3
# drone present
# Drone info:  2633.3057 (8, 9)
# 4
# tank reloading present
# Tank info:  2353.2332 (5, 2)
# 5
# drone reloading present
# Drone info:  1090.4395 (11, 9)
# 6
# tank present
# Tank info:  2759.4927 (5, 2)
# drone present
# Drone info:  2856.3335 (6, 0)
# tank reloading present
# Tank info:  2759.4927 (5, 2)
# drone reloading present
# Drone info:  1329.6665 (11, 9)
# 7
# tank present
# Tank info:  2949.1938 (4, 0)
# drone present
# Drone info:  3039.2358 (5, 0)
# drone reloading present
# Drone info:  1358.6427 (5, 0)
# 8
# tank present
# Tank info:  2871.037 (5, 1)
# drone present
# Drone info:  2959.031 (5, 0)
# drone reloading present
# Drone info:  1360.76 (5, 0)
# 9
# tank present
# Tank info:  2737.7136 (4, 0)
# drone present
# Drone info:  2921.4033 (5, 0)
# drone reloading present
# Drone info:  1286.6704 (12, 7)
# 10
# tank present
# Tank info:  2879.8982 (5, 2)
# drone present
# Drone info:  2990.3677 (5, 0)
# drone reloading present
# Drone info:  1405.5173 (5, 1)
# 11
# tank present
# Tank info:  2843.7002 (9, 4)
# drone present
# Drone info:  3046.4954 (5, 0)
# drone reloading present
# Drone info:  1332.3198 (5, 1)
# 12
# tank present
# Tank info:  2904.941 (4, 1)
# drone present
# Drone info:  3047.713 (5, 1)
# drone reloading present
# Drone info:  1355.7212 (9, 5)
# 13
# tank present
# Tank info:  2875.4805 (5, 2)
# drone present
# Drone info:  3133.4927 (5, 1)
# drone reloading present
# Drone info:  1354.0562 (6, 1)
# 14
# tank present
# Tank info:  2877.4224 (4, 1)
# drone present
# Drone info:  3054.0913 (5, 1)
# drone reloading present
# Drone info:  1392.7385 (6, 1)
# 15
# tank present
# Tank info:  2900.5513 (5, 2)
# drone present
# Drone info:  3074.2966 (5, 1)
# drone reloading present
# Drone info:  1370.3789 (9, 9)
# 16
# tank present
# Tank info:  2926.3074 (4, 1)
# drone present
# Drone info:  3169.9053 (5, 1)
# drone reloading present
# Drone info:  1366.2498 (10, 10)
# 17
# tank present
# Tank info:  3080.879 (4, 1)
# drone present
# Drone info:  3191.3972 (5, 1)
# drone reloading present
# Drone info:  1434.1799 (5, 2)
# 18
# tank present
# Tank info:  2859.2617 (5, 3)
# drone present
# Drone info:  3094.9526 (5, 1)
# drone reloading present
# Drone info:  1414.5256 (5, 2)
# 19
# tank present
# Tank info:  2743.6592 (4, 2)
# drone present
# Drone info:  2992.9165 (5, 1)
# drone reloading present
# Drone info:  1301.8118 (12, 7)
# 20
# tank present
# Tank info:  2851.064 (4, 2)
# drone present
# Drone info:  3021.2246 (5, 2)
# drone reloading present
# Drone info:  1419.6354 (5, 2)
# 21
# tank present
# Tank info:  2907.5198 (5, 3)
# drone present
# Drone info:  3080.7854 (5, 2)
# drone reloading present
# Drone info:  1350.5675 (5, 2)
# 22
# drone present
# Drone info:  2708.2646 (6, 2)
# tank reloading present
# Tank info:  2390.0425 (5, 4)
# drone reloading present
# Drone info:  1171.9366 (5, 2)
# 23
# 24
# tank present
# Tank info:  2680.2952 (5, 4)
# drone present
# Drone info:  2928.9644 (6, 2)
# tank reloading present
# Tank info:  2680.2952 (5, 4)
# drone reloading present
# Drone info:  1340.765 (5, 2)
# 25
# tank present
# Tank info:  2902.9688 (5, 3)
# drone present
# Drone info:  3063.5276 (5, 2)
# drone reloading present
# Drone info:  1399.551 (9, 5)
# 26
# tank present
# Tank info:  2935.602 (4, 3)
# drone present
# Drone info:  3173.6763 (5, 2)
# drone reloading present
# Drone info:  1388.2 (5, 2)
# 27
# tank present
# Tank info:  2950.4106 (4, 2)
# drone present
# Drone info:  3080.3027 (5, 2)
# drone reloading present
# Drone info:  1386.4453 (6, 3)
# 28
# tank present
# Tank info:  2890.21 (5, 4)
# drone present
# Drone info:  3073.7153 (5, 2)
# drone reloading present
# Drone info:  1340.2583 (9, 9)
# 29
# tank present
# Tank info:  2851.9148 (5, 4)
# drone present
# Drone info:  3189.4307 (5, 2)
# drone reloading present
# Drone info:  1381.7023 (6, 3)
# 30
# 31
# tank present
# Tank info:  2967.2405 (4, 3)
# drone present
# Drone info:  3130.7627 (5, 3)
# drone reloading present
# Drone info:  1401.7319 (5, 3)
# 32
# tank present
# Tank info:  2852.9092 (5, 4)
# drone present
# Drone info:  3089.027 (5, 3)
# drone reloading present
# Drone info:  1372.0518 (12, 8)
# 33
# tank present
# Tank info:  2749.0784 (4, 3)
# drone present
# Drone info:  2981.2646 (5, 3)
# drone reloading present
# Drone info:  1325.2756 (12, 7)
# 34
# tank present
# Tank info:  2894.3604 (4, 3)
# drone present
# Drone info:  3032.1746 (5, 3)
# drone reloading present
# Drone info:  1444.4993 (5, 3)
# 35
# tank present
# Tank info:  2956.1138 (5, 4)
# drone present
# Drone info:  3115.7021 (5, 3)
# drone reloading present
# Drone info:  1345.8157 (6, 4)
# 36
# tank present
# Tank info:  2942.1743 (4, 4)
# drone present
# Drone info:  3104.212 (5, 3)
# drone reloading present
# Drone info:  1385.6589 (9, 5)
# 37
# tank present
# Tank info:  2898.6062 (5, 5)
# drone present
# Drone info:  3172.46 (5, 3)
# drone reloading present
# Drone info:  1409.82 (5, 4)
# 38
# tank present
# Tank info:  2854.48 (5, 5)
# drone present
# Drone info:  3041.777 (5, 3)
# drone reloading present
# Drone info:  1368.3254 (6, 4)
# 39
# tank present
# Tank info:  2871.6025 (4, 4)
# drone present
# Drone info:  3061.8157 (5, 4)
# drone reloading present
# Drone info:  1300.6022 (9, 9)
# 40
# tank present
# Tank info:  2932.5715 (9, 9)
# drone present
# Drone info:  3159.3413 (5, 4)
# drone reloading present
# Drone info:  1415.2004 (5, 4)
# 41
# tank present
# Tank info:  2514.5425 (5, 5)
# drone present
# Drone info:  2758.1794 (5, 4)
# drone reloading present
# Drone info:  1157.5659 (5, 4)
# 42
# drone present
# Drone info:  2698.4463 (5, 5)
# tank reloading present
# Tank info:  2385.7585 (5, 6)
# drone reloading present
# Drone info:  1162.8682 (5, 4)
# 43
# drone reloading present
# Drone info:  1108.6926 (11, 9)
# 44
# tank present
# Tank info:  2792.654 (5, 6)
# drone present
# Drone info:  2959.5137 (6, 4)
# tank reloading present
# Tank info:  2792.654 (5, 6)
# drone reloading present
# Drone info:  1435.9556 (11, 9)
# 45
# tank present
# Tank info:  3022.4531 (4, 4)
# drone present
# Drone info:  3156.3489 (5, 4)
# drone reloading present
# Drone info:  1449.1588 (6, 4)
# 46
# tank present
# Tank info:  2873.0027 (5, 5)
# drone present
# Drone info:  3087.476 (5, 4)
# drone reloading present
# Drone info:  1376.9872 (12, 8)
# 47
# tank present
# Tank info:  2785.3972 (4, 5)
# drone present
# Drone info:  3020.1306 (5, 4)
# drone reloading present
# Drone info:  1325.0703 (12, 7)
# 48
# tank present
# Tank info:  2849.8708 (4, 5)
# drone present
# Drone info:  3028.788 (5, 4)
# drone reloading present
# Drone info:  1435.5735 (5, 5)
# 49
# tank present
# Tank info:  2853.299 (5, 6)
# drone present
# Drone info:  3084.8262 (5, 5)
# drone reloading present
# Drone info:  1324.9465 (5, 5)

# %%
img = uframes[6]
z = Image.fromarray(img)
z.show()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)
import time
for i in range(40):
    img = uframes[i]
    #print(np.shape(img))
    z = Image.fromarray(img)
    z.show()
    time.sleep(5)

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)


def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

for i in range(32):

    tank_info_panel = i
    drone_info_panel = i
    #Blank
    img = Image.open("spacecraft/0blank.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Blank: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Blank: ",val,pos)


    
    img = Image.open("spacecraft/0tank.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Tank: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Tank: ",val,pos)


    #Drone

    img = Image.open("spacecraft/0drone.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Drone: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Drone: ",val,pos)
    
        
    img = Image.open("spacecraft/0tank_reloading.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Tank reloading: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Tank reloading: ",val,pos)


    #Drone

    img = Image.open("spacecraft/0drone_reloading.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Drone reloading: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Drone reloading: ",val,pos)


    #Tank and Drone
    img = Image.open("spacecraft/0.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TD: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("TD: ",val,pos)
    
    print("done ",i)
    print("++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# Blank:  6030.4375 (11, 2)
# Blank:  6030.4375 (11, 2)
# Tank:  6313.0186 (6, 0)
# Tank:  6313.0186 (6, 0)
# Drone:  6352.264 (10, 10)
# Drone:  6352.264 (10, 10)
# Tank reloading:  6397.289 (5, 1)
# Tank reloading:  6397.289 (5, 1)
# Drone reloading:  6365.005 (11, 9)
# Drone reloading:  6365.005 (11, 9)
# TD:  6710.33 (11, 10)
# TD:  6710.33 (11, 10)
# done  0
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  7292.926 (9, 12)
# Blank:  7292.926 (9, 12)
# Tank:  7563.21 (9, 12)
# Tank:  7563.21 (9, 12)
# Drone:  7634.428 (9, 12)
# Drone:  7634.428 (9, 12)
# Tank reloading:  7727.736 (6, 0)
# Tank reloading:  7727.736 (6, 0)
# Drone reloading:  7651.0894 (10, 9)
# Drone reloading:  7651.0894 (10, 9)
# TD:  7923.5293 (10, 11)
# TD:  7923.5293 (10, 11)
# done  1
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  91.698265 (5, 0)
# Tank:  91.698265 (5, 0)
# Drone:  24.079773 (10, 9)
# Drone:  24.079773 (10, 9)
# Tank reloading:  99.876816 (5, 2)
# Tank reloading:  99.876816 (5, 2)
# Drone reloading:  105.821335 (10, 9)
# Drone reloading:  105.821335 (10, 9)
# TD:  240.94351 (5, 0)
# TD:  240.94351 (5, 0)
# done  2
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  24.783487 (7, 9)
# Blank:  24.783487 (7, 9)
# Tank:  112.870514 (5, 1)
# Tank:  112.870514 (5, 1)
# Drone:  34.009605 (7, 9)
# Drone:  34.009605 (7, 9)
# Tank reloading:  54.76466 (5, 1)
# Tank reloading:  54.76466 (5, 1)
# Drone reloading:  24.783487 (7, 9)
# Drone reloading:  24.783487 (7, 9)
# TD:  184.71616 (11, 11)
# TD:  184.71616 (11, 11)
# done  3
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  8995.51 (13, 5)
# Blank:  8995.51 (13, 5)
# Tank:  9250.804 (4, 0)
# Tank:  9250.804 (4, 0)
# Drone:  9275.936 (10, 10)
# Drone:  9275.936 (10, 10)
# Tank reloading:  9277.022 (5, 0)
# Tank reloading:  9277.022 (5, 0)
# Drone reloading:  9214.348 (11, 10)
# Drone reloading:  9214.348 (11, 10)
# TD:  9599.721 (11, 10)
# TD:  9599.721 (11, 10)
# done  4
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  7749.788 (10, 3)
# Blank:  7749.788 (10, 3)
# Tank:  8085.9336 (4, 1)
# Tank:  8085.9336 (4, 1)
# Drone:  8178.285 (11, 9)
# Drone:  8178.285 (11, 9)
# Tank reloading:  8279.332 (5, 1)
# Tank reloading:  8279.332 (5, 1)
# Drone reloading:  8110.3154 (10, 10)
# Drone reloading:  8110.3154 (10, 10)
# TD:  8591.169 (10, 9)
# TD:  8591.169 (10, 9)
# done  5
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  3850.3618 (2, 8)
# Blank:  3850.3618 (2, 8)
# Tank:  4173.1846 (6, 0)
# Tank:  4173.1846 (6, 0)
# Drone:  4192.449 (10, 10)
# Drone:  4192.449 (10, 10)
# Tank reloading:  4362.8086 (6, 0)
# Tank reloading:  4362.8086 (6, 0)
# Drone reloading:  4229.2246 (11, 10)
# Drone reloading:  4229.2246 (11, 10)
# TD:  4599.176 (10, 10)
# TD:  4599.176 (10, 10)
# done  6
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  7423.867 (1, 1)
# Blank:  7423.867 (1, 1)
# Tank:  7631.924 (5, 1)
# Tank:  7631.924 (5, 1)
# Drone:  7731.4097 (10, 10)
# Drone:  7731.4097 (10, 10)
# Tank reloading:  7777.064 (5, 0)
# Tank reloading:  7777.064 (5, 0)
# Drone reloading:  7786.7617 (10, 10)
# Drone reloading:  7786.7617 (10, 10)
# TD:  8008.909 (5, 1)
# TD:  8008.909 (5, 1)
# done  7
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1435.148 (6, 8)
# Blank:  1435.148 (6, 8)
# Tank:  1731.2336 (4, 1)
# Tank:  1731.2336 (4, 1)
# Drone:  1745.4163 (11, 9)
# Drone:  1745.4163 (11, 9)
# Tank reloading:  1761.7563 (5, 1)
# Tank reloading:  1761.7563 (5, 1)
# Drone reloading:  1627.5316 (6, 8)
# Drone reloading:  1627.5316 (6, 8)
# TD:  2133.924 (11, 10)
# TD:  2133.924 (11, 10)
# done  8
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  4542.583 (11, 12)
# Blank:  4542.583 (11, 12)
# Tank:  4770.271 (11, 12)
# Tank:  4770.271 (11, 12)
# Drone:  4796.5015 (11, 12)
# Drone:  4796.5015 (11, 12)
# Tank reloading:  4881.9473 (5, 1)
# Tank reloading:  4881.9473 (5, 1)
# Drone reloading:  4930.5254 (11, 9)
# Drone reloading:  4930.5254 (11, 9)
# TD:  5119.535 (12, 11)
# TD:  5119.535 (12, 11)
# done  9
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  51.859566 (6, 0)
# Tank:  51.859566 (6, 0)
# Drone:  27.896717 (10, 9)
# Drone:  27.896717 (10, 9)
# Tank reloading:  27.792164 (5, 1)
# Tank reloading:  27.792164 (5, 1)
# Drone reloading:  11.585205 (10, 9)
# Drone reloading:  11.585205 (10, 9)
# TD:  130.50137 (10, 10)
# TD:  130.50137 (10, 10)
# done  10
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  28484.219 (10, 11)
# Blank:  28484.219 (10, 11)
# Tank:  28520.79 (10, 11)
# Tank:  28520.79 (10, 11)
# Drone:  28671.879 (10, 10)
# Drone:  28671.879 (10, 10)
# Tank reloading:  28874.695 (6, 1)
# Tank reloading:  28874.695 (6, 1)
# Drone reloading:  28633.322 (10, 11)
# Drone reloading:  28633.322 (10, 11)
# TD:  28751.31 (11, 11)
# TD:  28751.31 (11, 11)
# done  11
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  374.45703 (7, 9)
# Blank:  374.45703 (7, 9)
# Tank:  524.1942 (5, 1)
# Tank:  524.1942 (5, 1)
# Drone:  566.43884 (10, 10)
# Drone:  566.43884 (10, 10)
# Tank reloading:  601.3748 (5, 0)
# Tank reloading:  601.3748 (5, 0)
# Drone reloading:  506.30917 (10, 9)
# Drone reloading:  506.30917 (10, 9)
# TD:  697.41516 (11, 10)
# TD:  697.41516 (11, 10)
# done  12
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  15505.9375 (11, 13)
# Blank:  15505.9375 (11, 13)
# Tank:  15764.656 (5, 1)
# Tank:  15764.656 (5, 1)
# Drone:  15801.258 (11, 10)
# Drone:  15801.258 (11, 10)
# Tank reloading:  16015.086 (5, 0)
# Tank reloading:  16015.086 (5, 0)
# Drone reloading:  15654.12 (11, 10)
# Drone reloading:  15654.12 (11, 10)
# TD:  16105.51 (5, 1)
# TD:  16105.51 (5, 1)
# done  13
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  315.94183 (10, 12)
# Blank:  315.94183 (10, 12)
# Tank:  389.31177 (10, 12)
# Tank:  389.31177 (10, 12)
# Drone:  466.74567 (11, 9)
# Drone:  466.74567 (11, 9)
# Tank reloading:  378.86508 (10, 12)
# Tank reloading:  378.86508 (10, 12)
# Drone reloading:  501.22565 (10, 12)
# Drone reloading:  501.22565 (10, 12)
# TD:  574.7948 (11, 10)
# TD:  574.7948 (11, 10)
# done  14
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  323.19617 (10, 13)
# Blank:  323.19617 (10, 13)
# Tank:  526.13794 (5, 1)
# Tank:  526.13794 (5, 1)
# Drone:  450.18396 (11, 9)
# Drone:  450.18396 (11, 9)
# Tank reloading:  471.68622 (5, 0)
# Tank reloading:  471.68622 (5, 0)
# Drone reloading:  462.03186 (11, 9)
# Drone reloading:  462.03186 (11, 9)
# TD:  758.7136 (11, 10)
# TD:  758.7136 (11, 10)
# done  15
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  150.25323 (11, 11)
# Blank:  150.25323 (11, 11)
# Tank:  263.76874 (5, 0)
# Tank:  263.76874 (5, 0)
# Drone:  236.20544 (11, 10)
# Drone:  236.20544 (11, 10)
# Tank reloading:  382.88306 (5, 0)
# Tank reloading:  382.88306 (5, 0)
# Drone reloading:  175.33182 (11, 8)
# Drone reloading:  175.33182 (11, 8)
# TD:  459.7015 (11, 10)
# TD:  459.7015 (11, 10)
# done  16
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  14320.631 (16, 12)
# Blank:  14320.631 (16, 12)
# Tank:  14353.914 (16, 12)
# Tank:  14353.914 (16, 12)
# Drone:  14425.411 (10, 10)
# Drone:  14425.411 (10, 10)
# Tank reloading:  14506.45 (5, 1)
# Tank reloading:  14506.45 (5, 1)
# Drone reloading:  14370.489 (10, 8)
# Drone reloading:  14370.489 (10, 8)
# TD:  14445.98 (10, 10)
# TD:  14445.98 (10, 10)
# done  17
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  172.07431 (10, 12)
# Blank:  172.07431 (10, 12)
# Tank:  305.0288 (5, 1)
# Tank:  305.0288 (5, 1)
# Drone:  319.38333 (11, 10)
# Drone:  319.38333 (11, 10)
# Tank reloading:  273.8933 (5, 1)
# Tank reloading:  273.8933 (5, 1)
# Drone reloading:  283.73157 (10, 10)
# Drone reloading:  283.73157 (10, 10)
# TD:  431.42212 (11, 10)
# TD:  431.42212 (11, 10)
# done  18
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  170.94727 (10, 2)
# Blank:  170.94727 (10, 2)
# Tank:  334.21298 (4, 1)
# Tank:  334.21298 (4, 1)
# Drone:  361.7343 (10, 11)
# Drone:  361.7343 (10, 11)
# Tank reloading:  429.42017 (5, 1)
# Tank reloading:  429.42017 (5, 1)
# Drone reloading:  298.835 (10, 9)
# Drone reloading:  298.835 (10, 9)
# TD:  544.7146 (10, 11)
# TD:  544.7146 (10, 11)
# done  19
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  42.672237 (9, 12)
# Blank:  42.672237 (9, 12)
# Tank:  92.917915 (9, 12)
# Tank:  92.917915 (9, 12)
# Drone:  97.62856 (9, 12)
# Drone:  97.62856 (9, 12)
# Tank reloading:  93.33926 (5, 1)
# Tank reloading:  93.33926 (5, 1)
# Drone reloading:  106.234985 (10, 9)
# Drone reloading:  106.234985 (10, 9)
# TD:  169.11603 (11, 9)
# TD:  169.11603 (11, 9)
# done  20
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  6921.207 (12, 2)
# Blank:  6921.207 (12, 2)
# Tank:  7135.3784 (6, 0)
# Tank:  7135.3784 (6, 0)
# Drone:  7194.257 (11, 10)
# Drone:  7194.257 (11, 10)
# Tank reloading:  7317.041 (4, 0)
# Tank reloading:  7317.041 (4, 0)
# Drone reloading:  7179.242 (11, 10)
# Drone reloading:  7179.242 (11, 10)
# TD:  7527.0 (11, 11)
# TD:  7527.0 (11, 11)
# done  21
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  25.255066 (8, 9)
# Blank:  25.255066 (8, 9)
# Tank:  156.70833 (5, 0)
# Tank:  156.70833 (5, 0)
# Drone:  77.091675 (11, 9)
# Drone:  77.091675 (11, 9)
# Tank reloading:  122.028694 (5, 0)
# Tank reloading:  122.028694 (5, 0)
# Drone reloading:  147.3464 (10, 9)
# Drone reloading:  147.3464 (10, 9)
# TD:  333.06714 (5, 0)
# TD:  333.06714 (5, 0)
# done  22
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  0.0 (0, 0)
# Tank:  0.0 (0, 0)
# Drone:  0.0 (0, 0)
# Drone:  0.0 (0, 0)
# Tank reloading:  0.0 (0, 0)
# Tank reloading:  0.0 (0, 0)
# Drone reloading:  0.0 (0, 0)
# Drone reloading:  0.0 (0, 0)
# TD:  0.0 (0, 0)
# TD:  0.0 (0, 0)
# done  23
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  3817.0005 (6, 9)
# Blank:  3817.0005 (6, 9)
# Tank:  4149.4507 (5, 0)
# Tank:  4149.4507 (5, 0)
# Drone:  4100.4185 (10, 10)
# Drone:  4100.4185 (10, 10)
# Tank reloading:  4199.4062 (5, 0)
# Tank reloading:  4199.4062 (5, 0)
# Drone reloading:  4111.6274 (10, 9)
# Drone reloading:  4111.6274 (10, 9)
# TD:  4538.5186 (10, 10)
# TD:  4538.5186 (10, 10)
# done  24
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  79.4991 (15, 15)
# Blank:  79.4991 (15, 15)
# Tank:  239.8229 (5, 1)
# Tank:  239.8229 (5, 1)
# Drone:  170.4319 (10, 9)
# Drone:  170.4319 (10, 9)
# Tank reloading:  247.18979 (5, 0)
# Tank reloading:  247.18979 (5, 0)
# Drone reloading:  106.84668 (10, 10)
# Drone reloading:  106.84668 (10, 10)
# TD:  379.30133 (5, 1)
# TD:  379.30133 (5, 1)
# done  25
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  2587.1875 (11, 11)
# Blank:  2587.1875 (11, 11)
# Tank:  2846.6494 (5, 0)
# Tank:  2846.6494 (5, 0)
# Drone:  2881.7954 (11, 9)
# Drone:  2881.7954 (11, 9)
# Tank reloading:  2941.5198 (4, 1)
# Tank reloading:  2941.5198 (4, 1)
# Drone reloading:  2959.9932 (11, 9)
# Drone reloading:  2959.9932 (11, 9)
# TD:  3265.4531 (5, 0)
# TD:  3265.4531 (5, 0)
# done  26
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  5026.1973 (16, 14)
# Blank:  5026.1973 (16, 14)
# Tank:  5338.915 (5, 0)
# Tank:  5338.915 (5, 0)
# Drone:  5373.4854 (10, 9)
# Drone:  5373.4854 (10, 9)
# Tank reloading:  5465.433 (6, 1)
# Tank reloading:  5465.433 (6, 1)
# Drone reloading:  5335.285 (10, 9)
# Drone reloading:  5335.285 (10, 9)
# TD:  5905.72 (10, 10)
# TD:  5905.72 (10, 10)
# done  27
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  12819.695 (15, 15)
# Blank:  12819.695 (15, 15)
# Tank:  13135.973 (15, 15)
# Tank:  13135.973 (15, 15)
# Drone:  13138.252 (9, 9)
# Drone:  13138.252 (9, 9)
# Tank reloading:  13494.194 (5, 0)
# Tank reloading:  13494.194 (5, 0)
# Drone reloading:  13063.715 (15, 15)
# Drone reloading:  13063.715 (15, 15)
# TD:  13598.862 (10, 10)
# TD:  13598.862 (10, 10)
# done  28
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  719.8484 (10, 11)
# Blank:  719.8484 (10, 11)
# Tank:  833.80164 (10, 11)
# Tank:  833.80164 (10, 11)
# Drone:  930.52045 (10, 11)
# Drone:  930.52045 (10, 11)
# Tank reloading:  955.81854 (5, 1)
# Tank reloading:  955.81854 (5, 1)
# Drone reloading:  903.8184 (11, 9)
# Drone reloading:  903.8184 (11, 9)
# TD:  1124.4618 (10, 11)
# TD:  1124.4618 (10, 11)
# done  29
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  13056.463 (2, 9)
# Blank:  13056.463 (2, 9)
# Tank:  13206.75 (4, 1)
# Tank:  13206.75 (4, 1)
# Drone:  13316.672 (10, 9)
# Drone:  13316.672 (10, 9)
# Tank reloading:  13473.336 (6, 1)
# Tank reloading:  13473.336 (6, 1)
# Drone reloading:  13285.063 (11, 9)
# Drone reloading:  13285.063 (11, 9)
# TD:  13584.771 (10, 9)
# TD:  13584.771 (10, 9)
# done  30
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  975.1273 (17, 15)
# Blank:  975.1273 (17, 15)
# Tank:  1298.4028 (5, 0)
# Tank:  1298.4028 (5, 0)
# Drone:  1211.3696 (11, 9)
# Drone:  1211.3696 (11, 9)
# Tank reloading:  1350.303 (5, 0)
# Tank reloading:  1350.303 (5, 0)
# Drone reloading:  1184.7102 (12, 9)
# Drone reloading:  1184.7102 (12, 9)
# TD:  1735.5718 (5, 0)
# TD:  1735.5718 (5, 0)
# done  31
# ++++++++++++++++++++++++++++++++++++++++++++

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

tank_info_panel = 4
drone_info_panel = 24

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

#Blank
for i in range(12):
    img = uframes[i]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank,pos_tank = val_pos(output_tank)
    print(i)
    output_drone = output[0][drone_info_panel]
    val_drone,pos_drone = val_pos(output_drone)
    if val_tank>500:
        print("tank present")
        print("Tank info: ",val_tank,pos_tank)
    if val_drone>770:
        print("drone present")
        print("Drone info: ",val_drone,pos_drone)
# Out:
# 0
# 1
# tank present
# Tank info:  520.7602 (6, 2)
# 2
# drone present
# Drone info:  781.4645 (1, 4)
# 3
# tank present
# Tank info:  634.67224 (6, 2)
# drone present
# Drone info:  942.7866 (1, 4)
# 4
# tank present
# Tank info:  654.7293 (6, 8)
# drone present
# Drone info:  927.96313 (1, 4)
# 5
# tank present
# Tank info:  642.7981 (6, 13)
# drone present
# Drone info:  985.1527 (1, 4)
# 6
# tank present
# Tank info:  722.30286 (6, 2)
# drone present
# Drone info:  938.44824 (5, 1)
# 7
# tank present
# Tank info:  740.57965 (6, 8)
# drone present
# Drone info:  860.5968 (5, 7)
# 8
# tank present
# Tank info:  730.4288 (6, 13)
# drone present
# Drone info:  976.33765 (5, 12)
# 9
# tank present
# Tank info:  669.9697 (6, 2)
# drone present
# Drone info:  1017.36505 (13, 15)
# 10
# tank present
# Tank info:  690.02686 (6, 8)
# drone present
# Drone info:  1002.5415 (13, 15)
# 11
# tank present
# Tank info:  678.09564 (6, 13)
# drone present
# Drone info:  1059.7312 (13, 15)

# %%
im1 = Image.open('tree1.png')
im1 = im1.resize((100,100))

imt = Image.open('tank.png')
imt = imt.resize((100,100))


im2 = Image.open('tree2.png')
im2 = im2.resize((100,100))

im3 = Image.open('tree3.png')
im3 = im3.resize((100,100))

im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((200,200))

imb = Image.open('bullet.png')
imb = imb.resize((40,40))



img_blank = Image.new('RGB', (720, 1080), color = '#9b7653')
img_blank.paste(im1,(5,75),im1)
img_blank.paste(im1,(450,550),im1)
img_blank.paste(im1,(205,720),im1)
img_blank.paste(im2,(500,900),im2)
img_blank.paste(im2,(650,750),im2)
img_blank.paste(im2,(320,440),im2)
img_blank.paste(im3,(100,600),im3)
img_blank.paste(im3,(440,620),im3)
img_blank.paste(im3,(300,150),im3)
img_blank.paste(imt.rotate(180),(500,500),imt.rotate(180))
img_blank = np.asarray(img_blank)
img_blank = cv2.resize(img_blank,(100,100))
pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
output = model(pil.reshape(1,3,100, 100))[0].detach().numpy()
output = output[0][info_panel]
val,pos = val_pos(output)
print(val,pos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c18b098abae9> in <module>
#      36 pil = torch.from_numpy(pil)
#      37 output = model(pil.reshape(1,3,100, 100))[0].detach().numpy()
# ---> 38 output = output[0][info_panel]
#      39 val,pos = val_pos(output)
#      40 print(val,pos)
#
# NameError: name 'info_panel' is not defined

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(12):
    k = uframes[i]
    #k.show()
    v = np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32)
    v = torch.from_numpy(v)
    filename = "Marginalization_Simple-increased_channels-32/ref_image_new_" + str(i) + ".txt"
    file = open(filename, 'w')
    file.write(str(model(v.reshape(1,3,100, 100))[0].detach().numpy()))
    file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

filename = "Marginalization_Simple-increased_channels-32/fc_weights.txt"
file = open(filename, 'w')
file.write(str(model.fc1.weight.detach().numpy()))
print(np.shape(model.fc1.weight.detach().numpy()))
file.close()
# Out:
# (15, 10368)

# %%
##Weights

import operator
k=model.fc1.weight.detach().numpy()
for i in range(15):
    index, value = max(enumerate(k[i]), key=operator.itemgetter(1))
    print("FC - Feature "+ "i: ",index,value)
    print("CNN value: ", )
# Out:
# FC - Feature i:  684 0.041578084
# CNN value:
# FC - Feature i:  684 0.051804464
# CNN value:
# FC - Feature i:  360 0.04816093
# CNN value:
# FC - Feature i:  492 0.035558272
# CNN value:
# FC - Feature i:  478 0.06459166
# CNN value:
# FC - Feature i:  585 0.049136233
# CNN value:
# FC - Feature i:  492 0.081621096
# CNN value:
# FC - Feature i:  360 0.065480515
# CNN value:
# FC - Feature i:  585 0.04792851
# CNN value:
# FC - Feature i:  492 0.06556648
# CNN value:
# FC - Feature i:  684 0.035789683
# CNN value:
# FC - Feature i:  684 0.034514345
# CNN value:
# FC - Feature i:  817 0.043642323
# CNN value:
# FC - Feature i:  492 0.088237286
# CNN value:
# FC - Feature i:  492 0.09752004
# CNN value:

# %%
import operator
import sys
#t1d1
img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
# img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))

# #t2d2
# img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
# draw = ImageDraw.Draw(img_blank)
# draw.ellipse((35,35,38,38), fill=(255, 0, 0))
# img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
# draw.ellipse((40,50,43,53), fill=(50, 182, 150))

# #t3d3
# img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
# img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
# img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
# img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

v = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
v = torch.from_numpy(v)
k = model(v.reshape(1,3,100, 100))[0].view(model(v.reshape(1,3,100, 100))[0].size(0), -1).detach().numpy()

filename = "Marginalization_Simple/flattened_tank_pos_1.txt"
file = open(filename, 'w')
file.write(str(k))
file.close()


# print(np.shape(k))
# index, value = max(enumerate(k), key=operator.itemgetter(1))
# print(index,value)


import operator
p=model.fc1.weight.detach().numpy()
for i in range(15):
    index, value = max(enumerate(p[i]), key=operator.itemgetter(1))
    print("FC - Feature "+ str(i) +" : ",index,value)
    print
    print("CNN value: ",k[0][index] )
# Out:
# FC - Feature 0 :  684 0.041578084
# CNN value:  17.59211
# FC - Feature 1 :  684 0.051804464
# CNN value:  17.59211
# FC - Feature 2 :  360 0.04816093
# CNN value:  0.53643996
# FC - Feature 3 :  492 0.035558272
# CNN value:  0.53643996
# FC - Feature 4 :  478 0.06459166
# CNN value:  0.53643996
# FC - Feature 5 :  585 0.049136233
# CNN value:  0.53643996
# FC - Feature 6 :  492 0.081621096
# CNN value:  0.53643996
# FC - Feature 7 :  360 0.065480515
# CNN value:  0.53643996
# FC - Feature 8 :  585 0.04792851
# CNN value:  0.53643996
# FC - Feature 9 :  492 0.06556648
# CNN value:  0.53643996
# FC - Feature 10 :  684 0.035789683
# CNN value:  17.59211
# FC - Feature 11 :  684 0.034514345
# CNN value:  17.59211
# FC - Feature 12 :  817 0.043642323
# CNN value:  17.59211
# FC - Feature 13 :  492 0.088237286
# CNN value:  0.53643996
# FC - Feature 14 :  492 0.09752004
# CNN value:  0.53643996

# %%
import random


p=0
class_data = []
while(p<len(uframes)):
    data3=[]
    print(p)
    for i in range(50):
        img = uframes[p]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        temp = model(x_1[i].reshape(1,3,100,100))[1]
        #print(temp)
        class_data.append((list(temp.detach().numpy()[0]),p))
    p+=1
    print(len(class_data))

random.shuffle(class_data)
random.shuffle(class_data)

print("length ", len(class_data))
# Out:
# 0
# 50
# 1
# 100
# 2
# 150
# 3
# 200
# 4
# 250
# 5
# 300
# 6
# 350
# 7
# 400
# 8
# 450
# 9
# 500
# 10
# 550
# 11
# 600
# length  600

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from colorama import init  
import time
import cv2

print(np.shape(uframes[0]))


#z  = np.array(np.transpose(np.asarray(z),(2,0,1)),dtype=np.float32)
# import some data to play with
print("Length of Class data: ", len(class_data))
# Take the first two features. We could avoid this by using a two-dim dataset
X = [(i[0]) for i in class_data]
y = [i[1] for i in class_data]
#print(X,np.shape(X))
#print(y,np.shape(y))
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel='linear', C=C)
clf = clf.fit(X, y)
data3=[]
y3=0

n1 = "\x1b[31m\"Drone Stationary, Tank Firing\"\x1b[0m"
n2 = "\x1b[31m\"Drone Reloading, Tank Firing\"\x1b[0m"
n3 = "\x1b[31m\"Drone Firing, Tank Stationary\"\x1b[0m"
n4 = "\x1b[31m\"Drone Firing, Tank Reloading\"\x1b[0m"
n5 = "\x1b[31m\"Drone Firing, Tank Firing\"\x1b[0m"

names = ['Just Background','Only Tank moving', 'Only Drone Moving', 'Drone stationary, Tank Stationary', 'Drone Stationary, Tank Reloading' ,
         n1, 'Drone reloading, Tank Stationary', 'Drone reloading, Tank Reloading', n2 , n3,n4,n5]

print("Start")

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

for i in range(12):
    #z = cv2.imread('Images_100/0a.png')
    #l = Image.fromarray(z)
#     print("shape of z", np.shape(z),type(z))
#     #l.show()
#     #z  = cv2.resize(z,(100,100))
#     img = uframes[i]
#     print(np.shape(img))
#     img.show()
#     data3.append(np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32))
#     y3 = np.array(data3)
#     x_1 = torch.from_numpy(y3)
# #     random_img = random.choice(x)
# #     print("random", np.shape(random_img),type(random_img))
# #     show = random_img.detach().numpy() * 255
# #     show = np.array(np.transpose(show,(1,2,0)),dtype=np.uint8)
# #     print("show", np.shape(show),type(show))
# #     ms = Image.fromarray(show)
# #     ms.show()
#     temp = model(x_1[i].reshape(1,3,100,100))[1]
#     temp = temp.detach().numpy()
#     img_blank.show()
#     #print(temp)
#     z = clf.predict(temp)
#     print(names[z[0]])
    img = uframes[i]
    print(np.shape(img))
    img.show()
    #ms = Image.fromarray(z)
    #ms.show()
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    temp = model(x_1[i].reshape(1,3,100,100))[1]
    temp = temp.detach().numpy()
    print(temp)
    z = clf.predict(temp)
    print(names[z[0]])
# Out:
# (100, 100, 3)
# Length of Class data:  600
# Start
# (100, 100, 3)
# [[5.69654167e-01 9.99462187e-01 5.63863292e-02 4.24214751e-01
#   9.99946237e-01 3.76719624e-01 9.24754981e-03 9.96866763e-01
#   3.24720666e-02 6.23485744e-01 9.99366581e-01 1.33173708e-05
#   9.99919176e-01 1.10880566e-04 7.16020440e-05]]
# Just Background
# (100, 100, 3)
# [[1.0693459e-01 9.7853309e-01 6.2482929e-01 8.8721722e-01 9.2732191e-01
#   3.8686104e-04 4.0334295e-03 9.7163016e-01 4.2039016e-01 9.9970645e-01
#   9.6105587e-01 4.5536429e-02 9.1955161e-01 2.7226047e-03 7.8407951e-02]]
# Only Tank moving
# (100, 100, 3)
# [[7.3534204e-03 9.9773276e-01 9.8508829e-01 9.9262118e-01 4.5104271e-01
#   3.5262175e-04 1.2917872e-04 7.4658793e-01 9.1725689e-01 9.9936992e-01
#   9.9860114e-01 5.1300049e-01 5.2829486e-01 2.9081654e-02 4.6734187e-01]]
# Only Drone Moving
# (100, 100, 3)
# [[6.6964526e-04 9.1521192e-01 9.9945718e-01 9.9930429e-01 5.6288450e-04
#   2.2586556e-07 5.6052031e-05 2.4077968e-01 9.9584311e-01 9.9999964e-01
#   9.1780317e-01 9.9973506e-01 1.0335925e-03 4.2442623e-01 9.9904162e-01]]
# Drone stationary, Tank Stationary
# (100, 100, 3)
# [[6.1773854e-01 5.1048535e-01 4.2821926e-01 3.8129362e-01 1.0322047e-02
#   8.4455933e-05 2.3334846e-03 2.1261269e-04 6.1853075e-01 9.9990475e-01
#   4.9628347e-01 9.9220043e-01 6.8009188e-03 9.8382390e-01 9.9368638e-01]]
# Drone Stationary, Tank Reloading
# (100, 100, 3)
# [[9.9997580e-01 8.7049991e-02 3.9350489e-01 2.6484555e-05 1.4167073e-01
#   1.3029476e-03 3.0017098e-05 3.1996256e-01 1.2829518e-01 9.9855381e-01
#   6.7431293e-02 8.8297009e-01 4.4132985e-02 6.9923133e-01 9.5737994e-01]]
# "Drone Stationary, Tank Firing"
# (100, 100, 3)
# [[9.9999666e-01 2.1902008e-06 1.0000000e+00 3.5267242e-06 3.7724271e-07
#   2.0260264e-03 6.5317053e-01 9.9999988e-01 2.2876749e-05 9.9758089e-01
#   4.7796307e-06 9.9999976e-01 3.5909158e-01 4.6132133e-08 6.4752334e-01]]
# Drone reloading, Tank Stationary
# (100, 100, 3)
# [[1.0000000e+00 2.1159988e-07 9.9998021e-01 1.5131814e-09 6.9859670e-06
#   4.3155217e-01 9.8743409e-01 9.9986637e-01 1.5483755e-07 5.7010096e-01
#   4.2174099e-07 9.9999261e-01 7.8759670e-01 3.8049018e-06 2.1713410e-01]]
# Drone reloading, Tank Reloading
# (100, 100, 3)
# [[1.0000000e+00 1.9347251e-08 9.9997711e-01 6.5030982e-14 1.1054412e-04
#   9.2142385e-01 5.0211656e-01 9.9999988e-01 1.4054513e-08 8.0260172e-02
#   3.0951572e-08 9.9987626e-01 9.6154159e-01 1.4544214e-07 3.8078785e-02]]
# "Drone Reloading, Tank Firing"
# (100, 100, 3)
# [[9.9998307e-01 9.9999917e-01 9.1853076e-01 1.7807450e-05 1.3325374e-02
#   9.9982435e-01 4.4189114e-06 2.7935535e-01 4.3374286e-03 1.8264313e-04
#   9.9999952e-01 9.9133462e-01 9.9873489e-01 3.9311872e-05 5.1611115e-04]]
# "Drone Firing, Tank Stationary"
# (100, 100, 3)
# [[1.0000000e+00 9.9999106e-01 4.5650690e-03 7.6405922e-09 2.0006411e-01
#   9.9999952e-01 1.8434954e-04 2.5986764e-04 2.9483532e-05 5.8745394e-07
#   9.9999404e-01 7.9409081e-01 9.9980861e-01 3.2320421e-03 7.7956029e-05]]
# "Drone Firing, Tank Reloading"
# (100, 100, 3)
# [[1.0000000e+00 9.9990249e-01 3.9572958e-03 3.2836459e-13 7.9830289e-01
#   1.0000000e+00 2.3663674e-06 3.6512318e-01 2.6762741e-06 3.8656605e-08
#   9.9991810e-01 1.8614928e-01 9.9997163e-01 1.2392933e-04 1.1127093e-05]]
# "Drone Firing, Tank Firing"

# %%
import numpy as np
import matplotlib.pyplot as plt
print(droner)
x = [dronec[i][0] for i in range(len(dronec))]
y = [dronec[i][1] for i in range(len(dronec))]
x1 = [droner[i][0] for i in range(len(droner))]
y1 = [droner[i][1] for i in range(len(droner))]
#
#plt.scatter(y,x)
plt.scatter(y1,x1,color='red')
plt.show
# Out:
# []
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(60,60),imt.rotate(180))
#img_blank.paste(im_drone.resize((10,10)),(10,30),im_drone.resize((10,10)))
#img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
#draw = ImageDraw.Draw(img_blank)
#draw.ellipse((60,60,68,68), fill=(255, 0, 0))
# img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
#draw = ImageDraw.Draw(img_blank)
#draw.ellipse((10,30,18,38), fill=(50, 182, 150))
#img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
#img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
img_blank.show()
pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
filename = "lesser_15_features/testing.txt"
file = open(filename, 'w')
file.write(str(model(pil.reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)
img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
#img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
#img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))

#img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))

pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
filename = "Marginalization_Simple-increased_channels-32/drone_pos_3.txt"
file = open(filename, 'w')
file.write(str(model(pil.reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import cv2
vidcap = cv2.VideoCapture('tank.avi')
success,image = vidcap.read()
count = 0
while success:
  cv2.imwrite("frame/tank_frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  False

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)   

from PIL import  Image,ImageDraw

img = uframes[20]
z = Image.fromarray(img)
z.show()
data3=[]
data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
y3 = np.array(data3)
x_1 = torch.from_numpy(y3)
temp = model(x_1[0].reshape(1,3,100,100))[0].detach().numpy()
filename = "Marginalization_Simple-increased_channels-32-video-multiple/TD.txt"
file = open(filename, 'w')
file.write(str(model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)   

from PIL import  Image,ImageDraw

img = Image.open("frame/tank_frame0.jpg")
img =  cv2.resize(np.asarray(img),(100,100))
data3=[]
data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
y3 = np.array(data3)
x_1 = torch.from_numpy(y3)
temp = model(x_1[0].reshape(1,3,100,100))[0].detach().numpy()
filename = "Marginalization_Simple-increased_channels-32-video-multiple/tank.txt"
file = open(filename, 'w')
file.write(str(model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()))
file.close()
