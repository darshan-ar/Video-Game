# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random
import cv2
from torchvision import models
from torchsummary import summary

Batch_Size = 50
num_epochs = 200
learning_rate = 1e-5
samples = 10000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
uframes = []

im1 = Image.open('tree1.png')
im1 = im1.resize((8,8))

imt = Image.open('tank.png')
imt = imt.resize((10,10))


im2 = Image.open('tree2.png')
im2 = im2.resize((8,8))

im3 = Image.open('tree3.png')
im3 = im3.resize((8,8))

im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((10,10))

imb = Image.open('bullet.png')
imb = imb.resize((2,2))

for i in range(1):
    
    #blank
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)

    uframes.append(img_blank)
    
    #only tank
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    
    uframes.append(img_blank)
    
    #only drone
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t1d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t2d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,35,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t3d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t1d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((40,50,43,53), fill=(50, 182, 150))
    
    uframes.append(img_blank)
    
    #t2d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,35,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw.ellipse((40,50,43,53), fill=(50, 182, 150))
    
    
    uframes.append(img_blank)
    
    #t3d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((40,50,43,53), fill=(50, 182, 150))
    
    
    uframes.append(img_blank)
    
    #t1d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    uframes.append(img_blank)
    
    #t2d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,35,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    
    uframes.append(img_blank)
    
    #t3d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    
    uframes.append(img_blank)



for i in range(samples):
    data1.append(np.array(np.transpose(np.asarray(uframes[i % len(uframes)]),(2,0,1)),dtype=np.float32))
    data2.append(np.array(np.transpose(np.asarray(uframes[(i+1) % len(uframes)]),(2,0,1)),dtype=np.float32))



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = '#9b7653')
img.paste(im1,(5,75),im1)
img.paste(im1,(10,55),im1)
img.paste(im1,(25,50),im1)
img.paste(im2,(75,5),im2)
img.paste(im2,(60,30),im2)
img.paste(im2,(90,20),im2)
img.paste(im3,(75,60),im3)
img.paste(im3,(60,80),im3)
im_n = np.reshape(img,(100,100,3))
b = np.asarray(im_n)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)

#y0 = np.array(np.transpose(np.asarray(y0),(0,3,1,2)),dtype=np.float32)
#y1 = np.array(np.transpose(np.asarray(y1),(0,3,1,2)),dtype=np.float32)
print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=10, stride=1)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=5)

#         # Convolution 2
#         self.cnn2 = nn.Conv2d(in_channels=16, out_channels=3, kernel_size=5, stride=1, padding=2)
#         self.relu2 = nn.ReLU()

#         # Max pool 2
#         self.maxpool2 = nn.MaxPool2d(kernel_size=5)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(972, 15)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        #out = self.cnn2(out)
        #out = self.relu2(out)

        # Max pool 2 
        #out = self.maxpool2(out)
        im_out = out
        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return im_out,out
    
model = CNNModel()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x)[1],model(y)[1])
        # ===================backward====================
 
        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print("shape: ", np.shape(model(x[0].reshape(1,3,100, 100))[0]))
#     print("x: ", model(x[0].reshape(1,3,100, 100)))
#     print("y:", model(y[0].reshape(1,3,100, 100)))
#     print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# (10000, 3, 100, 100)
# epoch [1/200], loss:-0.1810
# shape:  torch.Size([1, 3, 18, 18])
# epoch [2/200], loss:-0.3160
# shape:  torch.Size([1, 3, 18, 18])
# epoch [3/200], loss:-0.2396
# shape:  torch.Size([1, 3, 18, 18])
# epoch [4/200], loss:-0.3346
# shape:  torch.Size([1, 3, 18, 18])
# epoch [5/200], loss:-0.5581
# shape:  torch.Size([1, 3, 18, 18])
# epoch [6/200], loss:-0.4054
# shape:  torch.Size([1, 3, 18, 18])
# epoch [7/200], loss:-0.7491
# shape:  torch.Size([1, 3, 18, 18])
# epoch [8/200], loss:-0.7655
# shape:  torch.Size([1, 3, 18, 18])
# epoch [9/200], loss:-0.9463
# shape:  torch.Size([1, 3, 18, 18])
# epoch [10/200], loss:-0.8627
# shape:  torch.Size([1, 3, 18, 18])
# epoch [11/200], loss:-0.9813
# shape:  torch.Size([1, 3, 18, 18])
# epoch [12/200], loss:-1.0740
# shape:  torch.Size([1, 3, 18, 18])
# epoch [13/200], loss:-1.1995
# shape:  torch.Size([1, 3, 18, 18])
# epoch [14/200], loss:-1.4837
# shape:  torch.Size([1, 3, 18, 18])
# epoch [15/200], loss:-1.3466
# shape:  torch.Size([1, 3, 18, 18])
# epoch [16/200], loss:-1.2872
# shape:  torch.Size([1, 3, 18, 18])
# epoch [17/200], loss:-1.4789
# shape:  torch.Size([1, 3, 18, 18])
# epoch [18/200], loss:-1.7577
# shape:  torch.Size([1, 3, 18, 18])
# epoch [19/200], loss:-1.5105
# shape:  torch.Size([1, 3, 18, 18])
# epoch [20/200], loss:-1.5664
# shape:  torch.Size([1, 3, 18, 18])
# epoch [21/200], loss:-1.6431
# shape:  torch.Size([1, 3, 18, 18])
# epoch [22/200], loss:-1.4670
# shape:  torch.Size([1, 3, 18, 18])
# epoch [23/200], loss:-1.5692
# shape:  torch.Size([1, 3, 18, 18])
# epoch [24/200], loss:-1.4715
# shape:  torch.Size([1, 3, 18, 18])
# epoch [25/200], loss:-1.6729
# shape:  torch.Size([1, 3, 18, 18])
# epoch [26/200], loss:-1.7708
# shape:  torch.Size([1, 3, 18, 18])
# epoch [27/200], loss:-1.7114
# shape:  torch.Size([1, 3, 18, 18])
# epoch [28/200], loss:-1.5100
# shape:  torch.Size([1, 3, 18, 18])
# epoch [29/200], loss:-1.7441
# shape:  torch.Size([1, 3, 18, 18])
# epoch [30/200], loss:-1.6492
# shape:  torch.Size([1, 3, 18, 18])
# epoch [31/200], loss:-1.6132
# shape:  torch.Size([1, 3, 18, 18])
# epoch [32/200], loss:-1.6349
# shape:  torch.Size([1, 3, 18, 18])
# epoch [33/200], loss:-1.5017
# shape:  torch.Size([1, 3, 18, 18])
# epoch [34/200], loss:-1.6830
# shape:  torch.Size([1, 3, 18, 18])
# epoch [35/200], loss:-1.5573
# shape:  torch.Size([1, 3, 18, 18])
# epoch [36/200], loss:-1.7418
# shape:  torch.Size([1, 3, 18, 18])
# epoch [37/200], loss:-1.6400
# shape:  torch.Size([1, 3, 18, 18])
# epoch [38/200], loss:-1.6531
# shape:  torch.Size([1, 3, 18, 18])
# epoch [39/200], loss:-1.5028
# shape:  torch.Size([1, 3, 18, 18])
# epoch [40/200], loss:-1.5208
# shape:  torch.Size([1, 3, 18, 18])
# epoch [41/200], loss:-1.6888
# shape:  torch.Size([1, 3, 18, 18])
# epoch [42/200], loss:-1.5565
# shape:  torch.Size([1, 3, 18, 18])
# epoch [43/200], loss:-1.4887
# shape:  torch.Size([1, 3, 18, 18])
# epoch [44/200], loss:-1.3828
# shape:  torch.Size([1, 3, 18, 18])
# epoch [45/200], loss:-1.5893
# shape:  torch.Size([1, 3, 18, 18])
# epoch [46/200], loss:-1.9014
# shape:  torch.Size([1, 3, 18, 18])
# epoch [47/200], loss:-1.6349
# shape:  torch.Size([1, 3, 18, 18])
# epoch [48/200], loss:-1.5787
# shape:  torch.Size([1, 3, 18, 18])
# epoch [49/200], loss:-1.5649
# shape:  torch.Size([1, 3, 18, 18])
# epoch [50/200], loss:-1.7951
# shape:  torch.Size([1, 3, 18, 18])
# epoch [51/200], loss:-1.5223
# shape:  torch.Size([1, 3, 18, 18])
# epoch [52/200], loss:-1.5829
# shape:  torch.Size([1, 3, 18, 18])
# epoch [53/200], loss:-1.5939
# shape:  torch.Size([1, 3, 18, 18])
# epoch [54/200], loss:-1.5600
# shape:  torch.Size([1, 3, 18, 18])
# epoch [55/200], loss:-1.6617
# shape:  torch.Size([1, 3, 18, 18])
# epoch [56/200], loss:-1.7150
# shape:  torch.Size([1, 3, 18, 18])
# epoch [57/200], loss:-1.5124
# shape:  torch.Size([1, 3, 18, 18])
# epoch [58/200], loss:-1.6351
# shape:  torch.Size([1, 3, 18, 18])
# epoch [59/200], loss:-1.5511
# shape:  torch.Size([1, 3, 18, 18])
# epoch [60/200], loss:-1.8629
# shape:  torch.Size([1, 3, 18, 18])
# epoch [61/200], loss:-1.5407
# shape:  torch.Size([1, 3, 18, 18])
# epoch [62/200], loss:-1.5861
# shape:  torch.Size([1, 3, 18, 18])
# epoch [63/200], loss:-1.7363
# shape:  torch.Size([1, 3, 18, 18])
# epoch [64/200], loss:-1.6217
# shape:  torch.Size([1, 3, 18, 18])
# epoch [65/200], loss:-1.6353
# shape:  torch.Size([1, 3, 18, 18])
# epoch [66/200], loss:-1.6084
# shape:  torch.Size([1, 3, 18, 18])
# epoch [67/200], loss:-1.6021
# shape:  torch.Size([1, 3, 18, 18])
# epoch [68/200], loss:-1.6863
# shape:  torch.Size([1, 3, 18, 18])
# epoch [69/200], loss:-1.5883
# shape:  torch.Size([1, 3, 18, 18])
# epoch [70/200], loss:-1.8242
# shape:  torch.Size([1, 3, 18, 18])
# epoch [71/200], loss:-1.6713
# shape:  torch.Size([1, 3, 18, 18])
# epoch [72/200], loss:-1.7188
# shape:  torch.Size([1, 3, 18, 18])
# epoch [73/200], loss:-1.6533
# shape:  torch.Size([1, 3, 18, 18])
# epoch [74/200], loss:-1.6652
# shape:  torch.Size([1, 3, 18, 18])
# epoch [75/200], loss:-1.7596
# shape:  torch.Size([1, 3, 18, 18])
# epoch [76/200], loss:-1.6677
# shape:  torch.Size([1, 3, 18, 18])
# epoch [77/200], loss:-1.5574
# shape:  torch.Size([1, 3, 18, 18])
# epoch [78/200], loss:-1.5386
# shape:  torch.Size([1, 3, 18, 18])
# epoch [79/200], loss:-1.6567
# shape:  torch.Size([1, 3, 18, 18])
# epoch [80/200], loss:-1.5950
# shape:  torch.Size([1, 3, 18, 18])
# epoch [81/200], loss:-1.6627
# shape:  torch.Size([1, 3, 18, 18])
# epoch [82/200], loss:-1.5852
# shape:  torch.Size([1, 3, 18, 18])
# epoch [83/200], loss:-1.7679
# shape:  torch.Size([1, 3, 18, 18])
# epoch [84/200], loss:-1.6220
# shape:  torch.Size([1, 3, 18, 18])
# epoch [85/200], loss:-1.6425
# shape:  torch.Size([1, 3, 18, 18])
# epoch [86/200], loss:-1.6209
# shape:  torch.Size([1, 3, 18, 18])
# epoch [87/200], loss:-1.6342
# shape:  torch.Size([1, 3, 18, 18])
# epoch [88/200], loss:-1.7291
# shape:  torch.Size([1, 3, 18, 18])
# epoch [89/200], loss:-1.5843
# shape:  torch.Size([1, 3, 18, 18])
# epoch [90/200], loss:-1.5077
# shape:  torch.Size([1, 3, 18, 18])
# epoch [91/200], loss:-1.6778
# shape:  torch.Size([1, 3, 18, 18])
# epoch [92/200], loss:-1.6109
# shape:  torch.Size([1, 3, 18, 18])
# epoch [93/200], loss:-1.6527
# shape:  torch.Size([1, 3, 18, 18])
# epoch [94/200], loss:-1.6892
# shape:  torch.Size([1, 3, 18, 18])
# epoch [95/200], loss:-1.7253
# shape:  torch.Size([1, 3, 18, 18])
# epoch [96/200], loss:-1.7857
# shape:  torch.Size([1, 3, 18, 18])
# epoch [97/200], loss:-1.6875
# shape:  torch.Size([1, 3, 18, 18])
# epoch [98/200], loss:-1.6617
# shape:  torch.Size([1, 3, 18, 18])
# epoch [99/200], loss:-1.8597
# shape:  torch.Size([1, 3, 18, 18])
# epoch [100/200], loss:-1.5042
# shape:  torch.Size([1, 3, 18, 18])
# epoch [101/200], loss:-1.6620
# shape:  torch.Size([1, 3, 18, 18])
# epoch [102/200], loss:-1.4830
# shape:  torch.Size([1, 3, 18, 18])
# epoch [103/200], loss:-1.7934
# shape:  torch.Size([1, 3, 18, 18])
# epoch [104/200], loss:-1.8077
# shape:  torch.Size([1, 3, 18, 18])
# epoch [105/200], loss:-1.7769
# shape:  torch.Size([1, 3, 18, 18])
# epoch [106/200], loss:-1.7672
# shape:  torch.Size([1, 3, 18, 18])
# epoch [107/200], loss:-1.6403
# shape:  torch.Size([1, 3, 18, 18])
# epoch [108/200], loss:-1.8267
# shape:  torch.Size([1, 3, 18, 18])
# epoch [109/200], loss:-1.4998
# shape:  torch.Size([1, 3, 18, 18])
# epoch [110/200], loss:-1.5859
# shape:  torch.Size([1, 3, 18, 18])
# epoch [111/200], loss:-1.5486
# shape:  torch.Size([1, 3, 18, 18])
# epoch [112/200], loss:-1.7792
# shape:  torch.Size([1, 3, 18, 18])
# epoch [113/200], loss:-1.5633
# shape:  torch.Size([1, 3, 18, 18])
# epoch [114/200], loss:-1.5083
# shape:  torch.Size([1, 3, 18, 18])
# epoch [115/200], loss:-1.9162
# shape:  torch.Size([1, 3, 18, 18])
# epoch [116/200], loss:-1.7059
# shape:  torch.Size([1, 3, 18, 18])
# epoch [117/200], loss:-1.7443
# shape:  torch.Size([1, 3, 18, 18])
# epoch [118/200], loss:-1.5977
# shape:  torch.Size([1, 3, 18, 18])
# epoch [119/200], loss:-1.6885
# shape:  torch.Size([1, 3, 18, 18])
# epoch [120/200], loss:-1.7090
# shape:  torch.Size([1, 3, 18, 18])
# epoch [121/200], loss:-1.7051
# shape:  torch.Size([1, 3, 18, 18])
# epoch [122/200], loss:-1.6549
# shape:  torch.Size([1, 3, 18, 18])
# epoch [123/200], loss:-1.7882
# shape:  torch.Size([1, 3, 18, 18])
# epoch [124/200], loss:-1.6425
# shape:  torch.Size([1, 3, 18, 18])
# epoch [125/200], loss:-1.5977
# shape:  torch.Size([1, 3, 18, 18])
# epoch [126/200], loss:-1.6104
# shape:  torch.Size([1, 3, 18, 18])
# epoch [127/200], loss:-1.6915
# shape:  torch.Size([1, 3, 18, 18])
# epoch [128/200], loss:-1.6974
# shape:  torch.Size([1, 3, 18, 18])
# epoch [129/200], loss:-1.7410
# shape:  torch.Size([1, 3, 18, 18])
# epoch [130/200], loss:-1.7662
# shape:  torch.Size([1, 3, 18, 18])
# epoch [131/200], loss:-1.6142
# shape:  torch.Size([1, 3, 18, 18])
# epoch [132/200], loss:-1.6183
# shape:  torch.Size([1, 3, 18, 18])
# epoch [133/200], loss:-1.5502
# shape:  torch.Size([1, 3, 18, 18])
# epoch [134/200], loss:-1.6568
# shape:  torch.Size([1, 3, 18, 18])
# epoch [135/200], loss:-1.8659
# shape:  torch.Size([1, 3, 18, 18])
# epoch [136/200], loss:-1.5637
# shape:  torch.Size([1, 3, 18, 18])
# epoch [137/200], loss:-1.6453
# shape:  torch.Size([1, 3, 18, 18])
# epoch [138/200], loss:-1.8325
# shape:  torch.Size([1, 3, 18, 18])
# epoch [139/200], loss:-1.4733
# shape:  torch.Size([1, 3, 18, 18])
# epoch [140/200], loss:-1.9071
# shape:  torch.Size([1, 3, 18, 18])
# epoch [141/200], loss:-1.8433
# shape:  torch.Size([1, 3, 18, 18])
# epoch [142/200], loss:-1.7359
# shape:  torch.Size([1, 3, 18, 18])
# epoch [143/200], loss:-1.6891
# shape:  torch.Size([1, 3, 18, 18])
# epoch [144/200], loss:-1.6419
# shape:  torch.Size([1, 3, 18, 18])
# epoch [145/200], loss:-1.7873
# shape:  torch.Size([1, 3, 18, 18])
# epoch [146/200], loss:-1.6242
# shape:  torch.Size([1, 3, 18, 18])
# epoch [147/200], loss:-1.6699
# shape:  torch.Size([1, 3, 18, 18])
# epoch [148/200], loss:-1.6556
# shape:  torch.Size([1, 3, 18, 18])
# epoch [149/200], loss:-1.7551
# shape:  torch.Size([1, 3, 18, 18])
# epoch [150/200], loss:-1.7409
# shape:  torch.Size([1, 3, 18, 18])
# epoch [151/200], loss:-1.5153
# shape:  torch.Size([1, 3, 18, 18])
# epoch [152/200], loss:-1.6595
# shape:  torch.Size([1, 3, 18, 18])
# epoch [153/200], loss:-1.7925
# shape:  torch.Size([1, 3, 18, 18])
# epoch [154/200], loss:-1.7372
# shape:  torch.Size([1, 3, 18, 18])
# epoch [155/200], loss:-1.7644
# shape:  torch.Size([1, 3, 18, 18])
# epoch [156/200], loss:-1.6499
# shape:  torch.Size([1, 3, 18, 18])
# epoch [157/200], loss:-1.6349
# shape:  torch.Size([1, 3, 18, 18])
# epoch [158/200], loss:-1.7695
# shape:  torch.Size([1, 3, 18, 18])
# epoch [159/200], loss:-1.7003
# shape:  torch.Size([1, 3, 18, 18])
# epoch [160/200], loss:-1.6295
# shape:  torch.Size([1, 3, 18, 18])
# epoch [161/200], loss:-1.7439
# shape:  torch.Size([1, 3, 18, 18])
# epoch [162/200], loss:-1.7563
# shape:  torch.Size([1, 3, 18, 18])
# epoch [163/200], loss:-1.6895
# shape:  torch.Size([1, 3, 18, 18])
# epoch [164/200], loss:-1.7423
# shape:  torch.Size([1, 3, 18, 18])
# epoch [165/200], loss:-1.6505
# shape:  torch.Size([1, 3, 18, 18])
# epoch [166/200], loss:-1.7687
# shape:  torch.Size([1, 3, 18, 18])
# epoch [167/200], loss:-1.6081
# shape:  torch.Size([1, 3, 18, 18])
# epoch [168/200], loss:-1.5757
# shape:  torch.Size([1, 3, 18, 18])
# epoch [169/200], loss:-1.6623
# shape:  torch.Size([1, 3, 18, 18])
# epoch [170/200], loss:-1.7831
# shape:  torch.Size([1, 3, 18, 18])
# epoch [171/200], loss:-1.7442
# shape:  torch.Size([1, 3, 18, 18])
# epoch [172/200], loss:-1.6805
# shape:  torch.Size([1, 3, 18, 18])
# epoch [173/200], loss:-1.5697
# shape:  torch.Size([1, 3, 18, 18])
# epoch [174/200], loss:-1.6517
# shape:  torch.Size([1, 3, 18, 18])
# epoch [175/200], loss:-1.7192
# shape:  torch.Size([1, 3, 18, 18])
# epoch [176/200], loss:-1.5610
# shape:  torch.Size([1, 3, 18, 18])
# epoch [177/200], loss:-1.8113
# shape:  torch.Size([1, 3, 18, 18])
# epoch [178/200], loss:-1.6662
# shape:  torch.Size([1, 3, 18, 18])
# epoch [179/200], loss:-1.6325
# shape:  torch.Size([1, 3, 18, 18])
# epoch [180/200], loss:-1.6948
# shape:  torch.Size([1, 3, 18, 18])
# epoch [181/200], loss:-1.7621
# shape:  torch.Size([1, 3, 18, 18])
# epoch [182/200], loss:-1.4843
# shape:  torch.Size([1, 3, 18, 18])
# epoch [183/200], loss:-1.7093
# shape:  torch.Size([1, 3, 18, 18])
# epoch [184/200], loss:-1.6951
# shape:  torch.Size([1, 3, 18, 18])
# epoch [185/200], loss:-1.7461
# shape:  torch.Size([1, 3, 18, 18])
# epoch [186/200], loss:-1.6201
# shape:  torch.Size([1, 3, 18, 18])
# epoch [187/200], loss:-1.5964
# shape:  torch.Size([1, 3, 18, 18])
# epoch [188/200], loss:-1.6476
# shape:  torch.Size([1, 3, 18, 18])
# epoch [189/200], loss:-1.7142
# shape:  torch.Size([1, 3, 18, 18])
# epoch [190/200], loss:-1.6113
# shape:  torch.Size([1, 3, 18, 18])
# epoch [191/200], loss:-1.7220
# shape:  torch.Size([1, 3, 18, 18])
# epoch [192/200], loss:-1.7013
# shape:  torch.Size([1, 3, 18, 18])
# epoch [193/200], loss:-1.7582
# shape:  torch.Size([1, 3, 18, 18])
# epoch [194/200], loss:-1.6929
# shape:  torch.Size([1, 3, 18, 18])
# epoch [195/200], loss:-1.8032
# shape:  torch.Size([1, 3, 18, 18])
# epoch [196/200], loss:-1.7704
# shape:  torch.Size([1, 3, 18, 18])
# epoch [197/200], loss:-1.6309
# shape:  torch.Size([1, 3, 18, 18])
# epoch [198/200], loss:-1.8126
# shape:  torch.Size([1, 3, 18, 18])
# epoch [199/200], loss:-1.9570
# shape:  torch.Size([1, 3, 18, 18])
# epoch [200/200], loss:-1.6003
# shape:  torch.Size([1, 3, 18, 18])

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(1):
    k = uframes[1]
    k.show()
    v = np.array(np.transpose(np.asarray(uframes[1]),(2,0,1)),dtype=np.float32)
    v = torch.from_numpy(v)
    filename = "Testing features-18x18/flattened_weights" + str(i) + ".txt"
    file = open(filename, 'w')
    file.write(str(model(v.reshape(1,3,100, 100))[0].view(model(v.reshape(1,3,100, 100))[0].size(0), -1).detach().numpy()))
    
    file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

filename = "Testing features-18x18/fc_weights.txt"
file = open(filename, 'w')
k=model.fc1.weight.detach().numpy()
file.write(str(k))
print(np.shape(k))
file.close()
# Out:
# (15, 972)

# %%
import operator
for i in range(15):
    index, value = max(enumerate(k[i]), key=operator.itemgetter(1))
    print(index,value)
# Out:
# 19 0.15882565
# 909 0.053384442
# 621 0.10594394
# 19 0.14024815
# 324 0.08181751
# 19 0.20711575
# 379 0.04618722
# 585 0.056471404
# 621 0.07029031
# 550 0.051472645
# 324 0.07888084
# 324 0.052968647
# 379 0.049390156
# 324 0.047608472
# 19 0.044314206

# %%
import random


p=0
class_data = []
while(p<len(uframes)):
    data3=[]
    print(p)
    for i in range(50):
        img = uframes[p]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        temp = model(x_1[i].reshape(1,3,100,100))[1]
        #print(temp)
        class_data.append((list(temp.detach().numpy()[0]),p))
    p+=1
    print(len(class_data))

random.shuffle(class_data)
random.shuffle(class_data)

print("length ", len(class_data))
# Out:
# 0
# 50
# 1
# 100
# 2
# 150
# 3
# 200
# 4
# 250
# 5
# 300
# 6
# 350
# 7
# 400
# 8
# 450
# 9
# 500
# 10
# 550
# 11
# 600
# length  600

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from colorama import init  
import time
import cv2

print(np.shape(uframes[0]))


#z  = np.array(np.transpose(np.asarray(z),(2,0,1)),dtype=np.float32)
# import some data to play with
print("Length of Class data: ", len(class_data))
# Take the first two features. We could avoid this by using a two-dim dataset
X = [(i[0]) for i in class_data]
y = [i[1] for i in class_data]
#print(X,np.shape(X))
#print(y,np.shape(y))
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel='linear', C=C)
clf = clf.fit(X, y)
data3=[]
y3=0

n1 = "\x1b[31m\"Drone Stationary, Tank Firing\"\x1b[0m"
n2 = "\x1b[31m\"Drone Reloading, Tank Firing\"\x1b[0m"
n3 = "\x1b[31m\"Drone Firing, Tank Stationary\"\x1b[0m"
n4 = "\x1b[31m\"Drone Firing, Tank Reloading\"\x1b[0m"
n5 = "\x1b[31m\"Drone Firing, Tank Firing\"\x1b[0m"

names = ['Just Background','Only Tank moving', 'Only Drone Moving', 'Drone stationary, Tank Stationary', 'Drone Stationary, Tank Reloading' ,
         n1, 'Drone reloading, Tank Stationary', 'Drone reloading, Tank Reloading', n2 , n3,n4,n5]

print("Start")

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

for i in range(12):
    #z = cv2.imread('Images_100/0a.png')
    #l = Image.fromarray(z)
#     print("shape of z", np.shape(z),type(z))
#     #l.show()
#     #z  = cv2.resize(z,(100,100))
#     img = uframes[i]
#     print(np.shape(img))
#     img.show()
#     data3.append(np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32))
#     y3 = np.array(data3)
#     x_1 = torch.from_numpy(y3)
# #     random_img = random.choice(x)
# #     print("random", np.shape(random_img),type(random_img))
# #     show = random_img.detach().numpy() * 255
# #     show = np.array(np.transpose(show,(1,2,0)),dtype=np.uint8)
# #     print("show", np.shape(show),type(show))
# #     ms = Image.fromarray(show)
# #     ms.show()
#     temp = model(x_1[i].reshape(1,3,100,100))[1]
#     temp = temp.detach().numpy()
#     img_blank.show()
#     #print(temp)
#     z = clf.predict(temp)
#     print(names[z[0]])
    img = uframes[i]
    print(np.shape(img))
    img.show()
    #ms = Image.fromarray(z)
    #ms.show()
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    temp = model(x_1[i].reshape(1,3,100,100))[1]
    temp = temp.detach().numpy()
    print(temp)
    z = clf.predict(temp)
    print(names[z[0]])
# Out:
# (100, 100, 3)
# Length of Class data:  600
# Start
# (100, 100, 3)
# [[0.9916 0.9999 0.4063 0.2608 1.     0.6005 0.2732 0.6298 1.     0.9986
#   1.     1.     0.0005 0.9134 0.0005]]
# Just Background
# (100, 100, 3)
# [[0.9976 0.9962 0.0002 1.     0.9739 0.999  0.7184 0.1783 0.9971 0.9987
#   0.9721 0.9911 0.0086 0.4307 0.0088]]
# Only Tank moving
# (100, 100, 3)
# [[1.     0.9976 0.     0.9998 0.5138 1.     0.9953 0.0037 0.9989 0.9998
#   0.5131 0.5967 0.433  0.0042 0.4404]]
# Only Drone Moving
# (100, 100, 3)
# [[1.     0.871  0.     1.     0.0002 1.     0.9993 0.0005 0.8829 0.9998
#   0.0002 0.0042 0.9357 0.0003 0.9386]]
# Drone stationary, Tank Stationary
# (100, 100, 3)
# [[0.9997 0.341  0.     1.     0.0038 1.     0.5173 0.5586 0.3735 0.988
#   0.0041 0.0034 0.9997 0.9416 0.9997]]
# Drone Stationary, Tank Reloading
# (100, 100, 3)
# [[1.     0.0006 0.0004 0.998  0.0439 0.9995 0.0569 0.9984 0.0008 1.
#   0.0472 0.019  0.6184 0.9494 0.6172]]
# "Drone Stationary, Tank Firing"
# (100, 100, 3)
# [[0.2888 0.0001 0.0045 1.     0.     0.9947 0.0001 0.9999 0.0001 1.
#   0.     0.3727 0.     0.     0.    ]]
# Drone reloading, Tank Stationary
# (100, 100, 3)
# [[0.0036 0.     0.5477 1.     0.0001 0.4544 0.     1.     0.     0.9998
#   0.0002 0.7865 0.0001 0.0001 0.0001]]
# Drone reloading, Tank Reloading
# (100, 100, 3)
# [[0.5442 0.     0.9991 0.9998 0.0016 0.0009 0.     1.     0.     1.
#   0.0016 0.704  0.     0.0001 0.    ]]
# "Drone Reloading, Tank Firing"
# (100, 100, 3)
# [[1.     1.     0.9994 0.9999 0.0095 0.0006 0.0003 0.9996 1.     0.1643
#   0.0103 0.146  0.     0.2295 0.0001]]
# "Drone Firing, Tank Stationary"
# (100, 100, 3)
# [[0.9986 1.     1.     0.5106 0.1819 0.     0.     1.     1.     0.0036
#   0.1807 0.1233 0.0105 0.9999 0.0129]]
# "Drone Firing, Tank Reloading"
# (100, 100, 3)
# [[1.     0.9975 1.     0.0017 0.7289 0.     0.     1.     0.998  0.6171
#   0.7273 0.4414 0.     0.9999 0.    ]]
# "Drone Firing, Tank Firing"

# %%
print(len(uframes
         ))
# Out:
# 12

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(60,60),imt.rotate(180))
#img_blank.paste(im_drone.resize((10,10)),(10,30),im_drone.resize((10,10)))
#img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
#draw = ImageDraw.Draw(img_blank)
#draw.ellipse((60,60,68,68), fill=(255, 0, 0))
# img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
#draw = ImageDraw.Draw(img_blank)
#draw.ellipse((10,30,18,38), fill=(50, 182, 150))
#img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
#img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
img_blank.show()
pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
filename = "lesser_15_features/testing.txt"
file = open(filename, 'w')
file.write(str(model(pil.reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)
img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
img_blank.show()
pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
filename = "Testing features-18x18/drone_pos3.txt"
file = open(filename, 'w')
file.write(str(model(pil.reshape(1,3,100, 100))[0].detach().numpy()))
file.close()
