# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random
import cv2
from torchvision import models
from torchsummary import summary

Batch_Size = 50
num_epochs = 200
learning_rate = 1e-5
samples = 10000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
uframes = []

im1 = Image.open('tree1.png')
im1 = im1.resize((8,8))

imt = Image.open('tank.png')
imt = imt.resize((10,10))


im2 = Image.open('tree2.png')
im2 = im2.resize((8,8))

im3 = Image.open('tree3.png')
im3 = im3.resize((8,8))

im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((10,10))

imb = Image.open('bullet.png')
imb = imb.resize((2,2))

for i in range(1):
    
    #blank
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)

    uframes.append(img_blank)
    
    #only tank
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    
    uframes.append(img_blank)
    
    #only drone
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t1d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t2d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((30,30,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t3d1
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))
    
    uframes.append(img_blank)
    
    #t1d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,45,43,53), fill=(50, 182, 150))
    
    uframes.append(img_blank)
    
    #t2d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((30,30,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw.ellipse((35,45,43,53), fill=(50, 182, 150))
    
    
    uframes.append(img_blank)
    
    #t3d2
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((35,45,43,53), fill=(50, 182, 150))
    
    
    uframes.append(img_blank)
    
    #t1d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    uframes.append(img_blank)
    
    #t2d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
    draw = ImageDraw.Draw(img_blank)
    draw.ellipse((30,30,38,38), fill=(255, 0, 0))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    
    uframes.append(img_blank)
    
    #t3d3
    img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
    img_blank.paste(im1,(5,7),im1)
    img_blank.paste(im1,(45,55),im1)
    img_blank.paste(im1,(25,72),im1)
    img_blank.paste(im2,(50,90),im2)
    img_blank.paste(im2,(60,75),im2)
    img_blank.paste(im2,(30,40),im2)
    img_blank.paste(im3,(10,60),im3)
    img_blank.paste(im3,(44,62),im3)
    img_blank.paste(im3,(30,15),im3)
    img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
    img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
    img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
    img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))
    
    
    uframes.append(img_blank)



for i in range(samples):
    data1.append(np.array(np.transpose(np.asarray(uframes[i % len(uframes)]),(2,0,1)),dtype=np.float32))
    data2.append(np.array(np.transpose(np.asarray(uframes[(i+1) % len(uframes)]),(2,0,1)),dtype=np.float32))



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = '#9b7653')
img.paste(im1,(5,75),im1)
img.paste(im1,(10,55),im1)
img.paste(im1,(25,50),im1)
img.paste(im2,(75,5),im2)
img.paste(im2,(60,30),im2)
img.paste(im2,(90,20),im2)
img.paste(im3,(75,60),im3)
img.paste(im3,(60,80),im3)
im_n = np.reshape(img,(100,100,3))
b = np.asarray(im_n)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)

#y0 = np.array(np.transpose(np.asarray(y0),(0,3,1,2)),dtype=np.float32)
#y1 = np.array(np.transpose(np.asarray(y1),(0,3,1,2)),dtype=np.float32)
print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=10, stride=1)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)

        # Convolution 2
        self.cnn2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=10, stride=1)
        self.relu2 = nn.ReLU()

        # Max pool 2
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)
        
        # Convolution 3
        self.cnn3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=10, stride=1)
        self.relu3 = nn.ReLU()

        # Max pool 2
        self.maxpool3 = nn.MaxPool2d(kernel_size=5)
        

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(64, 15)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        out = self.cnn2(out)
        out = self.relu2(out)

        # Max pool 2 
        out = self.maxpool2(out)
        
        # Convolution 3 
        out = self.cnn3(out)
        out = self.relu3(out)

        # Max pool 2 
        out = self.maxpool3(out)
        
        im_out = out
        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return im_out,out
    
model = CNNModel()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x)[1],model(y)[1])
        # ===================backward====================
 
        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    print("shape: ", np.shape(model(x[0].reshape(1,3,100, 100))[0]))
#     print("x: ", model(x[0].reshape(1,3,100, 100)))
#     print("y:", model(y[0].reshape(1,3,100, 100)))
#     print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# (10000, 3, 100, 100)
# epoch [1/200], loss:-0.0921
# shape:  torch.Size([1, 64, 1, 1])
# epoch [2/200], loss:-0.6552
# shape:  torch.Size([1, 64, 1, 1])
# epoch [3/200], loss:-0.7194
# shape:  torch.Size([1, 64, 1, 1])
# epoch [4/200], loss:-0.6627
# shape:  torch.Size([1, 64, 1, 1])
# epoch [5/200], loss:-0.5475
# shape:  torch.Size([1, 64, 1, 1])
# epoch [6/200], loss:-0.3835
# shape:  torch.Size([1, 64, 1, 1])
# epoch [7/200], loss:-0.5220
# shape:  torch.Size([1, 64, 1, 1])
# epoch [8/200], loss:-0.6945
# shape:  torch.Size([1, 64, 1, 1])
# epoch [9/200], loss:-0.6208
# shape:  torch.Size([1, 64, 1, 1])
# epoch [10/200], loss:-0.7826
# shape:  torch.Size([1, 64, 1, 1])
# epoch [11/200], loss:-0.8273
# shape:  torch.Size([1, 64, 1, 1])
# epoch [12/200], loss:-0.7624
# shape:  torch.Size([1, 64, 1, 1])
# epoch [13/200], loss:-0.9210
# shape:  torch.Size([1, 64, 1, 1])
# epoch [14/200], loss:-0.7817
# shape:  torch.Size([1, 64, 1, 1])
# epoch [15/200], loss:-1.2007
# shape:  torch.Size([1, 64, 1, 1])
# epoch [16/200], loss:-1.1339
# shape:  torch.Size([1, 64, 1, 1])
# epoch [17/200], loss:-1.3538
# shape:  torch.Size([1, 64, 1, 1])
# epoch [18/200], loss:-1.3351
# shape:  torch.Size([1, 64, 1, 1])
# epoch [19/200], loss:-1.4649
# shape:  torch.Size([1, 64, 1, 1])
# epoch [20/200], loss:-1.0837
# shape:  torch.Size([1, 64, 1, 1])
# epoch [21/200], loss:-1.2603
# shape:  torch.Size([1, 64, 1, 1])
# epoch [22/200], loss:-1.3988
# shape:  torch.Size([1, 64, 1, 1])
# epoch [23/200], loss:-1.3598
# shape:  torch.Size([1, 64, 1, 1])
# epoch [24/200], loss:-1.3651
# shape:  torch.Size([1, 64, 1, 1])
# epoch [25/200], loss:-1.4948
# shape:  torch.Size([1, 64, 1, 1])
# epoch [26/200], loss:-1.2673
# shape:  torch.Size([1, 64, 1, 1])
# epoch [27/200], loss:-1.5364
# shape:  torch.Size([1, 64, 1, 1])
# epoch [28/200], loss:-1.3555
# shape:  torch.Size([1, 64, 1, 1])
# epoch [29/200], loss:-1.5321
# shape:  torch.Size([1, 64, 1, 1])
# epoch [30/200], loss:-1.3307
# shape:  torch.Size([1, 64, 1, 1])
# epoch [31/200], loss:-1.5081
# shape:  torch.Size([1, 64, 1, 1])
# epoch [32/200], loss:-1.5363
# shape:  torch.Size([1, 64, 1, 1])
# epoch [33/200], loss:-1.4274
# shape:  torch.Size([1, 64, 1, 1])
# epoch [34/200], loss:-1.2988
# shape:  torch.Size([1, 64, 1, 1])
# epoch [35/200], loss:-1.4695
# shape:  torch.Size([1, 64, 1, 1])
# epoch [36/200], loss:-1.5068
# shape:  torch.Size([1, 64, 1, 1])
# epoch [37/200], loss:-1.3769
# shape:  torch.Size([1, 64, 1, 1])
# epoch [38/200], loss:-1.3798
# shape:  torch.Size([1, 64, 1, 1])
# epoch [39/200], loss:-1.4816
# shape:  torch.Size([1, 64, 1, 1])
# epoch [40/200], loss:-1.4570
# shape:  torch.Size([1, 64, 1, 1])
# epoch [41/200], loss:-1.2715
# shape:  torch.Size([1, 64, 1, 1])
# epoch [42/200], loss:-1.5437
# shape:  torch.Size([1, 64, 1, 1])
# epoch [43/200], loss:-1.5219
# shape:  torch.Size([1, 64, 1, 1])
# epoch [44/200], loss:-1.5256
# shape:  torch.Size([1, 64, 1, 1])
# epoch [45/200], loss:-1.4035
# shape:  torch.Size([1, 64, 1, 1])
# epoch [46/200], loss:-1.5455
# shape:  torch.Size([1, 64, 1, 1])
# epoch [47/200], loss:-1.5743
# shape:  torch.Size([1, 64, 1, 1])
# epoch [48/200], loss:-1.4914
# shape:  torch.Size([1, 64, 1, 1])
# epoch [49/200], loss:-1.6048
# shape:  torch.Size([1, 64, 1, 1])
# epoch [50/200], loss:-1.5694
# shape:  torch.Size([1, 64, 1, 1])
# epoch [51/200], loss:-1.6129
# shape:  torch.Size([1, 64, 1, 1])
# epoch [52/200], loss:-1.5902
# shape:  torch.Size([1, 64, 1, 1])
# epoch [53/200], loss:-1.7139
# shape:  torch.Size([1, 64, 1, 1])
# epoch [54/200], loss:-1.5912
# shape:  torch.Size([1, 64, 1, 1])
# epoch [55/200], loss:-1.6882
# shape:  torch.Size([1, 64, 1, 1])
# epoch [56/200], loss:-1.6677
# shape:  torch.Size([1, 64, 1, 1])
# epoch [57/200], loss:-1.6140
# shape:  torch.Size([1, 64, 1, 1])
# epoch [58/200], loss:-1.7691
# shape:  torch.Size([1, 64, 1, 1])
# epoch [59/200], loss:-1.7168
# shape:  torch.Size([1, 64, 1, 1])
# epoch [60/200], loss:-1.7317
# shape:  torch.Size([1, 64, 1, 1])
# epoch [61/200], loss:-1.7666
# shape:  torch.Size([1, 64, 1, 1])
# epoch [62/200], loss:-1.7086
# shape:  torch.Size([1, 64, 1, 1])
# epoch [63/200], loss:-1.8670
# shape:  torch.Size([1, 64, 1, 1])
# epoch [64/200], loss:-1.7085
# shape:  torch.Size([1, 64, 1, 1])
# epoch [65/200], loss:-1.8035
# shape:  torch.Size([1, 64, 1, 1])
# epoch [66/200], loss:-1.7319
# shape:  torch.Size([1, 64, 1, 1])
# epoch [67/200], loss:-1.7865
# shape:  torch.Size([1, 64, 1, 1])
# epoch [68/200], loss:-1.7970
# shape:  torch.Size([1, 64, 1, 1])
# epoch [69/200], loss:-1.7838
# shape:  torch.Size([1, 64, 1, 1])
# epoch [70/200], loss:-1.8435
# shape:  torch.Size([1, 64, 1, 1])
# epoch [71/200], loss:-1.8256
# shape:  torch.Size([1, 64, 1, 1])
# epoch [72/200], loss:-1.7951
# shape:  torch.Size([1, 64, 1, 1])
# epoch [73/200], loss:-1.7769
# shape:  torch.Size([1, 64, 1, 1])
# epoch [74/200], loss:-1.8069
# shape:  torch.Size([1, 64, 1, 1])
# epoch [75/200], loss:-1.8226
# shape:  torch.Size([1, 64, 1, 1])
# epoch [76/200], loss:-1.8004
# shape:  torch.Size([1, 64, 1, 1])
# epoch [77/200], loss:-1.7354
# shape:  torch.Size([1, 64, 1, 1])
# epoch [78/200], loss:-1.7722
# shape:  torch.Size([1, 64, 1, 1])
# epoch [79/200], loss:-1.7432
# shape:  torch.Size([1, 64, 1, 1])
# epoch [80/200], loss:-1.7325
# shape:  torch.Size([1, 64, 1, 1])
# epoch [81/200], loss:-1.7790
# shape:  torch.Size([1, 64, 1, 1])
# epoch [82/200], loss:-1.8036
# shape:  torch.Size([1, 64, 1, 1])
# epoch [83/200], loss:-1.8481
# shape:  torch.Size([1, 64, 1, 1])
# epoch [84/200], loss:-1.7712
# shape:  torch.Size([1, 64, 1, 1])
# epoch [85/200], loss:-1.7932
# shape:  torch.Size([1, 64, 1, 1])
# epoch [86/200], loss:-1.8124
# shape:  torch.Size([1, 64, 1, 1])
# epoch [87/200], loss:-1.7778
# shape:  torch.Size([1, 64, 1, 1])
# epoch [88/200], loss:-1.7722
# shape:  torch.Size([1, 64, 1, 1])
# epoch [89/200], loss:-1.8250
# shape:  torch.Size([1, 64, 1, 1])
# epoch [90/200], loss:-1.7807
# shape:  torch.Size([1, 64, 1, 1])
# epoch [91/200], loss:-1.8279
# shape:  torch.Size([1, 64, 1, 1])
# epoch [92/200], loss:-1.7459
# shape:  torch.Size([1, 64, 1, 1])
# epoch [93/200], loss:-1.9319
# shape:  torch.Size([1, 64, 1, 1])
# epoch [94/200], loss:-1.8299
# shape:  torch.Size([1, 64, 1, 1])
# epoch [95/200], loss:-1.8572
# shape:  torch.Size([1, 64, 1, 1])
# epoch [96/200], loss:-1.8596
# shape:  torch.Size([1, 64, 1, 1])
# epoch [97/200], loss:-1.8405
# shape:  torch.Size([1, 64, 1, 1])
# epoch [98/200], loss:-1.8009
# shape:  torch.Size([1, 64, 1, 1])
# epoch [99/200], loss:-1.6628
# shape:  torch.Size([1, 64, 1, 1])
# epoch [100/200], loss:-1.7836
# shape:  torch.Size([1, 64, 1, 1])
# epoch [101/200], loss:-1.8172
# shape:  torch.Size([1, 64, 1, 1])
# epoch [102/200], loss:-1.7989
# shape:  torch.Size([1, 64, 1, 1])
# epoch [103/200], loss:-1.8009
# shape:  torch.Size([1, 64, 1, 1])
# epoch [104/200], loss:-1.8339
# shape:  torch.Size([1, 64, 1, 1])
# epoch [105/200], loss:-1.8504
# shape:  torch.Size([1, 64, 1, 1])
# epoch [106/200], loss:-1.8342
# shape:  torch.Size([1, 64, 1, 1])
# epoch [107/200], loss:-1.7334
# shape:  torch.Size([1, 64, 1, 1])
# epoch [108/200], loss:-1.7548
# shape:  torch.Size([1, 64, 1, 1])
# epoch [109/200], loss:-1.8331
# shape:  torch.Size([1, 64, 1, 1])
# epoch [110/200], loss:-1.8067
# shape:  torch.Size([1, 64, 1, 1])
# epoch [111/200], loss:-1.9106
# shape:  torch.Size([1, 64, 1, 1])
# epoch [112/200], loss:-1.8271
# shape:  torch.Size([1, 64, 1, 1])
# epoch [113/200], loss:-1.8250
# shape:  torch.Size([1, 64, 1, 1])
# epoch [114/200], loss:-1.8518
# shape:  torch.Size([1, 64, 1, 1])
# epoch [115/200], loss:-1.8767
# shape:  torch.Size([1, 64, 1, 1])
# epoch [116/200], loss:-1.8957
# shape:  torch.Size([1, 64, 1, 1])
# epoch [117/200], loss:-1.8371
# shape:  torch.Size([1, 64, 1, 1])
# epoch [118/200], loss:-1.8513
# shape:  torch.Size([1, 64, 1, 1])
# epoch [119/200], loss:-1.8411
# shape:  torch.Size([1, 64, 1, 1])
# epoch [120/200], loss:-1.8660
# shape:  torch.Size([1, 64, 1, 1])
# epoch [121/200], loss:-1.8791
# shape:  torch.Size([1, 64, 1, 1])
# epoch [122/200], loss:-1.8451
# shape:  torch.Size([1, 64, 1, 1])
# epoch [123/200], loss:-1.8403
# shape:  torch.Size([1, 64, 1, 1])
# epoch [124/200], loss:-1.8347
# shape:  torch.Size([1, 64, 1, 1])
# epoch [125/200], loss:-1.8279
# shape:  torch.Size([1, 64, 1, 1])
# epoch [126/200], loss:-1.8666
# shape:  torch.Size([1, 64, 1, 1])
# epoch [127/200], loss:-1.7845
# shape:  torch.Size([1, 64, 1, 1])
# epoch [128/200], loss:-1.8716
# shape:  torch.Size([1, 64, 1, 1])
# epoch [129/200], loss:-1.8443
# shape:  torch.Size([1, 64, 1, 1])
# epoch [130/200], loss:-1.8535
# shape:  torch.Size([1, 64, 1, 1])
# epoch [131/200], loss:-1.8063
# shape:  torch.Size([1, 64, 1, 1])
# epoch [132/200], loss:-1.8998
# shape:  torch.Size([1, 64, 1, 1])
# epoch [133/200], loss:-1.8196
# shape:  torch.Size([1, 64, 1, 1])
# epoch [134/200], loss:-1.8788
# shape:  torch.Size([1, 64, 1, 1])
# epoch [135/200], loss:-1.8525
# shape:  torch.Size([1, 64, 1, 1])
# epoch [136/200], loss:-1.8584
# shape:  torch.Size([1, 64, 1, 1])
# epoch [137/200], loss:-1.8450
# shape:  torch.Size([1, 64, 1, 1])
# epoch [138/200], loss:-1.7546
# shape:  torch.Size([1, 64, 1, 1])
# epoch [139/200], loss:-1.7783
# shape:  torch.Size([1, 64, 1, 1])
# epoch [140/200], loss:-1.8739
# shape:  torch.Size([1, 64, 1, 1])
# epoch [141/200], loss:-1.8707
# shape:  torch.Size([1, 64, 1, 1])
# epoch [142/200], loss:-1.8463
# shape:  torch.Size([1, 64, 1, 1])
# epoch [143/200], loss:-1.8684
# shape:  torch.Size([1, 64, 1, 1])
# epoch [144/200], loss:-1.8852
# shape:  torch.Size([1, 64, 1, 1])
# epoch [145/200], loss:-1.7537
# shape:  torch.Size([1, 64, 1, 1])
# epoch [146/200], loss:-1.7989
# shape:  torch.Size([1, 64, 1, 1])
# epoch [147/200], loss:-1.8738
# shape:  torch.Size([1, 64, 1, 1])
# epoch [148/200], loss:-1.8982
# shape:  torch.Size([1, 64, 1, 1])
# epoch [149/200], loss:-1.8550
# shape:  torch.Size([1, 64, 1, 1])
# epoch [150/200], loss:-1.8646
# shape:  torch.Size([1, 64, 1, 1])
# epoch [151/200], loss:-1.8495
# shape:  torch.Size([1, 64, 1, 1])
# epoch [152/200], loss:-1.7602
# shape:  torch.Size([1, 64, 1, 1])
# epoch [153/200], loss:-1.8570
# shape:  torch.Size([1, 64, 1, 1])
# epoch [154/200], loss:-1.9006
# shape:  torch.Size([1, 64, 1, 1])
# epoch [155/200], loss:-1.8307
# shape:  torch.Size([1, 64, 1, 1])
# epoch [156/200], loss:-1.8545
# shape:  torch.Size([1, 64, 1, 1])
# epoch [157/200], loss:-1.8744
# shape:  torch.Size([1, 64, 1, 1])
# epoch [158/200], loss:-1.8900
# shape:  torch.Size([1, 64, 1, 1])
# epoch [159/200], loss:-1.7562
# shape:  torch.Size([1, 64, 1, 1])
# epoch [160/200], loss:-1.9180
# shape:  torch.Size([1, 64, 1, 1])
# epoch [161/200], loss:-1.8038
# shape:  torch.Size([1, 64, 1, 1])
# epoch [162/200], loss:-1.8655
# shape:  torch.Size([1, 64, 1, 1])
# epoch [163/200], loss:-1.8981
# shape:  torch.Size([1, 64, 1, 1])
# epoch [164/200], loss:-1.8878
# shape:  torch.Size([1, 64, 1, 1])
# epoch [165/200], loss:-1.8282
# shape:  torch.Size([1, 64, 1, 1])
# epoch [166/200], loss:-1.9174
# shape:  torch.Size([1, 64, 1, 1])
# epoch [167/200], loss:-1.7758
# shape:  torch.Size([1, 64, 1, 1])
# epoch [168/200], loss:-1.9388
# shape:  torch.Size([1, 64, 1, 1])
# epoch [169/200], loss:-1.8548
# shape:  torch.Size([1, 64, 1, 1])
# epoch [170/200], loss:-1.8881
# shape:  torch.Size([1, 64, 1, 1])
# epoch [171/200], loss:-1.8731
# shape:  torch.Size([1, 64, 1, 1])
# epoch [172/200], loss:-1.8820
# shape:  torch.Size([1, 64, 1, 1])
# epoch [173/200], loss:-1.8716
# shape:  torch.Size([1, 64, 1, 1])
# epoch [174/200], loss:-1.8701
# shape:  torch.Size([1, 64, 1, 1])
# epoch [175/200], loss:-1.8755
# shape:  torch.Size([1, 64, 1, 1])
# epoch [176/200], loss:-1.9110
# shape:  torch.Size([1, 64, 1, 1])
# epoch [177/200], loss:-1.8621
# shape:  torch.Size([1, 64, 1, 1])
# epoch [178/200], loss:-1.8579
# shape:  torch.Size([1, 64, 1, 1])
# epoch [179/200], loss:-1.8433
# shape:  torch.Size([1, 64, 1, 1])
# epoch [180/200], loss:-1.8881
# shape:  torch.Size([1, 64, 1, 1])
# epoch [181/200], loss:-1.9073
# shape:  torch.Size([1, 64, 1, 1])
# epoch [182/200], loss:-1.8603
# shape:  torch.Size([1, 64, 1, 1])
# epoch [183/200], loss:-1.8577
# shape:  torch.Size([1, 64, 1, 1])
# epoch [184/200], loss:-1.8999
# shape:  torch.Size([1, 64, 1, 1])
# epoch [185/200], loss:-1.8472
# shape:  torch.Size([1, 64, 1, 1])
# epoch [186/200], loss:-1.8893
# shape:  torch.Size([1, 64, 1, 1])
# epoch [187/200], loss:-1.9170
# shape:  torch.Size([1, 64, 1, 1])
# epoch [188/200], loss:-1.8909
# shape:  torch.Size([1, 64, 1, 1])
# epoch [189/200], loss:-1.9124
# shape:  torch.Size([1, 64, 1, 1])
# epoch [190/200], loss:-1.8786
# shape:  torch.Size([1, 64, 1, 1])
# epoch [191/200], loss:-1.8785
# shape:  torch.Size([1, 64, 1, 1])
# epoch [192/200], loss:-1.9246
# shape:  torch.Size([1, 64, 1, 1])
# epoch [193/200], loss:-1.9051
# shape:  torch.Size([1, 64, 1, 1])
# epoch [194/200], loss:-1.8659
# shape:  torch.Size([1, 64, 1, 1])
# epoch [195/200], loss:-1.7794
# shape:  torch.Size([1, 64, 1, 1])
# epoch [196/200], loss:-1.9291
# shape:  torch.Size([1, 64, 1, 1])
# epoch [197/200], loss:-1.8954
# shape:  torch.Size([1, 64, 1, 1])
# epoch [198/200], loss:-1.9328
# shape:  torch.Size([1, 64, 1, 1])
# epoch [199/200], loss:-1.8543
# shape:  torch.Size([1, 64, 1, 1])
# epoch [200/200], loss:-1.9256
# shape:  torch.Size([1, 64, 1, 1])

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(12):
    k = uframes[i]
    k.show()
    v = np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32)
    v = torch.from_numpy(v)
    filename = "Testing features-Copy3/ref_image_new_" + str(i) + ".txt"
    file = open(filename, 'w')
    file.write(str(model(v.reshape(1,3,100, 100))[0].detach().numpy()))
    file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
#img_blank.paste(imt.rotate(180),(60,60),imt.rotate(180))
img_blank.paste(im_drone.resize((10,10)),(10,30),im_drone.resize((10,10)))
#img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
#draw = ImageDraw.Draw(img_blank)
#draw.ellipse((60,60,68,68), fill=(255, 0, 0))
# img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
draw = ImageDraw.Draw(img_blank)
draw.ellipse((10,30,18,38), fill=(50, 182, 150))
#img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
#img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
filename = "Testing features-Copy3/drone_random_reloading.txt"
file = open(filename, 'w')
file.write(str(model(pil.reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import random


p=0
class_data = []
while(p<len(uframes)):
    data3=[]
    print(p)
    for i in range(50):
        img = uframes[p]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        temp = model(x_1[i].reshape(1,3,100,100))[1]
        #print(temp)
        class_data.append((list(temp.detach().numpy()[0]),p))
    p+=1
    print(len(class_data))

random.shuffle(class_data)
random.shuffle(class_data)

print("length ", len(class_data))
# Out:
# 0
# 50
# 1
# 100
# 2
# 150
# 3
# 200
# 4
# 250
# 5
# 300
# 6
# 350
# 7
# 400
# 8
# 450
# 9
# 500
# 10
# 550
# 11
# 600
# length  600

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from colorama import init  
import time
import cv2

print(np.shape(uframes[0]))


#z  = np.array(np.transpose(np.asarray(z),(2,0,1)),dtype=np.float32)
# import some data to play with
print("Length of Class data: ", len(class_data))
# Take the first two features. We could avoid this by using a two-dim dataset
X = [(i[0]) for i in class_data]
y = [i[1] for i in class_data]
#print(X,np.shape(X))
#print(y,np.shape(y))
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel='linear', C=C)
clf = clf.fit(X, y)
data3=[]
y3=0

n1 = "\x1b[31m\"Drone Stationary, Tank Firing\"\x1b[0m"
n2 = "\x1b[31m\"Drone Reloading, Tank Firing\"\x1b[0m"
n3 = "\x1b[31m\"Drone Firing, Tank Stationary\"\x1b[0m"
n4 = "\x1b[31m\"Drone Firing, Tank Reloading\"\x1b[0m"
n5 = "\x1b[31m\"Drone Firing, Tank Firing\"\x1b[0m"

names = ['Just Background','Only Tank moving', 'Only Drone Moving', 'Drone stationary, Tank Stationary', 'Drone Stationary, Tank Reloading' ,
         n1, 'Drone reloading, Tank Stationary', 'Drone reloading, Tank Reloading', n2 , n3,n4,n5]

print("Start")

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

for i in range(12):
    #z = cv2.imread('Images_100/0a.png')
    #l = Image.fromarray(z)
#     print("shape of z", np.shape(z),type(z))
#     #l.show()
#     #z  = cv2.resize(z,(100,100))
#     img = uframes[i]
#     print(np.shape(img))
#     img.show()
#     data3.append(np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32))
#     y3 = np.array(data3)
#     x_1 = torch.from_numpy(y3)
# #     random_img = random.choice(x)
# #     print("random", np.shape(random_img),type(random_img))
# #     show = random_img.detach().numpy() * 255
# #     show = np.array(np.transpose(show,(1,2,0)),dtype=np.uint8)
# #     print("show", np.shape(show),type(show))
# #     ms = Image.fromarray(show)
# #     ms.show()
#     temp = model(x_1[i].reshape(1,3,100,100))[1]
#     temp = temp.detach().numpy()
#     img_blank.show()
#     #print(temp)
#     z = clf.predict(temp)
#     print(names[z[0]])
    img = uframes[i]
    print(np.shape(img))
    img.show()
    #ms = Image.fromarray(z)
    #ms.show()
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    temp = model(x_1[i].reshape(1,3,100,100))[1]
    temp = temp.detach().numpy()
    print(temp)
    z = clf.predict(temp)
    print(names[z[0]])
# Out:
# (100, 100, 3)
# Length of Class data:  600
# Start
# (100, 100, 3)
# [[9.9964762e-01 8.1897885e-01 9.9978477e-01 9.9996102e-01 5.4822757e-04
#   1.7027254e-01 2.9592840e-02 1.5681053e-03 3.6965781e-01 9.9973506e-01
#   9.9203473e-01 9.9998331e-01 6.1879742e-01 1.1223551e-03 2.9726899e-03]]
# Just Background
# (100, 100, 3)
# [[0.99583226 0.265868   0.9995672  0.9989673  0.04256432 0.72421557
#   0.5408718  0.02209499 0.8653821  0.9898577  0.5801916  0.99977237
#   0.99451447 0.03037894 0.00331354]]
# Only Tank moving
# (100, 100, 3)
# [[9.8752034e-01 1.0831837e-03 9.9994302e-01 7.8011924e-01 5.5020463e-01
#   9.7588491e-01 9.9971348e-01 3.2476979e-04 9.8718041e-01 9.9932706e-01
#   9.7922184e-02 9.5010996e-01 9.9121070e-01 4.6754545e-01 1.4878098e-03]]
# Only Drone Moving
# (100, 100, 3)
# [[0.68783057 0.0043087  0.9995285  0.27069035 0.9838361  0.989489
#   0.9999914  0.00772426 0.99035674 0.8568874  0.00206856 0.50795484
#   0.9998982  0.952459   0.00235231]]
# Drone stationary, Tank Stationary
# (100, 100, 3)
# [[1.8987429e-01 5.1870131e-01 9.9886084e-01 2.1286076e-04 9.9800962e-01
#   5.5232513e-01 9.9934810e-01 1.1371014e-04 7.4991482e-01 3.7955874e-01
#   3.0698136e-03 4.7191779e-06 9.9828869e-01 9.9766111e-01 6.8121110e-05]]
# Drone Stationary, Tank Reloading
# (100, 100, 3)
# [[4.5261186e-05 9.9985492e-01 5.9735614e-01 4.2898310e-03 4.7580916e-01
#   2.5697304e-02 9.9993300e-01 1.3488200e-03 2.9780614e-01 9.8319456e-04
#   2.9265743e-02 4.0409630e-03 9.9954408e-01 9.7050923e-01 3.4016899e-05]]
# "Drone Stationary, Tank Firing"
# (100, 100, 3)
# [[1.3845547e-03 9.9993527e-01 6.8983153e-02 1.6334965e-05 4.5017885e-05
#   5.2093654e-03 9.9993718e-01 5.3166747e-01 4.6761055e-04 4.7991672e-04
#   1.7939712e-03 7.1636987e-01 9.9139386e-01 4.0308306e-01 4.6754014e-04]]
# Drone reloading, Tank Stationary
# (100, 100, 3)
# [[2.5970364e-01 9.9999988e-01 9.2476672e-05 3.6722867e-07 3.1409706e-03
#   6.0235518e-01 9.9999607e-01 9.9983215e-01 2.6669470e-03 2.1924797e-01
#   7.7340643e-05 9.9999022e-01 6.2543005e-01 8.3322674e-03 5.5706108e-01]]
# Drone reloading, Tank Reloading
# (100, 100, 3)
# [[8.3992064e-01 9.9999964e-01 5.3395797e-04 2.6447780e-05 5.5482304e-01
#   9.8526078e-01 7.4662852e-01 9.9997580e-01 7.8781992e-02 7.3597282e-01
#   3.5646665e-04 9.9999976e-01 1.3291574e-01 4.3998696e-04 9.9918646e-01]]
# "Drone Reloading, Tank Firing"
# (100, 100, 3)
# [[9.9973089e-01 9.9991858e-01 1.7025938e-02 3.4621605e-01 9.9187589e-01
#   8.7741667e-01 3.4824872e-01 8.9474332e-01 9.1488801e-02 9.9960250e-01
#   1.7327605e-01 4.0249425e-01 1.9628444e-04 3.3796811e-01 9.9957305e-01]]
# "Drone Firing, Tank Stationary"
# (100, 100, 3)
# [[9.9943334e-01 9.9999344e-01 3.8608927e-01 8.6797702e-01 9.9650747e-01
#   3.0850896e-01 7.0414151e-04 3.4065235e-01 2.0090532e-02 9.9993455e-01
#   6.9137990e-01 1.7837842e-04 3.3980873e-04 6.2191200e-01 9.0706402e-01]]
# "Drone Firing, Tank Reloading"
# (100, 100, 3)
# [[9.9346703e-01 9.9999976e-01 8.2684940e-01 9.9994135e-01 5.0967759e-01
#   3.7681372e-03 1.7038047e-04 6.8789501e-05 4.9080113e-03 9.9102366e-01
#   9.9377269e-01 4.5188636e-01 1.6716768e-01 3.4180108e-01 4.5632690e-01]]
# "Drone Firing, Tank Firing"

# %%
print(len(uframes
         ))
# Out:
# 12
