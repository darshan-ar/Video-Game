# %% [raw]
# In this code, multiple positions, reloading and firing of drone and tank. Drone: Spacecraft. Reloading State: Going Black. Firing State: Firing
#
# Channels:64
# Output: 15
# CNN kernel: 10
# Maxpool kernel:10

# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random
import cv2
from torchvision import models
from torchsummary import summary

Batch_Size = 50
num_epochs = 200
learning_rate = 1e-5
samples = 20000

data1 = []
data2= []


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset
uframes = []
vidcap = cv2.VideoCapture('firing.avi')
success,image = vidcap.read()
while success:
    uframes.append(image)   
    success,image = vidcap.read()

# cap = cv2.VideoCapture('video_drone_tank.avi')


# ret, frame = cap.read()

# uframes.append(frame)
# flag = 0
# z = 0
# while(z<30):
#     ret, frame = cap.read()
#     #np_frame = cv2.imread('video', frame) # does not work
#     #np_frame = np.asarray(cv2.GetMat(frame)) # does not work
#     #print(np_frame.shape)
#     for a in uframes:
#         if (np.array(a).any() != None):
#             print("a: ",np.shape(a))
#             print("frame: ",np.shape(a))
#             difference = cv2.subtract(np.array(a), np.array(frame))    
#             result = not np.any(difference)
#             #print("inside for")
#             if result is True:
#                 flag = 1
#                 #print("setting flag")
#                 break
#     if(not flag):
#         #print("appending")
#         uframes.append(frame)
#     z+=1

for i,frame in enumerate(uframes):
    uframes[i] = cv2.resize(frame,(100,100))
    
print(np.shape(uframes[0]))

print("length: ",len(uframes))
for i in range(samples):
    data1.append(np.array(np.transpose(np.asarray(uframes[i % len(uframes)]),(2,0,1)),dtype=np.float32))
    data2.append(np.array(np.transpose(np.asarray(uframes[(i+1) % len(uframes)]),(2,0,1)),dtype=np.float32))



#%%%%%%%%%%%%%%%%%%%%%%%%%%% Noisy data
img = Image.new('RGB', (100,100), color = '#9b7653')
# img.paste(im1,(5,75),im1)
# img.paste(im1,(10,55),im1)
# img.paste(im1,(25,50),im1)
# img.paste(im2,(75,5),im2)
# img.paste(im2,(60,30),im2)
# img.paste(im2,(90,20),im2)
# img.paste(im3,(75,60),im3)
# img.paste(im3,(60,80),im3)
im_n = np.reshape(img,(100,100,3))
b = np.asarray(im_n)
b = np.array(b, dtype=np.float32)
b = np.transpose(b,(2,0,1))
b = torch.from_numpy(b)

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%       

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Data Preparation

y0 = np.asarray(data1)
y1 = np.asarray(data2)

#y0 = np.array(np.transpose(np.asarray(y0),(0,3,1,2)),dtype=np.float32)
#y1 = np.array(np.transpose(np.asarray(y1),(0,3,1,2)),dtype=np.float32)
print(np.shape(y0))

x = torch.from_numpy(y0)
y = torch.from_numpy(y1)


torch_dataset = Data.TensorDataset(x,y)


loader = Data.DataLoader(

    dataset=torch_dataset,

    batch_size=Batch_Size,

    shuffle=True,

    num_workers=0,

)


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Defining NN

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Convolution 1
        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=10, stride=1)
        self.relu1 = nn.ReLU()

        # Max pool 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=5)

#         # Convolution 2
#         self.cnn2 = nn.Conv2d(in_channels=16, out_channels=3, kernel_size=5, stride=1, padding=2)
#         self.relu2 = nn.ReLU()

#         # Max pool 2
#         self.maxpool2 = nn.MaxPool2d(kernel_size=5)

        # Fully connected 1 (readout)
        self.fc1 = nn.Linear(20736, 15)
        self.sigmoid1 = nn.Sigmoid()

    def forward(self, x):
        # Convolution 1
        out = self.cnn1(x)
        out = self.relu1(out)

        # Max pool 1
        out = self.maxpool1(out)

        # Convolution 2 
        #out = self.cnn2(out)
        #out = self.relu2(out)

        # Max pool 2 
        #out = self.maxpool2(out)
        im_out = out
        # Resize
        # Original size: (100, 32, 7, 7)
        # out.size(0): 100
        # New out size: (100, 32*7*7)
        out = out.view(out.size(0), -1)

        # Linear function (readout)
        out = self.fc1(out)
        out = self.sigmoid1(out)
        return im_out,out
    
model = CNNModel()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% - Loss Function

def h_score(fx, gy):
 
    fx = fx - fx.mean(0)

    gy = gy - gy.mean(0)

    Nsamples = fx.size(0)
    #print(fx, np.shape(fx))
    #print(gy, np.shape(gy))
    #print(np.shape((torch.transpose(fx,3,2))),np.shape(fx))
    covf = torch.matmul(fx.t(), fx) / Nsamples

    covg = torch.matmul(gy.t(), gy) / Nsamples

    h = -2 * torch.mean((fx * gy).sum(1)) + (covf * covg).sum()

    return h


optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)





for epoch in range(num_epochs):
    for x,y in loader:
        optimizer.zero_grad()
        # ===================forward=====================
        #loss = criterion(output1, img)
        loss = h_score(model(x)[1],model(y)[1])
        # ===================backward====================
 
        #optimizer_1.zero_grad()
        loss.backward()
        optimizer.step()
        #optimizer_1.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    #print("shape: ", np.shape(model(x[0].reshape(1,3,100, 100))[0]))
#     print("x: ", model(x[0].reshape(1,3,100, 100)))
#     print("y:", model(y[0].reshape(1,3,100, 100)))
#     print("b:", model(b.reshape(1,3,100, 100)))
# Out:
# (100, 100, 3)
# length:  366
# (20000, 3, 100, 100)
# epoch [1/200], loss:-0.7648
# epoch [2/200], loss:-0.5609
# epoch [3/200], loss:-0.5488
# epoch [4/200], loss:-0.6572
# epoch [5/200], loss:-0.8681
# epoch [6/200], loss:-0.6650
# epoch [7/200], loss:-0.8541
# epoch [8/200], loss:-1.1512
# epoch [9/200], loss:-0.8592
# epoch [10/200], loss:-1.0444
# epoch [11/200], loss:-0.9844
# epoch [12/200], loss:-0.8968
# epoch [13/200], loss:-1.1682
# epoch [14/200], loss:-1.1146
# epoch [15/200], loss:-1.3228
# epoch [16/200], loss:-1.0338
# epoch [17/200], loss:-1.2190
# epoch [18/200], loss:-1.6338
# epoch [19/200], loss:-1.8874
# epoch [20/200], loss:-1.5097
# epoch [21/200], loss:-1.4356
# epoch [22/200], loss:-1.6915
# epoch [23/200], loss:-1.5015
# epoch [24/200], loss:-1.9866
# epoch [25/200], loss:-1.7635
# epoch [26/200], loss:-2.2156
# epoch [27/200], loss:-2.4984
# epoch [28/200], loss:-2.4658
# epoch [29/200], loss:-2.4060
# epoch [30/200], loss:-2.5647
# epoch [31/200], loss:-2.7934
# epoch [32/200], loss:-2.5897
# epoch [33/200], loss:-2.7852
# epoch [34/200], loss:-3.2002
# epoch [35/200], loss:-2.6750
# epoch [36/200], loss:-3.1401
# epoch [37/200], loss:-3.2417
# epoch [38/200], loss:-3.0936
# epoch [39/200], loss:-2.7223
# epoch [40/200], loss:-3.2349
# epoch [41/200], loss:-3.4352
# epoch [42/200], loss:-3.6474
# epoch [43/200], loss:-3.5121
# epoch [44/200], loss:-3.5677
# epoch [45/200], loss:-3.2362
# epoch [46/200], loss:-3.5777
# epoch [47/200], loss:-3.7250
# epoch [48/200], loss:-3.2025
# epoch [49/200], loss:-2.7509
# epoch [50/200], loss:-3.6412
# epoch [51/200], loss:-3.7374
# epoch [52/200], loss:-3.5457
# epoch [53/200], loss:-3.2284
# epoch [54/200], loss:-3.4292
# epoch [55/200], loss:-3.6176
# epoch [56/200], loss:-3.3783
# epoch [57/200], loss:-3.6331
# epoch [58/200], loss:-3.6716
# epoch [59/200], loss:-4.4871
# epoch [60/200], loss:-4.0185
# epoch [61/200], loss:-4.3761
# epoch [62/200], loss:-3.8292
# epoch [63/200], loss:-3.8910
# epoch [64/200], loss:-3.6824
# epoch [65/200], loss:-3.9144
# epoch [66/200], loss:-4.4850
# epoch [67/200], loss:-3.9599
# epoch [68/200], loss:-4.4868
# epoch [69/200], loss:-3.8652
# epoch [70/200], loss:-4.3696
# epoch [71/200], loss:-4.0504
# epoch [72/200], loss:-4.1017
# epoch [73/200], loss:-4.3293
# epoch [74/200], loss:-4.3585
# epoch [75/200], loss:-3.9564
# epoch [76/200], loss:-4.3298
# epoch [77/200], loss:-4.1600
# epoch [78/200], loss:-3.6820
# epoch [79/200], loss:-4.5138
# epoch [80/200], loss:-4.3872
# epoch [81/200], loss:-3.9408
# epoch [82/200], loss:-4.3308
# epoch [83/200], loss:-3.8829
# epoch [84/200], loss:-3.9227
# epoch [85/200], loss:-3.7926
# epoch [86/200], loss:-4.1285
# epoch [87/200], loss:-4.3212
# epoch [88/200], loss:-4.0285
# epoch [89/200], loss:-4.1593
# epoch [90/200], loss:-4.0730
# epoch [91/200], loss:-4.2195
# epoch [92/200], loss:-4.6592
# epoch [93/200], loss:-4.1839
# epoch [94/200], loss:-4.4028
# epoch [95/200], loss:-4.4108
# epoch [96/200], loss:-4.3440
# epoch [97/200], loss:-4.1147
# epoch [98/200], loss:-4.5714
# epoch [99/200], loss:-4.0725
# epoch [100/200], loss:-3.9139
# epoch [101/200], loss:-4.2602
# epoch [102/200], loss:-4.0468
# epoch [103/200], loss:-4.1456
# epoch [104/200], loss:-4.0377
# epoch [105/200], loss:-4.1507
# epoch [106/200], loss:-4.4059
# epoch [107/200], loss:-4.1440
# epoch [108/200], loss:-4.4868
# epoch [109/200], loss:-4.5173
# epoch [110/200], loss:-4.2259
# epoch [111/200], loss:-4.0686
# epoch [112/200], loss:-4.5627
# epoch [113/200], loss:-4.3216
# epoch [114/200], loss:-4.0320
# epoch [115/200], loss:-4.3041
# epoch [116/200], loss:-4.2731
# epoch [117/200], loss:-4.5621
# epoch [118/200], loss:-4.5505
# epoch [119/200], loss:-4.2744
# epoch [120/200], loss:-4.4116
# epoch [121/200], loss:-4.1382
# epoch [122/200], loss:-4.2853
# epoch [123/200], loss:-4.2393
# epoch [124/200], loss:-4.3157
# epoch [125/200], loss:-4.2994
# epoch [126/200], loss:-4.0148
# epoch [127/200], loss:-4.0455
# epoch [128/200], loss:-4.5268
# epoch [129/200], loss:-4.3531
# epoch [130/200], loss:-4.3221
# epoch [131/200], loss:-4.4987
# epoch [132/200], loss:-4.5509
# epoch [133/200], loss:-4.1084
# epoch [134/200], loss:-4.1294
# epoch [135/200], loss:-4.0112
# epoch [136/200], loss:-4.3121
# epoch [137/200], loss:-4.2293
# epoch [138/200], loss:-4.2617
# epoch [139/200], loss:-4.6564
# epoch [140/200], loss:-4.3217
# epoch [141/200], loss:-3.9737
# epoch [142/200], loss:-4.2265
# epoch [143/200], loss:-4.3854
# epoch [144/200], loss:-4.5681
# epoch [145/200], loss:-4.4468
# epoch [146/200], loss:-3.8929
# epoch [147/200], loss:-4.6447
# epoch [148/200], loss:-4.1276
# epoch [149/200], loss:-4.3157
# epoch [150/200], loss:-4.5900
# epoch [151/200], loss:-4.3955
# epoch [152/200], loss:-4.1541
# epoch [153/200], loss:-4.5228
# epoch [154/200], loss:-4.3498
# epoch [155/200], loss:-4.2956
# epoch [156/200], loss:-3.8415
# epoch [157/200], loss:-4.2865
# epoch [158/200], loss:-3.9832
# epoch [159/200], loss:-4.4919
# epoch [160/200], loss:-4.2756
# epoch [161/200], loss:-4.2577
# epoch [162/200], loss:-4.1314
# epoch [163/200], loss:-4.3707
# epoch [164/200], loss:-3.8308
# epoch [165/200], loss:-4.3361
# epoch [166/200], loss:-4.7342
# epoch [167/200], loss:-3.9044
# epoch [168/200], loss:-3.5192
# epoch [169/200], loss:-4.4893
# epoch [170/200], loss:-3.9607
# epoch [171/200], loss:-4.3520
# epoch [172/200], loss:-4.0741
# epoch [173/200], loss:-4.3854
# epoch [174/200], loss:-4.4715
# epoch [175/200], loss:-4.5330
# epoch [176/200], loss:-4.1381
# epoch [177/200], loss:-4.3176
# epoch [178/200], loss:-4.2287
# epoch [179/200], loss:-4.4611
# epoch [180/200], loss:-4.3507
# epoch [181/200], loss:-4.3929
# epoch [182/200], loss:-4.3203
# epoch [183/200], loss:-4.6792
# epoch [184/200], loss:-4.1472
# epoch [185/200], loss:-4.4714
# epoch [186/200], loss:-4.4386
# epoch [187/200], loss:-4.5299
# epoch [188/200], loss:-4.4998
# epoch [189/200], loss:-4.0513
# epoch [190/200], loss:-4.2863
# epoch [191/200], loss:-4.2457
# epoch [192/200], loss:-4.2140
# epoch [193/200], loss:-4.5237
# epoch [194/200], loss:-4.5339
# epoch [195/200], loss:-4.1542
# epoch [196/200], loss:-4.5154
# epoch [197/200], loss:-4.8572
# epoch [198/200], loss:-4.7856
# epoch [199/200], loss:-4.3724
# epoch [200/200], loss:-4.5122

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

drone_panels={}
tank_panels={}
tank_reloading_panels={}
drone_reloading_panels={}
tank_firing_panels={}
drone_firing_panels={}

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

for i in range(64):

    tank_info_panel = i
    #rone_info_panel = i
    #Blank
    img = uframes[1]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Blank: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("Blank: ",val,pos)


    print("**********")
    img = uframes[3]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank_info,pos_tank_info = val_pos(output_tank)
    print("Tank: ",val_tank_info,pos_tank_info)
#     output_drone = output[0][drone_info_panel]
#     val_tank_drone_info,pos_tank_drone_info = val_pos(output_drone)
#     print("Tank: ",val,pos)
    print("**********")

    #Drone
    img = uframes[4]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_drone_info,pos_drone_info = val_pos(output_tank)
    print("Drone: ",val_drone_info,pos_drone_info)
#     output_drone = output[0][drone_info_panel]
#     val_drone_drone_info,pos_drone_drone_info = val_pos(output_drone)
#     print("Drone: ",val,pos)
    
    print("**********")  
    img = uframes[5]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank_reloading_info,pos_tank_reloading_info = val_pos(output_tank)
    print("Tank reloading: ",val_tank_reloading_info,pos_tank_reloading_info)
#     output_drone = output[0][drone_info_panel]
#     val_tank_reloading_drone_info,pos_tank_reloading_drone_info = val_pos(output_drone)
#     print("Tank reloading: ",val,pos)

    print("**********")
    #Drone Reloadingg
    img = uframes[6]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_drone_reloading_info,pos_drone_reloading_info = val_pos(output_tank)
    print("Drone reloading: ",val_drone_reloading_info,pos_drone_reloading_info)
#     output_drone = output[0][drone_info_panel]
#     val_drone_reloading_drone_info,pos_drone_reloading_drone_info = val_pos(output_drone)
#     print("Drone reloading: ",val,pos)

    #Tank Firing
    print("**********")  
    img = uframes[7]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank_firing_info,pos_tank_firing_info = val_pos(output_tank)
    print("Tank Firing: ",val_tank_firing_info,pos_tank_firing_info)
#     output_drone = output[0][drone_info_panel]_firing
#     val_tank_reloading_drone_info,pos_tank_reloading_drone_info = val_pos(output_drone)
#     print("Tank reloading: ",val,pos)

    print("**********")
    #Drone Firing
    img = uframes[8]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_drone_firing_info,pos_drone_firing_info = val_pos(output_tank)
    print("Drone firing: ",val_drone_firing_info,pos_drone_firing_info)
#     output_drone = output[0][drone_info_panel]
#     val_drone_reloading_drone_info,pos_drone_reloading_drone_info = val_pos(output_drone)
#     print("Drone reloading: ",val,pos)


    print("**********")
    #Tank and Drone
    img= uframes[0]
    z = Image.fromarray(img)
    #z.show()
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TD: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("TD: ",val,pos)
    
    print("**********")
    #Tank and Drone reloading
    img= uframes[6]
    z = Image.fromarray(img)
    #z.show()
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TrDr: ",val,pos)
#     output_drone = output[0][drone_info_panel]
#     val,pos = val_pos(output_drone)
#     print("TD: ",val,pos)
    
    print("\nPanel ",i)
    print("\n++++++++++++++++++++++++++++++++++++++++++++\n")
    if val_tank_info > max(val_drone_reloading_info,val_tank_reloading_info,val_drone_info,val_tank_firing_info
,val_drone_firing_info):
        tank_panels[i]=val_tank_info-5
    elif val_drone_info > max(val_drone_reloading_info,val_tank_reloading_info,val_tank_info,val_tank_firing_info
,val_drone_firing_info):
        drone_panels[i]=val_drone_info-5
    elif val_tank_reloading_info > max(val_drone_reloading_info,val_tank_info,val_drone_info,val_tank_firing_info
,val_drone_firing_info):
        tank_reloading_panels[i]=val_tank_reloading_info-5
    elif val_drone_reloading_info > max(val_tank_reloading_info,val_tank_info,val_drone_info,val_tank_firing_info
,val_drone_firing_info):
        drone_reloading_panels[i]=val_drone_reloading_info-2
    elif val_tank_firing_info > max(val_drone_reloading_info,val_tank_reloading_info,val_drone_info,val_tank_info
,val_drone_firing_info):
        tank_firing_panels[i] = val_tank_firing_info-2
    elif val_drone_firing_info > max(val_drone_reloading_info,val_tank_reloading_info,val_tank_info,val_tank_firing_info
,val_drone_info):
        drone_firing_panels[i] = val_drone_firing_info-2
        
print("\nTank: \n", tank_panels)
print("\nDrone: \n", drone_panels)
print("\nTank Reloading: \n", tank_reloading_panels)
print("\nDrone Reloading: \n", drone_reloading_panels)
print("\nTank Firing: \n", tank_firing_panels)
print("\nDrone Firing: \n", drone_firing_panels)
# Out:
# Blank:  737.21246 (11, 12)
# **********
# Tank:  893.6975 (6, 1)
# **********
# Drone:  918.44434 (11, 9)
# **********
# Tank reloading:  967.60596 (6, 0)
# **********
# Drone reloading:  945.01337 (12, 10)
# **********
# Tank Firing:  1069.1018 (6, 1)
# **********
# Drone firing:  927.6393 (11, 9)
# **********
# TD:  1080.5676 (11, 9)
# **********
# TrDr:  945.01337 (12, 10)
#
# Panel  0
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  368.77252 (16, 14)
# **********
# Tank:  534.67944 (5, 0)
# **********
# Drone:  511.8779 (10, 9)
# **********
# Tank reloading:  559.76404 (5, 1)
# **********
# Drone reloading:  566.1815 (10, 9)
# **********
# Tank Firing:  585.7864 (6, 1)
# **********
# Drone firing:  484.81296 (10, 9)
# **********
# TD:  675.4623 (5, 0)
# **********
# TrDr:  566.1815 (10, 9)
#
# Panel  1
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1649.5396 (2, 9)
# **********
# Tank:  1957.1108 (6, 1)
# **********
# Drone:  2067.3235 (11, 9)
# **********
# Tank reloading:  2087.6555 (5, 0)
# **********
# Drone reloading:  1967.9371 (12, 10)
# **********
# Tank Firing:  2060.9365 (7, 1)
# **********
# Drone firing:  1975.8025 (11, 10)
# **********
# TD:  2353.125 (11, 9)
# **********
# TrDr:  1967.9371 (12, 10)
#
# Panel  2
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  675.8136 (10, 11)
# **********
# Tank:  831.596 (6, 0)
# **********
# Drone:  927.1415 (10, 10)
# **********
# Tank reloading:  875.7538 (5, 1)
# **********
# Drone reloading:  1015.33813 (11, 9)
# **********
# Tank Firing:  1036.6904 (5, 1)
# **********
# Drone firing:  897.53467 (10, 10)
# **********
# TD:  1064.1431 (10, 10)
# **********
# TrDr:  1015.33813 (11, 9)
#
# Panel  3
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2193.6323 (16, 15)
# **********
# Tank:  2470.1282 (16, 15)
# **********
# Drone:  2563.3193 (10, 9)
# **********
# Tank reloading:  2606.4639 (4, 0)
# **********
# Drone reloading:  2480.4797 (10, 10)
# **********
# Tank Firing:  2568.336 (6, 2)
# **********
# Drone firing:  2507.8625 (10, 9)
# **********
# TD:  2844.2734 (10, 9)
# **********
# TrDr:  2480.4797 (10, 10)
#
# Panel  4
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  916.0237 (11, 12)
# **********
# Tank:  1056.0793 (11, 12)
# **********
# Drone:  1082.8423 (11, 9)
# **********
# Tank reloading:  1341.0791 (5, 0)
# **********
# Drone reloading:  1151.0996 (11, 10)
# **********
# Tank Firing:  1076.9685 (11, 12)
# **********
# Drone firing:  1101.8784 (11, 9)
# **********
# TD:  1211.116 (11, 9)
# **********
# TrDr:  1151.0996 (11, 10)
#
# Panel  5
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  542.73444 (2, 7)
# **********
# Tank:  698.5355 (4, 1)
# **********
# Drone:  662.8987 (11, 10)
# **********
# Tank reloading:  829.64124 (5, 0)
# **********
# Drone reloading:  754.45215 (10, 10)
# **********
# Tank Firing:  757.47034 (6, 2)
# **********
# Drone firing:  689.55383 (10, 10)
# **********
# TD:  821.8292 (11, 10)
# **********
# TrDr:  754.45215 (10, 10)
#
# Panel  6
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  772.62 (10, 2)
# **********
# Tank:  1000.31635 (5, 0)
# **********
# Drone:  1095.2484 (11, 9)
# **********
# Tank reloading:  1115.7286 (6, 1)
# **********
# Drone reloading:  1016.45337 (10, 10)
# **********
# Tank Firing:  1030.2393 (5, 1)
# **********
# Drone firing:  1001.031 (10, 10)
# **********
# TD:  1316.4331 (5, 0)
# **********
# TrDr:  1016.45337 (10, 10)
#
# Panel  7
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  864.1349 (7, 9)
# **********
# Tank:  1017.46545 (5, 2)
# **********
# Drone:  1119.1161 (10, 10)
# **********
# Tank reloading:  1259.1172 (4, 0)
# **********
# Drone reloading:  1169.5751 (10, 9)
# **********
# Tank Firing:  1293.2698 (5, 0)
# **********
# Drone firing:  1098.1761 (11, 8)
# **********
# TD:  1272.6849 (11, 10)
# **********
# TrDr:  1169.5751 (10, 9)
#
# Panel  8
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2657.287 (10, 13)
# **********
# Tank:  2890.6243 (10, 13)
# **********
# Drone:  2943.3943 (10, 9)
# **********
# Tank reloading:  3096.1306 (6, 0)
# **********
# Drone reloading:  2802.1912 (10, 13)
# **********
# Tank Firing:  2918.6973 (10, 13)
# **********
# Drone firing:  2814.6384 (10, 13)
# **********
# TD:  3153.48 (10, 13)
# **********
# TrDr:  2802.1912 (10, 13)
#
# Panel  9
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  472.6557 (11, 12)
# **********
# Tank:  605.6462 (11, 12)
# **********
# Drone:  592.18506 (11, 12)
# **********
# Tank reloading:  665.79736 (5, 1)
# **********
# Drone reloading:  674.5292 (10, 10)
# **********
# Tank Firing:  867.28156 (5, 1)
# **********
# Drone firing:  619.1289 (10, 9)
# **********
# TD:  716.7525 (11, 12)
# **********
# TrDr:  674.5292 (10, 10)
#
# Panel  10
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  403.99258 (16, 15)
# **********
# Tank:  546.87897 (16, 15)
# **********
# Drone:  602.42523 (11, 9)
# **********
# Tank reloading:  722.585 (5, 0)
# **********
# Drone reloading:  671.51245 (11, 9)
# **********
# Tank Firing:  677.38403 (6, 0)
# **********
# Drone firing:  622.69604 (11, 9)
# **********
# TD:  734.10724 (11, 9)
# **********
# TrDr:  671.51245 (11, 9)
#
# Panel  11
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  935.608 (7, 8)
# **********
# Tank:  1254.2446 (5, 1)
# **********
# Drone:  1173.0918 (9, 10)
# **********
# Tank reloading:  1064.6133 (5, 0)
# **********
# Drone reloading:  1371.4381 (11, 10)
# **********
# Tank Firing:  1345.2295 (6, 1)
# **********
# Drone firing:  1264.8298 (10, 10)
# **********
# TD:  1497.6577 (5, 1)
# **********
# TrDr:  1371.4381 (11, 10)
#
# Panel  12
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1147.1396 (7, 10)
# **********
# Tank:  1474.2688 (7, 10)
# **********
# Drone:  1554.2001 (11, 10)
# **********
# Tank reloading:  1747.8324 (5, 0)
# **********
# Drone reloading:  1668.9224 (10, 9)
# **********
# Tank Firing:  1638.708 (5, 1)
# **********
# Drone firing:  1550.4242 (11, 10)
# **********
# TD:  1866.1359 (11, 10)
# **********
# TrDr:  1668.9224 (10, 9)
#
# Panel  13
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  591.609 (10, 12)
# **********
# Tank:  761.7163 (6, 0)
# **********
# Drone:  793.70166 (11, 10)
# **********
# Tank reloading:  796.05865 (4, 1)
# **********
# Drone reloading:  774.7302 (11, 10)
# **********
# Tank Firing:  876.5531 (5, 1)
# **********
# Drone firing:  827.4335 (10, 10)
# **********
# TD:  945.6027 (6, 0)
# **********
# TrDr:  774.7302 (11, 10)
#
# Panel  14
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1000.4685 (11, 3)
# **********
# Tank:  1242.3252 (5, 1)
# **********
# Drone:  1249.0363 (11, 10)
# **********
# Tank reloading:  1277.3052 (5, 0)
# **********
# Drone reloading:  1249.6188 (11, 10)
# **********
# Tank Firing:  1250.2451 (6, 1)
# **********
# Drone firing:  1213.0663 (11, 10)
# **********
# TD:  1488.8242 (5, 1)
# **********
# TrDr:  1249.6188 (11, 10)
#
# Panel  15
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2283.061 (2, 9)
# **********
# Tank:  2586.1208 (2, 9)
# **********
# Drone:  2636.4888 (10, 9)
# **********
# Tank reloading:  2682.9146 (6, 1)
# **********
# Drone reloading:  2543.3633 (2, 9)
# **********
# Tank Firing:  2625.692 (5, 1)
# **********
# Drone firing:  2575.0884 (10, 9)
# **********
# TD:  2938.4932 (10, 9)
# **********
# TrDr:  2543.3633 (2, 9)
#
# Panel  16
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1681.5632 (8, 9)
# **********
# Tank:  1957.1677 (5, 0)
# **********
# Drone:  2092.1992 (11, 8)
# **********
# Tank reloading:  2179.645 (4, 1)
# **********
# Drone reloading:  2326.4172 (11, 9)
# **********
# Tank Firing:  2215.7153 (5, 1)
# **********
# Drone firing:  2198.3496 (11, 8)
# **********
# TD:  2359.0054 (5, 0)
# **********
# TrDr:  2326.4172 (11, 9)
#
# Panel  17
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1587.4934 (17, 13)
# **********
# Tank:  1895.0348 (5, 0)
# **********
# Drone:  2004.101 (11, 9)
# **********
# Tank reloading:  2020.9481 (5, 0)
# **********
# Drone reloading:  2200.687 (11, 10)
# **********
# Tank Firing:  2158.2021 (6, 2)
# **********
# Drone firing:  2011.4083 (11, 9)
# **********
# TD:  2294.3198 (11, 9)
# **********
# TrDr:  2200.687 (11, 10)
#
# Panel  18
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  696.2737 (7, 8)
# **********
# Tank:  782.82446 (5, 0)
# **********
# Drone:  872.951 (7, 8)
# **********
# Tank reloading:  844.6137 (6, 0)
# **********
# Drone reloading:  1091.0536 (10, 9)
# **********
# Tank Firing:  1030.4427 (5, 0)
# **********
# Drone firing:  891.47504 (11, 9)
# **********
# TD:  959.52185 (5, 0)
# **********
# TrDr:  1091.0536 (10, 9)
#
# Panel  19
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1878.2374 (8, 10)
# **********
# Tank:  2162.0208 (5, 1)
# **********
# Drone:  2232.905 (10, 9)
# **********
# Tank reloading:  2362.0554 (6, 1)
# **********
# Drone reloading:  2492.9668 (11, 9)
# **********
# Tank Firing:  2335.8086 (6, 2)
# **********
# Drone firing:  2321.0322 (10, 9)
# **********
# TD:  2483.841 (10, 9)
# **********
# TrDr:  2492.9668 (11, 9)
#
# Panel  20
#
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1461.2822 (11, 13)
# **********
# Tank:  1762.1584 (5, 0)
# **********
# Drone:  1799.0723 (10, 9)
# **********
# Tank reloading:  1780.3761 (6, 1)
# **********
# Drone reloading:  2071.7107 (11, 9)
# **********
# Tank Firing:  2065.9531 (6, 1)
# **********
# Drone firing:  1962.6809 (11, 9)
# **********
# TD:  2101.0054 (5, 0)
# **********
# TrDr:  2071.7107 (11, 9)
#
# Panel  21
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  870.57263 (13, 6)
# **********
# Tank:  1196.8208 (6, 1)
# **********
# Drone:  1097.4614 (13, 6)
# **********
# Tank reloading:  1049.9459 (6, 0)
# **********
# Drone reloading:  1143.0398 (10, 9)
# **********
# Tank Firing:  1175.513 (5, 1)
# **********
# Drone firing:  1125.1782 (13, 6)
# **********
# TD:  1413.0906 (6, 1)
# **********
# TrDr:  1143.0398 (10, 9)
#
# Panel  22
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1903.5225 (10, 13)
# **********
# Tank:  2100.783 (6, 1)
# **********
# Drone:  2216.375 (10, 9)
# **********
# Tank reloading:  2310.023 (5, 1)
# **********
# Drone reloading:  2117.2659 (10, 13)
# **********
# Tank Firing:  2179.8613 (10, 13)
# **********
# Drone firing:  2096.589 (10, 9)
# **********
# TD:  2414.473 (6, 1)
# **********
# TrDr:  2117.2659 (10, 13)
#
# Panel  23
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1805.702 (11, 13)
# **********
# Tank:  2098.817 (4, 0)
# **********
# Drone:  2203.0913 (10, 10)
# **********
# Tank reloading:  2231.3088 (5, 1)
# **********
# Drone reloading:  2157.9897 (10, 10)
# **********
# Tank Firing:  2243.3276 (5, 2)
# **********
# Drone firing:  2130.349 (10, 9)
# **********
# TD:  2494.7463 (10, 10)
# **********
# TrDr:  2157.9897 (10, 10)
#
# Panel  24
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  763.2835 (11, 2)
# **********
# Tank:  888.7905 (11, 2)
# **********
# Drone:  929.21094 (10, 11)
# **********
# Tank reloading:  1053.931 (5, 0)
# **********
# Drone reloading:  1012.7987 (10, 9)
# **********
# Tank Firing:  975.9421 (5, 0)
# **********
# Drone firing:  858.46924 (10, 11)
# **********
# TD:  1053.5035 (10, 11)
# **********
# TrDr:  1012.7987 (10, 9)
#
# Panel  25
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  600.12714 (12, 12)
# **********
# Tank:  806.94183 (4, 0)
# **********
# Drone:  844.42554 (10, 9)
# **********
# Tank reloading:  868.82526 (5, 0)
# **********
# Drone reloading:  835.15186 (12, 10)
# **********
# Tank Firing:  922.7073 (7, 1)
# **********
# Drone firing:  814.4508 (10, 9)
# **********
# TD:  1049.073 (4, 0)
# **********
# TrDr:  835.15186 (12, 10)
#
# Panel  26
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1427.8878 (0, 1)
# **********
# Tank:  1668.0736 (5, 1)
# **********
# Drone:  1654.0331 (10, 10)
# **********
# Tank reloading:  1699.742 (6, 0)
# **********
# Drone reloading:  1630.7971 (10, 10)
# **********
# Tank Firing:  1751.9396 (5, 1)
# **********
# Drone firing:  1592.2747 (10, 9)
# **********
# TD:  1887.563 (5, 1)
# **********
# TrDr:  1630.7971 (10, 10)
#
# Panel  27
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  137.38843 (1, 1)
# **********
# Tank:  279.9598 (5, 1)
# **********
# Drone:  266.83966 (11, 9)
# **********
# Tank reloading:  198.77988 (5, 2)
# **********
# Drone reloading:  374.85474 (10, 9)
# **********
# Tank Firing:  602.314 (5, 1)
# **********
# Drone firing:  279.00925 (11, 10)
# **********
# TD:  404.36682 (11, 9)
# **********
# TrDr:  374.85474 (10, 9)
#
# Panel  28
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  3028.1472 (11, 12)
# **********
# Tank:  3315.7798 (4, 0)
# **********
# Drone:  3324.5488 (10, 9)
# **********
# Tank reloading:  3379.6372 (5, 1)
# **********
# Drone reloading:  3361.154 (11, 9)
# **********
# Tank Firing:  3460.9673 (4, 1)
# **********
# Drone firing:  3328.3364 (11, 9)
# **********
# TD:  3609.3713 (10, 9)
# **********
# TrDr:  3361.154 (11, 9)
#
# Panel  29
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1095.3567 (11, 12)
# **********
# Tank:  1426.8589 (5, 0)
# **********
# Drone:  1425.0225 (10, 10)
# **********
# Tank reloading:  1362.6644 (5, 1)
# **********
# Drone reloading:  1484.1552 (10, 10)
# **********
# Tank Firing:  1467.5978 (5, 2)
# **********
# Drone firing:  1362.9044 (10, 10)
# **********
# TD:  1750.4829 (10, 10)
# **********
# TrDr:  1484.1552 (10, 10)
#
# Panel  30
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2326.0654 (10, 12)
# **********
# Tank:  2643.977 (6, 1)
# **********
# Drone:  2633.0134 (11, 10)
# **********
# Tank reloading:  2710.4712 (5, 0)
# **********
# Drone reloading:  2824.7522 (11, 10)
# **********
# Tank Firing:  2766.4246 (6, 1)
# **********
# Drone firing:  2639.0317 (11, 10)
# **********
# TD:  2948.816 (11, 10)
# **********
# TrDr:  2824.7522 (11, 10)
#
# Panel  31
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2508.2278 (7, 10)
# **********
# Tank:  2794.6924 (5, 0)
# **********
# Drone:  2919.56 (10, 9)
# **********
# Tank reloading:  2836.4912 (6, 1)
# **********
# Drone reloading:  2841.639 (11, 9)
# **********
# Tank Firing:  2851.7336 (6, 0)
# **********
# Drone firing:  2868.9287 (10, 9)
# **********
# TD:  3204.5435 (10, 9)
# **********
# TrDr:  2841.639 (11, 9)
#
# Panel  32
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  427.25092 (17, 14)
# **********
# Tank:  676.0692 (6, 0)
# **********
# Drone:  650.9506 (10, 9)
# **********
# Tank reloading:  581.61145 (6, 0)
# **********
# Drone reloading:  1084.2288 (11, 9)
# **********
# Tank Firing:  972.496 (6, 1)
# **********
# Drone firing:  792.3091 (10, 9)
# **********
# TD:  900.60114 (6, 0)
# **********
# TrDr:  1084.2288 (11, 9)
#
# Panel  33
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1223.9268 (16, 15)
# **********
# Tank:  1505.2053 (16, 15)
# **********
# Drone:  1492.2151 (16, 15)
# **********
# Tank reloading:  1449.5552 (16, 15)
# **********
# Drone reloading:  1471.68 (16, 15)
# **********
# Tank Firing:  1565.792 (5, 1)
# **********
# Drone firing:  1470.5276 (16, 15)
# **********
# TD:  1772.5747 (8, 10)
# **********
# TrDr:  1471.68 (16, 15)
#
# Panel  34
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  852.67737 (2, 8)
# **********
# Tank:  1017.9315 (5, 0)
# **********
# Drone:  987.5243 (11, 9)
# **********
# Tank reloading:  1084.1218 (6, 0)
# **********
# Drone reloading:  1208.4524 (11, 9)
# **********
# Tank Firing:  1151.2622 (5, 1)
# **********
# Drone firing:  1057.2189 (2, 8)
# **********
# TD:  1154.8629 (5, 0)
# **********
# TrDr:  1208.4524 (11, 9)
#
# Panel  35
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  731.33203 (2, 8)
# **********
# Tank:  926.06726 (5, 0)
# **********
# Drone:  879.58777 (2, 8)
# **********
# Tank reloading:  866.37054 (5, 1)
# **********
# Drone reloading:  913.542 (11, 9)
# **********
# Tank Firing:  1051.0405 (5, 0)
# **********
# Drone firing:  998.5288 (11, 9)
# **********
# TD:  1076.4513 (5, 0)
# **********
# TrDr:  913.542 (11, 9)
#
# Panel  36
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  347.3424 (2, 9)
# **********
# Tank:  441.97998 (5, 1)
# **********
# Drone:  419.36597 (2, 9)
# **********
# Tank reloading:  512.671 (6, 1)
# **********
# Drone reloading:  490.24915 (10, 10)
# **********
# Tank Firing:  541.23773 (5, 1)
# **********
# Drone firing:  412.09875 (2, 9)
# **********
# TD:  516.30743 (5, 1)
# **********
# TrDr:  490.24915 (10, 10)
#
# Panel  37
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2432.4526 (6, 8)
# **********
# Tank:  2646.8616 (6, 1)
# **********
# Drone:  2731.399 (10, 10)
# **********
# Tank reloading:  2836.7063 (5, 1)
# **********
# Drone reloading:  2737.87 (10, 9)
# **********
# Tank Firing:  2681.7532 (4, 0)
# **********
# Drone firing:  2717.6045 (10, 9)
# **********
# TD:  2935.3525 (10, 10)
# **********
# TrDr:  2737.87 (10, 9)
#
# Panel  38
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2114.8032 (8, 8)
# **********
# Tank:  2367.929 (4, 0)
# **********
# Drone:  2407.235 (10, 10)
# **********
# Tank reloading:  2437.1807 (6, 0)
# **********
# Drone reloading:  2559.4377 (12, 9)
# **********
# Tank Firing:  2515.7334 (5, 1)
# **********
# Drone firing:  2354.933 (8, 8)
# **********
# TD:  2652.3413 (10, 10)
# **********
# TrDr:  2559.4377 (12, 9)
#
# Panel  39
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  904.8712 (10, 11)
# **********
# Tank:  1141.131 (4, 0)
# **********
# Drone:  1164.3656 (11, 9)
# **********
# Tank reloading:  1356.0728 (5, 1)
# **********
# Drone reloading:  1204.924 (10, 10)
# **********
# Tank Firing:  1248.2297 (5, 2)
# **********
# Drone firing:  1102.2233 (10, 11)
# **********
# TD:  1390.7427 (11, 9)
# **********
# TrDr:  1204.924 (10, 10)
#
# Panel  40
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  968.7812 (10, 14)
# **********
# Tank:  1291.8562 (4, 0)
# **********
# Drone:  1211.3478 (10, 10)
# **********
# Tank reloading:  1323.7493 (5, 0)
# **********
# Drone reloading:  1334.9607 (11, 10)
# **********
# Tank Firing:  1369.3535 (5, 2)
# **********
# Drone firing:  1227.8569 (11, 10)
# **********
# TD:  1525.7095 (10, 10)
# **********
# TrDr:  1334.9607 (11, 10)
#
# Panel  41
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2234.5972 (10, 11)
# **********
# Tank:  2397.089 (10, 11)
# **********
# Drone:  2477.0684 (10, 11)
# **********
# Tank reloading:  2745.5835 (5, 0)
# **********
# Drone reloading:  2542.5378 (10, 9)
# **********
# Tank Firing:  2513.1973 (5, 0)
# **********
# Drone firing:  2471.4111 (11, 9)
# **********
# TD:  2634.318 (10, 11)
# **********
# TrDr:  2542.5378 (10, 9)
#
# Panel  42
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  977.9923 (10, 12)
# **********
# Tank:  1224.1357 (5, 0)
# **********
# Drone:  1141.1447 (11, 11)
# **********
# Tank reloading:  1292.8545 (5, 0)
# **********
# Drone reloading:  1212.9175 (10, 10)
# **********
# Tank Firing:  1313.4336 (5, 2)
# **********
# Drone firing:  1125.4758 (11, 10)
# **********
# TD:  1397.9961 (5, 0)
# **********
# TrDr:  1212.9175 (10, 10)
#
# Panel  43
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  637.6094 (16, 14)
# **********
# Tank:  870.3696 (5, 0)
# **********
# Drone:  800.5341 (11, 9)
# **********
# Tank reloading:  773.32513 (4, 0)
# **********
# Drone reloading:  860.82837 (10, 10)
# **********
# Tank Firing:  864.63043 (5, 1)
# **********
# Drone firing:  786.9311 (10, 9)
# **********
# TD:  1028.449 (5, 0)
# **********
# TrDr:  860.82837 (10, 10)
#
# Panel  44
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  32.459408 (10, 12)
# **********
# Tank:  82.05254 (5, 1)
# **********
# Drone:  47.066017 (10, 10)
# **********
# Tank reloading:  34.17305 (10, 12)
# **********
# Drone reloading:  68.280525 (11, 10)
# **********
# Tank Firing:  93.630165 (5, 1)
# **********
# Drone firing:  64.85873 (10, 10)
# **********
# TD:  93.54078 (5, 1)
# **********
# TrDr:  68.280525 (11, 10)
#
# Panel  45
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  833.94403 (10, 13)
# **********
# Tank:  1126.1619 (5, 1)
# **********
# Drone:  1043.5679 (10, 10)
# **********
# Tank reloading:  1078.6611 (5, 0)
# **********
# Drone reloading:  1198.3713 (11, 9)
# **********
# Tank Firing:  1210.5339 (5, 1)
# **********
# Drone firing:  1081.6909 (11, 10)
# **********
# TD:  1328.6412 (5, 1)
# **********
# TrDr:  1198.3713 (11, 9)
#
# Panel  46
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1886.5787 (13, 5)
# **********
# Tank:  2115.2034 (13, 5)
# **********
# Drone:  2250.2205 (10, 10)
# **********
# Tank reloading:  2260.2498 (5, 1)
# **********
# Drone reloading:  2266.6865 (11, 8)
# **********
# Tank Firing:  2262.9766 (5, 0)
# **********
# Drone firing:  2258.832 (11, 10)
# **********
# TD:  2491.3396 (10, 10)
# **********
# TrDr:  2266.6865 (11, 8)
#
# Panel  47
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  941.0055 (11, 2)
# **********
# Tank:  1159.5505 (5, 1)
# **********
# Drone:  1151.9438 (11, 9)
# **********
# Tank reloading:  1171.3413 (5, 1)
# **********
# Drone reloading:  1266.1959 (11, 9)
# **********
# Tank Firing:  1295.3429 (6, 1)
# **********
# Drone firing:  1137.6049 (11, 9)
# **********
# TD:  1361.5317 (5, 0)
# **********
# TrDr:  1266.1959 (11, 9)
#
# Panel  48
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1528.249 (8, 8)
# **********
# Tank:  1817.4214 (5, 1)
# **********
# Drone:  1873.4338 (10, 9)
# **********
# Tank reloading:  2061.0059 (5, 1)
# **********
# Drone reloading:  2028.5127 (11, 10)
# **********
# Tank Firing:  2004.2435 (6, 1)
# **********
# Drone firing:  1812.1445 (11, 9)
# **********
# TD:  2158.3406 (5, 1)
# **********
# TrDr:  2028.5127 (11, 10)
#
# Panel  49
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1938.79 (10, 13)
# **********
# Tank:  2300.6655 (5, 0)
# **********
# Drone:  2392.7861 (10, 9)
# **********
# Tank reloading:  2244.58 (10, 13)
# **********
# Drone reloading:  2399.603 (10, 8)
# **********
# Tank Firing:  2500.2998 (5, 0)
# **********
# Drone firing:  2332.3887 (10, 8)
# **********
# TD:  2739.954 (10, 9)
# **********
# TrDr:  2399.603 (10, 8)
#
# Panel  50
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  0.0 (0, 0)
# **********
# Tank:  0.0 (0, 0)
# **********
# Drone:  0.0 (0, 0)
# **********
# Tank reloading:  0.0 (0, 0)
# **********
# Drone reloading:  0.0 (0, 0)
# **********
# Tank Firing:  0.0 (0, 0)
# **********
# Drone firing:  0.0 (0, 0)
# **********
# TD:  0.0 (0, 0)
# **********
# TrDr:  0.0 (0, 0)
#
# Panel  51
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  2565.4343 (7, 9)
# **********
# Tank:  2809.2405 (7, 9)
# **********
# Drone:  2824.8728 (11, 9)
# **********
# Tank reloading:  2980.6523 (4, 0)
# **********
# Drone reloading:  2733.2568 (7, 9)
# **********
# Tank Firing:  2853.8447 (4, 0)
# **********
# Drone firing:  2761.5483 (11, 10)
# **********
# TD:  3053.656 (11, 9)
# **********
# TrDr:  2733.2568 (7, 9)
#
# Panel  52
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  392.08643 (8, 9)
# **********
# Tank:  574.7909 (5, 1)
# **********
# Drone:  598.47473 (9, 10)
# **********
# Tank reloading:  602.64954 (5, 0)
# **********
# Drone reloading:  887.76404 (11, 10)
# **********
# Tank Firing:  814.21063 (6, 1)
# **********
# Drone firing:  634.9918 (9, 9)
# **********
# TD:  780.0648 (5, 1)
# **********
# TrDr:  887.76404 (11, 10)
#
# Panel  53
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  697.71454 (10, 11)
# **********
# Tank:  991.6811 (5, 0)
# **********
# Drone:  900.638 (10, 9)
# **********
# Tank reloading:  862.1079 (6, 0)
# **********
# Drone reloading:  1089.8689 (10, 10)
# **********
# Tank Firing:  1164.512 (5, 1)
# **********
# Drone firing:  944.2113 (10, 10)
# **********
# TD:  1199.7998 (5, 0)
# **********
# TrDr:  1089.8689 (10, 10)
#
# Panel  54
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  278.4524 (16, 14)
# **********
# Tank:  473.6386 (5, 1)
# **********
# Drone:  429.0426 (10, 10)
# **********
# Tank reloading:  391.8166 (6, 0)
# **********
# Drone reloading:  567.17413 (11, 10)
# **********
# Tank Firing:  510.0013 (5, 1)
# **********
# Drone firing:  445.1555 (10, 10)
# **********
# TD:  634.9909 (5, 1)
# **********
# TrDr:  567.17413 (11, 10)
#
# Panel  55
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  515.0071 (16, 14)
# **********
# Tank:  776.32245 (5, 0)
# **********
# Drone:  626.6741 (16, 14)
# **********
# Tank reloading:  632.2268 (5, 0)
# **********
# Drone reloading:  787.66595 (11, 9)
# **********
# Tank Firing:  888.2388 (6, 0)
# **********
# Drone firing:  679.8396 (11, 8)
# **********
# TD:  879.1127 (5, 0)
# **********
# TrDr:  787.66595 (11, 9)
#
# Panel  56
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  321.78082 (11, 3)
# **********
# Tank:  421.98138 (11, 3)
# **********
# Drone:  486.0574 (10, 9)
# **********
# Tank reloading:  492.14893 (5, 1)
# **********
# Drone reloading:  550.437 (10, 9)
# **********
# Tank Firing:  552.9176 (5, 1)
# **********
# Drone firing:  410.15915 (10, 9)
# **********
# TD:  583.27936 (10, 9)
# **********
# TrDr:  550.437 (10, 9)
#
# Panel  57
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1549.0444 (11, 3)
# **********
# Tank:  1837.8356 (4, 0)
# **********
# Drone:  1945.6345 (10, 9)
# **********
# Tank reloading:  2116.5874 (5, 1)
# **********
# Drone reloading:  1948.4645 (11, 10)
# **********
# Tank Firing:  1864.9539 (6, 0)
# **********
# Drone firing:  1905.1619 (11, 9)
# **********
# TD:  2227.2595 (11, 9)
# **********
# TrDr:  1948.4645 (11, 10)
#
# Panel  58
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  609.9319 (2, 9)
# **********
# Tank:  786.3274 (6, 0)
# **********
# Drone:  805.459 (11, 11)
# **********
# Tank reloading:  1138.5034 (5, 0)
# **********
# Drone reloading:  873.98535 (11, 10)
# **********
# Tank Firing:  852.8113 (6, 2)
# **********
# Drone firing:  791.41644 (11, 10)
# **********
# TD:  973.02325 (6, 0)
# **********
# TrDr:  873.98535 (11, 10)
#
# Panel  59
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  554.1295 (10, 13)
# **********
# Tank:  845.1028 (5, 0)
# **********
# Drone:  754.99133 (10, 9)
# **********
# Tank reloading:  628.7637 (10, 13)
# **********
# Drone reloading:  1192.6663 (11, 10)
# **********
# Tank Firing:  1207.7706 (6, 1)
# **********
# Drone firing:  858.1144 (11, 10)
# **********
# TD:  1043.2075 (5, 0)
# **********
# TrDr:  1192.6663 (11, 10)
#
# Panel  60
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  889.38776 (10, 12)
# **********
# Tank:  1089.8744 (5, 1)
# **********
# Drone:  1162.991 (11, 10)
# **********
# Tank reloading:  1132.396 (6, 1)
# **********
# Drone reloading:  1205.7815 (10, 10)
# **********
# Tank Firing:  1128.8142 (5, 1)
# **********
# Drone firing:  1115.4467 (11, 10)
# **********
# TD:  1364.2993 (11, 10)
# **********
# TrDr:  1205.7815 (10, 10)
#
# Panel  61
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  602.9774 (8, 9)
# **********
# Tank:  758.1686 (5, 0)
# **********
# Drone:  761.1571 (11, 10)
# **********
# Tank reloading:  924.3412 (5, 1)
# **********
# Drone reloading:  1022.3025 (11, 9)
# **********
# Tank Firing:  992.625 (6, 0)
# **********
# Drone firing:  812.63 (11, 9)
# **********
# TD:  904.5312 (5, 0)
# **********
# TrDr:  1022.3025 (11, 9)
#
# Panel  62
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
# Blank:  1068.5243 (11, 13)
# **********
# Tank:  1209.5697 (11, 13)
# **********
# Drone:  1264.6318 (10, 9)
# **********
# Tank reloading:  1388.866 (5, 0)
# **********
# Drone reloading:  1173.7522 (12, 11)
# **********
# Tank Firing:  1232.1702 (6, 0)
# **********
# Drone firing:  1183.3713 (11, 13)
# **********
# TD:  1409.8728 (10, 9)
# **********
# TrDr:  1173.7522 (12, 11)
#
# Panel  63
#
# ++++++++++++++++++++++++++++++++++++++++++++
#
#
# Tank:
#  {22: 1191.82080078125, 44: 865.36962890625}
#
# Drone:
#  {32: 2914.56005859375}
#
# Tank Reloading:
#  {2: 2082.655517578125, 4: 2601.4638671875, 5: 1336.0791015625, 6: 824.6412353515625, 7: 1110.7286376953125, 9: 3091.130615234375, 11: 717.5850219726562, 13: 1742.8323974609375, 15: 1272.30517578125, 16: 2677.91455078125, 23: 2305.02294921875, 25: 1048.9310302734375, 38: 2831.706298828125, 40: 1351.07275390625, 42: 2740.58349609375, 49: 2056.005859375, 52: 2975.65234375, 58: 2111.58740234375, 59: 1133.50341796875, 63: 1383.865966796875}
#
# Drone Reloading:
#  {12: 1369.4381103515625, 17: 2324.417236328125, 18: 2198.68701171875, 19: 1089.0535888671875, 20: 2490.966796875, 21: 2069.710693359375, 30: 1482.1551513671875, 31: 2822.752197265625, 33: 1082.228759765625, 35: 1206.452392578125, 39: 2557.437744140625, 47: 2264.6865234375, 53: 885.7640380859375, 55: 565.1741333007812, 61: 1203.781494140625, 62: 1020.302490234375}
#
# Tank Firing:
#  {0: 1067.101806640625, 1: 583.786376953125, 3: 1034.6904296875, 8: 1291.269775390625, 10: 865.2815551757812, 14: 874.5531005859375, 24: 2241.32763671875, 26: 920.707275390625, 27: 1749.9395751953125, 28: 600.3140258789062, 29: 3458.96728515625, 34: 1563.7919921875, 36: 1049.04052734375, 37: 539.2377319335938, 41: 1367.353515625, 43: 1311.43359375, 45: 91.63016510009766, 46: 1208.533935546875, 48: 1293.3428955078125, 50: 2498.2998046875, 54: 1162.511962890625, 56: 886.23876953125, 57: 550.9176025390625, 60: 1205.7706298828125}
#
# Drone Firing:
#  {}

# %%
for i in range(12):
    img = uframes[i]
    z = Image.fromarray(img)
    z.show()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for j in range(len(list(tank_reloading_panels))):
    
    tank_info_panel = list(tank_firing_panels)[0]
    drone_info_panel = list(drone_panels)[0]
    tankr_info_panel = list(tank_reloading_panels)[j]
    droner_info_panel = list(drone_reloading_panels)[0] #12

    #print(tankr_info_panel,tank_reloading_panels[tankr_info_panel])

    tank_threshold= tank_firing_panels[tank_info_panel]
    tankr_threshold= tank_reloading_panels[tankr_info_panel]
    drone_threshold= drone_panels[drone_info_panel]
    droner_threshold= drone_reloading_panels[droner_info_panel]

    def val_pos(array):
        value = np.sum(array)
        position = np.unravel_index(np.argmax(array),array.shape)
        return value,position
    dronec=[]
    tankc=[]
    tankr=[]
    droner=[]
    #Blank
    for i in range(50):
        #x = cv2.imread(r"C:\Users\darshan19\Desktop\AoI\CNN\Images1\0b.png",-1)
        #x = cv2.resize(x,(100,100))
        img = uframes[i]
        #print(np.shape(img))
        # = Image.fromarray(img)
        #z.show()
        data3=[]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        #print(np.shape(x_1))
        output = model(x_1.reshape(1,3,100, 100))[0].detach().numpy()
        output_tank = output[0][tank_info_panel]
        val_tank,pos_tank = val_pos(output_tank)
        output_tankr = output[0][tankr_info_panel]
        val_tankr,pos_tankr = val_pos(output_tankr)
        print(i)
        output_drone = output[0][drone_info_panel]
        val_drone,pos_drone = val_pos(output_drone)
        output_droner = output[0][droner_info_panel]
        val_droner,pos_droner = val_pos(output_droner)

        if val_tank>tank_threshold:
#             print("tank present")
#             print("Tank info: ",val_tank,pos_tank)
            tankc.append(pos_tank)
    
        if val_tankr>tankr_threshold:
            print("tank reloading present")
            print("Tank info: ",val_tank,pos_tank)
            tankr.append(pos_tankr)
        if val_droner>droner_threshold:
#             print("drone reloading present")
#             print("Drone info: ",val_droner,pos_droner)
            dronec.append(pos_drone)
    print("\n")
    print(list(tank_reloading_panels)[j])
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n\n")
# Out:
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# tank reloading present
# Tank info:  1120.012 (6, 4)
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 2
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# tank reloading present
# Tank info:  1120.012 (6, 4)
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 4
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# 1
# 2
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# 11
# 12
# 13
# 14
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# 20
# 21
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# 25
# 26
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# 30
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# 38
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# 49
#
#
# 5
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# 12
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
#
#
# 6
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# tank reloading present
# Tank info:  1120.012 (6, 4)
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 7
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# 14
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# 49
#
#
# 9
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# 23
# 24
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 11
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 13
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# tank reloading present
# Tank info:  1120.012 (6, 4)
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 15
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# tank reloading present
# Tank info:  1120.012 (6, 4)
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 16
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 23
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# tank reloading present
# Tank info:  1120.012 (6, 4)
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 25
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# tank reloading present
# Tank info:  1120.012 (6, 4)
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 38
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 40
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# 11
# 12
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 42
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# tank reloading present
# Tank info:  1150.0126 (6, 3)
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# tank reloading present
# Tank info:  1120.012 (6, 4)
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 49
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# tank reloading present
# Tank info:  1196.0261 (12, 5)
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 52
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# tank reloading present
# Tank info:  1260.1443 (6, 1)
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# tank reloading present
# Tank info:  1117.9336 (12, 7)
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# tank reloading present
# Tank info:  1174.3464 (12, 5)
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 58
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# 1
# 2
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# 11
# 12
# 13
# 14
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# 18
# 19
# 20
# 21
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# 25
# 26
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# 29
# 30
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# 35
# 36
# 37
# 38
# 39
# 40
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# 46
# 47
# 48
# 49
#
#
# 59
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# 0
# tank reloading present
# Tank info:  1080.5676 (11, 9)
# 1
# 2
# 3
# 4
# 5
# tank reloading present
# Tank info:  967.60596 (6, 0)
# 6
# 7
# 8
# 9
# tank reloading present
# Tank info:  1175.0786 (12, 10)
# 10
# tank reloading present
# Tank info:  1085.0298 (6, 0)
# 11
# 12
# tank reloading present
# Tank info:  1084.7615 (6, 1)
# 13
# 14
# tank reloading present
# Tank info:  1261.3171 (5, 2)
# 15
# tank reloading present
# Tank info:  1066.9042 (6, 0)
# 16
# 17
# tank reloading present
# Tank info:  1123.9536 (10, 4)
# 18
# tank reloading present
# Tank info:  1136.884 (9, 6)
# 19
# tank reloading present
# Tank info:  1142.0544 (9, 7)
# 20
# tank reloading present
# Tank info:  1087.3159 (6, 2)
# 21
# tank reloading present
# Tank info:  1143.1035 (11, 9)
# 22
# tank reloading present
# Tank info:  1003.74927 (5, 1)
# 23
# 24
# 25
# 26
# tank reloading present
# Tank info:  1183.6692 (12, 9)
# 27
# tank reloading present
# Tank info:  1183.3298 (12, 7)
# 28
# tank reloading present
# Tank info:  1107.4369 (6, 3)
# 29
# tank reloading present
# Tank info:  1175.3372 (12, 5)
# 30
# tank reloading present
# Tank info:  1201.7703 (5, 3)
# 31
# tank reloading present
# Tank info:  1036.403 (4, 3)
# 32
# 33
# tank reloading present
# Tank info:  1240.7537 (12, 5)
# 34
# tank reloading present
# Tank info:  1096.7478 (10, 4)
# 35
# tank reloading present
# Tank info:  1123.042 (9, 6)
# 36
# tank reloading present
# Tank info:  1184.9673 (9, 7)
# 37
# tank reloading present
# Tank info:  1118.1953 (6, 4)
# 38
# tank reloading present
# Tank info:  1163.643 (11, 9)
# 39
# 40
# tank reloading present
# Tank info:  1311.0901 (6, 4)
# 41
# tank reloading present
# Tank info:  1057.5981 (5, 2)
# 42
# 43
# 44
# 45
# tank reloading present
# Tank info:  1152.6687 (5, 4)
# 46
# tank reloading present
# Tank info:  1112.6201 (12, 7)
# 47
# tank reloading present
# Tank info:  1069.6923 (6, 4)
# 48
# 49
# tank reloading present
# Tank info:  1215.1154 (6, 4)
#
#
# 63
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)


tank_info_panel = 44#list(tank_panels)[2]
#drone_info_panel = 0#list(drone_panels)[1]
tankr_info_panel = 59#list(tank_reloading_panels)[4]
#droner_info_panel = 17#list(drone_reloading_panels)[12]
tankf_info_panel = 28
#print(drone_info_panel,drone_panels[drone_info_panel])

tank_threshold= tank_panels[tank_info_panel]
tankr_threshold= tank_reloading_panels[tankr_info_panel]
#drone_threshold= drone_panels[drone_info_panel]
#droner_threshold= drone_reloading_panels[droner_info_panel]
tankf_threshold = tank_firing_panels[tankf_info_panel]
def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position
dronec=[]
tankc=[]
tankr=[]
droner=[]
tankf=[]
#Blank
print(len(uframes))
for i in range(200):
    #x = cv2.imread(r"C:\Users\darshan19\Desktop\AoI\CNN\Images1\0b.png",-1)
    #x = cv2.resize(x,(100,100))
    img = uframes[i]
    #print(np.shape(img))
    # = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    #print(np.shape(x_1))
    output = model(x_1.reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank,pos_tank = val_pos(output_tank)
    output_tankr = output[0][tankr_info_panel]
    val_tankr,pos_tankr = val_pos(output_tankr)
    output_tankf = output[0][tankf_info_panel]
    val_tankf,pos_tankf = val_pos(output_tankf)
    print(i)
#     output_drone = output[0][drone_info_panel]
#     val_drone,pos_drone = val_pos(output_drone)
#     output_droner = output[0][droner_info_panel]
#     val_droner,pos_droner = val_pos(output_droner)
    
    if val_tank>tank_threshold:
        print("tank present")
        print("Tank info: ",val_tank,pos_tank)
        tankc.append(pos_tank)
    if val_tankr>tankr_threshold:
        print("tank reloading present")
        print("Tank info: ",val_tank,pos_tank)
        tankr.append(pos_tankr)
    if val_tankf>tankf_threshold:
        tankf.append(pos_tankf)
    print("\n")
    print("******************************************************************************")
    print("\n")
# Out:
# 366
# 0
# tank present
# Tank info:  1028.449 (5, 0)
#
#
# ******************************************************************************
#
#
# 1
#
#
# ******************************************************************************
#
#
# 2
# tank present
# Tank info:  1016.0216 (10, 9)
#
#
# ******************************************************************************
#
#
# 3
# tank present
# Tank info:  870.3696 (5, 0)
#
#
# ******************************************************************************
#
#
# 4
#
#
# ******************************************************************************
#
#
# 5
# tank reloading present
# Tank info:  773.32513 (4, 0)
#
#
# ******************************************************************************
#
#
# 6
#
#
# ******************************************************************************
#
#
# 7
#
#
# ******************************************************************************
#
#
# 8
#
#
# ******************************************************************************
#
#
# 9
# tank present
# Tank info:  992.93304 (4, 0)
# tank reloading present
# Tank info:  992.93304 (4, 0)
#
#
# ******************************************************************************
#
#
# 10
# tank present
# Tank info:  1025.943 (12, 9)
#
#
# ******************************************************************************
#
#
# 11
# tank present
# Tank info:  913.1572 (12, 7)
#
#
# ******************************************************************************
#
#
# 12
# tank present
# Tank info:  983.3029 (12, 6)
#
#
# ******************************************************************************
#
#
# 13
# tank present
# Tank info:  964.5813 (12, 5)
#
#
# ******************************************************************************
#
#
# 14
# tank present
# Tank info:  970.3253 (11, 4)
#
#
# ******************************************************************************
#
#
# 15
# tank reloading present
# Tank info:  851.2271 (4, 1)
#
#
# ******************************************************************************
#
#
# 16
#
#
# ******************************************************************************
#
#
# 17
# tank present
# Tank info:  965.191 (10, 4)
#
#
# ******************************************************************************
#
#
# 18
# tank present
# Tank info:  958.62695 (9, 6)
#
#
# ******************************************************************************
#
#
# 19
# tank present
# Tank info:  969.15375 (9, 8)
#
#
# ******************************************************************************
#
#
# 20
# tank present
# Tank info:  952.33276 (10, 9)
#
#
# ******************************************************************************
#
#
# 21
# tank present
# Tank info:  1002.5318 (5, 2)
#
#
# ******************************************************************************
#
#
# 22
# tank present
# Tank info:  881.40955 (4, 2)
# tank reloading present
# Tank info:  881.40955 (4, 2)
#
#
# ******************************************************************************
#
#
# 23
# tank present
# Tank info:  875.67065 (10, 10)
#
#
# ******************************************************************************
#
#
# 24
#
#
# ******************************************************************************
#
#
# 25
#
#
# ******************************************************************************
#
#
# 26
# tank present
# Tank info:  1017.99335 (12, 9)
#
#
# ******************************************************************************
#
#
# 27
# tank present
# Tank info:  948.822 (12, 7)
# tank reloading present
# Tank info:  948.822 (12, 7)
#
#
# ******************************************************************************
#
#
# 28
# tank present
# Tank info:  997.0935 (12, 6)
#
#
# ******************************************************************************
#
#
# 29
# tank present
# Tank info:  968.80774 (12, 5)
#
#
# ******************************************************************************
#
#
# 30
# tank present
# Tank info:  994.66315 (11, 4)
#
#
# ******************************************************************************
#
#
# 31
# tank present
# Tank info:  882.4393 (4, 2)
# tank reloading present
# Tank info:  882.4393 (4, 2)
#
#
# ******************************************************************************
#
#
# 32
#
#
# ******************************************************************************
#
#
# 33
# tank present
# Tank info:  1070.1462 (4, 2)
# tank reloading present
# Tank info:  1070.1462 (4, 2)
#
#
# ******************************************************************************
#
#
# 34
# tank present
# Tank info:  1007.5851 (5, 3)
#
#
# ******************************************************************************
#
#
# 35
# tank present
# Tank info:  925.28595 (9, 6)
#
#
# ******************************************************************************
#
#
# 36
# tank present
# Tank info:  940.5875 (9, 8)
#
#
# ******************************************************************************
#
#
# 37
# tank present
# Tank info:  950.3669 (5, 3)
#
#
# ******************************************************************************
#
#
# 38
# tank present
# Tank info:  990.80817 (5, 3)
#
#
# ******************************************************************************
#
#
# 39
#
#
# ******************************************************************************
#
#
# 40
# tank present
# Tank info:  1040.25 (10, 9)
#
#
# ******************************************************************************
#
#
# 41
# tank reloading present
# Tank info:  837.8422 (4, 3)
#
#
# ******************************************************************************
#
#
# 42
# tank present
# Tank info:  875.12274 (10, 10)
#
#
# ******************************************************************************
#
#
# 43
# tank present
# Tank info:  884.9248 (5, 4)
#
#
# ******************************************************************************
#
#
# 44
#
#
# ******************************************************************************
#
#
# 45
# tank present
# Tank info:  1038.6265 (12, 9)
#
#
# ******************************************************************************
#
#
# 46
# tank present
# Tank info:  974.6633 (12, 7)
#
#
# ******************************************************************************
#
#
# 47
# tank present
# Tank info:  1010.20917 (12, 6)
#
#
# ******************************************************************************
#
#
# 48
# tank present
# Tank info:  969.3135 (5, 4)
#
#
# ******************************************************************************
#
#
# 49
# tank present
# Tank info:  951.2454 (11, 4)
#
#
# ******************************************************************************
#
#
# 50
# tank present
# Tank info:  887.34033 (4, 4)
# tank reloading present
# Tank info:  887.34033 (4, 4)
#
#
# ******************************************************************************
#
#
# 51
#
#
# ******************************************************************************
#
#
# 52
# tank present
# Tank info:  1013.3544 (5, 4)
#
#
# ******************************************************************************
#
#
# 53
# tank present
# Tank info:  939.2163 (9, 6)
#
#
# ******************************************************************************
#
#
# 54
# tank present
# Tank info:  957.75085 (9, 8)
#
#
# ******************************************************************************
#
#
# 55
# tank present
# Tank info:  1000.44763 (5, 4)
#
#
# ******************************************************************************
#
#
# 56
# tank present
# Tank info:  922.9131 (5, 5)
#
#
# ******************************************************************************
#
#
# 57
#
#
# ******************************************************************************
#
#
# 58
# tank reloading present
# Tank info:  863.35785 (4, 4)
#
#
# ******************************************************************************
#
#
# 59
# tank present
# Tank info:  878.0544 (10, 10)
#
#
# ******************************************************************************
#
#
# 60
# tank present
# Tank info:  872.6942 (5, 6)
#
#
# ******************************************************************************
#
#
# 61
#
#
# ******************************************************************************
#
#
# 62
# tank present
# Tank info:  1092.8716 (4, 4)
# tank reloading present
# Tank info:  1092.8716 (4, 4)
#
#
# ******************************************************************************
#
#
# 63
# tank present
# Tank info:  1021.19104 (12, 9)
#
#
# ******************************************************************************
#
#
# 64
# tank present
# Tank info:  956.29333 (12, 7)
# tank reloading present
# Tank info:  956.29333 (12, 7)
#
#
# ******************************************************************************
#
#
# 65
# tank present
# Tank info:  963.36554 (12, 6)
#
#
# ******************************************************************************
#
#
# 66
# tank present
# Tank info:  970.52966 (5, 5)
#
#
# ******************************************************************************
# 67
# tank present
# Tank info:  976.4442 (11, 4)
#
#
# ******************************************************************************
#
#
# 68
# tank reloading present
# Tank info:  836.8881 (4, 5)
#
#
# ******************************************************************************
#
#
# 69
#
#
# ******************************************************************************
#
#
# 70
# tank present
# Tank info:  1021.12915 (5, 5)
#
#
# ******************************************************************************
#
#
# 71
# tank present
# Tank info:  952.27264 (9, 6)
#
#
# ******************************************************************************
#
#
# 72
# tank present
# Tank info:  937.14813 (9, 8)
#
#
# ******************************************************************************
#
#
# 73
# tank present
# Tank info:  983.54126 (5, 6)
#
#
# ******************************************************************************
#
#
# 74
# tank present
# Tank info:  912.68176 (5, 6)
#
#
# ******************************************************************************
#
#
# 75
#
#
# ******************************************************************************
#
#
# 76
# tank present
# Tank info:  1041.8602 (10, 10)
#
#
# ******************************************************************************
#
#
# 77
#
#
# ******************************************************************************
#
#
# 78
# tank present
# Tank info:  881.3823 (4, 6)
# tank reloading present
# Tank info:  881.3823 (4, 6)
#
#
# ******************************************************************************
#
#
# 79
# tank present
# Tank info:  878.8338 (10, 10)
#
#
# ******************************************************************************
#
#
# 80
# tank present
# Tank info:  876.17737 (5, 7)
#
#
# ******************************************************************************
#
#
# 81
#
#
# ******************************************************************************
#
#
# 82
# tank present
# Tank info:  1019.0701 (12, 9)
#
#
# ******************************************************************************
#
#
# 83
# tank present
# Tank info:  973.56586 (12, 7)
# tank reloading present
# Tank info:  973.56586 (12, 7)
#
#
# ******************************************************************************
#
#
# 84
# tank present
# Tank info:  964.7902 (12, 6)
#
#
# ******************************************************************************
#
#
# 85
# tank present
# Tank info:  990.3473 (12, 5)
#
#
# ******************************************************************************
#
#
# 86
# tank present
# Tank info:  991.0939 (11, 4)
#
#
# ******************************************************************************
#
#
# 87
# tank present
# Tank info:  893.13306 (4, 7)
# tank reloading present
# Tank info:  893.13306 (4, 7)
#
#
# ******************************************************************************
#
#
# 88
#
#
# ******************************************************************************
#
#
# 89
# tank present
# Tank info:  1083.67 (4, 7)
# tank reloading present
# Tank info:  1083.67 (4, 7)
#
#
# ******************************************************************************
#
#
# 90
# tank present
# Tank info:  963.05835 (5, 7)
#
#
# ******************************************************************************
#
#
# 91
# tank present
# Tank info:  937.7033 (9, 6)
#
#
# ******************************************************************************
#
#
# 92
# tank present
# Tank info:  960.4883 (9, 8)
#
#
# ******************************************************************************
#
#
# 93
# tank present
# Tank info:  1003.67236 (5, 7)
#
#
# ******************************************************************************
#
#
# 94
# tank present
# Tank info:  935.10626 (5, 7)
#
#
# ******************************************************************************
#
#
# 95
# tank reloading present
# Tank info:  824.9368 (4, 7)
#
#
# ******************************************************************************
#
#
# 96
# tank present
# Tank info:  879.8849 (10, 10)
#
#
# ******************************************************************************
#
#
# 97
#
#
# ******************************************************************************
#
#
# 98
#
#
# ******************************************************************************
#
#
# 99
# tank present
# Tank info:  1047.7362 (12, 9)
#
#
# ******************************************************************************
#
#
# 100
# tank present
# Tank info:  1017.99084 (5, 8)
#
#
# ******************************************************************************
#
#
# 101
# tank present
# Tank info:  915.2804 (12, 6)
#
#
# ******************************************************************************
#
#
# 102
# tank present
# Tank info:  951.4843 (12, 5)
#
#
# ******************************************************************************
#
#
# 103
# tank present
# Tank info:  988.85144 (11, 4)
#
#
# ******************************************************************************
#
#
# 104
# tank reloading present
# Tank info:  856.2018 (4, 8)
#
#
# ******************************************************************************
#
#
# 105
#
#
# ******************************************************************************
#
#
# 106
# tank present
# Tank info:  951.5874 (10, 4)
#
#
# ******************************************************************************
#
#
# 107
# tank present
# Tank info:  968.31836 (9, 6)
#
#
# ******************************************************************************
#
#
# 108
# tank present
# Tank info:  993.62665 (9, 8)
#
#
# ******************************************************************************
#
#
# 109
# tank present
# Tank info:  1016.8898 (5, 9)
#
#
# ******************************************************************************
#
#
# 110
# tank present
# Tank info:  922.61304 (5, 9)
#
#
# ******************************************************************************
#
#
# 111
#
#
# ******************************************************************************
#
#
# 112
# tank present
# Tank info:  1038.3336 (5, 10)
#
#
# ******************************************************************************
#
#
# 113
#
#
# ******************************************************************************
#
#
# 114
# tank present
# Tank info:  915.8682 (4, 9)
# tank reloading present
# Tank info:  915.8682 (4, 9)
#
#
# ******************************************************************************
#
#
# 115
# tank present
# Tank info:  877.92896 (10, 10)
#
#
# ******************************************************************************
#
#
# 116
# tank present
# Tank info:  875.8966 (5, 10)
#
#
# ******************************************************************************
#
#
# 117
#
#
# ******************************************************************************
#
#
# 118
# tank present
# Tank info:  1137.7556 (4, 9)
# tank reloading present
# Tank info:  1137.7556 (4, 9)
#
#
# ******************************************************************************
#
#
# 119
# tank present
# Tank info:  1003.92194 (12, 9)
#
#
# ******************************************************************************
#
#
# 120
# tank present
# Tank info:  1036.2705 (5, 9)
#
#
# ******************************************************************************
#
#
# 121
# tank present
# Tank info:  936.68304 (12, 6)
#
#
# ******************************************************************************
#
#
# 122
# tank present
# Tank info:  982.1861 (12, 5)
#
#
# ******************************************************************************
#
#
# 123
# tank present
# Tank info:  1014.36694 (5, 9)
#
#
# ******************************************************************************
#
#
# 124
# tank reloading present
# Tank info:  847.38586 (4, 9)
#
#
# ******************************************************************************
#
#
# 125
#
#
# ******************************************************************************
#
#
# 126
# tank present
# Tank info:  957.4868 (10, 4)
#
#
# ******************************************************************************
#
#
# 127
# tank present
# Tank info:  924.3876 (9, 6)
#
#
# ******************************************************************************
#
#
# 128
# tank present
# Tank info:  970.8512 (5, 10)
#
#
# ******************************************************************************
#
#
# 129
# tank present
# Tank info:  971.10156 (5, 10)
#
#
# ******************************************************************************
#
#
# 130
# tank present
# Tank info:  936.98 (5, 10)
#
#
# ******************************************************************************
#
#
# 131
# tank reloading present
# Tank info:  854.60547 (4, 10)
#
#
# ******************************************************************************
#
#
# 132
# tank present
# Tank info:  879.8849 (10, 10)
#
#
# ******************************************************************************
#
#
# 133
# tank present
# Tank info:  895.7674 (5, 11)
#
#
# ******************************************************************************
#
#
# 134
#
#
# ******************************************************************************
#
#
# 135
# tank present
# Tank info:  1029.6321 (12, 9)
#
#
# ******************************************************************************
#
#
# 136
# tank present
# Tank info:  1038.9034 (5, 10)
#
#
# ******************************************************************************
#
#
# 137
# tank present
# Tank info:  957.08264 (12, 6)
#
#
# ******************************************************************************
#
#
# 138
# tank present
# Tank info:  950.68506 (12, 5)
#
#
# ******************************************************************************
#
#
# 139
# tank present
# Tank info:  1021.29626 (5, 11)
#
#
# ******************************************************************************
#
#
# 140
# tank present
# Tank info:  872.63696 (4, 11)
# tank reloading present
# Tank info:  872.63696 (4, 11)
#
#
# ******************************************************************************
#
#
# 141
#
#
# ******************************************************************************
#
#
# 142
# tank present
# Tank info:  1062.8088 (4, 11)
# tank reloading present
# Tank info:  1062.8088 (4, 11)
#
#
# ******************************************************************************
# 143
# tank present
# Tank info:  922.9546 (10, 4)
#
#
# ******************************************************************************
#
#
# 144
# tank present
# Tank info:  935.8417 (9, 6)
#
#
# ******************************************************************************
#
#
# 145
# tank present
# Tank info:  974.5549 (5, 11)
#
#
# ******************************************************************************
#
#
# 146
# tank present
# Tank info:  938.56793 (5, 11)
#
#
# ******************************************************************************
#
#
# 147
# tank present
# Tank info:  940.54834 (5, 11)
#
#
# ******************************************************************************
#
#
# 148
#
#
# ******************************************************************************
#
#
# 149
# tank present
# Tank info:  1032.7773 (5, 13)
#
#
# ******************************************************************************
#
#
# 150
#
#
# ******************************************************************************
#
#
# 151
# tank present
# Tank info:  890.71924 (4, 11)
# tank reloading present
# Tank info:  890.71924 (4, 11)
#
#
# ******************************************************************************
#
#
# 152
# tank present
# Tank info:  878.2119 (10, 10)
#
#
# ******************************************************************************
#
#
# 153
# tank present
# Tank info:  867.77795 (5, 13)
#
#
# ******************************************************************************
#
#
# 154
#
#
# ******************************************************************************
#
#
# 155
# tank present
# Tank info:  1041.9946 (12, 9)
#
#
# ******************************************************************************
#
#
# 156
# tank present
# Tank info:  977.8998 (5, 12)
# tank reloading present
# Tank info:  977.8998 (5, 12)
#
#
# ******************************************************************************
#
#
# 157
# tank present
# Tank info:  932.0882 (12, 6)
#
#
# ******************************************************************************
#
#
# 158
# tank present
# Tank info:  968.9878 (12, 5)
#
#
# ******************************************************************************
#
#
# 159
# tank present
# Tank info:  995.64014 (5, 12)
#
#
# ******************************************************************************
#
#
# 160
# tank reloading present
# Tank info:  825.8297 (4, 12)
#
#
# ******************************************************************************
#
#
# 161
#
#
# ******************************************************************************
#
#
# 162
# tank present
# Tank info:  948.8524 (10, 4)
#
#
# ******************************************************************************
#
#
# 163
# tank present
# Tank info:  964.91785 (9, 6)
#
#
# ******************************************************************************
#
#
# 164
# tank present
# Tank info:  1023.278 (5, 13)
#
#
# ******************************************************************************
#
#
# 165
# tank present
# Tank info:  909.90173 (10, 9)
#
#
# ******************************************************************************
#
#
# 166
# tank present
# Tank info:  908.9546 (11, 10)
#
#
# ******************************************************************************
#
#
# 167
#
#
# ******************************************************************************
#
#
# 168
# tank present
# Tank info:  893.48224 (4, 13)
# tank reloading present
# Tank info:  893.48224 (4, 13)
#
#
# ******************************************************************************
#
#
# 169
# tank present
# Tank info:  879.0593 (10, 10)
#
#
# ******************************************************************************
#
#
# 170
#
#
# ******************************************************************************
#
#
# 171
#
#
# ******************************************************************************
#
#
# 172
# tank present
# Tank info:  1121.2467 (4, 13)
# tank reloading present
# Tank info:  1121.2467 (4, 13)
#
#
# ******************************************************************************
#
#
# 173
# tank present
# Tank info:  1048.8652 (12, 9)
#
#
# ******************************************************************************
#
#
# 174
# tank present
# Tank info:  964.8967 (12, 7)
#
#
# ******************************************************************************
#
#
# 175
# tank present
# Tank info:  957.3779 (12, 6)
#
#
# ******************************************************************************
#
#
# 176
# tank present
# Tank info:  1005.98315 (12, 5)
#
#
# ******************************************************************************
#
#
# 177
# tank present
# Tank info:  1038.7952 (5, 14)
#
#
# ******************************************************************************
#
#
# 178
# tank present
# Tank info:  908.1876 (4, 14)
# tank reloading present
# Tank info:  908.1876 (4, 14)
#
#
# ******************************************************************************
#
#
# 179
#
#
# ******************************************************************************
#
#
# 180
# tank present
# Tank info:  946.8721 (10, 4)
#
#
# ******************************************************************************
#
#
# 181
# tank present
# Tank info:  925.9773 (9, 6)
#
#
# ******************************************************************************
#
#
# 182
# tank present
# Tank info:  1013.9663 (5, 14)
#
#
# ******************************************************************************
#
#
# 183
# tank present
# Tank info:  926.49585 (10, 9)
#
#
# ******************************************************************************
#
#
# 184
# tank present
# Tank info:  980.3987 (11, 9)
#
#
# ******************************************************************************
#
#
# 185
#
#
# ******************************************************************************
#
#
# 186
# tank present
# Tank info:  1028.2023 (10, 9)
#
#
# ******************************************************************************
#
#
# 187
# tank reloading present
# Tank info:  852.16516 (4, 14)
#
#
# ******************************************************************************
#
#
# 188
# tank present
# Tank info:  875.67224 (10, 10)
#
#
# ******************************************************************************
#
#
# 189
# tank present
# Tank info:  871.33826 (5, 15)
#
#
# ******************************************************************************
#
#
# 190
#
#
# ******************************************************************************
#
#
# 191
# tank present
# Tank info:  1095.0441 (5, 14)
#
#
# ******************************************************************************
#
#
# 192
# tank present
# Tank info:  941.99133 (12, 7)
#
#
# ******************************************************************************
#
#
# 193
# tank present
# Tank info:  932.2837 (12, 6)
#
#
# ******************************************************************************
#
#
# 194
# tank present
# Tank info:  980.7755 (12, 5)
#
#
# ******************************************************************************
#
#
# 195
# tank present
# Tank info:  993.9961 (5, 15)
#
#
# ******************************************************************************
#
#
# 196
# tank present
# Tank info:  871.68146 (4, 15)
# tank reloading present
# Tank info:  871.68146 (4, 15)
#
#
# ******************************************************************************
#
#
# 197
#
#
# ******************************************************************************
#
#
# 198
# tank present
# Tank info:  1058.0815 (10, 5)
# tank reloading present
# Tank info:  1058.0815 (10, 5)
#
#
# ******************************************************************************
#
#
# 199
# tank present
# Tank info:  945.04395 (10, 4)
#
#
# ******************************************************************************

# %%
img = uframes[24]
z = Image.fromarray(img)
z.show()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)


def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

for i in range(32):

    tank_info_panel = i
    drone_info_panel = i
    #Blank
    img = Image.open("spacecraft/0blank.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Blank: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Blank: ",val,pos)


    
    img = Image.open("spacecraft/0tank.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Tank: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Tank: ",val,pos)


    #Drone

    img = Image.open("spacecraft/0drone.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Drone: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Drone: ",val,pos)
    
        
    img = Image.open("spacecraft/0tank_reloading.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Tank reloading: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Tank reloading: ",val,pos)


    #Drone

    img = Image.open("spacecraft/0drone_reloading.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("Drone reloading: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("Drone reloading: ",val,pos)


    #Tank and Drone
    img = Image.open("spacecraft/0.png")
    img =  cv2.resize(np.asarray(img),(100,100))
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val,pos = val_pos(output_tank)
    print("TD: ",val,pos)
    output_drone = output[0][drone_info_panel]
    val,pos = val_pos(output_drone)
    print("TD: ",val,pos)
    
    print("done ",i)
    print("++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# Blank:  385.18863 (10, 3)
# Blank:  385.18863 (10, 3)
# Tank:  512.6679 (5, 0)
# Tank:  512.6679 (5, 0)
# Drone:  491.6334 (11, 10)
# Drone:  491.6334 (11, 10)
# Tank reloading:  535.1559 (6, 1)
# Tank reloading:  535.1559 (6, 1)
# Drone reloading:  483.6514 (11, 9)
# Drone reloading:  483.6514 (11, 9)
# TD:  678.0335 (5, 0)
# TD:  678.0335 (5, 0)
# done  0
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  24570.285 (16, 15)
# Blank:  24570.285 (16, 15)
# Tank:  24819.215 (16, 15)
# Tank:  24819.215 (16, 15)
# Drone:  24844.879 (11, 9)
# Drone:  24844.879 (11, 9)
# Tank reloading:  25150.172 (5, 0)
# Tank reloading:  25150.172 (5, 0)
# Drone reloading:  24756.168 (11, 11)
# Drone reloading:  24756.168 (11, 11)
# TD:  25126.066 (11, 10)
# TD:  25126.066 (11, 10)
# done  1
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  2405.2634 (3, 8)
# Blank:  2405.2634 (3, 8)
# Tank:  2718.6584 (6, 1)
# Tank:  2718.6584 (6, 1)
# Drone:  2748.322 (10, 9)
# Drone:  2748.322 (10, 9)
# Tank reloading:  2891.2192 (5, 0)
# Tank reloading:  2891.2192 (5, 0)
# Drone reloading:  2657.215 (10, 10)
# Drone reloading:  2657.215 (10, 10)
# TD:  3148.4783 (10, 9)
# TD:  3148.4783 (10, 9)
# done  2
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  8416.891 (11, 12)
# Blank:  8416.891 (11, 12)
# Tank:  8660.594 (5, 1)
# Tank:  8660.594 (5, 1)
# Drone:  8691.426 (11, 12)
# Drone:  8691.426 (11, 12)
# Tank reloading:  8846.654 (5, 0)
# Tank reloading:  8846.654 (5, 0)
# Drone reloading:  8622.525 (10, 9)
# Drone reloading:  8622.525 (10, 9)
# TD:  8990.076 (5, 1)
# TD:  8990.076 (5, 1)
# done  3
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1.9199736 (10, 12)
# Blank:  1.9199736 (10, 12)
# Tank:  102.78109 (5, 1)
# Tank:  102.78109 (5, 1)
# Drone:  1.9199736 (10, 12)
# Drone:  1.9199736 (10, 12)
# Tank reloading:  1.9199736 (10, 12)
# Tank reloading:  1.9199736 (10, 12)
# Drone reloading:  71.95642 (10, 10)
# Drone reloading:  71.95642 (10, 10)
# TD:  146.4491 (5, 1)
# TD:  146.4491 (5, 1)
# done  4
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1552.1287 (7, 10)
# Blank:  1552.1287 (7, 10)
# Tank:  1791.9446 (4, 0)
# Tank:  1791.9446 (4, 0)
# Drone:  1812.4918 (11, 9)
# Drone:  1812.4918 (11, 9)
# Tank reloading:  2036.0718 (5, 1)
# Tank reloading:  2036.0718 (5, 1)
# Drone reloading:  1800.1954 (12, 9)
# Drone reloading:  1800.1954 (12, 9)
# TD:  2215.4873 (11, 11)
# TD:  2215.4873 (11, 11)
# done  5
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1430.9326 (11, 12)
# Blank:  1430.9326 (11, 12)
# Tank:  1681.3263 (11, 12)
# Tank:  1681.3263 (11, 12)
# Drone:  1739.56 (11, 9)
# Drone:  1739.56 (11, 9)
# Tank reloading:  1740.7021 (6, 0)
# Tank reloading:  1740.7021 (6, 0)
# Drone reloading:  1734.7278 (10, 10)
# Drone reloading:  1734.7278 (10, 10)
# TD:  1960.4856 (11, 9)
# TD:  1960.4856 (11, 9)
# done  6
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1498.4381 (11, 2)
# Blank:  1498.4381 (11, 2)
# Tank:  1816.531 (5, 1)
# Tank:  1816.531 (5, 1)
# Drone:  1776.8582 (10, 10)
# Drone:  1776.8582 (10, 10)
# Tank reloading:  1757.5642 (5, 0)
# Tank reloading:  1757.5642 (5, 0)
# Drone reloading:  1811.7799 (10, 10)
# Drone reloading:  1811.7799 (10, 10)
# TD:  2277.4185 (11, 11)
# TD:  2277.4185 (11, 11)
# done  7
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  3818.9587 (10, 11)
# Blank:  3818.9587 (10, 11)
# Tank:  4092.9734 (5, 0)
# Tank:  4092.9734 (5, 0)
# Drone:  4158.884 (11, 9)
# Drone:  4158.884 (11, 9)
# Tank reloading:  4208.376 (5, 1)
# Tank reloading:  4208.376 (5, 1)
# Drone reloading:  4024.7244 (10, 9)
# Drone reloading:  4024.7244 (10, 9)
# TD:  4430.9834 (11, 9)
# TD:  4430.9834 (11, 9)
# done  8
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  11870.693 (3, 8)
# Blank:  11870.693 (3, 8)
# Tank:  12060.139 (3, 8)
# Tank:  12060.139 (3, 8)
# Drone:  12154.389 (11, 10)
# Drone:  12154.389 (11, 10)
# Tank reloading:  12305.254 (4, 1)
# Tank reloading:  12305.254 (4, 1)
# Drone reloading:  12166.385 (11, 9)
# Drone reloading:  12166.385 (11, 9)
# TD:  12358.068 (10, 11)
# TD:  12358.068 (10, 11)
# done  9
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  76.26364 (10, 12)
# Blank:  76.26364 (10, 12)
# Tank:  126.85431 (5, 0)
# Tank:  126.85431 (5, 0)
# Drone:  129.12482 (10, 9)
# Drone:  129.12482 (10, 9)
# Tank reloading:  142.40044 (5, 0)
# Tank reloading:  142.40044 (5, 0)
# Drone reloading:  153.39871 (11, 10)
# Drone reloading:  153.39871 (11, 10)
# TD:  338.16696 (11, 11)
# TD:  338.16696 (11, 11)
# done  10
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  11789.486 (12, 11)
# Blank:  11789.486 (12, 11)
# Tank:  12007.085 (6, 0)
# Tank:  12007.085 (6, 0)
# Drone:  12108.867 (10, 10)
# Drone:  12108.867 (10, 10)
# Tank reloading:  12213.578 (5, 1)
# Tank reloading:  12213.578 (5, 1)
# Drone reloading:  11951.977 (11, 9)
# Drone reloading:  11951.977 (11, 9)
# TD:  12327.566 (10, 10)
# TD:  12327.566 (10, 10)
# done  11
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  163.04752 (16, 14)
# Blank:  163.04752 (16, 14)
# Tank:  243.49185 (4, 0)
# Tank:  243.49185 (4, 0)
# Drone:  187.56992 (11, 9)
# Drone:  187.56992 (11, 9)
# Tank reloading:  248.13255 (5, 1)
# Tank reloading:  248.13255 (5, 1)
# Drone reloading:  312.01495 (10, 9)
# Drone reloading:  312.01495 (10, 9)
# TD:  312.39532 (4, 0)
# TD:  312.39532 (4, 0)
# done  12
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  267.7516 (8, 9)
# Blank:  267.7516 (8, 9)
# Tank:  440.98477 (5, 1)
# Tank:  440.98477 (5, 1)
# Drone:  396.00876 (10, 9)
# Drone:  396.00876 (10, 9)
# Tank reloading:  404.91858 (6, 0)
# Tank reloading:  404.91858 (6, 0)
# Drone reloading:  418.8891 (11, 10)
# Drone reloading:  418.8891 (11, 10)
# TD:  655.881 (10, 10)
# TD:  655.881 (10, 10)
# done  13
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  924.6586 (10, 13)
# Blank:  924.6586 (10, 13)
# Tank:  1120.843 (10, 13)
# Tank:  1120.843 (10, 13)
# Drone:  1149.7418 (10, 9)
# Drone:  1149.7418 (10, 9)
# Tank reloading:  1186.8918 (10, 13)
# Tank reloading:  1186.8918 (10, 13)
# Drone reloading:  1238.5674 (12, 9)
# Drone reloading:  1238.5674 (12, 9)
# TD:  1352.8196 (11, 9)
# TD:  1352.8196 (11, 9)
# done  14
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  791.2262 (10, 12)
# Blank:  791.2262 (10, 12)
# Tank:  969.02246 (10, 12)
# Tank:  969.02246 (10, 12)
# Drone:  1007.20654 (10, 10)
# Drone:  1007.20654 (10, 10)
# Tank reloading:  896.66394 (10, 12)
# Tank reloading:  896.66394 (10, 12)
# Drone reloading:  1131.8282 (10, 10)
# Drone reloading:  1131.8282 (10, 10)
# TD:  1292.1936 (11, 11)
# TD:  1292.1936 (11, 11)
# done  15
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  164.93532 (5, 1)
# Tank:  164.93532 (5, 1)
# Drone:  53.181297 (11, 10)
# Drone:  53.181297 (11, 10)
# Tank reloading:  16.053507 (6, 1)
# Tank reloading:  16.053507 (6, 1)
# Drone reloading:  11.687356 (10, 9)
# Drone reloading:  11.687356 (10, 9)
# TD:  313.49728 (5, 1)
# TD:  313.49728 (5, 1)
# done  16
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  887.8002 (8, 10)
# Blank:  887.8002 (8, 10)
# Tank:  1110.7236 (5, 1)
# Tank:  1110.7236 (5, 1)
# Drone:  1096.8689 (10, 10)
# Drone:  1096.8689 (10, 10)
# Tank reloading:  1252.4817 (5, 0)
# Tank reloading:  1252.4817 (5, 0)
# Drone reloading:  1033.132 (8, 10)
# Drone reloading:  1033.132 (8, 10)
# TD:  1369.721 (10, 10)
# TD:  1369.721 (10, 10)
# done  17
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  11187.629 (16, 15)
# Blank:  11187.629 (16, 15)
# Tank:  11372.865 (6, 2)
# Tank:  11372.865 (6, 2)
# Drone:  11476.998 (11, 10)
# Drone:  11476.998 (11, 10)
# Tank reloading:  11559.797 (6, 0)
# Tank reloading:  11559.797 (6, 0)
# Drone reloading:  11553.63 (10, 9)
# Drone reloading:  11553.63 (10, 9)
# TD:  11743.968 (12, 11)
# TD:  11743.968 (12, 11)
# done  18
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  5811.877 (11, 12)
# Blank:  5811.877 (11, 12)
# Tank:  6062.1094 (11, 12)
# Tank:  6062.1094 (11, 12)
# Drone:  6105.2305 (11, 9)
# Drone:  6105.2305 (11, 9)
# Tank reloading:  6240.091 (5, 0)
# Tank reloading:  6240.091 (5, 0)
# Drone reloading:  6161.1436 (11, 9)
# Drone reloading:  6161.1436 (11, 9)
# TD:  6440.1455 (11, 10)
# TD:  6440.1455 (11, 10)
# done  19
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  24532.71 (12, 3)
# Blank:  24532.71 (12, 3)
# Tank:  24674.344 (12, 3)
# Tank:  24674.344 (12, 3)
# Drone:  24868.129 (10, 9)
# Drone:  24868.129 (10, 9)
# Tank reloading:  24884.844 (5, 1)
# Tank reloading:  24884.844 (5, 1)
# Drone reloading:  24686.473 (11, 9)
# Drone reloading:  24686.473 (11, 9)
# TD:  25034.541 (12, 9)
# TD:  25034.541 (12, 9)
# done  20
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  160.78061 (10, 13)
# Blank:  160.78061 (10, 13)
# Tank:  308.02267 (6, 1)
# Tank:  308.02267 (6, 1)
# Drone:  208.01671 (10, 13)
# Drone:  208.01671 (10, 13)
# Tank reloading:  226.81674 (5, 0)
# Tank reloading:  226.81674 (5, 0)
# Drone reloading:  272.68506 (12, 10)
# Drone reloading:  272.68506 (12, 10)
# TD:  420.11844 (6, 1)
# TD:  420.11844 (6, 1)
# done  21
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  53.2502 (10, 12)
# Blank:  53.2502 (10, 12)
# Tank:  174.52512 (5, 0)
# Tank:  174.52512 (5, 0)
# Drone:  124.26646 (10, 10)
# Drone:  124.26646 (10, 10)
# Tank reloading:  107.94854 (5, 2)
# Tank reloading:  107.94854 (5, 2)
# Drone reloading:  197.1109 (10, 9)
# Drone reloading:  197.1109 (10, 9)
# TD:  399.3283 (10, 10)
# TD:  399.3283 (10, 10)
# done  22
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1082.6456 (2, 8)
# Blank:  1082.6456 (2, 8)
# Tank:  1325.901 (5, 1)
# Tank:  1325.901 (5, 1)
# Drone:  1374.3658 (10, 9)
# Drone:  1374.3658 (10, 9)
# Tank reloading:  1401.387 (5, 0)
# Tank reloading:  1401.387 (5, 0)
# Drone reloading:  1286.0583 (11, 9)
# Drone reloading:  1286.0583 (11, 9)
# TD:  1615.2046 (5, 1)
# TD:  1615.2046 (5, 1)
# done  23
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  286.9539 (11, 11)
# Blank:  286.9539 (11, 11)
# Tank:  420.67145 (5, 0)
# Tank:  420.67145 (5, 0)
# Drone:  435.60278 (11, 10)
# Drone:  435.60278 (11, 10)
# Tank reloading:  557.5652 (5, 0)
# Tank reloading:  557.5652 (5, 0)
# Drone reloading:  418.51385 (11, 9)
# Drone reloading:  418.51385 (11, 9)
# TD:  725.0155 (11, 10)
# TD:  725.0155 (11, 10)
# done  24
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  748.41235 (12, 13)
# Blank:  748.41235 (12, 13)
# Tank:  1001.6749 (6, 1)
# Tank:  1001.6749 (6, 1)
# Drone:  973.8461 (11, 9)
# Drone:  973.8461 (11, 9)
# Tank reloading:  1134.4109 (6, 0)
# Tank reloading:  1134.4109 (6, 0)
# Drone reloading:  917.38904 (10, 9)
# Drone reloading:  917.38904 (10, 9)
# TD:  1291.3999 (6, 1)
# TD:  1291.3999 (6, 1)
# done  25
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  16786.326 (2, 8)
# Blank:  16786.326 (2, 8)
# Tank:  16954.887 (5, 0)
# Tank:  16954.887 (5, 0)
# Drone:  17100.383 (11, 9)
# Drone:  17100.383 (11, 9)
# Tank reloading:  17279.3 (5, 1)
# Tank reloading:  17279.3 (5, 1)
# Drone reloading:  16967.893 (11, 9)
# Drone reloading:  16967.893 (11, 9)
# TD:  17382.074 (5, 0)
# TD:  17382.074 (5, 0)
# done  26
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  13853.205 (10, 11)
# Blank:  13853.205 (10, 11)
# Tank:  14013.162 (10, 11)
# Tank:  14013.162 (10, 11)
# Drone:  14118.068 (11, 9)
# Drone:  14118.068 (11, 9)
# Tank reloading:  14180.816 (5, 0)
# Tank reloading:  14180.816 (5, 0)
# Drone reloading:  14094.271 (11, 11)
# Drone reloading:  14094.271 (11, 11)
# TD:  14350.802 (11, 11)
# TD:  14350.802 (11, 11)
# done  27
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  273.0174 (17, 14)
# Blank:  273.0174 (17, 14)
# Tank:  368.85803 (5, 0)
# Tank:  368.85803 (5, 0)
# Drone:  390.67377 (10, 9)
# Drone:  390.67377 (10, 9)
# Tank reloading:  326.31573 (17, 14)
# Tank reloading:  326.31573 (17, 14)
# Drone reloading:  476.73096 (11, 9)
# Drone reloading:  476.73096 (11, 9)
# TD:  541.4325 (5, 0)
# TD:  541.4325 (5, 0)
# done  28
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  24475.414 (13, 7)
# Blank:  24475.414 (13, 7)
# Tank:  24556.508 (13, 7)
# Tank:  24556.508 (13, 7)
# Drone:  24717.75 (11, 10)
# Drone:  24717.75 (11, 10)
# Tank reloading:  24941.531 (5, 1)
# Tank reloading:  24941.531 (5, 1)
# Drone reloading:  24601.855 (11, 10)
# Drone reloading:  24601.855 (11, 10)
# TD:  24812.273 (11, 9)
# TD:  24812.273 (11, 9)
# done  29
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  1460.5662 (13, 17)
# Blank:  1460.5662 (13, 17)
# Tank:  1658.6077 (13, 17)
# Tank:  1658.6077 (13, 17)
# Drone:  1695.6794 (11, 10)
# Drone:  1695.6794 (11, 10)
# Tank reloading:  1592.0769 (13, 17)
# Tank reloading:  1592.0769 (13, 17)
# Drone reloading:  1729.5194 (11, 8)
# Drone reloading:  1729.5194 (11, 8)
# TD:  2009.9253 (11, 10)
# TD:  2009.9253 (11, 10)
# done  30
# ++++++++++++++++++++++++++++++++++++++++++++
# Blank:  0.0 (0, 0)
# Blank:  0.0 (0, 0)
# Tank:  92.19703 (5, 0)
# Tank:  92.19703 (5, 0)
# Drone:  41.560806 (11, 9)
# Drone:  41.560806 (11, 9)
# Tank reloading:  30.90567 (5, 0)
# Tank reloading:  30.90567 (5, 0)
# Drone reloading:  14.500549 (11, 9)
# Drone reloading:  14.500549 (11, 9)
# TD:  177.17775 (10, 10)
# TD:  177.17775 (10, 10)
# done  31
# ++++++++++++++++++++++++++++++++++++++++++++

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

tank_info_panel = 4
drone_info_panel = 24

def val_pos(array):
    value = np.sum(array)
    position = np.unravel_index(np.argmax(array),array.shape)
    return value,position

#Blank
for i in range(12):
    img = uframes[i]
    z = Image.fromarray(img)
    #z.show()
    data3=[]
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    output = model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()
    output_tank = output[0][tank_info_panel]
    val_tank,pos_tank = val_pos(output_tank)
    print(i)
    output_drone = output[0][drone_info_panel]
    val_drone,pos_drone = val_pos(output_drone)
    if val_tank>500:
        print("tank present")
        print("Tank info: ",val_tank,pos_tank)
    if val_drone>770:
        print("drone present")
        print("Drone info: ",val_drone,pos_drone)
# Out:
# 0
# 1
# tank present
# Tank info:  520.7602 (6, 2)
# 2
# drone present
# Drone info:  781.4645 (1, 4)
# 3
# tank present
# Tank info:  634.67224 (6, 2)
# drone present
# Drone info:  942.7866 (1, 4)
# 4
# tank present
# Tank info:  654.7293 (6, 8)
# drone present
# Drone info:  927.96313 (1, 4)
# 5
# tank present
# Tank info:  642.7981 (6, 13)
# drone present
# Drone info:  985.1527 (1, 4)
# 6
# tank present
# Tank info:  722.30286 (6, 2)
# drone present
# Drone info:  938.44824 (5, 1)
# 7
# tank present
# Tank info:  740.57965 (6, 8)
# drone present
# Drone info:  860.5968 (5, 7)
# 8
# tank present
# Tank info:  730.4288 (6, 13)
# drone present
# Drone info:  976.33765 (5, 12)
# 9
# tank present
# Tank info:  669.9697 (6, 2)
# drone present
# Drone info:  1017.36505 (13, 15)
# 10
# tank present
# Tank info:  690.02686 (6, 8)
# drone present
# Drone info:  1002.5415 (13, 15)
# 11
# tank present
# Tank info:  678.09564 (6, 13)
# drone present
# Drone info:  1059.7312 (13, 15)

# %%
im1 = Image.open('tree1.png')
im1 = im1.resize((100,100))

imt = Image.open('tank.png')
imt = imt.resize((100,100))


im2 = Image.open('tree2.png')
im2 = im2.resize((100,100))

im3 = Image.open('tree3.png')
im3 = im3.resize((100,100))

im_drone = Image.open('drone4-1.png')
im_drone = im_drone.resize((200,200))

imb = Image.open('bullet.png')
imb = imb.resize((40,40))



img_blank = Image.new('RGB', (720, 1080), color = '#9b7653')
img_blank.paste(im1,(5,75),im1)
img_blank.paste(im1,(450,550),im1)
img_blank.paste(im1,(205,720),im1)
img_blank.paste(im2,(500,900),im2)
img_blank.paste(im2,(650,750),im2)
img_blank.paste(im2,(320,440),im2)
img_blank.paste(im3,(100,600),im3)
img_blank.paste(im3,(440,620),im3)
img_blank.paste(im3,(300,150),im3)
img_blank.paste(imt.rotate(180),(500,500),imt.rotate(180))
img_blank = np.asarray(img_blank)
img_blank = cv2.resize(img_blank,(100,100))
pil = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
pil = torch.from_numpy(pil)
output = model(pil.reshape(1,3,100, 100))[0].detach().numpy()
output = output[0][info_panel]
val,pos = val_pos(output)
print(val,pos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c18b098abae9> in <module>
#      36 pil = torch.from_numpy(pil)
#      37 output = model(pil.reshape(1,3,100, 100))[0].detach().numpy()
# ---> 38 output = output[0][info_panel]
#      39 val,pos = val_pos(output)
#      40 print(val,pos)
#
# NameError: name 'info_panel' is not defined

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(12):
    k = uframes[i]
    #k.show()
    v = np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32)
    v = torch.from_numpy(v)
    filename = "Marginalization_Simple-increased_channels-32/ref_image_new_" + str(i) + ".txt"
    file = open(filename, 'w')
    file.write(str(model(v.reshape(1,3,100, 100))[0].detach().numpy()))
    file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

filename = "Marginalization_Simple-increased_channels-32/fc_weights.txt"
file = open(filename, 'w')
file.write(str(model.fc1.weight.detach().numpy()))
print(np.shape(model.fc1.weight.detach().numpy()))
file.close()
# Out:
# (15, 10368)

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

for i in range(12):
    img = uframes[i]
    #print(np.shape(img))
    z = Image.fromarray(img)
    z.show()

# %%
import operator
import sys
#t1d1
img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(imt.rotate(180),(10,30),imt.rotate(180))
# img_blank.paste(im_drone.resize((10,10)),(2,10),im_drone.resize((10,10)))

# #t2d2
# img_blank.paste(imt.rotate(180),(30,30),imt.rotate(180))
# draw = ImageDraw.Draw(img_blank)
# draw.ellipse((35,35,38,38), fill=(255, 0, 0))
# img_blank.paste(im_drone.resize((10,10)),(35,45),im_drone.resize((10,10)))
# draw.ellipse((40,50,43,53), fill=(50, 182, 150))

# #t3d3
# img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
# img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
# img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
# img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

v = np.array(np.transpose(np.asarray(img_blank),(2,0,1)),dtype=np.float32)
v = torch.from_numpy(v)
k = model(v.reshape(1,3,100, 100))[0].view(model(v.reshape(1,3,100, 100))[0].size(0), -1).detach().numpy()

filename = "Marginalization_Simple/flattened_tank_pos_1.txt"
file = open(filename, 'w')
file.write(str(k))
file.close()


# print(np.shape(k))
# index, value = max(enumerate(k), key=operator.itemgetter(1))
# print(index,value)


import operator
p=model.fc1.weight.detach().numpy()
for i in range(15):
    index, value = max(enumerate(p[i]), key=operator.itemgetter(1))
    print("FC - Feature "+ str(i) +" : ",index,value)
    print
    print("CNN value: ",k[0][index] )
# Out:
# FC - Feature 0 :  684 0.041578084
# CNN value:  17.59211
# FC - Feature 1 :  684 0.051804464
# CNN value:  17.59211
# FC - Feature 2 :  360 0.04816093
# CNN value:  0.53643996
# FC - Feature 3 :  492 0.035558272
# CNN value:  0.53643996
# FC - Feature 4 :  478 0.06459166
# CNN value:  0.53643996
# FC - Feature 5 :  585 0.049136233
# CNN value:  0.53643996
# FC - Feature 6 :  492 0.081621096
# CNN value:  0.53643996
# FC - Feature 7 :  360 0.065480515
# CNN value:  0.53643996
# FC - Feature 8 :  585 0.04792851
# CNN value:  0.53643996
# FC - Feature 9 :  492 0.06556648
# CNN value:  0.53643996
# FC - Feature 10 :  684 0.035789683
# CNN value:  17.59211
# FC - Feature 11 :  684 0.034514345
# CNN value:  17.59211
# FC - Feature 12 :  817 0.043642323
# CNN value:  17.59211
# FC - Feature 13 :  492 0.088237286
# CNN value:  0.53643996
# FC - Feature 14 :  492 0.09752004
# CNN value:  0.53643996

# %%
import random


p=0
class_data = []
while(p<len(uframes)):
    data3=[]
    print(p)
    for i in range(50):
        img = uframes[p]
        data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
        y3 = np.array(data3)
        x_1 = torch.from_numpy(y3)
        temp = model(x_1[i].reshape(1,3,100,100))[1]
        #print(temp)
        class_data.append((list(temp.detach().numpy()[0]),p))
    p+=1
    print(len(class_data))

random.shuffle(class_data)
random.shuffle(class_data)

print("length ", len(class_data))
# Out:
# 0
# 50
# 1
# 100
# 2
# 150
# 3
# 200
# 4
# 250
# 5
# 300
# 6
# 350
# 7
# 400
# 8
# 450
# 9
# 500
# 10
# 550
# 11
# 600
# length  600

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from colorama import init  
import time
import cv2

print(np.shape(uframes[0]))


#z  = np.array(np.transpose(np.asarray(z),(2,0,1)),dtype=np.float32)
# import some data to play with
print("Length of Class data: ", len(class_data))
# Take the first two features. We could avoid this by using a two-dim dataset
X = [(i[0]) for i in class_data]
y = [i[1] for i in class_data]
#print(X,np.shape(X))
#print(y,np.shape(y))
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
clf = svm.SVC(kernel='linear', C=C)
clf = clf.fit(X, y)
data3=[]
y3=0

n1 = "\x1b[31m\"Drone Stationary, Tank Firing\"\x1b[0m"
n2 = "\x1b[31m\"Drone Reloading, Tank Firing\"\x1b[0m"
n3 = "\x1b[31m\"Drone Firing, Tank Stationary\"\x1b[0m"
n4 = "\x1b[31m\"Drone Firing, Tank Reloading\"\x1b[0m"
n5 = "\x1b[31m\"Drone Firing, Tank Firing\"\x1b[0m"

names = ['Just Background','Only Tank moving', 'Only Drone Moving', 'Drone stationary, Tank Stationary', 'Drone Stationary, Tank Reloading' ,
         n1, 'Drone reloading, Tank Stationary', 'Drone reloading, Tank Reloading', n2 , n3,n4,n5]

print("Start")

img_blank = Image.new('RGB', (100, 100), color = '#9b7653')
img_blank.paste(im1,(5,7),im1)
img_blank.paste(im1,(45,55),im1)
img_blank.paste(im1,(25,72),im1)
img_blank.paste(im2,(50,90),im2)
img_blank.paste(im2,(60,75),im2)
img_blank.paste(im2,(30,40),im2)
img_blank.paste(im3,(10,60),im3)
img_blank.paste(im3,(44,62),im3)
img_blank.paste(im3,(30,15),im3)
img_blank.paste(imt.rotate(180),(50,30),imt.rotate(180))
img_blank.paste(imb.resize((2,2)),(54,40),imb.resize((2,2)))
#img_blank.paste(im_drone.resize((10,10)),(50,70),im_drone.resize((10,10)))
#img_blank.paste(imb.resize((2,2)),(56,81),imb.resize((2,2)))

for i in range(12):
    #z = cv2.imread('Images_100/0a.png')
    #l = Image.fromarray(z)
#     print("shape of z", np.shape(z),type(z))
#     #l.show()
#     #z  = cv2.resize(z,(100,100))
#     img = uframes[i]
#     print(np.shape(img))
#     img.show()
#     data3.append(np.array(np.transpose(np.asarray(uframes[i]),(2,0,1)),dtype=np.float32))
#     y3 = np.array(data3)
#     x_1 = torch.from_numpy(y3)
# #     random_img = random.choice(x)
# #     print("random", np.shape(random_img),type(random_img))
# #     show = random_img.detach().numpy() * 255
# #     show = np.array(np.transpose(show,(1,2,0)),dtype=np.uint8)
# #     print("show", np.shape(show),type(show))
# #     ms = Image.fromarray(show)
# #     ms.show()
#     temp = model(x_1[i].reshape(1,3,100,100))[1]
#     temp = temp.detach().numpy()
#     img_blank.show()
#     #print(temp)
#     z = clf.predict(temp)
#     print(names[z[0]])
    img = uframes[i]
    print(np.shape(img))
    img.show()
    #ms = Image.fromarray(z)
    #ms.show()
    data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
    y3 = np.array(data3)
    x_1 = torch.from_numpy(y3)
    temp = model(x_1[i].reshape(1,3,100,100))[1]
    temp = temp.detach().numpy()
    print(temp)
    z = clf.predict(temp)
    print(names[z[0]])
# Out:
# (100, 100, 3)
# Length of Class data:  600
# Start
# (100, 100, 3)
# [[5.69654167e-01 9.99462187e-01 5.63863292e-02 4.24214751e-01
#   9.99946237e-01 3.76719624e-01 9.24754981e-03 9.96866763e-01
#   3.24720666e-02 6.23485744e-01 9.99366581e-01 1.33173708e-05
#   9.99919176e-01 1.10880566e-04 7.16020440e-05]]
# Just Background
# (100, 100, 3)
# [[1.0693459e-01 9.7853309e-01 6.2482929e-01 8.8721722e-01 9.2732191e-01
#   3.8686104e-04 4.0334295e-03 9.7163016e-01 4.2039016e-01 9.9970645e-01
#   9.6105587e-01 4.5536429e-02 9.1955161e-01 2.7226047e-03 7.8407951e-02]]
# Only Tank moving
# (100, 100, 3)
# [[7.3534204e-03 9.9773276e-01 9.8508829e-01 9.9262118e-01 4.5104271e-01
#   3.5262175e-04 1.2917872e-04 7.4658793e-01 9.1725689e-01 9.9936992e-01
#   9.9860114e-01 5.1300049e-01 5.2829486e-01 2.9081654e-02 4.6734187e-01]]
# Only Drone Moving
# (100, 100, 3)
# [[6.6964526e-04 9.1521192e-01 9.9945718e-01 9.9930429e-01 5.6288450e-04
#   2.2586556e-07 5.6052031e-05 2.4077968e-01 9.9584311e-01 9.9999964e-01
#   9.1780317e-01 9.9973506e-01 1.0335925e-03 4.2442623e-01 9.9904162e-01]]
# Drone stationary, Tank Stationary
# (100, 100, 3)
# [[6.1773854e-01 5.1048535e-01 4.2821926e-01 3.8129362e-01 1.0322047e-02
#   8.4455933e-05 2.3334846e-03 2.1261269e-04 6.1853075e-01 9.9990475e-01
#   4.9628347e-01 9.9220043e-01 6.8009188e-03 9.8382390e-01 9.9368638e-01]]
# Drone Stationary, Tank Reloading
# (100, 100, 3)
# [[9.9997580e-01 8.7049991e-02 3.9350489e-01 2.6484555e-05 1.4167073e-01
#   1.3029476e-03 3.0017098e-05 3.1996256e-01 1.2829518e-01 9.9855381e-01
#   6.7431293e-02 8.8297009e-01 4.4132985e-02 6.9923133e-01 9.5737994e-01]]
# "Drone Stationary, Tank Firing"
# (100, 100, 3)
# [[9.9999666e-01 2.1902008e-06 1.0000000e+00 3.5267242e-06 3.7724271e-07
#   2.0260264e-03 6.5317053e-01 9.9999988e-01 2.2876749e-05 9.9758089e-01
#   4.7796307e-06 9.9999976e-01 3.5909158e-01 4.6132133e-08 6.4752334e-01]]
# Drone reloading, Tank Stationary
# (100, 100, 3)
# [[1.0000000e+00 2.1159988e-07 9.9998021e-01 1.5131814e-09 6.9859670e-06
#   4.3155217e-01 9.8743409e-01 9.9986637e-01 1.5483755e-07 5.7010096e-01
#   4.2174099e-07 9.9999261e-01 7.8759670e-01 3.8049018e-06 2.1713410e-01]]
# Drone reloading, Tank Reloading
# (100, 100, 3)
# [[1.0000000e+00 1.9347251e-08 9.9997711e-01 6.5030982e-14 1.1054412e-04
#   9.2142385e-01 5.0211656e-01 9.9999988e-01 1.4054513e-08 8.0260172e-02
#   3.0951572e-08 9.9987626e-01 9.6154159e-01 1.4544214e-07 3.8078785e-02]]
# "Drone Reloading, Tank Firing"
# (100, 100, 3)
# [[9.9998307e-01 9.9999917e-01 9.1853076e-01 1.7807450e-05 1.3325374e-02
#   9.9982435e-01 4.4189114e-06 2.7935535e-01 4.3374286e-03 1.8264313e-04
#   9.9999952e-01 9.9133462e-01 9.9873489e-01 3.9311872e-05 5.1611115e-04]]
# "Drone Firing, Tank Stationary"
# (100, 100, 3)
# [[1.0000000e+00 9.9999106e-01 4.5650690e-03 7.6405922e-09 2.0006411e-01
#   9.9999952e-01 1.8434954e-04 2.5986764e-04 2.9483532e-05 5.8745394e-07
#   9.9999404e-01 7.9409081e-01 9.9980861e-01 3.2320421e-03 7.7956029e-05]]
# "Drone Firing, Tank Reloading"
# (100, 100, 3)
# [[1.0000000e+00 9.9990249e-01 3.9572958e-03 3.2836459e-13 7.9830289e-01
#   1.0000000e+00 2.3663674e-06 3.6512318e-01 2.6762741e-06 3.8656605e-08
#   9.9991810e-01 1.8614928e-01 9.9997163e-01 1.2392933e-04 1.1127093e-05]]
# "Drone Firing, Tank Firing"

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()
x_limit = [dronec[i][0] for i in range(len(dronec))]
y_limit = [dronec[i][1] for i in range(len(dronec))]
ax.set_xlim((0,max(x_limit)+3))
ax.set_ylim((0,max(y_limit)+3))

line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)
# animation function. This is called sequentially
def animate(i):
    x = np.array(x_limit)

    y = np.array(y_limit)
    line.set_data(y, x)
    return (line,)
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=1000, interval=1, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style

style.use('fivethirtyeight')

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
z=[[30,2],[1,2],[4,5]]
def animate(i):
    #graph_data = open('example.txt','r').read()
    lines = z#graph_data.split('\n')
    xs = []
    ys = []
    for line in lines:
        if len(line) > 1:
            x, y = line[0],line[1]
            print(x,y)
            xs.append(float(x))
            ys.append(float(y))
    ax1.clear()
    ax1.plot(xs, ys)
ani = animation.FuncAnimation(fig, animate, interval=1000000)
plt.show()
# Out:
# 30 2
# 1 2
# 4 5

# %%
import numpy as np
import matplotlib.pyplot as plt
print(tankc)
x1 = [tankc[i][0] for i in range(len(tankc))]
y1 = [tankc[i][1] for i in range(len(tankc))]

x2 = [tankr[i][0] for i in range(len(tankr))]
y2 = [tankr[i][1] for i in range(len(tankr))]

x3 = [tankf[i][0] for i in range(len(tankf))]
y3 = [tankf[i][1] for i in range(len(tankf))]

plt.scatter(y1,x1)
plt.scatter(y2,x2,color='red')
#plt.scatter(y3,x3,color='black')
plt.show
# Out:
# [(5, 0), (10, 9), (5, 0), (4, 0), (12, 9), (12, 7), (12, 6), (12, 5), (11, 4), (10, 4), (9, 6), (9, 8), (10, 9), (5, 2), (4, 2), (10, 10), (12, 9), (12, 7), (12, 6), (12, 5), (11, 4), (4, 2), (4, 2), (5, 3), (9, 6), (9, 8), (5, 3), (5, 3), (10, 9), (10, 10), (5, 4), (12, 9), (12, 7), (12, 6), (5, 4), (11, 4), (4, 4), (5, 4), (9, 6), (9, 8), (5, 4), (5, 5), (10, 10), (5, 6), (4, 4), (12, 9), (12, 7), (12, 6), (5, 5), (11, 4), (5, 5), (9, 6), (9, 8), (5, 6), (5, 6), (10, 10), (4, 6), (10, 10), (5, 7), (12, 9), (12, 7), (12, 6), (12, 5), (11, 4), (4, 7), (4, 7), (5, 7), (9, 6), (9, 8), (5, 7), (5, 7), (10, 10), (12, 9), (5, 8), (12, 6), (12, 5), (11, 4), (10, 4), (9, 6), (9, 8), (5, 9), (5, 9), (5, 10), (4, 9), (10, 10), (5, 10), (4, 9), (12, 9), (5, 9), (12, 6), (12, 5), (5, 9), (10, 4), (9, 6), (5, 10), (5, 10), (5, 10), (10, 10), (5, 11), (12, 9), (5, 10), (12, 6), (12, 5), (5, 11), (4, 11), (4, 11), (10, 4), (9, 6), (5, 11), (5, 11), (5, 11), (5, 13), (4, 11), (10, 10), (5, 13), (12, 9), (5, 12), (12, 6), (12, 5), (5, 12), (10, 4), (9, 6), (5, 13), (10, 9), (11, 10), (4, 13), (10, 10), (4, 13), (12, 9), (12, 7), (12, 6), (12, 5), (5, 14), (4, 14), (10, 4), (9, 6), (5, 14), (10, 9), (11, 9), (10, 9), (10, 10), (5, 15), (5, 14), (12, 7), (12, 6), (12, 5), (5, 15), (4, 15), (10, 5), (10, 4)]
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)   

from PIL import  Image,ImageDraw

img = uframes[20]
z = Image.fromarray(img)
z.show()
data3=[]
data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
y3 = np.array(data3)
x_1 = torch.from_numpy(y3)
temp = model(x_1[0].reshape(1,3,100,100))[0].detach().numpy()
filename = "Marginalization_Simple-increased_channels-32-video-multiple/TD.txt"
file = open(filename, 'w')
file.write(str(model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import sys
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)   

from PIL import  Image,ImageDraw

img = Image.open("frame/tank_frame0.jpg")
img =  cv2.resize(np.asarray(img),(100,100))
data3=[]
data3.append(np.array(np.transpose(np.asarray(img),(2,0,1)),dtype=np.float32))
y3 = np.array(data3)
x_1 = torch.from_numpy(y3)
temp = model(x_1[0].reshape(1,3,100,100))[0].detach().numpy()
filename = "Marginalization_Simple-increased_channels-32-video-multiple/tank.txt"
file = open(filename, 'w')
file.write(str(model(x_1[0].reshape(1,3,100, 100))[0].detach().numpy()))
file.close()

# %%
import seaborn as sns
from tqdm import trange
sns.set()

class MyRnn(nn.Module):
  def __init__(self, in_d=2, out_d=2, hidden_d=4, num_hidden=1):
    super(MyRnn, self).__init__()
    self.rnn = nn.RNN(input_size=in_d, hidden_size=hidden_d, num_layers=num_hidden)
    self.fc = nn.Linear(hidden_d, out_d)

  def forward(self, x, h0):
    r, h = self.rnn(x, h0)
    y = self.fc(r)  # no activation on the output
    return y, h

s1 = torch.tensor([[4, 15], [4, 14], [4, 13], [4, 12], [4, 11], [4, 10], [4, 9], [4, 8], [4,7], [4, 6], [4, 5], [4, 4], [4, 3], [4, 2]], dtype=torch.float)[:, None, :] 
s2 = torch.tensor([[4, 15], [5,15],[6,15],[7,15],[8,15],[9,15],[10,15],[11, 15],[12, 15],[12,14],[12,13],[12,12],[12,11],[12,10],[12,9],[12,8],[12,7],[12,6],[12,5]],dtype=torch.float)[:, None, :]

x = torch.cat((s1,s2),dim=0)
mu = x.mean(dim=0)
sig=x.std(dim=0)
sequences = [(s1-mu)/sig, (s2-mu)/sig]  # pythonic list to hold sequences of un-even length

in_d = s1.shape[-1]
out_d = in_d
hidden_d = 8
num_hidden = 1
rnn = MyRnn(in_d, out_d, hidden_d, num_hidden)
loss = []
criterion = nn.MSELoss()
opt = torch.optim.SGD(rnn.parameters(), lr=0.01)
n_epochs = 1000
for e in trange(n_epochs):
  for s in sequences:
    pred, _ = rnn(s[:-1,...], torch.zeros(num_hidden, 1, hidden_d, dtype=torch.float))  # predict next step, init hidden state to zero at the begining of the sequence
    err = criterion(pred, s[1:, ...])  # predict next step for each step
    opt.zero_grad()
    err.backward()
    opt.step()
    loss.append(err.item())
plt.plot(loss)
plt.ylabel('Loss')
plt.xlabel('iteration')
plt.show()

rnn.eval()
with torch.no_grad():
  k = 5 
  for si, s in enumerate(sequences):
    pred, h = rnn(s[:k,...], torch.zeros(num_hidden, 1, hidden_d, dtype=torch.float))  # given first k steps predict the next one
    print('seq {}, prev = {}  -> predicted {}th step = {}, actual step = {}'.format(si, s[k-1,...]*sig+mu, k, pred[-1, ...]*sig + mu, s[k, ...]*sig+mu))
    prev = (torch.round(pred[-1:, ...]*sig + mu) - mu) / sig  # round the prediction, attmepting to avoid accumulation of error
    # continue to predict 
    for j in  range(k+1, s.shape[0]):
      pred, h = rnn(prev, h)
      print('\t\tpredicted step {} (prev = {}) = {}, actual step = {}'.format(j, prev*sig+mu, pred[-1,...]*sig+mu, s[j, ...]*sig + mu))
      prev = (torch.round(pred*sig + mu) - mu) / sig
  print('\n')
# Out:
# 100%|██████████| 1000/1000 [00:03<00:00, 296.44it/s]
# seq 0, prev = tensor([[ 4., 11.]])  -> predicted 5th step = tensor([[ 4.0181, 10.1336]]), actual step = tensor([[ 4., 10.]])
# 		predicted step 6 (prev = tensor([[[ 4., 10.]]])) = tensor([[3.8167, 8.9214]]), actual step = tensor([[4., 9.]])
# 		predicted step 7 (prev = tensor([[[4., 9.]]])) = tensor([[3.7085, 7.7733]]), actual step = tensor([[4., 8.]])
# 		predicted step 8 (prev = tensor([[[4., 8.]]])) = tensor([[3.6956, 6.6876]]), actual step = tensor([[4., 7.]])
# 		predicted step 9 (prev = tensor([[[4., 7.]]])) = tensor([[3.7559, 5.6683]]), actual step = tensor([[4., 6.]])
# 		predicted step 10 (prev = tensor([[[4., 6.]]])) = tensor([[3.8623, 4.7333]]), actual step = tensor([[4., 5.]])
# 		predicted step 11 (prev = tensor([[[4., 5.]]])) = tensor([[3.9918, 3.9030]]), actual step = tensor([[4., 4.]])
# 		predicted step 12 (prev = tensor([[[4., 4.]]])) = tensor([[4.1273, 3.1905]]), actual step = tensor([[4., 3.]])
# 		predicted step 13 (prev = tensor([[[4., 3.]]])) = tensor([[4.2568, 2.5978]]), actual step = tensor([[4., 2.]])
# seq 1, prev = tensor([[ 8., 15.]])  -> predicted 5th step = tensor([[ 8.9599, 15.2723]]), actual step = tensor([[ 9., 15.]])
# 		predicted step 6 (prev = tensor([[[ 9., 15.]]])) = tensor([[10.0295, 15.0766]]), actual step = tensor([[10., 15.]])
# 		predicted step 7 (prev = tensor([[[10., 15.]]])) = tensor([[10.8225, 14.7624]]), actual step = tensor([[11., 15.]])
# 		predicted step 8 (prev = tensor([[[11., 15.]]])) = tensor([[11.4090, 14.4265]]), actual step = tensor([[12., 15.]])
# 		predicted step 9 (prev = tensor([[[11., 14.]]])) = tensor([[11.6254, 13.5042]]), actual step = tensor([[12., 14.]])
# 		predicted step 10 (prev = tensor([[[12., 14.]]])) = tensor([[12.0190, 13.0385]]), actual step = tensor([[12., 13.]])
# 		predicted step 11 (prev = tensor([[[12., 13.]]])) = tensor([[12.1595, 12.1242]]), actual step = tensor([[12., 12.]])
# 		predicted step 12 (prev = tensor([[[12., 12.]]])) = tensor([[12.2924, 11.0207]]), actual step = tensor([[12., 11.]])
# 		predicted step 13 (prev = tensor([[[12., 11.]]])) = tensor([[12.3490,  9.9360]]), actual step = tensor([[12., 10.]])
# 		predicted step 14 (prev = tensor([[[12., 10.]]])) = tensor([[12.3397,  8.8895]]), actual step = tensor([[12.,  9.]])
# 		predicted step 15 (prev = tensor([[[12.,  9.]]])) = tensor([[12.2592,  7.9072]]), actual step = tensor([[12.,  8.]])
# 		predicted step 16 (prev = tensor([[[12.,  8.]]])) = tensor([[12.1007,  6.9957]]), actual step = tensor([[12.,  7.]])
# 		predicted step 17 (prev = tensor([[[12.,  7.]]])) = tensor([[11.8620,  6.1537]]), actual step = tensor([[12.,  6.]])
# 		predicted step 18 (prev = tensor([[[12.,  6.]]])) = tensor([[11.5473,  5.3743]]), actual step = tensor([[12.,  5.]])
