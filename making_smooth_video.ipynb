# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random


data1 = []
data2= []
images = []

speed = 5
import math
from math import pi


image_folder = 'C:/Users/darshan19/Desktop/AoI/CNN/new_testing/'

def square(b_l,b_r,t_r,t_l):
    points=[]
    x1,y1=b_l[0],b_l[1]
    x2,y2=b_r[0],b_r[1]
    x3,y3=t_r[0],t_r[1]
    x4,y4=t_l[0],t_l[1]
    x=x1
    y=y1
    while(x<x2):
        x=x+40
        points.append((x,y))
    while(y3<y):
        y=y-40
        points.append((x,y))
    while(x4<x):
        x=x-40
        points.append((x,y))
    while(y1>y):
        y=y+40
        points.append((x,y))
    return points
circle = square((10,700),(500,700),(500,550),(10,550))
circle=circle*300

xcor = 10
ycor = 290
line = []
while(xcor<530):
    line.append((xcor,ycor))
    xcor +=5
print(len(circle))
line = line + line[::-1]
line = line*30


def square_gen():
    for i in range(len(circle)):
        yield circle[i]

square_next = square_gen()

def line_gen():
    for i in range(len(line)):
        yield line[i]

line_next= line_gen()

#print("circle",circle)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset

im1 = Image.open('tree1.png')
im1 = im1.resize((100,100))

imt = Image.open('C:/Users/darshan19/Downloads/attachments/new/tank_moving.png')
#imt = imt.resize((100,100))

imtr = Image.open('C:/Users/darshan19/Downloads/attachments/new/tank_reloading.png')
#imtr = imtr.resize((100,100))

imdr = Image.open('C:/Users/darshan19/Downloads/attachments/new/drone_reloading.png')
#imdr = imdr.resize((100,100))

im2 = Image.open('tree2.png')
im2 = im2.resize((100,100))

im3 = Image.open('tree3.png')
im3 = im3.resize((100,100))

im_drone = Image.open('C:/Users/darshan19/Downloads/attachments/new/drone_moving1.png')
#im_drone = im_drone.resize((100,100))


imtf = Image.open('C:/Users/darshan19/Downloads/attachments/new/tank_firing1.png')
imdf = Image.open('C:/Users/darshan19/Downloads/attachments/new/drone_firing1.png')

def new_image():
    img_blank = Image.new('RGB', (720, 1080), color = '#9b7653')
    img_blank.paste(im1,(5,75),im1)
    img_blank.paste(im1,(450,550),im1)
    img_blank.paste(im1,(205,720),im1)
    img_blank.paste(im2,(500,900),im2)
    img_blank.paste(im2,(650,750),im2)
    img_blank.paste(im2,(320,440),im2)
    img_blank.paste(im3,(100,600),im3)
    img_blank.paste(im3,(440,620),im3)
    img_blank.paste(im3,(300,150),im3)
    return img_blank

for i in range(1,500):
    
    #t1d1
    img_blank = new_image()
    img_blank.paste(imt,next(line_next),imt)
    img_blank.paste(im_drone,next(square_next),im_drone)
    image_name = str(i) +'.png'
    img_blank.save(image_folder+image_name,'PNG')    
    
    
    if i%30==0:
        for j in range(5):
            img_blank = new_image()
            image_name = str(i)+str(j) +'blank.png'
            img_blank.save(image_folder+image_name,'PNG')    
    if i%10==0 and i%20==10:
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            img_blank.paste(imdr,next(square_next),imdr)
            image_name = str(i)+str(j) +'tankr_droner.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtf,next(line_next),imtf)
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'tank_drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
    if i%20==0 and i%40==20:
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imt,next(line_next),imt)
            image_name = str(i)+str(j) +'tank.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            image_name = str(i)+str(j) +'tank_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()        
            img_blank.paste(imtf,next(line_next),imtf)
            image_name = str(i)+str(j) +'tank_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imt,next(line_next),imt)
            img_blank.paste(imdr,next(square_next),imdr)
            image_name = str(i)+str(j) +'tank_moving_drone_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imt,next(line_next),imt)
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'tank_moving_drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'tank_reloading_drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
            
            
    if i%40==0:
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(im_drone,next(square_next),im_drone)
            image_name = str(i)+str(j) +'drone.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imdr,next(square_next),imdr)
            image_name = str(i)+str(j) +'drone_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            img_blank.paste(im_drone,next(square_next),im_drone)
            image_name = str(i)+str(j) +'tank_reloading_drone_moving.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtf,next(line_next),imtf)
            img_blank.paste(im_drone,next(square_next),im_drone)
            image_name = str(i)+str(j) +'tank_firing_drone_moving.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtf,next(line_next),imtf)
            img_blank.paste(imdr,next(square_next),imdr)
            image_name = str(i)+str(j) +'tank_firing_drone_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
            
cv2.destroyAllWindows()
# Out:
# 10200

# %%
import cv2
import numpy as np
import glob
import os

img_array = []
for filename in sorted(glob.glob('C:/Users/darshan19/Desktop/AoI/CNN/new_testing/*'), key=os.path.getmtime):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
    print(filename)

out = cv2.VideoWriter('images_new_real.avi',cv2.VideoWriter_fourcc(*'DIVX'), 5, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
# Out:
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\1.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\2.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\3.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\4.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\5.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\6.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\7.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\8.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\9.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\10.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\100tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\101tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\102tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\103tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\104tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/new_testing\100tank_drone_firing.png
# ...

# %% [markdown]
# # Background Noise

# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random


data1 = []
data2= []
images = []

speed = 5
import math
from math import pi


image_folder = 'C:/Users/darshan19/Desktop/AoI/CNN/noisy/'

def square(b_l,b_r,t_r,t_l):
    points=[]
    x1,y1=b_l[0],b_l[1]
    x2,y2=b_r[0],b_r[1]
    x3,y3=t_r[0],t_r[1]
    x4,y4=t_l[0],t_l[1]
    x=x1
    y=y1
    while(x<x2):
        x=x+40
        points.append((x,y))
    while(y3<y):
        y=y-40
        points.append((x,y))
    while(x4<x):
        x=x-40
        points.append((x,y))
    while(y1>y):
        y=y+40
        points.append((x,y))
    return points
circle = square((10,700),(500,700),(500,550),(10,550))
circle=circle*300

xcor = 10
ycor = 290
line = []
while(xcor<530):
    line.append((xcor,ycor))
    xcor +=5
print(len(circle))
line = line + line[::-1]
line = line*30


def square_gen():
    for i in range(len(circle)):
        yield circle[i]

square_next = square_gen()

def line_gen():
    for i in range(len(line)):
        yield line[i]

line_next= line_gen()

#print("circle",circle)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset

im1 = Image.open('tree1.png')
im1 = im1.resize((100,100))

imt = Image.open('C:/Users/darshan19/Downloads/attachments/new/tank_moving.png')
#imt = imt.resize((100,100))

imtr = Image.open('C:/Users/darshan19/Downloads/attachments/new/tank_reloading.png')
#imtr = imtr.resize((100,100))

imdr = Image.open('C:/Users/darshan19/Downloads/attachments/new/drone_reloading.png')
#imdr = imdr.resize((100,100))


rndimg1 = Image.open('C:/Users/darshan19/Downloads/attachments/tank_firing.png')


rndimg2 = Image.open('C:/Users/darshan19/Downloads/attachments/drone_firing.png')
rndimg2 = rndimg2.resize((150,150))

img_bullet = Image.open('bullet.png')

im2 = Image.open('tree2.png')
im2 = im2.resize((100,100))

im3 = Image.open('tree3.png')
im3 = im3.resize((100,100))

im_drone = Image.open('C:/Users/darshan19/Downloads/attachments/new/drone_moving1.png')
#im_drone = im_drone.resize((100,100))


imtf = Image.open('C:/Users/darshan19/Downloads/attachments/new/tank_firing1.png')
imdf = Image.open('C:/Users/darshan19/Downloads/attachments/new/drone_firing1.png')

def new_image():
    img_blank = Image.new('RGB', (720, 1080), color = '#9b7653')
    img_blank.paste(im1,(5,75),im1)
    img_blank.paste(im1,(450,550),im1)
    img_blank.paste(im1,(205,720),im1)
    img_blank.paste(im2,(500,900),im2)
    img_blank.paste(im2,(650,750),im2)
    img_blank.paste(im2,(320,440),im2)
    img_blank.paste(im3,(100,600),im3)
    img_blank.paste(im3,(440,620),im3)
    img_blank.paste(im3,(300,150),im3)
    return img_blank


def gen_rand1():
    for i in range(2000):
        yield (random.randint(0,720),random.randint(0,1080))

gen_rand = gen_rand1()

for i in range(1,500):
    
    #t1d1
    img_blank = new_image()
    line_cor = next(line_next)
    img_blank.paste(imt,line_cor,imt)
    square_cor = next(square_next)
    img_blank.paste(im_drone,square_cor,im_drone)
    rand_cor = next(gen_rand)
    if (((rand_cor[0] not in range(line_cor[0]+200, line_cor[1]-200)) or (rand_cor[1] not in range(line_cor[1]+200, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+200, square_cor[0]-200)) or (rand_cor[1] not in range(square_cor[1]+200, square_cor[1]-200)))):
        img_blank.paste(rndimg1,rand_cor,rndimg1)
    
    image_name = str(i) +'.png'
    img_blank.save(image_folder+image_name,'PNG')    
    
    
    if i%30==0:
        for j in range(5):
            img_blank = new_image()
            image_name = str(i)+str(j) +'blank.png'
            img_blank.save(image_folder+image_name,'PNG')    
    if i%10==0 and i%20==10:
        for j in range(5):
            img_blank = new_image()
            line_cor = next(line_next)
            img_blank.paste(imtr,line_cor,imtr)
            square_cor = next(square_next)
            img_blank.paste(imdr,square_cor,imdr)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+200, line_cor[1]-200)) or (rand_cor[1] not in range(line_cor[1]+200, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+200, square_cor[0]-200)) or (rand_cor[1] not in range(square_cor[1]+200, square_cor[1]-200)))):
                img_blank.paste(rndimg2,rand_cor,rndimg2)
            image_name = str(i)+str(j) +'tankr_droner.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtf,next(line_next),imtf)
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'tank_drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
    if i%20==0 and i%40==20:
        for j in range(5):
            img_blank = new_image()
            line_cor = next(line_next)
            img_blank.paste(imt,line_cor,imt)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+200, line_cor[1]-200)) or (rand_cor[1] not in range(line_cor[1]+200, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+200, square_cor[0]-200)) or (rand_cor[1] not in range(square_cor[1]+200, square_cor[1]-200)))):
                img_blank.paste(rndimg2,rand_cor,rndimg2)
            image_name = str(i)+str(j) +'tank.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            image_name = str(i)+str(j) +'tank_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()        
            img_blank.paste(imtf,next(line_next),imtf)
            image_name = str(i)+str(j) +'tank_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imt,next(line_next),imt)
            img_blank.paste(imdr,next(square_next),imdr)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            image_name = str(i)+str(j) +'tank_moving_drone_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imt,next(line_next),imt)
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'tank_moving_drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            img_blank.paste(imdf,next(square_next),imdf)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            image_name = str(i)+str(j) +'tank_reloading_drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
            
            
    if i%40==0:
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(im_drone,next(square_next),im_drone)
            image_name = str(i)+str(j) +'drone.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            square_cor = next(square_next)
            img_blank.paste(imdr,square_cor,imdr)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+200, line_cor[1]-200)) or (rand_cor[1] not in range(line_cor[1]+200, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+200, square_cor[0]-200)) or (rand_cor[1] not in range(square_cor[1]+200, square_cor[1]-200)))):
                img_blank.paste(rndimg2,rand_cor,rndimg2)
            image_name = str(i)+str(j) +'drone_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            img_blank.paste(im_drone,next(square_next),im_drone)
            image_name = str(i)+str(j) +'tank_reloading_drone_moving.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtf,next(line_next),imtf)
            img_blank.paste(im_drone,next(square_next),im_drone)
            image_name = str(i)+str(j) +'tank_firing_drone_moving.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtf,next(line_next),imtf)
            img_blank.paste(imdr,next(square_next),imdr)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            image_name = str(i)+str(j) +'tank_firing_drone_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
            
cv2.destroyAllWindows()
# Out:
# 10200

# %%
import random
x_rand,y_rand = random.randint(0,720),random.randint(0,1080)
print(y_rand)
# Out:
# 146

# %%
import cv2
import numpy as np
import glob
import os

img_array = []
for filename in sorted(glob.glob('C:/Users/darshan19/Desktop/AoI/CNN/noisy/*'), key=os.path.getmtime):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
    print(filename)

out = cv2.VideoWriter('images_noisy_vehciles_random.avi',cv2.VideoWriter_fourcc(*'DIVX'), 5, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
# Out:
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\1.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\2.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\3.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\4.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\5.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\6.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\7.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\8.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\9.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\10.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\100tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\101tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\102tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\103tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\104tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\100tank_drone_firing.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy\101tank_drone_firing.png
# ...

# %% [markdown]
# # Just Bullets

# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST
import os
import torch.nn.functional as F
import cv2
import numpy as np
import torch.utils.data as Data
from PIL import  Image,ImageDraw
import numpy as np
import random


data1 = []
data2= []
images = []

speed = 5
import math
from math import pi


image_folder = 'C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets/'

def square(b_l,b_r,t_r,t_l):
    points=[]
    x1,y1=b_l[0],b_l[1]
    x2,y2=b_r[0],b_r[1]
    x3,y3=t_r[0],t_r[1]
    x4,y4=t_l[0],t_l[1]
    x=x1
    y=y1
    while(x<x2):
        x=x+40
        points.append((x,y))
    while(y3<y):
        y=y-40
        points.append((x,y))
    while(x4<x):
        x=x-40
        points.append((x,y))
    while(y1>y):
        y=y+40
        points.append((x,y))
    return points
circle = square((10,700),(500,700),(500,550),(10,550))
circle=circle*300

xcor = 10
ycor = 290
line = []
while(xcor<530):
    line.append((xcor,ycor))
    xcor +=5
print(len(circle))
line = line + line[::-1]
line = line*30


def square_gen():
    for i in range(len(circle)):
        yield circle[i]

square_next = square_gen()

def line_gen():
    for i in range(len(line)):
        yield line[i]

line_next= line_gen()

#print("circle",circle)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% --  Generate dataset

im1 = Image.open('tree1.png')
im1 = im1.resize((100,100))

imt = Image.open('C:/Users/darshan19/Downloads/attachments/new/tank_moving.png')
#imt = imt.resize((100,100))

imtr = Image.open('C:/Users/darshan19/Downloads/attachments/new/tank_reloading.png')
#imtr = imtr.resize((100,100))

imdr = Image.open('C:/Users/darshan19/Downloads/attachments/new/drone_reloading.png')
#imdr = imdr.resize((100,100))


rndimg1 = Image.open('C:/Users/darshan19/Downloads/attachments/tank_firing.png')


rndimg2 = Image.open('C:/Users/darshan19/Downloads/attachments/drone_firing.png')
rndimg2 = rndimg2.resize((150,150))

img_bullet = Image.open('bullet.png')

im2 = Image.open('tree2.png')
im2 = im2.resize((100,100))

im3 = Image.open('tree3.png')
im3 = im3.resize((100,100))

im_drone = Image.open('C:/Users/darshan19/Downloads/attachments/new/drone_moving1.png')
#im_drone = im_drone.resize((100,100))


imtf = Image.open('C:/Users/darshan19/Downloads/attachments/new/tank_firing1.png')
imdf = Image.open('C:/Users/darshan19/Downloads/attachments/new/drone_firing1.png')

def new_image():
    img_blank = Image.new('RGB', (720, 1080), color = '#9b7653')
    img_blank.paste(im1,(5,75),im1)
    img_blank.paste(im1,(450,550),im1)
    img_blank.paste(im1,(205,720),im1)
    img_blank.paste(im2,(500,900),im2)
    img_blank.paste(im2,(650,750),im2)
    img_blank.paste(im2,(320,440),im2)
    img_blank.paste(im3,(100,600),im3)
    img_blank.paste(im3,(440,620),im3)
    img_blank.paste(im3,(300,150),im3)
    return img_blank


def gen_rand1():
    for i in range(2000):
        yield (random.randint(0,720),random.randint(0,1080))

gen_rand = gen_rand1()

for i in range(1,500):
    
    #t1d1
    img_blank = new_image()
    line_cor = next(line_next)
    img_blank.paste(imt,line_cor,imt)
    square_cor = next(square_next)
    img_blank.paste(im_drone,square_cor,im_drone)
    rand_cor = next(gen_rand)
#     if (((rand_cor[0] not in range(line_cor[0]+200, line_cor[1]-200)) or (rand_cor[1] not in range(line_cor[1]+200, line_cor[1]-200)))  and 
#         ((rand_cor[0] not in range(square_cor[0]+200, square_cor[0]-200)) or (rand_cor[1] not in range(square_cor[1]+200, square_cor[1]-200)))):
#         img_blank.paste(rndimg1,rand_cor,rndimg1)
    
    image_name = str(i) +'.png'
    img_blank.save(image_folder+image_name,'PNG')    
    
    
    if i%30==0:
        for j in range(5):
            img_blank = new_image()
            image_name = str(i)+str(j) +'blank.png'
            img_blank.save(image_folder+image_name,'PNG')    
    if i%10==0 and i%20==10:
        for j in range(5):
            img_blank = new_image()
            line_cor = next(line_next)
            img_blank.paste(imtr,line_cor,imtr)
            square_cor = next(square_next)
            img_blank.paste(imdr,square_cor,imdr)
            rand_cor = next(gen_rand)
#             if (((rand_cor[0] not in range(line_cor[0]+200, line_cor[1]-200)) or (rand_cor[1] not in range(line_cor[1]+200, line_cor[1]-200)))  and 
#         ((rand_cor[0] not in range(square_cor[0]+200, square_cor[0]-200)) or (rand_cor[1] not in range(square_cor[1]+200, square_cor[1]-200)))):
#                 img_blank.paste(rndimg2,rand_cor,rndimg2)
            image_name = str(i)+str(j) +'tankr_droner.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtf,next(line_next),imtf)
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'tank_drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
    if i%20==0 and i%40==20:
        for j in range(5):
            img_blank = new_image()
            line_cor = next(line_next)
            img_blank.paste(imt,line_cor,imt)
            rand_cor = next(gen_rand)
#             if (((rand_cor[0] not in range(line_cor[0]+200, line_cor[1]-200)) or (rand_cor[1] not in range(line_cor[1]+200, line_cor[1]-200)))  and 
#         ((rand_cor[0] not in range(square_cor[0]+200, square_cor[0]-200)) or (rand_cor[1] not in range(square_cor[1]+200, square_cor[1]-200)))):
#                 img_blank.paste(rndimg2,rand_cor,rndimg2)
            image_name = str(i)+str(j) +'tank.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            image_name = str(i)+str(j) +'tank_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()        
            img_blank.paste(imtf,next(line_next),imtf)
            image_name = str(i)+str(j) +'tank_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imt,next(line_next),imt)
            img_blank.paste(imdr,next(square_next),imdr)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            image_name = str(i)+str(j) +'tank_moving_drone_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imt,next(line_next),imt)
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'tank_moving_drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            img_blank.paste(imdf,next(square_next),imdf)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            image_name = str(i)+str(j) +'tank_reloading_drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
            
            
    if i%40==0:
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(im_drone,next(square_next),im_drone)
            image_name = str(i)+str(j) +'drone.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            square_cor = next(square_next)
            img_blank.paste(imdr,square_cor,imdr)
            rand_cor = next(gen_rand)
#             if (((rand_cor[0] not in range(line_cor[0]+200, line_cor[1]-200)) or (rand_cor[1] not in range(line_cor[1]+200, line_cor[1]-200)))  and 
#         ((rand_cor[0] not in range(square_cor[0]+200, square_cor[0]-200)) or (rand_cor[1] not in range(square_cor[1]+200, square_cor[1]-200)))):
#                 img_blank.paste(rndimg2,rand_cor,rndimg2)
            image_name = str(i)+str(j) +'drone_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imdf,next(square_next),imdf)
            image_name = str(i)+str(j) +'drone_firing.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtr,next(line_next),imtr)
            img_blank.paste(im_drone,next(square_next),im_drone)
            image_name = str(i)+str(j) +'tank_reloading_drone_moving.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtf,next(line_next),imtf)
            img_blank.paste(im_drone,next(square_next),im_drone)
            image_name = str(i)+str(j) +'tank_firing_drone_moving.png'
            img_blank.save(image_folder+image_name,'PNG')
        for j in range(5):
            img_blank = new_image()
            img_blank.paste(imtf,next(line_next),imtf)
            img_blank.paste(imdr,next(square_next),imdr)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            rand_cor = next(gen_rand)
            if (((rand_cor[0] not in range(line_cor[0]+50, line_cor[1]-50)) or (rand_cor[1] not in range(line_cor[1]+50, line_cor[1]-200)))  and 
        ((rand_cor[0] not in range(square_cor[0]+50, square_cor[0]-50)) or (rand_cor[1] not in range(square_cor[1]+50, square_cor[1]-200)))):
                img_blank.paste(img_bullet,rand_cor,img_bullet)
            image_name = str(i)+str(j) +'tank_firing_drone_reloading.png'
            img_blank.save(image_folder+image_name,'PNG')
            
cv2.destroyAllWindows()
# Out:
# 10200

# %%
import cv2
import numpy as np
import glob
import os

img_array = []
for filename in sorted(glob.glob('C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets/*'), key=os.path.getmtime):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
    print(filename)

out = cv2.VideoWriter('images_noisy_bullets.avi',cv2.VideoWriter_fourcc(*'DIVX'), 5, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
# Out:
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\1.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\2.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\3.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\4.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\5.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\6.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\7.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\8.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\9.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\10.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\100tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\101tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\102tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\103tankr_droner.png
# C:/Users/darshan19/Desktop/AoI/CNN/noisy_bullets\104tankr_droner.png
# ...
